# %%
import sys
sys.path.append('../')
import scipy.io as sio
import mat73
import pandas as pd
import torch
import numpy as np
import torch.optim as optim
import torch.nn
import sklearn
import sklearn.metrics
import matplotlib.pyplot as plt
from alive_progress import alive_bar
from  utils.my_classes import dataset 
from torch.utils.data import DataLoader
import utils.DNN_functions as DNN_functions
import scipy
import random
import utils.AMSloss
from speechbrain.pretrained import SpeakerRecognition
import pickle
import os
from utils.my_classes import dataset
import utils.eval_metrics as eval_metrics
import copy
from speechbrain.pretrained import SpeakerRecognition
from a_DCF.a_DCF_package.a_dcf import a_dcf

seed = 42  # You can choose any integer value as the seed
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
# Set seed for Python's random module
random.seed(seed)
# Set seed for NumPy
np.random.seed(seed)
# Set seed for PyTorch (CPU and GPU, if available)
if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
# Set deterministic flags for PyTorch (if available)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
#To get my GPU device - GTX 4070 :)
seed = 42  # You can choose any integer value as the seed
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu');

if torch.cuda.is_available():
    print(torch.cuda.device_count())
    print(torch.cuda.device(0))
    print(torch.cuda.get_device_name(0))
    print(device)
# Out:
# 1
# <torch.cuda.device object at 0x000001E6FB5FB220>
# NVIDIA GeForce RTX 4070
# cuda

# %% [markdown]
# # loading the embedding for CM System:

# %%
from ASV_utils.data_loading import *



models_folder = "Deep_Learning_Codes/best_models/fixed order/models/"

data_path_male = "Data/pmf_both/not_normalize/male/"

data_path_female = "Data/pmf_both/not_normalize/female/"

male_embedded_groups_1_1,male_embedded_groups_1_2,male_embedded_groups_1_3,male_chosen_labels_1_1_is_spoofed,male_chosen_labels_2_1_is_spoofed,male_chosen_labels_3_1_is_spoofed,male_chosen_labels_numeric_1_1,male_chosen_labels_numeric_2_1,male_chosen_labels_numeric_3_1,male_chosen_labels_1_1_attack_logical,male_chosen_labels_2_1_attack_logical,male_chosen_labels_3_1_attack_logical,male_chosen_labels_1_1_name,male_chosen_labels_2_1_name,male_chosen_labels_3_1_name,male_chosen_labels_1_1_speaker_id,male_chosen_labels_2_1_speaker_id,male_chosen_labels_3_1_speaker_id,male_chosen_labels_1_1_sex,male_chosen_labels_2_1_sex,male_chosen_labels_3_1_sex  = load_data_male(data_path_male)

female_embedded_groups_1_1,female_embedded_groups_1_2,female_embedded_groups_1_3,female_chosen_labels_1_1_is_spoofed,female_chosen_labels_2_1_is_spoofed,female_chosen_labels_3_1_is_spoofed,female_chosen_labels_numeric_1_1,female_chosen_labels_numeric_2_1,female_chosen_labels_numeric_3_1,female_chosen_labels_1_1_attack_logical,female_chosen_labels_2_1_attack_logical,female_chosen_labels_3_1_attack_logical,female_chosen_labels_1_1_name,female_chosen_labels_2_1_name,female_chosen_labels_3_1_name,female_chosen_labels_1_1_speaker_id,female_chosen_labels_2_1_speaker_id,female_chosen_labels_3_1_speaker_id,female_chosen_labels_1_1_sex,female_chosen_labels_2_1_sex,female_chosen_labels_3_1_sex  = load_data_female(data_path_female)

# %% [markdown]
# # Pre Processing the channels And loading the Models - Male & Female:

# %%
import utils.my_functions as my_functions

columns_names,max_name_length = my_functions.get_columns_names_feature_importance(substruct=True)
true_channels_indexes = np.array(my_functions.get_real_channel(np.linspace(start=1, stop=len(columns_names), num=len(columns_names)),len(columns_names)))
true_channels_indexes = true_channels_indexes - 1
true_channels_indexes = true_channels_indexes.astype(int)
columns_names = np.array(columns_names)

female_embedded_groups_1_1 = female_embedded_groups_1_1[:,true_channels_indexes]
female_embedded_groups_1_2 = female_embedded_groups_1_2[:,true_channels_indexes]
female_embedded_groups_1_3 = female_embedded_groups_1_3[:,true_channels_indexes]

male_embedded_groups_1_1 = male_embedded_groups_1_1[:,true_channels_indexes]
male_embedded_groups_1_2 = male_embedded_groups_1_2[:,true_channels_indexes]
male_embedded_groups_1_3 = male_embedded_groups_1_3[:,true_channels_indexes]

# %%
from sklearn.preprocessing import StandardScaler
import re

your_list = columns_names[true_channels_indexes]
index_mapping ={}

# Define the custom sorting order for distance metrics
distance_metrics = [
    'Chi-square',
    'Correlation',
    'Hellinger',
    'Intersection',
    'Jensen-Shannon',
    'Kullback-Leibler Divergence',
    'Modified Kolmogorov-Smirnov',
    'Symmetrised Kullback-Leibler'
]

def custom_sort_key(item):
    # Use regex to extract filter type, channel number, and distance metric
    match = re.search(r'filter-(gammatone|gammtone_inv)-channel-(\d+)-distance-(.+?)-\[d_', item)
    if match:
        filter_type = match.group(1)  # 'gammatone' or 'gammtone_inv'
        channel = int(match.group(2))
        distance_metric = match.group(3)
        
        # Prioritize 'gammatone' before 'gammtone_inv'
        filter_priority = 0 if filter_type == 'gammatone' else 1

        # Sort by filter type, then by distance metric, and finally by channel
        return (filter_priority, distance_metrics.index(distance_metric), channel)

    else:
        # If the regex doesn't match, push the item to the end
        return (999, 999, 999)

# Sort the list based on the custom order
sorted_list = sorted(your_list, key=custom_sort_key)

for new_index, item in enumerate(sorted_list):
    old_index = np.where(columns_names[true_channels_indexes] == item)[0][0]
    index_mapping[old_index] = new_index
    
male_embedded_groups_1_1 = male_embedded_groups_1_1[:,list(index_mapping.keys())]
male_embedded_groups_1_2 = male_embedded_groups_1_2[:,list(index_mapping.keys())]
male_embedded_groups_1_3 = male_embedded_groups_1_3[:,list(index_mapping.keys())]

female_embedded_groups_1_1 = female_embedded_groups_1_1[:,list(index_mapping.keys())]
female_embedded_groups_1_2 = female_embedded_groups_1_2[:,list(index_mapping.keys())]
female_embedded_groups_1_3 = female_embedded_groups_1_3[:,list(index_mapping.keys())]

# %%
# define the subchannel model network
import torch
import torch.nn as nn
from utils.AMSloss import AdMSoftmaxLoss
import pickle
# define the subchannel model network
import torch.nn as nn
class SubChannelNetwork(nn.Module):
    def __init__(self, input_channel_size, output_channel_size):
        super(SubChannelNetwork, self).__init__()
        self.input_layer = nn.Linear(input_channel_size, output_channel_size)
        self.sigmoid = nn.Sigmoid()
        self.dropout = nn.Dropout(p=0.2)
        self.BN_4 = nn.BatchNorm1d(output_channel_size) 

        
    def forward(self, x):
        x = self.input_layer(x)
        x = self.BN_4(x) 
        x = self.sigmoid(x)
        x = self.dropout(x)
        return x

# define the model network
class DNN(nn.Module):
    def __init__(self, input_channel_size, num_subnetworks, output_channel_size, final_output_size):
        super(DNN, self).__init__()
        self.SubChannelNetwork = nn.ModuleList([
            SubChannelNetwork(input_channel_size, output_channel_size) for _ in range(num_subnetworks)
        ])
        self.fc_between_subnet = nn.Linear(num_subnetworks * output_channel_size,40)
        self.BN = nn.BatchNorm1d(40)
        self.fc = nn.Linear(40, final_output_size)
        self.sigmoid = nn.Sigmoid()
        self.droupout = nn.Dropout(p=0.2)
        self.loss = nn.BCEWithLogitsLoss()
        self.optimizer = None
        self.scheduler = None
        
        
    def forward(self, x):
        subnetwork_outputs = [self.SubChannelNetwork[idx](x[:, idx*input_channel_size:(idx+1)*input_channel_size].to(device)) for idx in range(len(self.SubChannelNetwork))]
        combined_output = torch.cat(subnetwork_outputs, dim=1)
        x = self.fc_between_subnet(combined_output)    
        x = self.BN(x)
        x = self.sigmoid(x)
        x = self.droupout(x)
        output = self.fc(x)
        return output 
    
    @staticmethod
    def count_parameters(model):
        return sum(p.numel() for p in model.parameters() if p.requires_grad)



# Just for checking the model and see the number of parameters
num_SubChannelNetwork = 16
input_channel_size = 10
output_channel_size = 5
final_output_size = 1
model = []
model = DNN(input_channel_size, num_SubChannelNetwork, output_channel_size, final_output_size)
model = model.to(device)
print(model)
n = DNN.count_parameters(model)
print("Number of parameters: %s" % n)
model = model.to(device) # send the model to the device

model = pickle.load(open(models_folder + "Male_best_model_8_6.pkl", 'rb'))

model.eval()

spoof_model_male = copy.deepcopy(model)
# Out:
# DNN(
#   (SubChannelNetwork): ModuleList(
#     (0-15): 16 x SubChannelNetwork(
#       (input_layer): Linear(in_features=10, out_features=5, bias=True)
#       (sigmoid): Sigmoid()
#       (dropout): Dropout(p=0.2, inplace=False)
#       (BN_4): BatchNorm1d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (fc_between_subnet): Linear(in_features=80, out_features=40, bias=True)
#   (BN): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc): Linear(in_features=40, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
#   (droupout): Dropout(p=0.2, inplace=False)
#   (loss): BCEWithLogitsLoss()
# )
# Number of parameters: 4401

# %%
import torch
import torch.nn as nn
from utils.AMSloss import AdMSoftmaxLoss
from utils.OCSoftmaxloss import OCSoftmax
import torch.nn as nn

class SubChannelNetwork(nn.Module):
    def __init__(self, input_channel_size, output_channel_size):
        super(SubChannelNetwork, self).__init__()
        self.input_layer = nn.Linear(input_channel_size, output_channel_size)
        self.sigmoid = nn.Sigmoid()
        self.dropout = nn.Dropout(p=0.2)
        self.BN_4 = nn.BatchNorm1d(output_channel_size) 
   
    def forward(self, x):
        res = x
        x = self.input_layer(x)
        x = self.BN_4(x) 
        x = self.sigmoid(x)
        x = self.dropout(x)
        x = res + x 
        return x

class DNN(nn.Module):
    def __init__(self, input_channel_size, num_subnetworks, output_channel_size, final_output_size, r_real , r_fake,alpha):
        super(DNN, self).__init__()
        self.SubChannelNetwork = nn.ModuleList([
            SubChannelNetwork(input_channel_size, output_channel_size) for _ in range(num_subnetworks)
        ])
        self.fc_between_subnet = nn.Linear(num_subnetworks * output_channel_size,40)
        self.BN = nn.BatchNorm1d(40)
        self.fc = nn.Linear(40, final_output_size)
        self.sigmoid = nn.Sigmoid()
        self.droupout = nn.Dropout(p=0.2)
        self.r_real = r_real
        self.r_fake = r_fake
        self.alpha = alpha
        self.loss = OCSoftmax(feat_dim = final_output_size, r_real = self.r_real, r_fake = self.r_fake, alpha = self.alpha)
        self.optimizer = None
        self.scheduler = None
        
        
    def forward(self, x):
        subnetwork_outputs = [self.SubChannelNetwork[idx](x[:, idx*input_channel_size:(idx+1)*input_channel_size].to(device)) for idx in range(len(self.SubChannelNetwork))]
        combined_output = torch.cat(subnetwork_outputs, dim=1)
        x = self.fc_between_subnet(combined_output)    
        x = self.BN(x)
        x = self.sigmoid(x)
        x = self.droupout(x)
        output = self.fc(x)
        return output 
    
    @staticmethod
    def count_parameters(model):
        return sum(p.numel() for p in model.parameters() if p.requires_grad)

r_real = 0.5 
r_fake = 0.1
alpha = 20
# Example usage
num_SubChannelNetwork = 16
input_channel_size = 10
output_channel_size = 10
final_output_size = 16*3
model = DNN(input_channel_size, num_SubChannelNetwork, output_channel_size, final_output_size,r_real = r_real , r_fake = r_fake,alpha = alpha)


model = model.to(device) # send the model to the device
model = pickle.load(open(models_folder + "Female_best_model_10_12.pkl", 'rb'))

model.eval()

spoof_model_female = copy.deepcopy(model)

# %%
scaler_male = StandardScaler(with_mean = True, with_std = True)
scaler_male.fit(male_embedded_groups_1_1)
mean_features = scaler_male.mean_
std_features = scaler_male.scale_
male_embedded_groups_1_1_norm = scaler_male.transform(male_embedded_groups_1_1)
male_embedded_groups_1_2_norm = scaler_male.transform(male_embedded_groups_1_2)
male_embedded_groups_1_3_norm = scaler_male.transform(male_embedded_groups_1_3)


scaler_female = StandardScaler(with_mean = True, with_std = True)
scaler_female.fit(female_embedded_groups_1_1)
mean_features = scaler_female.mean_
std_features = scaler_female.scale_
female_embedded_groups_1_1_norm = scaler_female.transform(female_embedded_groups_1_1)
female_embedded_groups_1_2_norm = scaler_female.transform(female_embedded_groups_1_2)
female_embedded_groups_1_3_norm = scaler_female.transform(female_embedded_groups_1_3)

# %%
embedded_groups_1_1_norm,embedded_groups_1_2_norm,embedded_groups_1_3_norm,chosen_labels_1_1_is_spoofed,chosen_labels_2_1_is_spoofed,chosen_labels_3_1_is_spoofed,chosen_labels_numeric_1_1,chosen_labels_numeric_2_1,chosen_labels_numeric_3_1,chosen_labels_1_1_attack_logical,chosen_labels_2_1_attack_logical,chosen_labels_3_1_attack_logical,chosen_labels_1_1_name,chosen_labels_2_1_name,chosen_labels_3_1_name,chosen_labels_1_1_speaker_id,chosen_labels_2_1_speaker_id,chosen_labels_3_1_speaker_id,chosen_labels_1_1_sex,chosen_labels_2_1_sex,chosen_labels_3_1_sex    =  concatenate_data(male_embedded_groups_1_1_norm,male_embedded_groups_1_2_norm,male_embedded_groups_1_3_norm,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    male_chosen_labels_1_1_is_spoofed,male_chosen_labels_2_1_is_spoofed,male_chosen_labels_3_1_is_spoofed,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    male_chosen_labels_numeric_1_1,male_chosen_labels_numeric_2_1,male_chosen_labels_numeric_3_1,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    male_chosen_labels_1_1_attack_logical,male_chosen_labels_2_1_attack_logical,male_chosen_labels_3_1_attack_logical,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    male_chosen_labels_1_1_name,male_chosen_labels_2_1_name,male_chosen_labels_3_1_name,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    male_chosen_labels_1_1_speaker_id,male_chosen_labels_2_1_speaker_id, male_chosen_labels_3_1_speaker_id,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    male_chosen_labels_1_1_sex,male_chosen_labels_2_1_sex,male_chosen_labels_3_1_sex,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    female_embedded_groups_1_1_norm,female_embedded_groups_1_2_norm,female_embedded_groups_1_3_norm,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    female_chosen_labels_1_1_is_spoofed,female_chosen_labels_2_1_is_spoofed,female_chosen_labels_3_1_is_spoofed,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    female_chosen_labels_numeric_1_1,female_chosen_labels_numeric_2_1,female_chosen_labels_numeric_3_1,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    female_chosen_labels_1_1_attack_logical,female_chosen_labels_2_1_attack_logical,female_chosen_labels_3_1_attack_logical,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    female_chosen_labels_1_1_name,female_chosen_labels_2_1_name,female_chosen_labels_3_1_name,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    female_chosen_labels_1_1_speaker_id,female_chosen_labels_2_1_speaker_id,female_chosen_labels_3_1_speaker_id,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    female_chosen_labels_1_1_sex,female_chosen_labels_2_1_sex,female_chosen_labels_3_1_sex)

# %%
embedded_groups_1_1,embedded_groups_1_2,embedded_groups_1_3,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_    =  concatenate_data(male_embedded_groups_1_1,male_embedded_groups_1_2,male_embedded_groups_1_3,
                                                                                                                        male_chosen_labels_1_1_is_spoofed,male_chosen_labels_2_1_is_spoofed,male_chosen_labels_3_1_is_spoofed,
                                                                                                                        male_chosen_labels_numeric_1_1,male_chosen_labels_numeric_2_1,male_chosen_labels_numeric_3_1,
                                                                                                                        male_chosen_labels_1_1_attack_logical,male_chosen_labels_2_1_attack_logical,male_chosen_labels_3_1_attack_logical,
                                                                                                                        male_chosen_labels_1_1_name,male_chosen_labels_2_1_name,male_chosen_labels_3_1_name,
                                                                                                                        male_chosen_labels_1_1_speaker_id,male_chosen_labels_2_1_speaker_id, male_chosen_labels_3_1_speaker_id,
                                                                                                                        male_chosen_labels_1_1_sex,male_chosen_labels_2_1_sex,male_chosen_labels_3_1_sex,
                                                                                                                        
                                                                                                                        female_embedded_groups_1_1,female_embedded_groups_1_2,female_embedded_groups_1_3,
                                                                                                                        female_chosen_labels_1_1_is_spoofed,female_chosen_labels_2_1_is_spoofed,female_chosen_labels_3_1_is_spoofed,
                                                                                                                        female_chosen_labels_numeric_1_1,female_chosen_labels_numeric_2_1,female_chosen_labels_numeric_3_1,
                                                                                                                        female_chosen_labels_1_1_attack_logical,female_chosen_labels_2_1_attack_logical,female_chosen_labels_3_1_attack_logical,
                                                                                                                        female_chosen_labels_1_1_name,female_chosen_labels_2_1_name,female_chosen_labels_3_1_name,
                                                                                                                        female_chosen_labels_1_1_speaker_id,female_chosen_labels_2_1_speaker_id,female_chosen_labels_3_1_speaker_id,
                                                                                                                        female_chosen_labels_1_1_sex,female_chosen_labels_2_1_sex,female_chosen_labels_3_1_sex)
scaler_all = StandardScaler(with_mean = True, with_std = True)
scaler_all.fit(embedded_groups_1_1)
mean_features = scaler_female.mean_
std_features = scaler_female.scale_
embedded_groups_1_1_all = scaler_all.transform(embedded_groups_1_1)
embedded_groups_1_2_all = scaler_all.transform(embedded_groups_1_2)
embedded_groups_1_3_all = scaler_all.transform(embedded_groups_1_3)

# %%
train_dataset_all = dataset(data = embedded_groups_1_1_norm , is_spoofed = chosen_labels_1_1_is_spoofed , chosen_labels_numeric = chosen_labels_numeric_1_1,
                        attack_logical = chosen_labels_1_1_attack_logical, name = chosen_labels_1_1_name , speaker_id = chosen_labels_1_1_speaker_id, sex = chosen_labels_1_1_sex ,data_transform = None , labels_transform = None,
                        data_for_gender_classification = None,data_without_separation = embedded_groups_1_1_all);

Dev_dataset_all = dataset(data = embedded_groups_1_2_norm , is_spoofed = chosen_labels_2_1_is_spoofed , chosen_labels_numeric = chosen_labels_numeric_2_1,
                        attack_logical = chosen_labels_2_1_attack_logical, name = chosen_labels_2_1_name , speaker_id = chosen_labels_2_1_speaker_id, sex = chosen_labels_2_1_sex ,  data_transform = None , labels_transform = None,
                        data_for_gender_classification = None,data_without_separation = embedded_groups_1_2_all);


Eval_dataset_all = dataset(data = embedded_groups_1_3_norm , is_spoofed = chosen_labels_3_1_is_spoofed , chosen_labels_numeric = chosen_labels_numeric_3_1,
                        attack_logical = chosen_labels_3_1_attack_logical, name = chosen_labels_3_1_name , speaker_id = chosen_labels_3_1_speaker_id, sex = chosen_labels_3_1_sex , data_transform = None , labels_transform = None,
                        data_for_gender_classification = None,data_without_separation = embedded_groups_1_3_all);

# %%
train_dataset_all.name = np.array([str(elem).split("/")[-1].split("'")[0].split('.flac')[0] for elem in train_dataset_all.name])

Dev_dataset_all.name = np.array([str(elem).split("/")[-1].split("'")[0].split('.flac')[0] for elem in Dev_dataset_all.name])

Eval_dataset_all.name = np.array([str(elem).split("/")[-1].split("'")[0].split('.flac')[0] for elem in Eval_dataset_all.name])

# %%
from ASV_utils.data_loading import *


models_folder = "ECAPA_TDNN/inference_models/models_both_not_normalize/"

data_path_male = "Data/male_vs_female_DB_models/16_bits/none/male/"

data_path_female = "Data/male_vs_female_DB_models/16_bits/none/female/"

g_male_embedded_groups_1_1,g_male_embedded_groups_1_2,g_male_embedded_groups_1_3,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_  = load_data_male(data_path_male)

g_female_embedded_groups_1_1,g_female_embedded_groups_1_2,g_female_embedded_groups_1_3,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_  = load_data_female(data_path_female)

embedded_groups_1_1,embedded_groups_1_2,embedded_groups_1_3,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_    =  concatenate_data(g_male_embedded_groups_1_1,g_male_embedded_groups_1_2,g_male_embedded_groups_1_3,
                                                                                                                    male_chosen_labels_1_1_is_spoofed,male_chosen_labels_2_1_is_spoofed,male_chosen_labels_3_1_is_spoofed,
                                                                                                                    male_chosen_labels_numeric_1_1,male_chosen_labels_numeric_2_1,male_chosen_labels_numeric_3_1,
                                                                                                                    male_chosen_labels_1_1_attack_logical,male_chosen_labels_2_1_attack_logical,male_chosen_labels_3_1_attack_logical,
                                                                                                                    male_chosen_labels_1_1_name,male_chosen_labels_2_1_name,male_chosen_labels_3_1_name,
                                                                                                                    male_chosen_labels_1_1_speaker_id,male_chosen_labels_2_1_speaker_id, male_chosen_labels_3_1_speaker_id,
                                                                                                                    male_chosen_labels_1_1_sex,male_chosen_labels_2_1_sex,male_chosen_labels_3_1_sex,
                                                                                                                    
                                                                                                                    g_female_embedded_groups_1_1,g_female_embedded_groups_1_2,g_female_embedded_groups_1_3,
                                                                                                                    female_chosen_labels_1_1_is_spoofed,female_chosen_labels_2_1_is_spoofed,female_chosen_labels_3_1_is_spoofed,
                                                                                                                    female_chosen_labels_numeric_1_1,female_chosen_labels_numeric_2_1,female_chosen_labels_numeric_3_1,
                                                                                                                    female_chosen_labels_1_1_attack_logical,female_chosen_labels_2_1_attack_logical,female_chosen_labels_3_1_attack_logical,
                                                                                                                    female_chosen_labels_1_1_name,female_chosen_labels_2_1_name,female_chosen_labels_3_1_name,
                                                                                                                    female_chosen_labels_1_1_speaker_id,female_chosen_labels_2_1_speaker_id,female_chosen_labels_3_1_speaker_id,
                                                                                                                    female_chosen_labels_1_1_sex,female_chosen_labels_2_1_sex,female_chosen_labels_3_1_sex)
chosen_labels_1_1_sex = np.array([elem[0] for elem in chosen_labels_1_1_sex])
                                 
chosen_labels_2_1_sex = np.array([elem[0] for elem in chosen_labels_2_1_sex])

chosen_labels_3_1_sex = np.array([elem[0] for elem in chosen_labels_3_1_sex])

# %%
import utils.my_functions as my_functions

columns_names,max_name_length = my_functions.get_columns_names_feature_importance(substruct=True)
true_channels_indexes = np.array(my_functions.get_real_channel(np.linspace(start=1, stop=len(columns_names), num=len(columns_names)),len(columns_names)))
true_channels_indexes = true_channels_indexes - 1
true_channels_indexes = true_channels_indexes.astype(int)
columns_names = np.array(columns_names)
'''
g_female_embedded_groups_1_1 = g_female_embedded_groups_1_1[:,true_channels_indexes]
g_female_embedded_groups_1_2 = g_female_embedded_groups_1_2[:,true_channels_indexes]
g_female_embedded_groups_1_3 = g_female_embedded_groups_1_3[:,true_channels_indexes]

g_male_embedded_groups_1_1 = g_male_embedded_groups_1_1[:,true_channels_indexes]
g_male_embedded_groups_1_2 = g_male_embedded_groups_1_2[:,true_channels_indexes]
g_male_embedded_groups_1_3 = g_male_embedded_groups_1_3[:,true_channels_indexes]
'''

embedded_groups_1_1 = embedded_groups_1_1[:,true_channels_indexes]
embedded_groups_1_2 = embedded_groups_1_2[:,true_channels_indexes]
embedded_groups_1_3 = embedded_groups_1_3[:,true_channels_indexes]

from sklearn.preprocessing import StandardScaler
import re

your_list = columns_names[true_channels_indexes]
index_mapping ={}

# Define the custom sorting order for distance metrics
distance_metrics = [
    'Chi-square',
    'Correlation',
    'Hellinger',
    'Intersection',
    'Jensen-Shannon',
    'Kullback-Leibler Divergence',
    'Modified Kolmogorov-Smirnov',
    'Symmetrised Kullback-Leibler'
]

def custom_sort_key(item):
    # Use regex to extract filter type, channel number, and distance metric
    match = re.search(r'filter-(gammatone|gammtone_inv)-channel-(\d+)-distance-(.+?)-\[d_', item)
    if match:
        filter_type = match.group(1)  # 'gammatone' or 'gammtone_inv'
        channel = int(match.group(2))
        distance_metric = match.group(3)
        
        # Prioritize 'gammatone' before 'gammtone_inv'
        filter_priority = 0 if filter_type == 'gammatone' else 1

        # Sort by filter type, then by distance metric, and finally by channel
        return (filter_priority, distance_metrics.index(distance_metric), channel)

    else:
        # If the regex doesn't match, push the item to the end
        return (999, 999, 999)

# Sort the list based on the custom order
sorted_list = sorted(your_list, key=custom_sort_key)

for new_index, item in enumerate(sorted_list):
    old_index = np.where(columns_names[true_channels_indexes] == item)[0][0]
    index_mapping[old_index] = new_index
    

embedded_groups_1_1 = embedded_groups_1_1[:,list(index_mapping.keys())]
embedded_groups_1_2 = embedded_groups_1_2[:,list(index_mapping.keys())]
embedded_groups_1_3 = embedded_groups_1_3[:,list(index_mapping.keys())]

# %%
scaler = StandardScaler(with_mean = True, with_std = True)
scaler.fit(embedded_groups_1_1)
mean_features = scaler.mean_
std_features = scaler.scale_

embedded_groups_1_1 = scaler.transform(embedded_groups_1_1)
embedded_groups_1_2 = scaler.transform(embedded_groups_1_2)
embedded_groups_1_3 = scaler.transform(embedded_groups_1_3)

train_dataset_all.data_for_gender_classification = embedded_groups_1_1
Dev_dataset_all.data_for_gender_classification   = embedded_groups_1_2
Eval_dataset_all.data_for_gender_classification  = embedded_groups_1_3


train_dataset_all.sex = pd.Series([elem[0] for elem in train_dataset_all.sex])
Dev_dataset_all.sex = pd.Series([elem[0] for elem in Dev_dataset_all.sex])
Eval_dataset_all.sex = pd.Series([elem[0] for elem in Eval_dataset_all.sex])

# %%
total_labels = torch.Tensor(Eval_dataset_all.is_spoofed[(Eval_dataset_all.sex == 'female').values].values).cpu().numpy().copy()
total_data = torch.Tensor(Eval_dataset_all.data[(Eval_dataset_all.sex == 'female').values]).cpu().numpy().copy()
with torch.no_grad():
    model = model.to(device)
    test_output = spoof_model_female(torch.Tensor(total_data).to(device))
    loss , test_score = spoof_model_female.loss(torch.Tensor(test_output).to(device),None)
    test_score = -1*test_score
    
test_score_total = test_score.cpu().numpy().copy()

eer, test_thresh = my_functions.compute_eer(total_labels,test_score_total) # compute equal error rate

print(f"\tTest EER: ({eer}%) \tTest Threshold: {test_thresh}")
# Out:
# 	Test EER: (0.10129787907565715%) 	Test Threshold: -0.8330833536418566

# %%
total_labels = torch.Tensor(Eval_dataset_all.is_spoofed[(Eval_dataset_all.sex == 'male').values].values).cpu().numpy().copy()
total_data = torch.Tensor(Eval_dataset_all.data[(Eval_dataset_all.sex == 'male').values]).cpu().numpy().copy()
with torch.no_grad():
    model = model.to(device)
    test_score = torch.sigmoid(spoof_model_male(torch.Tensor(total_data).to(device)))
    
test_score_total = test_score.cpu().numpy().copy()

eer, test_thresh = my_functions.compute_eer(total_labels,test_score_total) # compute equal error rate

print(f"\tTest EER: ({eer}%) \tTest Threshold: {test_thresh}")
# Out:
# 	Test EER: (0.08672798948696905%) 	Test Threshold: 0.04048307612539639

# %%
import torchaudio
from speechbrain.pretrained import EncoderClassifier

# load the model - the moodel that check if it's female or male
gender_models = "ML_codes/pmf_both_classification_male_vs_female/new_female_and_male/female_vs_male_histograms/normalize_all_best_fixed_order/"

with open(os.path.join(gender_models,"gender_XGB_model_both_norm_male_vs_female_db_models_5_fixed_order.pkl"), 'rb') as fp:
#with open(os.path.join(models_folder,"gender_XGB_model_both_norm_male_vs_female_db_models.pkl"), 'rb') as fp:
    gender_model = pickle.load(fp)
    
# load the model - the model that check if it's the sampe speaker or not
verification_model = SpeakerRecognition.from_hparams(source="speechbrain/spkrec-ecapa-voxceleb", savedir='./ECAPA_TDNN/pretrained_models/spkrec-ecapa-voxceleb',run_opts={"device":"cuda"} )

classifier = EncoderClassifier.from_hparams(source="speechbrain/spkrec-ecapa-voxceleb", savedir='./ECAPA_TDNN/pretrained_models/spkrec-ecapa-voxceleb',run_opts={"device":"cuda"})

# %%
import pickle
from ASV_utils.ASV_my_functions import *
# Load the embeddings file:

with open('./ECAPA_TDNN/embeddings/dev_embedding_ecapa_voxceleb_flac.pkl', 'rb') as file:
    list_dev_files,embeddings_dev = pickle.load(file)
    list_dev_files = [name.rstrip('.flac') for name in list_dev_files]
    
with open('./ECAPA_TDNN/embeddings/eval_embedding_ecapa_voxceleb_flac.pkl', 'rb') as file:
    list_eval_files,embeddings_eval = pickle.load(file)
    list_eval_files = [name.rstrip('.flac') for name in list_eval_files]


embeddings_dev =[emb.cpu() for emb in embeddings_dev]
embeddings_dev = np.concatenate(embeddings_dev, axis=0)
embeddings_eval =[emb.cpu() for emb in embeddings_eval]
embeddings_eval = np.concatenate(embeddings_eval, axis=0)


path_enrollment_dev_female = "./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.dev.female.trn.txt"

path_enrollment_dev_male = "./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.dev.male.trn.txt"

path_enrollment_eval_female = "./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.eval.female.trn.txt"

path_enrollment_eval_male = "./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.eval.male.trn.txt"


enrollment_dev_female = make_enrollment(path_enrollment_dev_female,"female")

enrollment_dev_male = make_enrollment(path_enrollment_dev_male,"male")

enrollment_eval_female = make_enrollment(path_enrollment_eval_female,"female")

enrollment_eval_male = make_enrollment(path_enrollment_eval_male,"male")

enrollment_dev_female = extract_embeddings(list_dev_files,embeddings_dev,enrollment_dev_female)
list_dev_files,embeddings_dev = remove_enrollment_embeddings_from_embeddings_list(list_dev_files,embeddings_dev,enrollment_dev_female)

enrollment_dev_male = extract_embeddings(list_dev_files,embeddings_dev,enrollment_dev_male)
list_dev_files,embeddings_dev = remove_enrollment_embeddings_from_embeddings_list(list_dev_files,embeddings_dev,enrollment_dev_male)

enrollment_eval_female = extract_embeddings(list_eval_files,embeddings_eval,enrollment_eval_female)
list_eval_files,embeddings_eval = remove_enrollment_embeddings_from_embeddings_list(list_eval_files,embeddings_eval,enrollment_eval_female)

enrollment_eval_male = extract_embeddings(list_eval_files,embeddings_eval,enrollment_eval_male)
list_eval_files,embeddings_eval = remove_enrollment_embeddings_from_embeddings_list(list_eval_files,embeddings_eval,enrollment_eval_male)

# %%
path_trails_dev = "./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.dev.gi.trl.txt"
path_trails_eval = "./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.eval.gi.trl.txt"

def keys_to_values(key_list, input_dict):
    return [input_dict[key] for key in key_list if key in input_dict]

def read_trl_txt_file(path):
    speaker_id = []
    file_name = []
    spoof_label = []
    asv_label = []
    with open(path, 'r') as file:
        for line in file:
            parts = line.strip().split(' ')
            if len(parts) != 4:
                raise Exception("The line in the file is not in the right format")
            speaker_id.append(parts[0])
            file_name.append(parts[1])
            spoof_label.append(parts[2])
            asv_label.append(parts[3])
            
    return pd.Series(speaker_id), pd.Series(file_name), pd.Series(spoof_label),pd.Series(asv_label)

speaker_id_list_dev,file_name_according_speaker_id_dev , spoof_label_dev, asv_label_dev = read_trl_txt_file(path_trails_dev)

speaker_id_list_eval,file_name_according_speaker_id_eval , spoof_label_eval, asv_label_eval = read_trl_txt_file(path_trails_eval)
'''
speaker_id_dict_dev = dict(zip(file_name_according_speaker_id,speaker_id_list))

list_speaker_id_dev = keys_to_values(list_dev_files,speaker_id_dict_dev)


asv_label_dict_dev = dict(zip(file_name_according_speaker_id,asv_label_dev))

list_asv_label_dev = keys_to_values(list_dev_files,asv_label_dict_dev)





speaker_id_dict_eval = dict(zip(file_name_according_speaker_id,speaker_id_list))

list_speaker_id_eval = keys_to_values(list_eval_files,speaker_id_dict_eval)


asv_label_dict_eval = dict(zip(file_name_according_speaker_id,asv_label_eval))

list_asv_label_eval = keys_to_values(list_eval_files,asv_label_dict_eval)
'''
# Out:
# '\nspeaker_id_dict_dev = dict(zip(file_name_according_speaker_id,speaker_id_list))\n\nlist_speaker_id_dev = keys_to_values(list_dev_files,speaker_id_dict_dev)\n\n\nasv_label_dict_dev = dict(zip(file_name_according_speaker_id,asv_label_dev))\n\nlist_asv_label_dev = keys_to_values(list_dev_files,asv_label_dict_dev)\n\n\n\n\n\nspeaker_id_dict_eval = dict(zip(file_name_according_speaker_id,speaker_id_list))\n\nlist_speaker_id_eval = keys_to_values(list_eval_files,speaker_id_dict_eval)\n\n\nasv_label_dict_eval = dict(zip(file_name_according_speaker_id,asv_label_eval))\n\nlist_asv_label_eval = keys_to_values(list_eval_files,asv_label_dict_eval)\n'

# %%
from sklearn.metrics.pairwise import cosine_similarity
import torchaudio
import tqdm
from ASV_utils.config_thr import pmf_both_thr_gender_val ,pmf_both_thr_spoof_val_male,pmf_both_thr_spoof_val_female
from ASV_utils.tdcf_functions import compute_t_dcf

txt_file_path = "output.txt"
csv_file_path = "output.csv"
enrollment_male = enrollment_dev_male
enrollment_female = enrollment_dev_female
list_files = file_name_according_speaker_id_dev
data_set = Dev_dataset_all
asv_model = classifier
spoof_labels = spoof_label_dev
list_speaker_id = speaker_id_list_dev
list_asv_label = asv_label_dev

# %%
from ASV_utils.tdcf_functions import compute_t_dcf
import pickle
results = pickle.load(open("./dcf_and_tdcf/dcf_avg_score/pmf_both_tdcf/asv_protocol/objects_asv_and_cm_time_embeddings_avg_score_both_asv_protocol.pkl", 'rb'))

# %%
import pickle
results
# Out:
#           file_name  its_male its_male_ground_truth  its_spoof_male
# 0      LA_D_4004968      True                  male           False  \
# 1      LA_D_6027798      True                  male           False
# 2      LA_D_3986002      True                  male           False
# 3      LA_D_9330492      True                  male           False
# 4      LA_D_1364611      True                  male           False
# ...             ...       ...                   ...             ...
# 29543  LA_D_6306347     False                female            True
# 29544  LA_D_3133630     False                female            True
# 29545  LA_D_9909170     False                female            True
# 29546  LA_D_3790932     False                female            True
# 29547  LA_D_3387040     False                female            True
#
#        spoof_score_male  its_spoof_female  spoof_score_female
# 0              0.006150             False           -0.912122  \
# 1              0.006148             False           -0.935269
# 2              0.007109             False           -0.915763
# 3              0.005233             False           -0.903112
# 4              0.007441             False           -0.909984
# ...                 ...               ...                 ...
# 29543          0.959626              True            0.567938
# 29544          0.981835              True            0.644323
# 29545          0.979534              True            0.504778
# 29546          0.991858              True            0.779713
# 29547          0.930406              True            0.459398
#
#        spoof_ground_truth  asv_score_male  asv_score_female speaker_id_male
# 0                   False        0.561741          0.000000         LA_0073  \
# 1                   False        0.703008          0.000000         LA_0073
# 2                   False        0.675328          0.000000         LA_0073
# 3                   False        0.539661          0.000000         LA_0073
# 4                   False        0.506510          0.000000         LA_0073
# ...                   ...             ...               ...             ...
# 29543                True        0.000000          0.214340            None
# 29544                True        0.000000          0.155820            None
# 29545                True        0.000000          0.072316            None
# 29546                True        0.000000          0.182552            None
# 29547                True        0.000000          0.235617            None
#
#       speaker_id_female  find_speaker_in_enroll_male
# 0                  None                         True  \
# 1                  None                         True
# 2                  None                         True
# 3                  None                         True
# 4                  None                         True
# ...                 ...                          ...
# 29543           LA_0069                        False
# 29544           LA_0069                        False
# 29545           LA_0069                        False
# 29546           LA_0069                        False
# 29547           LA_0069                        False
#
#        find_speaker_in_enroll_female asv_label attack_type  in_cm_protocol
# 0                              False    target        none            True
# 1                              False    target        none            True
# 2                              False    target        none            True
# 3                              False    target        none            True
# 4                              False    target        none            True
# ...                              ...       ...         ...             ...
# 29543                           True     spoof         A06            True
# 29544                           True     spoof         A05            True
# 29545                           True     spoof         A06            True
# 29546                           True     spoof         A05            True
# 29547                           True     spoof         A06            True
#
# [29548 rows x 17 columns]

# %% [markdown]
# # Male - DEV:

# %% [markdown]
# ### with labels of gender:

# %%
labels_dev_male = torch.Tensor(Dev_dataset_all.is_spoofed[(Dev_dataset_all.sex == 'male').values].values).cpu().numpy().copy()
total_data = torch.Tensor(Dev_dataset_all.data[(Dev_dataset_all.sex == 'male').values]).cpu().numpy().copy()

with torch.no_grad():
    model = model.to(device)
    score_dev_male = torch.sigmoid(spoof_model_male(torch.Tensor(total_data).to(device)))
    
score_dev_male = score_dev_male.cpu().numpy().copy()

dev_male_eer, _ = my_functions.compute_eer(labels_dev_male,score_dev_male) # compute equal error rate

print(f"\tDev male EER: ({100*dev_male_eer}%)")
# Out:
# 	Dev male EER: (0.5546536796531659%)

# %%
#check what happen when the gender classification is mistake!!

bonafide_score_cm_male_dev = 1-score_dev_male[labels_dev_male == 0].flatten()
spoof_score_cm_male_dev = 1-score_dev_male[labels_dev_male == 1].flatten()
Prior_spoof = 0.05
target_scores_male_dev = results.loc[(results['asv_label'] ==  "target") & (results['its_male_ground_truth'] == 'male') ]["asv_score_male"].values
nontarget_scores_male_dev = results.loc[(results['asv_label'] == "nontarget") & (results['its_male_ground_truth'] == 'male') ]["asv_score_male"].values
spoof_scores_male_dev = results.loc[(results['asv_label'] ==  "spoof") & (results['its_male_ground_truth'] == 'male')]["asv_score_male"].values
list_asv_score = [0.261]
type = 'constrained'
#list_tDCF_norm_male_dev ,list_CM_thresholds_male_dev,list_tDCF_male_dev = compute_t_dcf(bonafide_score_cm_male_dev,spoof_score_cm_male_dev,Prior_spoof,target_scores_male_dev,nontarget_scores_male_dev,spoof_scores_male_dev,list_asv_score,type)

# %%
import numpy as np

def compute_a_dcf(cm_filenames, cm_scores, asv_speakers,asv_scores,asv_labels, asv_filenames, thresholds=np.array(np.arange(0, 1.01, 0.01).tolist()),val_CM_threshold = None,title = None,gender = 'male'):   
    if gender == 'male':
        thresholds = np.array(np.arange(0, 1.01, 0.01).tolist())
    elif gender == 'female':
        thresholds = np.array(np.arange(-1, 1.01, 0.01).tolist())
    
    # Initialize Costing Model
    Costing_model = a_dcf.CostModel()
    global_min_a_dcf = np.inf
    global_min_a_dcf_thresh = None
    # Create a dictionary to map filenames to cm_scores
    cm_score_dict = dict(zip(cm_filenames, cm_scores))
    asv_labels_dict = dict(zip(asv_filenames, asv_labels))
    asv_score_dict = dict(zip(asv_filenames, asv_scores))
    asv_speakers_dict = dict(zip(asv_filenames, asv_speakers))
    
    total_min_a_dcf = []
    total_min_a_dcf_thresh = []
    all_a_dcf = []
    all_a_dcf_thresh = []
    # Iterate over the thresholds
    for cm_threshold in thresholds:
        adjusted_scores = []
        adjusted_labels = []
        adjusted_filename = []
        adjusted_speakers = []  
        
        # Iterate over the asv_filenames and adjust cm_scores based on threshold
        for filename in asv_filenames:
            if filename in cm_score_dict:
                cm_score = cm_score_dict[filename]
                if cm_score > cm_threshold: # If the score is greater than the threshold, append the score - bonafide
                    adjusted_scores.append(asv_score_dict[filename])
                    adjusted_labels.append(asv_labels_dict[filename])
                    adjusted_speakers.append(asv_speakers_dict[filename])
                    adjusted_filename.append(adjusted_filename)  
                    
                else:
                    adjusted_scores.append(-np.inf) # If the score is lower than the threshold, append the score - spoof
                    adjusted_labels.append(asv_labels_dict[filename])
                    adjusted_speakers.append(asv_speakers_dict[filename])
                    adjusted_filename.append(adjusted_filename)  
            else:
                # If the filename is not found, append -np.inf or handle accordingly
                print("Error! Filename {filename} not found in cm_score_dict")
        
        # Compute the a-dcf
        min_a_dcf , min_a_dcf_thresh,a_dcfs_normed,a_dcf_thresh = a_dcf.calculate_a_dcf_python_old_version(asv_scores = np.array(adjusted_scores), asv_labels = np.array(adjusted_labels),cost_model = Costing_model, printres = True)
        all_a_dcf.append(a_dcfs_normed)
        all_a_dcf_thresh.append(a_dcf_thresh)
        total_min_a_dcf.append(min_a_dcf)
        total_min_a_dcf_thresh.append(min_a_dcf_thresh)
        if min_a_dcf < global_min_a_dcf:
            global_min_a_dcf = min_a_dcf
            global_min_a_dcf_thresh = min_a_dcf_thresh
            global_cm_threshold = cm_threshold
            
    print(f"Threshold: {global_cm_threshold} \tMin a-dcf: {global_min_a_dcf} \tMin a-dcf threshold: {global_min_a_dcf_thresh}")
    total_min_a_dcf = np.array(total_min_a_dcf)
    total_min_a_dcf_thresh = np.array(total_min_a_dcf_thresh)
    plt.figure(figsize=(10, 10))
    plt.plot(thresholds, total_min_a_dcf)
    plt.xlabel("CM Threshold")
    plt.ylabel("a-dcf")
    plt.scatter(global_cm_threshold, global_min_a_dcf, color='red')
    if val_CM_threshold is not None:
        plt.scatter(val_CM_threshold, total_min_a_dcf[thresholds == val_CM_threshold], color='green')
        plt.legend(["min a-dcf vs CM Threshold", "min a-dcf with Best CM Threshold", "min a-dcf with Validation CM Threshold"])
    else:
        plt.legend(["min a-dcf vs CM Threshold", "min a-dcf with Best CM Threshold"])
    if title is not None:
        plt.title(title)
    else:
        plt.title("min a-dcf vs CM Threshold")
    plt.show()
        

    return adjusted_scores, adjusted_labels, adjusted_speakers, adjusted_filename, global_min_a_dcf, global_min_a_dcf_thresh,np.array(all_a_dcf),np.array(all_a_dcf_thresh)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming list_tDCF_norm_male_dev, list_asv_score, and list_CM_thresholds_male_dev are defined
def heatmap_norm_adcf(list_aDCF_norm,cm_thresholds = np.array(np.arange(0, 1.01, 0.01).tolist()),sasv_thresholds =None,target_values= None,title = None,point_x_index=None, point_y_index=None,point_x_constrained=None,point_y_constrained=None,value = None,defualt_show = None):
    if defualt_show == 'male':
        cm_thresholds = np.array(np.arange(0, 1.01, 0.01).tolist())
    elif defualt_show == 'female':
        cm_thresholds = np.array(np.arange(-1, 1.01, 0.01).tolist())
    
    
    SIZE = 12
    
    plt.rc('legend', fontsize=SIZE)    # legend fontsize

    # Create a heatmap
    _, ax = plt.subplots(figsize=(10, 10))
    num_cm_to_plot = 10

    cmap = plt.get_cmap('viridis', 512) 

    # Plot heatmap
    heatmap = ax.imshow(np.array(list_aDCF_norm).transpose(), cmap=cmap, aspect='auto', vmin=0, origin='lower', interpolation='none')

    # Set ticks and labels for x-axis (ASV scores)
    asv_indices = np.linspace(0, len(cm_thresholds) - 1, num_cm_to_plot, dtype=int)
    ax.set_xticks(asv_indices)
    ax.set_xticklabels(["{:.2f}".format(cm_thresholds[i]) for i in asv_indices])

    
    # Find the closest values
    
    sasv_indices = [np.abs(sasv_thresholds[0] - target).argmin() for target in target_values]
    
    
    #Set ticks and labels for y-axis (CM scores)
    ax.set_yticks(sasv_indices)
    ax.set_yticklabels(["{:.3f}".format(sasv_thresholds[0][i]) for i in sasv_indices])
    
   
   
    if defualt_show is not None:
        if defualt_show == "male":
            defult_indices = [sasv_indices[0],sasv_indices[-1]]
            ax.set_yticks(defult_indices)
            list_values = [0,1]
            #list_values = [sasv_thresholds[0][0],sasv_thresholds[0][-1]]
            ax.set_yticklabels(["{:.3f}".format(i) for i in list_values])
        else:
            defult_indices = [sasv_indices[0],sasv_indices[-1]]
            ax.set_yticks(defult_indices)
            list_values = [-1,1]
            #list_values = [sasv_thresholds[0][0],sasv_thresholds[0][-1]]
            ax.set_yticklabels(["{:.3f}".format(i) for i in list_values])
    
    # Add colorbar
    cbar = plt.colorbar(heatmap)
    cbar.set_label('norm a-DCF Values', rotation=270, labelpad=15)

    # Set axis labels
    ax.set_xlabel('CM Thresholds')
    ax.set_ylabel('SASV Thresholds')
    ax.set_title(title)
    
    cm_indices, sasv_indices = np.meshgrid(
        np.arange(np.array(sasv_thresholds).shape[1]),
        np.arange(np.array(cm_thresholds).shape[0])
    )
    contour = ax.contour(np.array(list_aDCF_norm).transpose(), levels=10, colors='white', origin='lower')
    plt.clabel(contour, inline=True, fontsize=10, fmt='%.2f', colors='white',zorder=1)
    
     # Plot the point if provided
    if point_x_index is not None and point_y_index is not None:
        ax.scatter(point_x_index, point_y_index,zorder=2, color='red', marker='X', label=f'Min norm a-DCF Optimal at ({cm_thresholds[point_x_index]:.2f},{sasv_thresholds[point_x_index][point_y_index]:.2f}), Value: {list_aDCF_norm[point_x_index][point_y_index]:.4f}')
    
    
    if point_x_constrained is not None and point_y_constrained is not None:
        if value is None:
            ax.scatter(point_x_constrained, point_y_constrained, zorder=3,color='cyan', marker='X', label=f'Min norm a-DCF with val thr at ({cm_thresholds[point_x_constrained]:.2f},{sasv_thresholds[point_x_constrained][point_y_constrained]:.2f}), Value: {list_aDCF_norm[point_x_constrained][point_y_constrained]:.4f}')
        else:
            ax.scatter(point_x_constrained, point_y_constrained, zorder=3,color='cyan', marker='X', label=f'Min norm a-DCF with val thr at ({cm_thresholds[point_x_constrained]:.2f},{sasv_thresholds[point_x_constrained][point_y_constrained]:.2f}), Value: {value:.4f}')
    
    # Show the plot
    ax.legend(loc="lower right")
    plt.show()

# %%
cm_filesname = Dev_dataset_all.name[(Dev_dataset_all.sex == 'male')]
cm_scores = 1-score_dev_male.flatten()
asv_scores = results.loc[(results['its_male_ground_truth'] == 'male')]["asv_score_male"].values
asv_speakers =  results.loc[(results['its_male_ground_truth'] == 'male')]["speaker_id_male"].values
asv_filenames = results.loc[(results['its_male_ground_truth'] == 'male')]["file_name"].values
asv_labels = results.loc[(results['its_male_ground_truth'] == 'male')]["asv_label"].values
title = "Development Set - Male - with gender labels  - min a-dcf vs CM Threshold"
adjusted_scores_male_dev, adjusted_labels_male_dev, adjusted_speakers_male_dev, adjusted_filename_male_dev, global_min_a_dcf_male_dev, global_min_a_dcf_thresh_male_dev,all_a_dcf,all_a_dcf_thresh = compute_a_dcf(cm_filesname, cm_scores, asv_speakers,asv_scores,asv_labels, asv_filenames,title = title,gender= 'male')
# Out:
# a-DCF: 0.19880, threshold: 0.43342
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09901, threshold: 0.37567
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06661, threshold: 0.37567
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.05034, threshold: 0.36241
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.04169, threshold: 0.36241
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03548, threshold: 0.35621
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03182, threshold: 0.35621
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02891, threshold: 0.35621
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02729, threshold: 0.35621
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02526, threshold: 0.35621
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02425, threshold: 0.35621
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02329, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02221, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02106, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01984, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01889, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01842, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01788, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01741, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01713, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01673, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01605, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01565, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01544, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01497, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01477, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01418, threshold: 0.28467
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01405, threshold: 0.28467
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01371, threshold: 0.28467
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01344, threshold: 0.28467
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01310, threshold: 0.28467
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01290, threshold: 0.28467
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01263, threshold: 0.28467
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01229, threshold: 0.28467
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01188, threshold: 0.28467
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01161, threshold: 0.28467
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01121, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01093, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01053, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01026, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01006, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00972, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00965, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00931, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00897, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00884, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00884, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00884, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00863, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00857, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00850, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00824, threshold: 0.24739
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00785, threshold: 0.21702
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00751, threshold: 0.21702
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00731, threshold: 0.21702
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00710, threshold: 0.21702
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00670, threshold: 0.21702
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00643, threshold: 0.21702
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00636, threshold: 0.21702
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00609, threshold: 0.21696
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00561, threshold: 0.21696
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00541, threshold: 0.21696
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00534, threshold: 0.21696
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00501, threshold: 0.21696
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00487, threshold: 0.21696
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00635, threshold: 0.21696
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00635, threshold: 0.21647
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00628, threshold: 0.21647
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00621, threshold: 0.21647
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00574, threshold: 0.21647
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00574, threshold: 0.21647
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00547, threshold: 0.21503
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00526, threshold: 0.21503
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00513, threshold: 0.21503
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00513, threshold: 0.21503
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00486, threshold: 0.21503
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00472, threshold: 0.21198
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00466, threshold: 0.21198
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00439, threshold: 0.21198
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00754, threshold: 0.21198
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00902, threshold: 0.21198
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01049, threshold: 0.21198
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01043, threshold: 0.21198
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01036, threshold: 0.21198
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01190, threshold: 0.21198
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01177, threshold: 0.21198
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01177, threshold: 0.21198
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01170, threshold: 0.21198
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01486, threshold: 0.19623
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01815, threshold: 0.19623
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02144, threshold: 0.19623
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02802, threshold: 0.19598
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03286, threshold: 0.19598
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03601, threshold: 0.19598
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.04273, threshold: 0.19598
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.05764, threshold: 0.19598
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08774, threshold: 0.19598
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12301, threshold: 0.19598
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19999, threshold: 0.18899
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.41483, threshold: 0.18749
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# Threshold: 0.78 	Min a-dcf: 0.004385091991341991 	Min a-dcf threshold: 0.2119824184398902

# %%
min_index = np.unravel_index(np.nanargmin(all_a_dcf), all_a_dcf.shape)
point_x_index = min_index[0]
point_y_index = min_index[1]

heatmap_norm_adcf(list_aDCF_norm = np.array(all_a_dcf),cm_thresholds = np.array(np.arange(0, 1.01, 0.1).tolist()),sasv_thresholds = all_a_dcf_thresh,target_values =  [0,0.5,1],title ="Norm a-DCF - Male on Development Set",point_x_index= point_x_index, point_y_index= point_y_index,point_x_constrained=None,point_y_constrained=None,value = None,defualt_show = 'male')

# %% [markdown]
# ### with pred of gender:

# %%
labels_dev_male_gender_classification = torch.Tensor(Dev_dataset_all.is_spoofed[gender_model.predict(Dev_dataset_all.data_for_gender_classification) == 1]).cpu().numpy().copy()
total_data = torch.Tensor(Dev_dataset_all.data[gender_model.predict(Dev_dataset_all.data_for_gender_classification) == 1]).cpu().numpy().copy()
with torch.no_grad():
    model = model.to(device)
    score_dev_male_gender_classification = torch.sigmoid(spoof_model_male(torch.Tensor(total_data).to(device)))
    
score_dev_male_gender_classification = score_dev_male_gender_classification.cpu().numpy().copy()

dev_male_eer, _ = my_functions.compute_eer(labels_dev_male_gender_classification,score_dev_male_gender_classification) # compute equal error rate

print(f"\tDev male EER: ({100*dev_male_eer}%)")
# Out:
# 	Dev male EER: (0.5546536796531659%)

# %%
bonafide_score_cm_male_dev = 1-score_dev_male_gender_classification[labels_dev_male == 0].flatten()
spoof_score_cm_male_dev = 1- score_dev_male_gender_classification[labels_dev_male == 1].flatten()
Prior_spoof = 0.05
target_scores_male_dev = results.loc[(results['asv_label'] ==  "target") & (results['its_male'] == True) ]["asv_score_male"].values
nontarget_scores_male_dev = results.loc[(results['asv_label'] == "nontarget") & (results['its_male'] == True) ]["asv_score_male"].values
spoof_scores_male_dev = results.loc[(results['asv_label'] ==  "spoof") & (results['its_male'] == True)]["asv_score_male"].values
list_asv_score = [0.261]
type = 'constrained'
list_tDCF_norm_male_dev ,list_CM_thresholds_male_dev,list_tDCF_male_dev   = compute_t_dcf(bonafide_score_cm_male_dev,spoof_score_cm_male_dev,Prior_spoof,target_scores_male_dev,nontarget_scores_male_dev,spoof_scores_male_dev,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  3.08466 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  0.261
# the CM thresholds is:  [5.91026783e-04 1.59102678e-03 1.60676241e-03 ... 9.96470869e-01
#  9.96529162e-01 9.97042716e-01]
# the CM threshold min is: 0.7791557312011719
# the tDCF_norm is: [1.         0.99986472 0.99972944 ... 3.07755475 3.08110851 3.08466227]
# the min tDCF_norm is: 0.010588390412183788
# the tDCF is: [0.30370671 0.30366562 0.30362454 ... 0.93467403 0.93575333 0.93683263]
# the min tdcf is: 0.00321576521582151

# %%
cm_filesname = Dev_dataset_all.name[(Dev_dataset_all.sex == 'male')]
cm_scores = 1-score_dev_male.flatten()
asv_scores = results.loc[(results['its_male'] == True)]["asv_score_male"].values
asv_speakers =  results.loc[(results['its_male'] == True)]["speaker_id_male"].values
asv_filenames = results.loc[(results['its_male'] == True)]["file_name"].values
asv_labels = results.loc[(results['its_male'] == True)]["asv_label"].values
title = "Development Set - Male - with gender classification  - min a-dcf vs CM Threshold"
adjusted_scores_male_dev, adjusted_labels_male_dev, adjusted_speakers_male_dev, adjusted_filename_male_dev, global_min_a_dcf_male_dev, global_min_a_dcf_thresh_male_dev,all_a_dcf,all_a_dcf_thresh = compute_a_dcf(cm_filesname, cm_scores, asv_speakers,asv_scores,asv_labels, asv_filenames,title = title,gender= 'male')
# Out:
# a-DCF: 0.19880, threshold: 0.43342
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09901, threshold: 0.37567
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06661, threshold: 0.37567
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.05034, threshold: 0.36241
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.04169, threshold: 0.36241
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03548, threshold: 0.35621
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03182, threshold: 0.35621
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02891, threshold: 0.35621
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02729, threshold: 0.35621
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02526, threshold: 0.35621
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02425, threshold: 0.35621
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02329, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02221, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02106, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01984, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01889, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01842, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01788, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01741, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01713, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01673, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01605, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01565, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01544, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01497, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01477, threshold: 0.31388
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01418, threshold: 0.28467
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01405, threshold: 0.28467
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01371, threshold: 0.28467
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01344, threshold: 0.28467
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01310, threshold: 0.28467
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01290, threshold: 0.28467
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01263, threshold: 0.28467
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01229, threshold: 0.28467
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01188, threshold: 0.28467
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01161, threshold: 0.28467
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01121, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01093, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01053, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01026, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01006, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00972, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00965, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00931, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00897, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00884, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00884, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00884, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00863, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00857, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00850, threshold: 0.28319
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00824, threshold: 0.24739
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00785, threshold: 0.21702
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00751, threshold: 0.21702
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00731, threshold: 0.21702
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00710, threshold: 0.21702
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00670, threshold: 0.21702
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00643, threshold: 0.21702
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00636, threshold: 0.21702
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00609, threshold: 0.21696
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00561, threshold: 0.21696
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00541, threshold: 0.21696
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00534, threshold: 0.21696
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00501, threshold: 0.21696
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00487, threshold: 0.21696
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00635, threshold: 0.21696
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00635, threshold: 0.21647
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00628, threshold: 0.21647
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00621, threshold: 0.21647
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00574, threshold: 0.21647
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00574, threshold: 0.21647
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00547, threshold: 0.21503
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00526, threshold: 0.21503
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00513, threshold: 0.21503
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00513, threshold: 0.21503
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00486, threshold: 0.21503
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00472, threshold: 0.21198
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00466, threshold: 0.21198
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00439, threshold: 0.21198
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00754, threshold: 0.21198
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00902, threshold: 0.21198
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01049, threshold: 0.21198
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01043, threshold: 0.21198
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01036, threshold: 0.21198
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01190, threshold: 0.21198
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01177, threshold: 0.21198
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01177, threshold: 0.21198
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01170, threshold: 0.21198
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01486, threshold: 0.19623
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01815, threshold: 0.19623
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02144, threshold: 0.19623
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02802, threshold: 0.19598
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03286, threshold: 0.19598
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03601, threshold: 0.19598
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.04273, threshold: 0.19598
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.05764, threshold: 0.19598
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08774, threshold: 0.19598
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12301, threshold: 0.19598
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19999, threshold: 0.18899
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.41483, threshold: 0.18749
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# Threshold: 0.78 	Min a-dcf: 0.004385091991341991 	Min a-dcf threshold: 0.2119824184398902

# %%
all_a_dcf.shape
# Out:
# (101, 9185)

# %%
min_index = np.unravel_index(np.nanargmin(all_a_dcf), all_a_dcf.shape)
point_x_index = min_index[0]
point_y_index = min_index[1]

heatmap_norm_adcf(list_aDCF_norm = np.array(all_a_dcf),cm_thresholds = np.array(np.arange(0, 1.01, 0.01).tolist()),sasv_thresholds = all_a_dcf_thresh,target_values =  [0,0.5,1],title ="Norm a-DCF - Male on Development Set",point_x_index= point_x_index, point_y_index= point_y_index,point_x_constrained=None,point_y_constrained=None,value = None,defualt_show = 'male')

# %% [markdown]
# ## Female - DEV:

# %% [markdown]
# ### with labels of gender:

# %%
labels_dev_female = torch.Tensor(Dev_dataset_all.is_spoofed[(Dev_dataset_all.sex == 'female').values].values).cpu().numpy().copy()
total_data = torch.Tensor(Dev_dataset_all.data[(Dev_dataset_all.sex == 'female').values]).cpu().numpy().copy()
with torch.no_grad():
    model = model.to(device)
    output = spoof_model_female(torch.Tensor(total_data).to(device))
    _ , score_dev_female = spoof_model_female.loss(torch.Tensor(output).to(device),None)
    score_dev_female = -1*score_dev_female
    
score_dev_female = score_dev_female.cpu().numpy().copy()

eer, thresh = my_functions.compute_eer(labels_dev_female,score_dev_female) # compute equal error rate

print(f"\tDev Female EER:({100*eer}%)")
# Out:
# 	Dev Female EER:(0.0%)
# c:\Users\avish\OneDrive\Desktop\thesis_research\avishai_work\env\lib\site-packages\scipy\interpolate\_interpolate.py:653: RuntimeWarning: divide by zero encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# c:\Users\avish\OneDrive\Desktop\thesis_research\avishai_work\env\lib\site-packages\scipy\interpolate\_interpolate.py:656: RuntimeWarning: invalid value encountered in multiply
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo

# %%
bonafide_score_cm_female_dev = score_dev_female[labels_dev_female == 0].flatten()
bonafide_score_cm_female_dev = -1*bonafide_score_cm_female_dev

spoof_score_cm_female_dev = score_dev_female[labels_dev_female == 1].flatten()
spoof_score_cm_female_dev = -1*spoof_score_cm_female_dev
Prior_spoof = 0.05
target_scores_female_dev = results.loc[(results['asv_label'] ==  "target") & (results['its_male_ground_truth'] == 'female') ]["asv_score_female"].values
nontarget_scores_female_dev = results.loc[(results['asv_label'] == "nontarget") & (results['its_male_ground_truth'] == 'female') ]["asv_score_female"].values
spoof_scores_female_dev = results.loc[(results['asv_label'] ==  "spoof") & (results['its_male_ground_truth'] == 'female')]["asv_score_female"].values
list_asv_score = [0.397]
type = 'constrained'
list_tDCF_norm_female_dev ,list_CM_thresholds_female_dev,list_tDCF_female_dev  = compute_t_dcf(bonafide_score_cm_female_dev,spoof_score_cm_female_dev,Prior_spoof,target_scores_female_dev,nontarget_scores_female_dev,spoof_scores_female_dev,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  5.14878 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  0.397
# the CM thresholds is:  [-0.81040074 -0.80940074 -0.80887175 ...  0.94128716  0.94251966
#   0.9456234 ]
# the CM threshold min is: 0.546097993850708
# the tDCF_norm is: [1.         0.9999329  0.99986581 ... 5.14264952 5.14571427 5.14877902]
# the min tDCF_norm is: 0.0
# the tDCF is: [0.18048846 0.18047635 0.18046424 ... 0.92818889 0.92874204 0.92929519]
# the min tdcf is: 0.0

# %%
cm_filesname = Dev_dataset_all.name[(Dev_dataset_all.sex == 'female')]
cm_scores = -1*score_dev_female.flatten()
asv_scores = results.loc[(results['its_male_ground_truth'] == 'female')]["asv_score_female"].values
asv_speakers =  results.loc[(results['its_male_ground_truth'] == 'female')]["speaker_id_female"].values
asv_filenames = results.loc[(results['its_male_ground_truth'] == 'female')]["file_name"].values
asv_labels = results.loc[(results['its_male_ground_truth'] == 'female')]["asv_label"].values
title = "Development Set - Female - with gender labels  - min a-dcf vs CM Threshold"
adjusted_scores_female_dev, adjusted_labels_female_dev, adjusted_speakers_female_dev, adjusted_filename_female_dev, global_min_a_dcf_female_dev, global_min_a_dcf_thresh_female_dev,all_a_dcf,all_a_dcf_thresh = compute_a_dcf(cm_filesname, cm_scores, asv_speakers,asv_scores,asv_labels, asv_filenames,title = title,gender= 'female')
# Out:
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17516, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17308, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16942, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16463, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15854, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15223, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14740, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14240, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13814, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13301, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12912, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12499, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12087, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11607, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11154, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10718, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10215, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09799, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09329, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08923, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08534, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08121, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07695, threshold: 0.43835
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07323, threshold: 0.43835
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06991, threshold: 0.43835
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06692, threshold: 0.43835
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06380, threshold: 0.43835
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06072, threshold: 0.43835
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.05765, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.05513, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.05245, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.04983, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.04752, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.04517, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.04306, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.04118, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03933, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03786, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03611, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03450, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03323, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03198, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03081, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02967, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02838, threshold: 0.37200
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02718, threshold: 0.37200
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02627, threshold: 0.37200
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02523, threshold: 0.37200
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02395, threshold: 0.37200
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02285, threshold: 0.37200
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02201, threshold: 0.37200
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02100, threshold: 0.37200
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02013, threshold: 0.37200
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01943, threshold: 0.37200
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01886, threshold: 0.37177
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01808, threshold: 0.37177
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01755, threshold: 0.37177
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01705, threshold: 0.29491
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01631, threshold: 0.29491
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01554, threshold: 0.29491
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01477, threshold: 0.29491
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01386, threshold: 0.29491
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01309, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01225, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01155, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01111, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01064, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00997, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00947, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00900, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00833, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00762, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00725, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00665, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00611, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00591, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00571, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00548, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00534, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00514, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00484, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00460, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00444, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00413, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00403, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00387, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00353, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00320, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00306, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00299, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00283, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00266, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00249, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00219, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00195, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00192, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00179, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00165, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00158, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00152, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00142, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00125, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00118, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00112, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00101, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00095, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00088, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00085, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00071, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00071, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00071, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00071, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00065, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00065, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00065, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00058, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00058, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00058, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00054, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00048, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00048, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00048, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00139, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00139, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00241, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00241, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00241, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00241, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00241, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00241, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00330, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00432, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00636, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00941, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01043, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01654, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02264, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.04300, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07023, threshold: 0.30001
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14352, threshold: 0.30001
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.26057, threshold: 0.30001
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.45091, threshold: 0.30001
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# Threshold: 0.5500000000000014 	Min a-dcf: 0.00037698412698412696 	Min a-dcf threshold: 0.2914850671182979

# %%
min_index = np.unravel_index(np.nanargmin(all_a_dcf), all_a_dcf.shape)
point_x_index = min_index[0]
point_y_index = min_index[1]

heatmap_norm_adcf(list_aDCF_norm = np.array(all_a_dcf),cm_thresholds = np.array(np.arange(0, 1.01, 0.01).tolist()),sasv_thresholds = all_a_dcf_thresh,target_values =  [0,0.5,1],title ="Norm a-DCF - Female on Development Set",point_x_index= point_x_index, point_y_index= point_y_index,point_x_constrained=None,point_y_constrained=None,value = None,defualt_show = 'female')

# %% [markdown]
# ### with pred of gender:

# %%
labels_dev_female_gender_classification = torch.Tensor(Dev_dataset_all.is_spoofed[gender_model.predict(Dev_dataset_all.data_for_gender_classification) == 0].values).cpu().numpy().copy()
total_data = torch.Tensor(Dev_dataset_all.data[gender_model.predict(Dev_dataset_all.data_for_gender_classification) == 0]).cpu().numpy().copy()
with torch.no_grad():
    model = model.to(device)
    output = spoof_model_female(torch.Tensor(total_data).to(device))
    _ , score_dev_female_gender_classification = spoof_model_female.loss(torch.Tensor(output).to(device),None)
    score_dev_female_gender_classification = -1*score_dev_female_gender_classification
    
score_dev_female_gender_classification = score_dev_female_gender_classification.cpu().numpy().copy()

eer, thresh = my_functions.compute_eer(labels_dev_female_gender_classification,score_dev_female_gender_classification) # compute equal error rate

print(f"\tDev Female EER:({100*eer}%)")
# Out:
# 	Dev Female EER:(0.0%)
# c:\Users\avish\OneDrive\Desktop\thesis_research\avishai_work\env\lib\site-packages\scipy\interpolate\_interpolate.py:653: RuntimeWarning: divide by zero encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# c:\Users\avish\OneDrive\Desktop\thesis_research\avishai_work\env\lib\site-packages\scipy\interpolate\_interpolate.py:656: RuntimeWarning: invalid value encountered in multiply
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo

# %%
bonafide_score_cm_female_dev = score_dev_female[labels_dev_female_gender_classification == 0].flatten()
bonafide_score_cm_female_dev = -1*bonafide_score_cm_female_dev

spoof_score_cm_female_dev = score_dev_female[labels_dev_female_gender_classification == 1].flatten()
spoof_score_cm_female_dev = -1*spoof_score_cm_female_dev
Prior_spoof = 0.05
target_scores_female_dev = results.loc[(results['asv_label'] ==  "target") & (results['its_male'] == False) ]["asv_score_female"].values
nontarget_scores_female_dev = results.loc[(results['asv_label'] == "nontarget") & (results['its_male'] == False) ]["asv_score_female"].values
spoof_scores_female_dev = results.loc[(results['asv_label'] ==  "spoof") & (results['its_male'] == False)]["asv_score_female"].values
list_asv_score = [0.397]
type = 'constrained'

list_tDCF_norm_female_dev ,list_CM_thresholds_female_dev,list_tDCF_female_dev = compute_t_dcf(bonafide_score_cm_female_dev,spoof_score_cm_female_dev,Prior_spoof,target_scores_female_dev,nontarget_scores_female_dev,spoof_scores_female_dev,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  5.14878 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  0.397
# the CM thresholds is:  [-0.81040074 -0.80940074 -0.80887175 ...  0.94128716  0.94251966
#   0.9456234 ]
# the CM threshold min is: 0.546097993850708
# the tDCF_norm is: [1.         0.9999329  0.99986581 ... 5.14264952 5.14571427 5.14877902]
# the min tDCF_norm is: 0.0
# the tDCF is: [0.18048846 0.18047635 0.18046424 ... 0.92818889 0.92874204 0.92929519]
# the min tdcf is: 0.0

# %%
cm_filesname = Dev_dataset_all.name[(Dev_dataset_all.sex == 'female')]
cm_scores = -1*score_dev_female.flatten()
asv_scores = results.loc[(results['its_male'] == False)]["asv_score_female"].values
asv_speakers =  results.loc[(results['its_male'] == False)]["speaker_id_female"].values
asv_filenames = results.loc[(results['its_male'] == False)]["file_name"].values
asv_labels = results.loc[(results['its_male'] == False)]["asv_label"].values
title = "Development Set - Female - with gender labels  - min a-dcf vs CM Threshold"
adjusted_scores_female_dev, adjusted_labels_female_dev, adjusted_speakers_female_dev, adjusted_filename_female_dev, global_min_a_dcf_female_dev, global_min_a_dcf_thresh_female_dev,all_a_dcf,all_a_dcf_thresh = compute_a_dcf(cm_filesname, cm_scores, asv_speakers,asv_scores,asv_labels, asv_filenames,title = title,gender= 'female')
# Out:
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17550, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17516, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17308, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16942, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16463, threshold: 0.45279
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15854, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15223, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14740, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14240, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13814, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13301, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12912, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12499, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12087, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11607, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11154, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10718, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10215, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09799, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09329, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08923, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08534, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08121, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07695, threshold: 0.43835
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07323, threshold: 0.43835
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06991, threshold: 0.43835
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06692, threshold: 0.43835
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06380, threshold: 0.43835
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06072, threshold: 0.43835
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.05765, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.05513, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.05245, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.04983, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.04752, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.04517, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.04306, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.04118, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03933, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03786, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03611, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03450, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03323, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03198, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03081, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02967, threshold: 0.40000
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02838, threshold: 0.37200
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02718, threshold: 0.37200
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02627, threshold: 0.37200
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02523, threshold: 0.37200
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02395, threshold: 0.37200
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02285, threshold: 0.37200
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02201, threshold: 0.37200
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02100, threshold: 0.37200
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02013, threshold: 0.37200
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01943, threshold: 0.37200
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01886, threshold: 0.37177
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01808, threshold: 0.37177
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01755, threshold: 0.37177
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01705, threshold: 0.29491
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01631, threshold: 0.29491
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01554, threshold: 0.29491
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01477, threshold: 0.29491
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01386, threshold: 0.29491
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01309, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01225, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01155, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01111, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01064, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00997, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00947, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00900, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00833, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00762, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00725, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00665, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00611, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00591, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00571, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00548, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00534, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00514, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00484, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00460, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00444, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00413, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00403, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00387, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00353, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00320, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00306, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00299, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00283, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00266, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00249, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00219, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00195, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00192, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00179, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00165, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00158, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00152, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00142, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00125, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00118, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00112, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00101, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00095, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00088, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00085, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00071, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00071, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00071, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00071, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00065, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00065, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00065, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00058, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00058, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00058, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00054, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00048, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00048, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00048, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00044, threshold: 0.29382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00038, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00139, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00139, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00241, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00241, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00241, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00241, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00241, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00241, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00330, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00432, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00636, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00941, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01043, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01654, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02264, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.04300, threshold: 0.29149
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07023, threshold: 0.30001
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14352, threshold: 0.30001
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.26057, threshold: 0.30001
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.45091, threshold: 0.30001
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# Threshold: 0.5500000000000014 	Min a-dcf: 0.00037698412698412696 	Min a-dcf threshold: 0.2914850671182979

# %%
min_index = np.unravel_index(np.nanargmin(all_a_dcf), all_a_dcf.shape)
point_x_index = min_index[0]
point_y_index = min_index[1]

heatmap_norm_adcf(list_aDCF_norm = np.array(all_a_dcf),cm_thresholds = np.array(np.arange(0, 1.01, 0.01).tolist()),sasv_thresholds = all_a_dcf_thresh,target_values =  [0,0.5,1],title ="Norm a-DCF - Female on Development Set",point_x_index= point_x_index, point_y_index= point_y_index,point_x_constrained=None,point_y_constrained=None,value = None,defualt_show = 'female')

# %% [markdown]
# ## Eval:

# %%
from sklearn.metrics.pairwise import cosine_similarity
import torchaudio
import tqdm
from ASV_utils.config_thr import pmf_both_thr_gender_val ,pmf_both_thr_spoof_test_male,pmf_both_thr_spoof_test_female

txt_file_path = "output.txt"
csv_file_path = "output.csv"
enrollment_male = enrollment_eval_male
enrollment_female = enrollment_eval_female
list_files = file_name_according_speaker_id_eval
data_set = Eval_dataset_all
asv_model = classifier
spoof_labels = spoof_label_eval
list_speaker_id = speaker_id_list_eval
list_asv_label = asv_label_eval

#results_eval = inference_system_cm_asv_avg_score(spoof_labels,list_speaker_id,list_asv_label,txt_file_path,csv_file_path,pmf_both_thr_gender_val,pmf_both_thr_spoof_test_male,pmf_both_thr_spoof_test_female,enrollment_male, enrollment_female, list_files, data_set, gender_model, spoof_model_male, spoof_model_female, asv_model, device, verbose = False, verbose_txt = False,verbose_csv = False)

# %%
from ASV_utils.tdcf_functions import compute_t_dcf


import pickle
with open('./dcf_and_tdcf/dcf_avg_score/pmf_both_tdcf/asv_protocol/objects_asv_and_cm_time_embeddings_eval_avg_score_both_asv_protocol.pkl', 'rb') as f:
    results_eval = pickle.load(f)

# %% [markdown]
# ## Male - Eval:

# %% [markdown]
# ### with labels of gender:

# %%
labels_eval_male = torch.Tensor(Eval_dataset_all.is_spoofed[(Eval_dataset_all.sex == 'male').values].values).cpu().numpy().copy()
total_data = torch.Tensor(Eval_dataset_all.data[(Eval_dataset_all.sex == 'male').values]).cpu().numpy().copy()
with torch.no_grad():
    model = model.to(device)
    score_eval_male = torch.sigmoid(spoof_model_male(torch.Tensor(total_data).to(device)))
    
score_eval_male = score_eval_male.cpu().numpy().copy()

eer_eval_male, _ = my_functions.compute_eer(labels_eval_male,score_eval_male) # compute equal error rate

print(f"\t Eval Male EER: ({100*eer_eval_male}%)")
# Out:
# 	 Eval Male EER: (8.672798948696906%)

# %%
bonafide_score_cm_male_eval = 1-score_eval_male[labels_eval_male == 0].flatten()
spoof_score_cm_male_eval = 1-score_eval_male[labels_eval_male == 1].flatten()
Prior_spoof = 0.05
target_scores_male_eval = results_eval.loc[(results_eval['asv_label'] ==  "target") & (results_eval['its_male_ground_truth'] == 'male') ]["asv_score_male"].values
nontarget_scores_male_eval = results_eval.loc[(results_eval['asv_label'] == "nontarget") & (results_eval['its_male_ground_truth'] == 'male') ]["asv_score_male"].values
spoof_scores_male_eval = results_eval.loc[(results_eval['asv_label'] ==  "spoof") & (results_eval['its_male_ground_truth'] == 'male')]["asv_score_male"].values
list_asv_score = [0.261,0.352]
type = 'constrained'
list_tDCF_norm_male_eval ,list_CM_thresholds_male_eval,list_tDCF_male_eval  = compute_t_dcf(bonafide_score_cm_male_eval,spoof_score_cm_male_eval,Prior_spoof,target_scores_male_eval,nontarget_scores_male_eval,spoof_scores_male_eval,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  2.46362 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  0.261
# the CM thresholds is:  [4.97268677e-04 1.49726868e-03 1.50895119e-03 ... 9.96871948e-01
#  9.96981561e-01 9.97154653e-01]
# the CM threshold min is: 0.9096115231513977
# the tDCF_norm is: [1.         0.99994912 0.99989825 ... 2.46145908 2.4625382  2.46361731]
# the min tDCF_norm is: 0.21189614957577682
# the tDCF is: [0.37914632 0.37912703 0.37910774 ... 0.93325314 0.93366229 0.93407143]
# the min tdcf is: 0.08033964462319275
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  2.72851 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv evaluation set  0.352
# the CM thresholds is:  [4.97268677e-04 1.49726868e-03 1.50895119e-03 ... 9.96871948e-01
#  9.96981561e-01 9.97154653e-01]
# the CM threshold min is: 0.9096115231513977
# the tDCF_norm is: [1.         0.99994912 0.99989825 ... 2.72611801 2.72731315 2.7285083 ]
# the min tDCF_norm is: 0.21850972215095604
# the tDCF is: [0.34254172 0.34252429 0.34250686 ... 0.93380915 0.93421853 0.93462792]
# the min tdcf is: 0.07484869552515197

# %%
cm_filesname = Eval_dataset_all.name[(Eval_dataset_all.sex == 'male')]
cm_scores = 1-score_eval_male.flatten()
asv_scores = results_eval.loc[(results_eval['its_male_ground_truth'] == 'male')]["asv_score_male"].values
asv_speakers =  results_eval.loc[(results_eval['its_male_ground_truth'] == 'male')]["speaker_id_male"].values
asv_filenames = results_eval.loc[(results_eval['its_male_ground_truth'] == 'male')]["file_name"].values
asv_labels = results_eval.loc[(results_eval['its_male_ground_truth'] == 'male')]["asv_label"].values
male_dev_cm_thr = 0.76 
title = "Evaluation Set - Male - with gender labels  - min a-dcf vs CM Threshold"
adjusted_scores_male_eval, adjusted_labels_male_eval, adjusted_speakers_male_eval, adjusted_filename_male_eval, global_min_a_dcf_male_eval, global_min_a_dcf_thresh_male_eval,all_a_dcf,all_a_dcf_thresh = compute_a_dcf(cm_filesname, cm_scores, asv_speakers,asv_scores,asv_labels, asv_filenames,val_CM_threshold = male_dev_cm_thr, title = title,gender= 'male')
# Out:
# a-DCF: 0.32196, threshold: 0.48423
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.24547, threshold: 0.42873
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.23289, threshold: 0.42192
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22516, threshold: 0.42192
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22038, threshold: 0.42192
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21549, threshold: 0.42192
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21099, threshold: 0.42192
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20748, threshold: 0.42192
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20423, threshold: 0.42192
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20094, threshold: 0.42192
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19776, threshold: 0.42192
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19472, threshold: 0.37550
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19255, threshold: 0.37550
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19059, threshold: 0.37550
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18759, threshold: 0.37550
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18556, threshold: 0.37550
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18317, threshold: 0.37550
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18085, threshold: 0.37550
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17874, threshold: 0.37550
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17703, threshold: 0.37531
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17462, threshold: 0.37531
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17279, threshold: 0.37531
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17098, threshold: 0.37531
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16892, threshold: 0.37531
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16694, threshold: 0.37531
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16475, threshold: 0.37531
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16307, threshold: 0.37531
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16139, threshold: 0.37524
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15971, threshold: 0.37524
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15806, threshold: 0.37524
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15633, threshold: 0.37524
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15450, threshold: 0.37524
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15292, threshold: 0.37524
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15129, threshold: 0.37524
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15022, threshold: 0.37524
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14893, threshold: 0.37524
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14743, threshold: 0.37524
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14564, threshold: 0.37524
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14397, threshold: 0.37524
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14272, threshold: 0.37040
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14145, threshold: 0.37040
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13997, threshold: 0.37040
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13853, threshold: 0.37040
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13702, threshold: 0.37039
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13545, threshold: 0.37039
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13412, threshold: 0.37039
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13237, threshold: 0.37039
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13036, threshold: 0.37039
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12954, threshold: 0.37039
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12789, threshold: 0.37039
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12619, threshold: 0.37039
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12509, threshold: 0.37039
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12359, threshold: 0.37039
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12226, threshold: 0.37039
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12078, threshold: 0.33312
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11890, threshold: 0.33312
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11783, threshold: 0.33312
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11595, threshold: 0.33312
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11452, threshold: 0.33312
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11358, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11162, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10992, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10791, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10608, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10407, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10211, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10007, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09885, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09658, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09424, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09340, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09116, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08930, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08712, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08554, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08370, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08156, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07978, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07843, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07612, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07638, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07523, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07254, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07019, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06808, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06576, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06372, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06254, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06063, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06046, threshold: 0.33288
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06075, threshold: 0.33288
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06154, threshold: 0.33288
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06295, threshold: 0.33288
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06881, threshold: 0.33288
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07424, threshold: 0.33288
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08836, threshold: 0.33288
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10846, threshold: 0.31066
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14363, threshold: 0.31066
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22465, threshold: 0.29005
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.51993, threshold: 0.36965
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# Threshold: 0.89 	Min a-dcf: 0.06045902164284517 	Min a-dcf threshold: 0.33287825709895086

# %%
min_index = np.unravel_index(np.nanargmin(all_a_dcf), all_a_dcf.shape)
point_x_index = min_index[0]
point_y_index = min_index[1]
cm_thresholds = np.array(np.arange(0, 1.01, 0.01).tolist())
point_x_constrained = np.where(cm_thresholds == male_dev_cm_thr)[0][0]
point_y_constrained = np.nanargmin(np.array(all_a_dcf)[point_x_constrained])
heatmap_norm_adcf(list_aDCF_norm = np.array(all_a_dcf),cm_thresholds = cm_thresholds,sasv_thresholds = all_a_dcf_thresh,target_values =  [0,0.5,1],title ="Norm a-DCF - Male on Evaluation Set",point_x_index= point_x_index, point_y_index= point_y_index,point_x_constrained=point_x_constrained,point_y_constrained=point_y_constrained,value = None,defualt_show = 'male')

# %% [markdown]
# ### with pred of gender:

# %%
labels_eval_male_gender_classification = torch.Tensor(Eval_dataset_all.is_spoofed[gender_model.predict(Eval_dataset_all.data_for_gender_classification) == 1]).cpu().numpy().copy()
total_data = torch.Tensor(Eval_dataset_all.data[gender_model.predict(Eval_dataset_all.data_for_gender_classification) == 1]).cpu().numpy().copy()
with torch.no_grad():
    model = model.to(device)
    score_eval_male_gender_classification = torch.sigmoid(spoof_model_male(torch.Tensor(total_data).to(device)))
    
score_eval_male_gender_classification = score_eval_male_gender_classification.cpu().numpy().copy()

eval_male_eer, _ = my_functions.compute_eer(labels_eval_male_gender_classification,score_eval_male_gender_classification) # compute equal error rate

print(f"\tEval male with gender classification EER: ({100*eval_male_eer}%) ")
# Out:
# 	Eval male with gender classification EER: (8.522727272757948%)

# %%
bonafide_score_cm_male_eval = 1-score_eval_male_gender_classification[labels_eval_male_gender_classification == 0].flatten()
spoof_score_cm_male_eval = 1-score_eval_male_gender_classification[labels_eval_male_gender_classification == 1].flatten()

Prior_spoof = 0.05
target_scores_male_eval = results_eval.loc[(results_eval['asv_label'] ==  "target") & (results_eval['its_male'] == True) ]["asv_score_male"].values
nontarget_scores_male_eval = results_eval.loc[(results_eval['asv_label'] == "nontarget") & (results_eval['its_male'] == True) ]["asv_score_male"].values
spoof_scores_male_eval = results_eval.loc[(results_eval['asv_label'] ==  "spoof") & (results_eval['its_male'] == True)]["asv_score_male"].values
list_asv_score = [0.261,0.352]
type = 'constrained'
list_tDCF_norm_male_eval ,list_CM_thresholds_male_eval,list_tDCF_male_eval  = compute_t_dcf(bonafide_score_cm_male_eval,spoof_score_cm_male_eval,Prior_spoof,target_scores_male_eval,nontarget_scores_male_eval,spoof_scores_male_eval,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=2288, Nspoof=20331] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  2.55266 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  0.261
# the CM thresholds is:  [4.97268677e-04 1.49726868e-03 1.50895119e-03 ... 9.96871948e-01
#  9.96981561e-01 9.97154653e-01]
# the CM threshold min is: 0.9096115231513977
# the tDCF_norm is: [1.         0.99995081 0.99990163 ... 2.55042754 2.55154321 2.55265889]
# the min tDCF_norm is: 0.2129399255736636
# the tDCF is: [0.36365649 0.3636386  0.36362071 ... 0.92747952 0.92788524 0.92829096]
# the min tdcf is: 0.07743698488657133
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=2288, Nspoof=20331] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  2.82749 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv evaluation set  0.352
# the CM thresholds is:  [4.97268677e-04 1.49726868e-03 1.50895119e-03 ... 9.96871948e-01
#  9.96981561e-01 9.97154653e-01]
# the CM threshold min is: 0.9096115231513977
# the tDCF_norm is: [1.         0.99995081 0.99990163 ... 2.82501816 2.82625395 2.82748974]
# the min tDCF_norm is: 0.22002691006225772
# the tDCF is: [0.32846392 0.32844777 0.32843161 ... 0.92791655 0.92832246 0.92872837]
# the min tdcf is: 0.07227090184426527

# %%
cm_filesname = Eval_dataset_all.name[gender_model.predict(Eval_dataset_all.data_for_gender_classification) == 1]
cm_scores = 1-score_eval_male_gender_classification.flatten()
asv_scores = results_eval.loc[(results_eval['its_male'] == True)]["asv_score_male"].values
asv_speakers =  results_eval.loc[(results_eval['its_male'] == True)]["speaker_id_male"].values
asv_filenames = results_eval.loc[(results_eval['its_male'] == True)]["file_name"].values
asv_labels = results_eval.loc[(results_eval['its_male'] == True)]["asv_label"].values
male_dev_cm_thr = 0.76
title = "Evaluation Set - Male - with gender classification  - min a-dcf vs CM Threshold"
adjusted_scores_male_eval, adjusted_labels_male_eval, adjusted_speakers_male_eval, adjusted_filename_male_eval, global_min_a_dcf_male_eval, global_min_a_dcf_thresh_male_eval,all_a_dcf,all_a_dcf_thresh = compute_a_dcf(cm_filesname, cm_scores, asv_speakers,asv_scores,asv_labels, asv_filenames,val_CM_threshold = male_dev_cm_thr, title = title,gender= 'male')
# Out:
# a-DCF: 0.31625, threshold: 0.48423
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.24194, threshold: 0.42873
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22991, threshold: 0.42192
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22256, threshold: 0.42192
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21808, threshold: 0.42192
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21344, threshold: 0.42192
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20916, threshold: 0.42192
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20581, threshold: 0.42192
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20274, threshold: 0.42192
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19941, threshold: 0.37550
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19616, threshold: 0.37550
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19308, threshold: 0.37550
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19102, threshold: 0.37550
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18924, threshold: 0.37550
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18636, threshold: 0.37550
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18440, threshold: 0.37550
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18211, threshold: 0.37550
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17990, threshold: 0.37550
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17788, threshold: 0.37550
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17623, threshold: 0.37531
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17394, threshold: 0.37531
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17220, threshold: 0.37531
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17045, threshold: 0.37531
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16848, threshold: 0.37531
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16659, threshold: 0.37531
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16453, threshold: 0.37531
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16295, threshold: 0.37531
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16135, threshold: 0.37524
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15975, threshold: 0.37524
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15818, threshold: 0.37524
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15658, threshold: 0.37524
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15481, threshold: 0.37524
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15329, threshold: 0.37524
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15171, threshold: 0.37524
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15068, threshold: 0.37524
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14943, threshold: 0.37524
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14797, threshold: 0.37524
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14625, threshold: 0.37524
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14465, threshold: 0.37524
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14343, threshold: 0.37040
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14223, threshold: 0.37040
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14080, threshold: 0.37040
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13942, threshold: 0.37040
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13797, threshold: 0.37039
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13647, threshold: 0.37039
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13519, threshold: 0.37039
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13355, threshold: 0.37039
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13163, threshold: 0.37039
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13086, threshold: 0.37039
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12928, threshold: 0.37039
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12764, threshold: 0.37039
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12660, threshold: 0.37039
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12515, threshold: 0.37039
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12382, threshold: 0.33312
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12232, threshold: 0.33312
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12050, threshold: 0.33312
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11948, threshold: 0.33312
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11769, threshold: 0.33312
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11631, threshold: 0.33312
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11544, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11355, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11192, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10998, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10821, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10627, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10437, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10241, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10124, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09905, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09684, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09607, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09393, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09213, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09002, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08851, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08678, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08471, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08302, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08175, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07951, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07985, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07881, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07620, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07398, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07198, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06976, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06785, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06678, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06499, threshold: 0.33302
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06497, threshold: 0.33288
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06540, threshold: 0.33288
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06565, threshold: 0.33288
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06718, threshold: 0.33288
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07313, threshold: 0.33288
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07871, threshold: 0.33288
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09296, threshold: 0.33288
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11314, threshold: 0.31066
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14837, threshold: 0.31066
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22863, threshold: 0.29005
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.52206, threshold: 0.36965
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# Threshold: 0.89 	Min a-dcf: 0.06496903789454342 	Min a-dcf threshold: 0.33287825709895086

# %%
min_index = np.unravel_index(np.nanargmin(all_a_dcf), all_a_dcf.shape)
point_x_index = min_index[0]
point_y_index = min_index[1]
cm_thresholds = np.array(np.arange(0, 1.01, 0.01).tolist())
point_x_constrained = np.where(cm_thresholds == male_dev_cm_thr)[0][0]
point_y_constrained = np.nanargmin(np.array(all_a_dcf)[point_x_constrained])
heatmap_norm_adcf(list_aDCF_norm = np.array(all_a_dcf),cm_thresholds = cm_thresholds,sasv_thresholds = all_a_dcf_thresh,target_values =  [0,0.5,1],title ="Norm a-DCF - Male on Evaluation Set",point_x_index= point_x_index, point_y_index= point_y_index,point_x_constrained=point_x_constrained,point_y_constrained=point_y_constrained,value = None,defualt_show = 'male')

# %% [markdown]
# ## Female - Eval:

# %% [markdown]
# ### with labels of gender:

# %%
labels_eval_female = torch.Tensor(Eval_dataset_all.is_spoofed[(Eval_dataset_all.sex == 'female').values].values).cpu().numpy().copy()
total_data = torch.Tensor(Eval_dataset_all.data[(Eval_dataset_all.sex == 'female').values]).cpu().numpy().copy()
with torch.no_grad():
    model = model.to(device)
    output = spoof_model_female(torch.Tensor(total_data).to(device))
    _ , score_eval_female = spoof_model_female.loss(torch.Tensor(output).to(device),None)
    score_eval_female = -1*score_eval_female
    
score_eval_female = score_eval_female.cpu().numpy().copy()

eer_eval_female, _ = my_functions.compute_eer(labels_eval_female,score_eval_female) # compute equal error rate

print(f"\tEval Female labels gender EER: ({eer_eval_female}%)")
# Out:
# 	Eval Female labels gender EER: (0.10129787907565715%)

# %%
bonafide_score_cm_female_eval = score_eval_female[labels_eval_female == 0]
bonafide_score_cm_female_eval = -1*bonafide_score_cm_female_eval

spoof_score_cm_female_eval = score_eval_female[labels_eval_female == 1]
spoof_score_cm_female_eval  = -1*spoof_score_cm_female_eval

Prior_spoof = 0.05

target_scores_female_eval = results_eval.loc[(results_eval['asv_label'] ==  "target") & (results_eval['its_male_ground_truth'] == 'female') ]["asv_score_female"].values
nontarget_scores_female_eval = results_eval.loc[(results_eval['asv_label'] == "nontarget") & (results_eval['its_male_ground_truth'] == 'female') ]["asv_score_female"].values
spoof_scores_female_eval = results_eval.loc[(results_eval['asv_label'] ==  "spoof") & (results_eval['its_male_ground_truth'] == 'female')]["asv_score_female"].values

list_asv_score = [0.397,0.401]
type = 'constrained'
list_tDCF_norm_female_eval ,list_CM_thresholds_female_eval,list_tDCF_female_eval  = compute_t_dcf(bonafide_score_cm_female_eval,spoof_score_cm_female_eval,Prior_spoof,target_scores_female_eval,nontarget_scores_female_eval,spoof_scores_female_eval,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=5072, Nspoof=44226] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  2.97596 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  0.397
# the CM thresholds is:  [-0.82588501 -0.82488501 -0.82439852 ...  0.94250655  0.94292605
#   0.95455754]
# the CM threshold min is: 0.7508225440979004
# the tDCF_norm is: [1.         0.99997739 0.99995478 ... 2.97539983 2.97537722 2.97596396]
# the min tDCF_norm is: 0.29184519399415576
# the tDCF is: [0.3133564  0.31334931 0.31334223 ... 0.93236057 0.93235348 0.93253734]
# the min tdcf is: 0.09145155838122389
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=5072, Nspoof=44226] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  3.00467 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv evaluation set  0.401
# the CM thresholds is:  [-0.82588501 -0.82488501 -0.82439852 ...  0.94250655  0.94292605
#   0.95455754]
# the CM threshold min is: 0.7508225440979004
# the tDCF_norm is: [1.         0.99997739 0.99995478 ... 3.00410096 3.00407835 3.00467075]
# the min tDCF_norm is: 0.29272247173972643
# the tDCF is: [0.31030389 0.31029688 0.31028986 ... 0.93218422 0.93217721 0.93236103]
# the min tdcf is: 0.09083292273595026

# %%
cm_filesname = Eval_dataset_all.name[(Eval_dataset_all.sex == 'female').values]
cm_scores = -1*score_eval_female.flatten()
asv_scores = results_eval.loc[(results_eval['its_male_ground_truth'] == 'female')]["asv_score_female"].values
asv_speakers =  results_eval.loc[(results_eval['its_male_ground_truth'] == 'female')]["speaker_id_female"].values
asv_filenames = results_eval.loc[(results_eval['its_male_ground_truth'] == 'female')]["file_name"].values
asv_labels = results_eval.loc[(results_eval['its_male_ground_truth'] == 'female')]["asv_label"].values
female_dev_cm_thr = 0.5100000000000013 
title = "Evaluation Set - Female - with gender labels  - min a-dcf vs CM Threshold"
adjusted_scores_female_eval, adjusted_labels_female_eval, adjusted_speakers_female_eval, adjusted_filename_female_eval, global_min_a_dcf_female_eval, global_min_a_dcf_thresh_female_eval,all_a_dcf,all_a_dcf_thresh = compute_a_dcf(cm_filesname, cm_scores, asv_speakers,asv_scores,asv_labels, asv_filenames,val_CM_threshold = female_dev_cm_thr, title = title,gender= 'female')
# Out:
# a-DCF: 0.28711, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28711, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28711, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28711, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28711, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28711, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28711, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28711, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28711, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28711, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28711, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28711, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28711, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28711, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28711, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28711, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28711, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28711, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28709, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28702, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28675, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28605, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28477, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28256, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.27989, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.27723, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.27465, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.27208, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.26945, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.26650, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.26345, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.25973, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.25553, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.25138, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.24689, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.24269, threshold: 0.47567
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.23867, threshold: 0.47567
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.23463, threshold: 0.47567
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.23131, threshold: 0.46919
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22788, threshold: 0.46919
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22531, threshold: 0.46919
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22261, threshold: 0.46919
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22006, threshold: 0.46919
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21786, threshold: 0.46919
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21596, threshold: 0.46919
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21426, threshold: 0.46919
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21241, threshold: 0.46919
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21087, threshold: 0.45595
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20950, threshold: 0.45595
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20826, threshold: 0.45595
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20709, threshold: 0.45595
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20595, threshold: 0.45590
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20499, threshold: 0.45590
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20408, threshold: 0.45590
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20324, threshold: 0.45590
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20243, threshold: 0.45590
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20161, threshold: 0.45590
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20083, threshold: 0.45590
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20005, threshold: 0.45590
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19932, threshold: 0.45590
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19857, threshold: 0.45590
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19806, threshold: 0.45590
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19755, threshold: 0.45590
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19690, threshold: 0.45590
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19614, threshold: 0.44569
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19548, threshold: 0.44569
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19493, threshold: 0.44569
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19430, threshold: 0.44569
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19364, threshold: 0.44569
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19298, threshold: 0.44569
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19237, threshold: 0.44569
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19180, threshold: 0.44569
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19108, threshold: 0.44569
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19042, threshold: 0.44569
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18983, threshold: 0.44569
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18901, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18842, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18784, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18717, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18646, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18578, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18519, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18451, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18391, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18328, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18295, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18253, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18188, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18127, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18118, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18055, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18005, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17951, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17903, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17855, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17799, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17738, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17671, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17616, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17554, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17530, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17482, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17415, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17352, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17281, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17241, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17182, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17157, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17103, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17062, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17003, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16938, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16916, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16869, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16818, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16776, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16728, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16643, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16576, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16497, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16429, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16361, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16292, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16226, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16177, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16087, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16021, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15955, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15898, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15791, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15712, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15616, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15512, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15399, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15262, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15150, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14995, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14876, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14747, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14607, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14459, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14298, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14116, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13944, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13769, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13562, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13359, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13213, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13038, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12810, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12554, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12313, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12032, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11829, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11603, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11432, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11214, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10995, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10778, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10545, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10367, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10102, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09879, threshold: 0.39409
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09672, threshold: 0.39409
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09444, threshold: 0.39409
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09246, threshold: 0.39409
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09107, threshold: 0.37198
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08811, threshold: 0.37190
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08595, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08440, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08330, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08088, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07961, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07883, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07775, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07645, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07817, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07820, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08016, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08083, threshold: 0.37133
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08457, threshold: 0.37133
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09156, threshold: 0.37133
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09831, threshold: 0.37133
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10932, threshold: 0.37133
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12642, threshold: 0.37133
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15353, threshold: 0.36382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19535, threshold: 0.36382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.25331, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.33855, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.48993, threshold: 0.37092
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# Threshold: 0.7500000000000016 	Min a-dcf: 0.07645341506157632 	Min a-dcf threshold: 0.36816923726688733

# %%
min_index = np.unravel_index(np.nanargmin(all_a_dcf), all_a_dcf.shape)
point_x_index = min_index[0]
point_y_index = min_index[1]
cm_thresholds = np.array(np.arange(-1, 1.01, 0.01).tolist())
point_x_constrained = np.where(cm_thresholds == female_dev_cm_thr)[0][0]
point_y_constrained = np.nanargmin(np.array(all_a_dcf)[point_x_constrained])
heatmap_norm_adcf(list_aDCF_norm = np.array(all_a_dcf),cm_thresholds = cm_thresholds,sasv_thresholds = all_a_dcf_thresh,target_values =  [0,0.5,1],title ="Norm a-DCF - Female on Evaluation Set",point_x_index= point_x_index, point_y_index= point_y_index,point_x_constrained=point_x_constrained,point_y_constrained=point_y_constrained,value = None,defualt_show = 'female')

# %% [markdown]
# ### with pred of gender:

# %%
labels_eval_female_gender_classification = torch.Tensor(Eval_dataset_all.is_spoofed[gender_model.predict(Eval_dataset_all.data_for_gender_classification) == 0].values).cpu().numpy().copy()
total_data = torch.Tensor(Eval_dataset_all.data[gender_model.predict(Eval_dataset_all.data_for_gender_classification) == 0]).cpu().numpy().copy()
with torch.no_grad():
    model = model.to(device)
    output = spoof_model_female(torch.Tensor(total_data).to(device))
    _ , score_eval_female_gender_classification = spoof_model_female.loss(torch.Tensor(output).to(device),None)
    score_eval_female_gender_classification = -1*score_eval_female_gender_classification
    
score_eval_female_gender_classification = score_eval_female_gender_classification.cpu().numpy().copy()

eer, _ = my_functions.compute_eer(labels_eval_female_gender_classification,score_eval_female_gender_classification) # compute equal error rate

print(f"\tDev Female EER:({100*eer}%)")
# Out:
# 	Dev Female EER:(10.227090078299229%)

# %%
bonafide_score_cm_female_eval = score_eval_female_gender_classification[labels_eval_female_gender_classification == 0]
bonafide_score_cm_female_eval = -1*bonafide_score_cm_female_eval

spoof_score_cm_female_eval = score_eval_female_gender_classification[labels_eval_female_gender_classification == 1]
spoof_score_cm_female_eval  = -1*spoof_score_cm_female_eval

Prior_spoof = 0.05

target_scores_female_eval = results_eval.loc[(results_eval['asv_label'] ==  "target") & (results_eval['its_male'] == False) ]["asv_score_female"].values
nontarget_scores_female_eval = results_eval.loc[(results_eval['asv_label'] == "nontarget") & (results_eval['its_male'] == False) ]["asv_score_female"].values
spoof_scores_female_eval = results_eval.loc[(results_eval['asv_label'] ==  "spoof") & (results_eval['its_male'] == False)]["asv_score_female"].values

list_asv_score = [0.397,0.401]
type = 'constrained'
list_tDCF_norm_female_eval ,list_CM_thresholds_female_eval,list_tDCF_female_eval  = compute_t_dcf(bonafide_score_cm_female_eval,spoof_score_cm_female_eval,Prior_spoof,target_scores_female_eval,nontarget_scores_female_eval,spoof_scores_female_eval,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  2.95911 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  0.397
# the CM thresholds is:  [-0.82588501 -0.82488501 -0.82439852 ...  0.94250655  0.94292593
#   0.95455754]
# the CM threshold min is: 0.7508225440979004
# the tDCF_norm is: [1.         0.99997704 0.99995408 ... 2.9585515  2.95852854 2.95911253]
# the min tDCF_norm is: 0.29405488213702524
# the tDCF is: [0.31473445 0.31472722 0.31472    ... 0.93115808 0.93115085 0.93133465]
# the min tdcf is: 0.09254920138348616
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  2.98754 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv evaluation set  0.401
# the CM thresholds is:  [-0.82588501 -0.82488501 -0.82439852 ...  0.94250655  0.94292593
#   0.95455754]
# the CM threshold min is: 0.7508225440979004
# the tDCF_norm is: [1.         0.99997704 0.99995408 ... 2.98697429 2.98695132 2.98754093]
# the min tDCF_norm is: 0.2949525619352379
# the tDCF is: [0.31168056 0.3116734  0.31166625 ... 0.93098181 0.93097466 0.93115843]
# the min tdcf is: 0.09193097921308166

# %%
cm_filesname = Eval_dataset_all.name[gender_model.predict(Eval_dataset_all.data_for_gender_classification) == 0]
cm_scores = -1*score_eval_female_gender_classification.flatten()
asv_scores = results_eval.loc[(results_eval['its_male'] == False)]["asv_score_female"].values
asv_speakers =  results_eval.loc[(results_eval['its_male'] == False)]["speaker_id_female"].values
asv_filenames = results_eval.loc[(results_eval['its_male'] == False)]["file_name"].values
asv_labels = results_eval.loc[(results_eval['its_male'] == False)]["asv_label"].values
female_dev_cm_thr = 0.5100000000000013 
title = "Evaluation Set - Female - with gender classification  - min a-dcf vs CM Threshold"
adjusted_scores_female_eval, adjusted_labels_female_eval, adjusted_speakers_female_eval, adjusted_filename_female_eval, global_min_a_dcf_female_eval, global_min_a_dcf_thresh_female_eval,all_a_dcf,all_a_dcf_thresh = compute_a_dcf(cm_filesname, cm_scores, asv_speakers,asv_scores,asv_labels, asv_filenames,val_CM_threshold = female_dev_cm_thr, title = title,gender= 'female')
# Out:
# a-DCF: 0.29020, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.29020, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.29020, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.29020, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.29020, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.29020, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.29020, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.29020, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.29020, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.29020, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.29020, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.29020, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.29020, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.29020, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.29020, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.29020, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.29020, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.29020, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.29018, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.29012, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28985, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28914, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28784, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28560, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28289, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28023, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.27763, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.27503, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.27236, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.26940, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.26630, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.26256, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.25830, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.25410, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.24955, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.24544, threshold: 0.48386
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.24140, threshold: 0.47567
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.23729, threshold: 0.46919
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.23391, threshold: 0.46919
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.23042, threshold: 0.46919
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22783, threshold: 0.46919
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22508, threshold: 0.46919
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22250, threshold: 0.46919
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22026, threshold: 0.46919
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21834, threshold: 0.46919
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21664, threshold: 0.46919
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21476, threshold: 0.46919
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21323, threshold: 0.45595
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21185, threshold: 0.45595
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21059, threshold: 0.45595
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20942, threshold: 0.45595
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20826, threshold: 0.45590
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20728, threshold: 0.45590
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20635, threshold: 0.45590
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20550, threshold: 0.45590
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20467, threshold: 0.45590
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20385, threshold: 0.45590
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20306, threshold: 0.45590
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20227, threshold: 0.45590
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20153, threshold: 0.45590
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20077, threshold: 0.45590
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20024, threshold: 0.44569
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19968, threshold: 0.44569
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19899, threshold: 0.44569
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19821, threshold: 0.44569
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19754, threshold: 0.44569
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19698, threshold: 0.44569
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19635, threshold: 0.44569
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19568, threshold: 0.44569
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19501, threshold: 0.44569
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19439, threshold: 0.44569
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19381, threshold: 0.44569
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19309, threshold: 0.44569
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19239, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19177, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19092, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19033, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18973, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18905, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18833, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18764, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18704, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18635, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18575, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18510, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18478, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18435, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18369, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18307, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18297, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18233, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18181, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18127, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18078, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18029, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17972, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17910, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17843, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17787, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17725, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17701, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17652, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17583, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17520, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17448, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17407, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17347, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17321, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17266, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17225, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17165, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17099, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17076, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17029, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16978, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16936, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16887, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16801, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16733, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16655, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16586, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16521, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16454, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16386, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16339, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16248, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16183, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16120, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16067, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15964, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15888, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15795, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15693, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15584, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15454, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15345, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15191, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15072, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14950, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14818, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14669, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14516, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14338, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14169, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13998, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13791, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13591, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13446, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13268, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13040, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12787, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12548, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12270, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12070, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11846, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11674, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11453, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11232, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11009, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10777, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10596, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10328, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.10106, threshold: 0.39409
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09896, threshold: 0.39409
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09663, threshold: 0.39409
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09462, threshold: 0.39409
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09298, threshold: 0.39409
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08999, threshold: 0.37190
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08778, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08620, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08507, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08262, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08132, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08050, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07937, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07803, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07970, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07969, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08160, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08223, threshold: 0.37133
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08543, threshold: 0.37133
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09262, threshold: 0.37133
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09932, threshold: 0.37133
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11031, threshold: 0.37133
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12738, threshold: 0.37133
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15448, threshold: 0.36382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19606, threshold: 0.36382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.25379, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.33860, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.49008, threshold: 0.37092
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# Threshold: 0.7500000000000016 	Min a-dcf: 0.07803170662244306 	Min a-dcf threshold: 0.36816923726688733

# %%
min_index = np.unravel_index(np.nanargmin(all_a_dcf), all_a_dcf.shape)
point_x_index = min_index[0]
point_y_index = min_index[1]
cm_thresholds = np.array(np.arange(-1, 1.01, 0.01).tolist())
point_x_constrained = np.where(cm_thresholds == female_dev_cm_thr)[0][0]
point_y_constrained = np.nanargmin(np.array(all_a_dcf)[point_x_constrained])
heatmap_norm_adcf(list_aDCF_norm = np.array(all_a_dcf),cm_thresholds = cm_thresholds,sasv_thresholds = all_a_dcf_thresh,target_values =  [0,0.5,1],title ="Norm a-DCF - Female on Evaluation Set",point_x_index= point_x_index, point_y_index= point_y_index,point_x_constrained=point_x_constrained,point_y_constrained=point_y_constrained,value = None,defualt_show = 'female')

# %% [markdown]
# ## without Gender speration:

# %%
import torch
import torch.nn as nn
from utils.AMSloss import AdMSoftmaxLoss
from utils.OCSoftmaxloss import OCSoftmax
import torch.nn as nn

import torch.nn as nn
class SubChannelNetwork(nn.Module):
    def __init__(self, input_channel_size, output_channel_size):
        super(SubChannelNetwork, self).__init__()
        self.input_layer = nn.Linear(input_channel_size, output_channel_size)
        self.sigmoid = nn.Sigmoid()
        self.dropout = nn.Dropout(p=0.2)
        self.BN_4 = nn.BatchNorm1d(output_channel_size) 
   
    def forward(self, x):
        res = x
        x = self.input_layer(x)
        x = self.BN_4(x) 
        x = self.sigmoid(x)
        x = self.dropout(x)
        x = res + x 
        return x

class DNN(nn.Module):
    def __init__(self, input_channel_size, num_subnetworks, output_channel_size, final_output_size, r_real , r_fake,alpha):
        super(DNN, self).__init__()
        self.SubChannelNetwork = nn.ModuleList([
            SubChannelNetwork(input_channel_size, output_channel_size) for _ in range(num_subnetworks)
        ])
        self.fc_between_subnet = nn.Linear(num_subnetworks * output_channel_size,80)
        self.BN = nn.BatchNorm1d(80)
        self.fc = nn.Linear(80, final_output_size)
        self.sigmoid = nn.Sigmoid()
        self.droupout = nn.Dropout(p=0.2)
        self.r_real = r_real
        self.r_fake = r_fake
        self.alpha = alpha
        self.loss = OCSoftmax(feat_dim = final_output_size, r_real = self.r_real, r_fake = self.r_fake, alpha = self.alpha)
        self.optimizer = None
        self.scheduler = None
        
        
    def forward(self, x):
        subnetwork_outputs = [self.SubChannelNetwork[idx](x[:, idx*input_channel_size:(idx+1)*input_channel_size].to(device)) for idx in range(len(self.SubChannelNetwork))]
        combined_output = torch.cat(subnetwork_outputs, dim=1)
        x = self.fc_between_subnet(combined_output)    
        x = self.BN(x)
        x = self.sigmoid(x)
        x = self.droupout(x)
        output = self.fc(x)
        return output 
    
    @staticmethod
    def count_parameters(model):
        return sum(p.numel() for p in model.parameters() if p.requires_grad)


r_real = 0.9 
r_fake = 0.5
alpha = 20
input_channel_size = 10
output_channel_size = 10
num_SubChannelNetwork = 16
final_output_size = 16*2
model = DNN(input_channel_size, num_SubChannelNetwork, output_channel_size, final_output_size,r_real = r_real , r_fake = r_fake,alpha = alpha)
model = model.to(device)


model = model.to(device) # send the model to the device

models_folder = 'Deep_Learning_Codes/best_models/fixed order/models/'
model = pickle.load(open(models_folder + "male_and_female_2_neorun_end_OCS_both.pkl", 'rb'))

model.eval()

spoof_model = copy.deepcopy(model)

# %%
total_labels = torch.Tensor(Dev_dataset_all.is_spoofed.values).cpu().numpy().copy()
total_data = torch.Tensor(Dev_dataset_all.data_without_separation).cpu().numpy().copy()
with torch.no_grad():
    spoof_model = spoof_model.to(device)
    validation_output = spoof_model(torch.Tensor(total_data).to(device)).cpu()
    loss , validation_score = spoof_model.loss(torch.Tensor(validation_output).to(device),torch.LongTensor(total_labels).to(device))
    validation_score = -1*validation_score


test_score_total = validation_score.cpu().numpy().copy()

eer, test_thresh = my_functions.compute_eer(total_labels,test_score_total) # compute equal error rate
print(f"\tTest EER: ({100*eer}%) \tTest Threshold: {test_thresh}")
# Out:
# 	Test EER: (0.1076426264737441%) 	Test Threshold: -0.8789823616010454

# %%
total_labels = torch.Tensor(Eval_dataset_all.is_spoofed.values).cpu().numpy().copy()
total_data = torch.Tensor(Eval_dataset_all.data_without_separation).cpu().numpy().copy()
with torch.no_grad():
    spoof_model = spoof_model.to(device)
    test_output = spoof_model(torch.Tensor(total_data).to(device))
    _ , test_score = spoof_model.loss(torch.Tensor(test_output).to(device),torch.LongTensor(total_labels).to(device))
    test_score = -1*test_score
    
test_score_total = test_score.cpu().numpy().copy()

eer, test_thresh = my_functions.compute_eer(total_labels,test_score_total) # compute equal error rate


print(f"\tTest EER: ({100*eer}%) \tTest Threshold: {test_thresh}")
# Out:
# 	Test EER: (10.210740992543693%) 	Test Threshold: -0.9951076507568362

# %% [markdown]
# ## Dev:

# %%
from sklearn.metrics.pairwise import cosine_similarity
import torchaudio
import tqdm
from ASV_utils.config_thr import pmf_both_thr_spoof_val_all

txt_file_path = "output.txt"
csv_file_path = "output.csv"
enrollment_all  = enrollment_dev_male + enrollment_dev_female
list_files = file_name_according_speaker_id_dev
data_set = Dev_dataset_all
asv_model = classifier
spoof_labels = spoof_label_dev
list_speaker_id = speaker_id_list_dev
list_asv_label = asv_label_dev

#results_dev_without_gender = inference_system_cm_asv_avg_score_without_gender(spoof_labels,list_speaker_id,list_asv_label,txt_file_path,csv_file_path,pmf_both_thr_spoof_val_all,enrollment_all, list_files, data_set, spoof_model, asv_model, device, verbose = False, verbose_txt = False,verbose_csv = False)

# %%
import pickle
#with open('results_dev_without_gender_avg_score_both_asv_protocol.pkl', 'wb') as f:
#    pickle.dump(results_dev_without_gender,f)
    

import pickle
file_path = "./dcf_and_tdcf\dcf_avg_score/pmf_both_tdcf/asv_protocol/results_dev_without_gender_avg_score_both_asv_protocol.pkl"
with open(file_path, 'rb') as file:
    results_dev_without_gender = pickle.load(file)

# %%
labels_dev_without_gender = torch.Tensor(Dev_dataset_all.is_spoofed.values).cpu().numpy().copy()
total_data = torch.Tensor(Dev_dataset_all.data_without_separation).cpu().numpy().copy()
with torch.no_grad():
    spoof_model = spoof_model.to(device)
    output = spoof_model(torch.Tensor(total_data).to(device)).cpu()
    _ , score_dev_without_gender  = spoof_model.loss(torch.Tensor(output).to(device),None)
    score_dev_without_gender = -1*score_dev_without_gender


score_dev_without_gender = score_dev_without_gender.cpu().numpy().copy()

eer_dev_without_gender, _ = my_functions.compute_eer(labels_dev_without_gender,score_dev_without_gender) # compute equal error rate
print(f"\tTest EER: ({100*eer_dev_without_gender}%)")
# Out:
# 	Test EER: (0.1076426264737441%)

# %%
from ASV_utils.tdcf_functions import compute_t_dcf
gender = 'male'

check_male =(results_dev_without_gender['speaker_id'].isin(['LA_0073', 'LA_0071', 'LA_0070', 'LA_0076']))


bonafide_score_cm = score_dev_without_gender[(labels_dev_without_gender == 0) & (Dev_dataset_all.sex == gender)]
bonafide_score_cm = -1*bonafide_score_cm

spoof_score_cm = score_dev_without_gender[(labels_dev_without_gender == 1) & (Dev_dataset_all.sex == gender)]
spoof_score_cm = -1*spoof_score_cm

Prior_spoof = 0.05

target_scores = results_dev_without_gender.loc[(results_dev_without_gender['asv_label'] == "target") & check_male]["asv_score"].values
nontarget_scores = results_dev_without_gender.loc[(results_dev_without_gender['asv_label'] == "nontarget")  & check_male]["asv_score"].values
spoof_scores = results_dev_without_gender.loc[(results_dev_without_gender['asv_label'] ==  "spoof")  & check_male]["asv_score"].values

list_asv_score = [0.375]
type = 'constrained'
list_tDCF_norm_without_gender ,list_CM_thresholds_without_gender,list_tDCF_without_gender  = compute_t_dcf(bonafide_score_cm,spoof_score_cm,Prior_spoof,target_scores,nontarget_scores,spoof_scores,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  5.11547 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  0.375
# the CM thresholds is:  [-0.99752004 -0.99652004 -0.99635762 ...  0.99956161  0.99958646
#   0.9996103 ]
# the CM threshold min is: 0.7412421703338623
# the tDCF_norm is: [1.         0.99986472 0.99972944 ... 5.10368303 5.10957643 5.11546983]
# the min tDCF_norm is: 0.0012175324675324675
# the tDCF is: [0.17958604 0.17956174 0.17953745 ... 0.91655022 0.91760859 0.91866696]
# the min tdcf is: 0.00021865183315061563

# %%
gender = 'female'
check_female =(results_dev_without_gender['speaker_id'].isin(['LA_0078','LA_0075','LA_0074','LA_0072','LA_0077','LA_0069']))



bonafide_score_cm = score_dev_without_gender[(labels_dev_without_gender == 0) & (Dev_dataset_all.sex == gender)]
bonafide_score_cm = -1*bonafide_score_cm

spoof_score_cm = score_dev_without_gender[(labels_dev_without_gender == 1) & (Dev_dataset_all.sex == gender)]
spoof_score_cm = -1*spoof_score_cm

Prior_spoof = 0.05

target_scores = results_dev_without_gender.loc[(results_dev_without_gender['asv_label'] == "target") & check_female]["asv_score"].values
nontarget_scores = results_dev_without_gender.loc[(results_dev_without_gender['asv_label'] == "nontarget")  & check_female]["asv_score"].values
spoof_scores = results_dev_without_gender.loc[(results_dev_without_gender['asv_label'] ==  "spoof")  & check_female]["asv_score"].values

list_asv_score = [0.375]
type = 'constrained'
list_tDCF_norm_without_gender ,list_CM_thresholds_without_gender,list_tDCF_without_gender  = compute_t_dcf(bonafide_score_cm,spoof_score_cm,Prior_spoof,target_scores,nontarget_scores,spoof_scores,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  4.69769 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  0.375
# the CM thresholds is:  [-0.99801869 -0.99701869 -0.99699306 ...  0.99943107  0.99950331
#   0.99964386]
# the CM threshold min is: 0.7436689138412476
# the tDCF_norm is: [1.         0.9999329  0.99986581 ... 4.69209416 4.6948904  4.69768664]
# the min tDCF_norm is: 0.001878690284487386
# the tDCF is: [0.19833602 0.19832271 0.1983094  ... 0.93061127 0.93116586 0.93172046]
# the min tdcf is: 0.00037261194853359587

# %%
from ASV_utils.tdcf_functions import compute_t_dcf

bonafide_score_cm = score_dev_without_gender[labels_dev_without_gender == 0]
bonafide_score_cm = -1*bonafide_score_cm

spoof_score_cm = score_dev_without_gender[labels_dev_without_gender == 1]
spoof_score_cm = -1*spoof_score_cm

Prior_spoof = 0.05

target_scores = results_dev_without_gender.loc[results_dev_without_gender['asv_label'] == "target"]["asv_score"].values
nontarget_scores = results_dev_without_gender.loc[results_dev_without_gender['asv_label'] == "nontarget"]["asv_score"].values
spoof_scores = results_dev_without_gender.loc[results_dev_without_gender['asv_label'] ==  "spoof"]["asv_score"].values

list_asv_score = [0.375]
type = 'constrained'
list_tDCF_norm_without_gender ,list_CM_thresholds_without_gender,list_tDCF_without_gender  = compute_t_dcf(bonafide_score_cm,spoof_score_cm,Prior_spoof,target_scores,nontarget_scores,spoof_scores,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  4.82264 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  0.375
# the CM thresholds is:  [-0.99801869 -0.99701869 -0.99699306 ...  0.99958646  0.9996103
#   0.99964386]
# the CM threshold min is: 0.7436689138412476
# the tDCF_norm is: [1.         0.99995515 0.9999103  ... 4.81885292 4.82074564 4.82263835]
# the min tDCF_norm is: 0.0016594904915679942
# the tDCF is: [0.19211966 0.19211105 0.19210243 ... 0.9257964  0.92616003 0.92652365]
# the min tdcf is: 0.000318820753526709

# %%
results_dev_without_gender
# Out:
#           file_name  its_spoof  spoof_score  spoof_ground_truth  asv_score
# 0      LA_D_4004968      False    -0.999041               False   0.561741  \
# 1      LA_D_6027798      False    -0.999023               False   0.703008
# 2      LA_D_3986002      False    -0.998454               False   0.675328
# 3      LA_D_9330492      False    -0.998825               False   0.539661
# 4      LA_D_1364611      False    -0.998916               False   0.506510
# ...             ...        ...          ...                 ...        ...
# 29543  LA_D_6306347       True     0.973411                True   0.214340
# 29544  LA_D_3133630       True     0.983333                True   0.155820
# 29545  LA_D_9909170       True     0.973568                True   0.072316
# 29546  LA_D_3790932       True     0.991438                True   0.182552
# 29547  LA_D_3387040       True     0.955417                True   0.235617
#
#       speaker_id  find_speaker_in_enroll asv_label attack_type  in_cm_protocol
# 0        LA_0073                    True    target        none            True
# 1        LA_0073                    True    target        none            True
# 2        LA_0073                    True    target        none            True
# 3        LA_0073                    True    target        none            True
# 4        LA_0073                    True    target        none            True
# ...          ...                     ...       ...         ...             ...
# 29543    LA_0069                    True     spoof         A06            True
# 29544    LA_0069                    True     spoof         A05            True
# 29545    LA_0069                    True     spoof         A06            True
# 29546    LA_0069                    True     spoof         A05            True
# 29547    LA_0069                    True     spoof         A06            True
#
# [29548 rows x 10 columns]

# %%
cm_filesname = Dev_dataset_all.name
cm_scores = -1*score_dev_without_gender.flatten()
asv_scores = results_dev_without_gender["asv_score"].values
asv_speakers =  results_dev_without_gender["speaker_id"].values
asv_filenames = results_dev_without_gender["file_name"].values
asv_labels = results_dev_without_gender["asv_label"].values
title = "Development Set - Male & Female - min a-dcf vs CM Threshold"
adjusted_scores_dev_without_gender, adjusted_labels_dev_without_gender, adjusted_speakers_dev_without_gender, adjusted_filename_dev_without_gender, global_min_a_dcf_dev_without_gender, global_min_a_dcf_thresh_dev_without_gender,all_a_dcf,all_a_dcf_thresh = compute_a_dcf(cm_filesname, cm_scores, asv_speakers,asv_scores,asv_labels, asv_filenames,title = title,gender= 'female')
# Out:
# a-DCF: 0.18634, threshold: 0.43819
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14346, threshold: 0.43352
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08924, threshold: 0.39268
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06598, threshold: 0.37567
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.05080, threshold: 0.37567
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.04033, threshold: 0.37567
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03331, threshold: 0.36235
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02853, threshold: 0.36230
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02559, threshold: 0.36230
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02325, threshold: 0.31395
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02063, threshold: 0.31395
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01855, threshold: 0.31395
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01691, threshold: 0.31360
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01576, threshold: 0.31360
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01464, threshold: 0.31360
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01358, threshold: 0.30593
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01263, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01209, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01153, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01086, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01032, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00987, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00956, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00915, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00886, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00859, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00839, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00817, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00792, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00756, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00738, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00720, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00711, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00696, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00684, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00678, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00673, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00662, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00649, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00637, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00622, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00610, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00595, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00588, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00583, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00577, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00572, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00572, threshold: 0.28438
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00570, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00566, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00559, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00552, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00545, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00541, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00536, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00536, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00534, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00534, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00532, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00527, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00523, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00521, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00514, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00507, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00500, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00496, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00496, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00494, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00492, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00487, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00485, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00485, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00483, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00483, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00478, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00469, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00469, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00467, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00465, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00465, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00460, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00460, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00456, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00453, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00449, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00449, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00449, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00449, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00444, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00442, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00435, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00433, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00429, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00426, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00426, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00424, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00422, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00422, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00418, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00418, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00415, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00413, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00413, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00411, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00406, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00404, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00404, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00400, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00391, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00391, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00388, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00388, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00388, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00384, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00384, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00379, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00375, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00375, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00373, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00373, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00370, threshold: 0.28359
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00368, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00368, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00366, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00364, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00361, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00359, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00357, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00355, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00355, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00355, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00352, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00350, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00350, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00350, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00348, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00348, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00346, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00346, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00341, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00339, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00335, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00335, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00335, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00335, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00335, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00335, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00332, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00332, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00330, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00328, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00323, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00323, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00319, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00319, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00314, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00314, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00314, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00314, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00312, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00310, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00308, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00308, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00305, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00305, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00299, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00296, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00296, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00296, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00296, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00292, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00290, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00287, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00283, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00281, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00278, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00278, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00278, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00278, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00278, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00337, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00337, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00333, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00331, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00328, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00326, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00324, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00322, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00319, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00376, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00374, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00369, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00365, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00360, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00356, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00349, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00410, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00469, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.00659, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01230, threshold: 0.28275
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# Threshold: 0.7500000000000016 	Min a-dcf: 0.002784825273244374 	Min a-dcf threshold: 0.2827546081759713

# %%
min_index = np.unravel_index(np.nanargmin(all_a_dcf), all_a_dcf.shape)
point_x_index = min_index[0]
point_y_index = min_index[1]

heatmap_norm_adcf(list_aDCF_norm = np.array(all_a_dcf),cm_thresholds = np.array(np.arange(0, 1.01, 0.01).tolist()),sasv_thresholds = all_a_dcf_thresh,target_values =  [0,0.5,1],title ="Norm a-DCF - Male & Female on Development Set",point_x_index= point_x_index, point_y_index= point_y_index,point_x_constrained=None,point_y_constrained=None,value = None,defualt_show = 'female')

# %% [markdown]
# ## Eval:

# %%
from sklearn.metrics.pairwise import cosine_similarity
import torchaudio
import tqdm
from ASV_utils.config_thr import pmf_both_thr_spoof_test_all

txt_file_path = "output.txt"
csv_file_path = "output.csv"
enrollment_all  = enrollment_eval_male + enrollment_eval_female
list_files = file_name_according_speaker_id_eval
data_set = Eval_dataset_all
asv_model = classifier
spoof_labels = spoof_label_eval
list_speaker_id = speaker_id_list_eval
list_asv_label = asv_label_eval

#results_eval_without_gender = inference_system_cm_asv_avg_score_without_gender(spoof_labels,list_speaker_id,list_asv_label,txt_file_path,csv_file_path,pmf_both_thr_spoof_test_all,enrollment_all, list_files, data_set, spoof_model, asv_model, device, verbose = False, verbose_txt = False,verbose_csv = False)

# %%
import pickle
file_path = "./dcf_and_tdcf\dcf_avg_score/pmf_both_tdcf/asv_protocol/results_eval_without_gender_avg_score_both_asv_protocol.pkl"
with open(file_path, 'rb') as file:
    results_eval_without_gender = pickle.load(file)

# %%
labels_eval_without_gender = torch.Tensor(Eval_dataset_all.is_spoofed.values).cpu().numpy().copy()
total_data = torch.Tensor(Eval_dataset_all.data_without_separation).cpu().numpy().copy()
with torch.no_grad():
    spoof_model = spoof_model.to(device)
    output = spoof_model(torch.Tensor(total_data).to(device))
    _ , score_eval_without_gender = spoof_model.loss(torch.Tensor(output).to(device),None)
    score_eval_without_gender = -1*score_eval_without_gender
    
score_eval_without_gender = score_eval_without_gender.cpu().numpy().copy()

eer_eval_without_gender, _ = my_functions.compute_eer(labels_eval_without_gender,score_eval_without_gender) # compute equal error rate


print(f"\tTest EER: ({100*eer_eval_without_gender}%)")
# Out:
# 	Test EER: (10.210740992543693%)

# %%
def read_text_file(file_path):
    try:
        with open(file_path, 'r',) as file:
            lines = file.readlines()
            split_lines = [line.strip().split(' ')[0] for line in lines]
        return split_lines
    except FileNotFoundError:
        print("Error: File not found.")
        return None
    except Exception as e:
        print(f"Error: {e}")
        return None


file_path = "./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.eval.male.trn.txt"
possible_speakers_male = read_text_file(file_path)

file_path = "./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.eval.female.trn.txt"
possible_speakers_female = read_text_file(file_path)

# %%
from ASV_utils.tdcf_functions import compute_t_dcf
gender = 'male'

check_male =(results_eval_without_gender['speaker_id'].isin(possible_speakers_male))


bonafide_score_cm = score_eval_without_gender[(labels_eval_without_gender == 0) & (Eval_dataset_all.sex == gender)]
bonafide_score_cm = -1*bonafide_score_cm

spoof_score_cm = score_eval_without_gender[(labels_eval_without_gender == 1) & (Eval_dataset_all.sex == gender)]
spoof_score_cm = -1*spoof_score_cm

Prior_spoof = 0.05

target_scores = results_eval_without_gender.loc[(results_eval_without_gender['asv_label'] == "target") & check_male]["asv_score"].values
nontarget_scores = results_eval_without_gender.loc[(results_eval_without_gender['asv_label'] == "nontarget")  & check_male]["asv_score"].values
spoof_scores = results_eval_without_gender.loc[(results_eval_without_gender['asv_label'] ==  "spoof")  & check_male]["asv_score"].values

list_asv_score = [0.384]
type = 'constrained'
list_tDCF_norm_without_gender ,list_CM_thresholds_without_gender,list_tDCF_without_gender  = compute_t_dcf(bonafide_score_cm,spoof_score_cm,Prior_spoof,target_scores,nontarget_scores,spoof_scores,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  2.83051 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  0.384
# the CM thresholds is:  [-0.99685462 -0.99585462 -0.99558783 ...  0.99955177  0.99956244
#   0.99958259]
# the CM threshold min is: 0.9851580262184143
# the tDCF_norm is: [1.         0.99994912 0.99989825 ... 2.82802851 2.82926833 2.83050815]
# the min tDCF_norm is: 0.3223897326861755
# the tDCF is: [0.32801689 0.3280002  0.32798351 ... 0.92764112 0.9280478  0.92845448]
# the min tdcf is: 0.10574927765029084

# %%
gender = 'female'
check_female =(results_eval_without_gender['speaker_id'].isin(possible_speakers_female))



bonafide_score_cm = score_eval_without_gender[(labels_eval_without_gender == 0) &  (Eval_dataset_all.sex == gender)]
bonafide_score_cm = -1*bonafide_score_cm

spoof_score_cm = score_eval_without_gender[(labels_eval_without_gender == 1) &  (Eval_dataset_all.sex == gender)]
spoof_score_cm = -1*spoof_score_cm

Prior_spoof = 0.05

target_scores = results_eval_without_gender.loc[(results_eval_without_gender['asv_label'] == "target") & check_female]["asv_score"].values
nontarget_scores = results_eval_without_gender.loc[(results_eval_without_gender['asv_label'] == "nontarget")  & check_female]["asv_score"].values
spoof_scores = results_eval_without_gender.loc[(results_eval_without_gender['asv_label'] ==  "spoof")  & check_female]["asv_score"].values

list_asv_score = [0.384]
type = 'constrained'
list_tDCF_norm_without_gender ,list_CM_thresholds_without_gender,list_tDCF_without_gender  = compute_t_dcf(bonafide_score_cm,spoof_score_cm,Prior_spoof,target_scores,nontarget_scores,spoof_scores,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=5072, Nspoof=44226] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  2.90121 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  0.384
# the CM thresholds is:  [-0.99741258 -0.99641258 -0.99634379 ...  0.99961841  0.99963832
#   0.99964005]
# the CM threshold min is: 0.9918527603149414
# the tDCF_norm is: [1.         0.99997739 0.99995478 ... 2.9000658  2.9006378  2.90120981]
# the min tDCF_norm is: 0.3123132742953533
# the tDCF is: [0.32182427 0.32181699 0.32180971 ... 0.93331155 0.93349563 0.93367972]
# the min tdcf is: 0.10050999034608069

# %%
from ASV_utils.tdcf_functions import compute_t_dcf
gender = 'all'
bonafide_score_cm = score_eval_without_gender[labels_eval_without_gender == 0]
bonafide_score_cm = -1*bonafide_score_cm

spoof_score_cm = score_eval_without_gender[labels_eval_without_gender == 1]
spoof_score_cm = -1*spoof_score_cm

Prior_spoof = 0.05

target_scores = results_eval_without_gender.loc[results_eval_without_gender['asv_label'] == "target"]["asv_score"].values
nontarget_scores = results_eval_without_gender.loc[results_eval_without_gender['asv_label'] == "nontarget"]["asv_score"].values
spoof_scores = results_eval_without_gender.loc[results_eval_without_gender['asv_label'] ==  "spoof"]["asv_score"].values

list_asv_score = [0.375,0.384]
type = 'constrained'
list_tDCF_norm_without_gender ,list_CM_thresholds_without_gender,list_tDCF_without_gender  = compute_t_dcf(bonafide_score_cm,spoof_score_cm,Prior_spoof,target_scores,nontarget_scores,spoof_scores,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  2.83829 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  0.375
# the CM thresholds is:  [-0.99741258 -0.99641258 -0.99634379 ...  0.99961841  0.99963832
#   0.99964005]
# the CM threshold min is: 0.9907342791557312
# the tDCF_norm is: [1.         0.99998435 0.99996869 ... 2.83751952 2.83790542 2.83829132]
# the min tDCF_norm is: 0.3161699221278934
# the tDCF is: [0.32898156 0.32897641 0.32897126 ... 0.9334916  0.93361855 0.93374551]
# the min tdcf is: 0.10401407412792035
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  2.88010 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv evaluation set  0.384
# the CM thresholds is:  [-0.99741258 -0.99641258 -0.99634379 ...  0.99961841  0.99963832
#   0.99964005]
# the CM threshold min is: 0.989303469657898
# the tDCF_norm is: [1.         0.99998435 0.99996869 ... 2.87931872 2.8797103  2.88010188]
# the min tDCF_norm is: 0.3178631686463419
# the tDCF is: [0.32372969 0.32372462 0.32371955 ... 0.93212095 0.93224772 0.93237449]
# the min tdcf is: 0.102901744766768

# %%
results_eval_without_gender
# Out:
#            file_name  its_spoof  spoof_score  spoof_ground_truth  asv_score
# 0       LA_E_1103494      False    -0.998118               False   0.607649  \
# 1       LA_E_4861467      False    -0.998306               False   0.652226
# 2       LA_E_6229989      False    -0.998424               False   0.645379
# 3       LA_E_4483232      False    -0.998880               False   0.710620
# 4       LA_E_3110493      False    -0.999037               False   0.564846
# ...              ...        ...          ...                 ...        ...
# 102574  LA_E_6346294      False    -0.996954                True   0.276046
# 102575  LA_E_4892925       True     0.978704                True   0.260937
# 102576  LA_E_4102704      False    -0.996466                True   0.218130
# 102577  LA_E_4796101       True    -0.966712                True   0.287498
# 102578  LA_E_1174268       True     0.920937                True   0.403238
#
#        speaker_id  find_speaker_in_enroll asv_label attack_type
# 0         LA_0015                    True    target        none  \
# 1         LA_0015                    True    target        none
# 2         LA_0015                    True    target        none
# 3         LA_0015                    True    target        none
# 4         LA_0015                    True    target        none
# ...           ...                     ...       ...         ...
# 102574    LA_0020                    True     spoof         A18
# 102575    LA_0020                    True     spoof         A19
# 102576    LA_0020                    True     spoof         A17
# 102577    LA_0020                    True     spoof         A18
# 102578    LA_0020                    True     spoof         A19
#
#         in_cm_protocol
# 0                 True
# 1                 True
# 2                 True
# 3                 True
# 4                 True
# ...                ...
# 102574            True
# 102575            True
# 102576            True
# 102577            True
# 102578            True
#
# [102579 rows x 10 columns]

# %%
cm_filesname = Eval_dataset_all.name
cm_scores = -1*score_eval_without_gender.flatten()
asv_scores = results_eval_without_gender["asv_score"].values
asv_speakers =  results_eval_without_gender["speaker_id"].values
asv_filenames = results_eval_without_gender["file_name"].values
asv_labels = results_eval_without_gender["asv_label"].values
title = "Evaluation Set - Male & Female - min a-dcf vs CM Threshold"
val_thr = 0.9500000000000017 
adjusted_scores_eval_without_gender, adjusted_labels_eval_without_gender, adjusted_speakers_eval_without_gender, adjusted_filename_eval_without_gender, global_min_a_dcf_eval_without_gender, global_min_a_dcf_thresh_eval_without_gender,all_a_dcf,all_a_dcf_thresh = compute_a_dcf(cm_filesname, cm_scores, asv_speakers,asv_scores,asv_labels, asv_filenames,title = title, val_CM_threshold = val_thr,gender= 'female')
# Out:
# a-DCF: 0.29709, threshold: 0.48416
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.29068, threshold: 0.48416
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.26227, threshold: 0.48416
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.23589, threshold: 0.45480
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22051, threshold: 0.44558
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21050, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20404, threshold: 0.43838
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19996, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19704, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19475, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19300, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19169, threshold: 0.43836
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19039, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18938, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18853, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18774, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18712, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18651, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18607, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18568, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18522, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18475, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18437, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18399, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18368, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18343, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18309, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18288, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18261, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18233, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18208, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18186, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18158, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18135, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18113, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18089, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18064, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18044, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18022, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18007, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17990, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17970, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17959, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17944, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17932, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17931, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17918, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17923, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17907, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17892, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17876, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17862, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17853, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17833, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17821, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17809, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17798, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17785, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17777, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17763, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17750, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17735, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17727, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17729, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17715, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17700, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17686, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17677, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17668, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17663, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17656, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17647, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17645, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17632, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17622, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17611, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17599, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17589, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17578, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17570, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17563, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17554, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17543, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17534, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17525, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17514, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17507, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17497, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17491, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17483, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17473, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17470, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17461, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17446, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17440, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17433, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17421, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17413, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17403, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17394, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17384, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17375, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17366, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17357, threshold: 0.43556
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17348, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17338, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17330, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17318, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17307, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17295, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17286, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17282, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17270, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17261, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17250, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17238, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17228, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17222, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17216, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17206, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17195, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17185, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17174, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17163, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17170, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17157, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17145, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17139, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17131, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17117, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17105, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17096, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17085, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17075, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17065, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17058, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17043, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17031, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17017, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17004, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16995, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16985, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16974, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16960, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16950, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16943, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16933, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16921, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16912, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16916, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16901, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16885, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16867, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16855, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16835, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16817, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16793, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16772, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16763, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16741, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16726, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16706, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16686, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16654, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16629, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16607, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16576, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16557, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16535, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16511, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16487, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16461, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16434, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16405, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16377, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16344, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16308, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16266, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16222, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16192, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16136, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16096, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16042, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16000, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15954, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15902, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15868, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15818, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15722, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15621, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15488, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15334, threshold: 0.42871
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15133, threshold: 0.40201
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14945, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14620, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14220, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.13708, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12994, threshold: 0.40120
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11760, threshold: 0.36817
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.09990, threshold: 0.36382
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# Threshold: 0.9900000000000018 	Min a-dcf: 0.09989535997299472 	Min a-dcf threshold: 0.36382288282567804

# %%
min_index = np.unravel_index(np.nanargmin(all_a_dcf), all_a_dcf.shape)
point_x_index = min_index[0]
point_y_index = min_index[1]
cm_thresholds = np.array(np.arange(-1, 1.01, 0.01).tolist())
point_x_constrained = np.where(cm_thresholds == val_thr)[0][0]
point_y_constrained = np.nanargmin(np.array(all_a_dcf)[point_x_constrained])
heatmap_norm_adcf(list_aDCF_norm = np.array(all_a_dcf),cm_thresholds = cm_thresholds,sasv_thresholds = all_a_dcf_thresh,target_values =  [0,0.5,1],title ="Norm a-DCF - Male & Female on Evaluation Set",point_x_index= point_x_index, point_y_index= point_y_index,point_x_constrained=point_x_constrained,point_y_constrained=point_y_constrained,value = None,defualt_show = 'female')

# %% [markdown]
# ### read from ASVspoof2019 scores:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import utils.eval_metrics as eval_metrics 
def read_txt_ASV2019_scores(file_path):
    is_spoofed = []
    label = []
    score = []
    with open(file_path, 'r') as file:
        for line in file:
            parts = line.strip().split(' ')
            if len(parts) != 3:
                raise Exception("The line in the file is not in the right format")
            is_spoofed.append(parts[0])
            label.append(parts[1])
            score.append(parts[2])
            
    return pd.Series(is_spoofed), pd.Series(label), pd.Series(score)

# %% [markdown]
# ### Dev

# %%
file_path ="./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.dev.gi.trl.scores.txt"
 
ASV2019_attack_type ,ASV2019_label,ASV2019_scores  = read_txt_ASV2019_scores(file_path)

bonafide_score_cm = score_dev_without_gender[labels_dev_without_gender == 0]
bonafide_score_cm = -1*bonafide_score_cm

spoof_score_cm = score_dev_without_gender[labels_dev_without_gender == 1]
spoof_score_cm = -1*spoof_score_cm

Prior_spoof = 0.05

ASV2019_target_scores = ASV2019_scores.loc[ASV2019_label == "target"].astype(float)
ASV2019_nontarget_scores = ASV2019_scores.loc[ASV2019_label == "nontarget"].astype(float)
ASV2019_spoof_scores = ASV2019_scores.loc[ASV2019_label == "spoof"].astype(float)

ASV2019_eer_scores_dev,ASV2019_thr_eer_scores_dev,_,_ = eval_metrics.compute_eer(ASV2019_target_scores.values.astype(float),ASV2019_nontarget_scores.values.astype(float))

list_asv_score = [ASV2019_thr_eer_scores_dev]
type = 'constrained'
list_tDCF_norm_without_gender ,list_CM_thresholds_without_gender,list_tDCF_without_gender = compute_t_dcf(bonafide_score_cm,spoof_score_cm,Prior_spoof,ASV2019_target_scores,ASV2019_nontarget_scores,ASV2019_spoof_scores,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  2.40799 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  -3.548998
# the CM thresholds is:  [-0.99801869 -0.99701869 -0.99699306 ...  0.99958646  0.9996103
#   0.99964386]
# the CM threshold min is: 0.7436689138412476
# the tDCF_norm is: [1.         0.99995515 0.9999103  ... 2.40609984 2.40704489 2.40798994]
# the min tDCF_norm is: 0.0016594904915679942
# the tDCF is: [0.38013545 0.3801184  0.38010135 ... 0.91464385 0.91500309 0.91536234]
# the min tdcf is: 0.0006308311652890444

# %%
cm_filesname = Dev_dataset_all.name
cm_scores = -1*score_dev_without_gender.flatten()
asv_scores = ASV2019_scores
asv_speakers =  results_dev_without_gender["speaker_id"].values
asv_filenames = results_dev_without_gender["file_name"].values
asv_labels = ASV2019_label
title = "Development Set - Male & Female - ASV ASVSpoof2019  - min a-dcf vs CM Threshold"
adjusted_scores_dev_without_gender2, adjusted_labels_dev_without_gender, adjusted_speakers_dev_without_gender2, adjusted_filename_dev_without_gender2, global_min_a_dcf_dev_without_gender2, global_min_a_dcf_thresh_dev_without_gender2,all_a_dcf,all_a_dcf_thresh = compute_a_dcf(cm_filesname, cm_scores, asv_speakers,asv_scores,asv_labels, asv_filenames,title = title,gender= 'female')
# Out:
# a-DCF: 0.35706, threshold: 6.83363
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28554, threshold: 5.98618
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19459, threshold: 0.31796
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14688, threshold: -0.88591
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.11179, threshold: -2.84202
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.08712, threshold: -2.84202
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.07232, threshold: -2.84202
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.06228, threshold: -6.19196
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.05560, threshold: -6.19196
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.05033, threshold: -6.19196
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.04582, threshold: -6.19196
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.04259, threshold: -6.19196
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.04014, threshold: -6.19196
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03815, threshold: -6.19196
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03631, threshold: -6.19196
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03480, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03350, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03249, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03143, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.03038, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02948, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02872, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02811, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02760, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02708, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02666, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02632, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02589, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02560, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02511, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02486, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02459, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02444, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02424, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02401, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02394, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02385, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02367, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02347, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02329, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02307, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02291, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02271, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02262, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02258, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02251, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02244, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02240, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02233, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02222, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02210, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02202, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02195, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02190, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02184, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02179, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02175, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02172, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02170, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02166, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02159, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02157, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02150, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02143, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02132, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02127, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02125, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02119, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02110, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02105, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02103, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02103, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02101, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02101, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02096, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02083, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02080, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02071, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02069, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02067, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02053, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02051, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02047, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02045, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02040, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02040, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02040, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02040, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02033, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02029, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02027, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02022, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02018, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02013, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02013, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02011, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02009, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02002, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01997, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01997, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01995, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01993, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01993, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01991, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01984, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01982, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01982, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01977, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01968, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01968, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01964, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01964, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01964, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01959, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01959, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01953, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01944, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01944, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01941, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01939, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01937, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01932, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01932, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01930, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01926, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01923, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01921, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01917, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01914, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01910, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01910, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01908, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01905, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01905, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01905, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01903, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01901, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01899, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01899, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01894, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01892, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01885, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01885, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01885, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01885, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01881, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01879, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01876, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01874, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01872, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01870, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01861, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01861, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01856, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01854, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01847, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01845, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01843, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01840, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01838, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01836, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01831, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01831, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01829, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01829, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01823, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01820, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01820, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01820, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01820, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01816, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01814, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01811, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01805, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01800, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01796, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01796, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01796, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01796, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01796, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01791, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01789, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01784, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01782, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01780, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01775, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01771, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01769, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01766, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01823, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01821, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01816, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01810, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01803, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01796, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01789, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01851, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.01907, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02161, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.02727, threshold: -13.84311
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# Threshold: 0.8800000000000017 	Min a-dcf: 0.017664465978290574 	Min a-dcf threshold: -13.84311

# %%
min_index = np.unravel_index(np.nanargmin(all_a_dcf), all_a_dcf.shape)
point_x_index = min_index[0]
point_y_index = min_index[1]

heatmap_norm_adcf(list_aDCF_norm = np.array(all_a_dcf),cm_thresholds = np.array(np.arange(-1, 1.01, 0.01).tolist()),sasv_thresholds = all_a_dcf_thresh,target_values =  [0,0.5,1],title ="Norm a-DCF - Male & Female on Development Set",point_x_index= point_x_index, point_y_index= point_y_index,point_x_constrained=None,point_y_constrained=None,value = None,defualt_show = 'female')

# %% [markdown]
# ### Eval

# %%
file_path ="./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.eval.gi.trl.scores.txt"
 
ASV2019_attack_type ,ASV2019_label,ASV2019_scores  = read_txt_ASV2019_scores(file_path)

bonafide_score_cm = score_eval_without_gender[labels_eval_without_gender == 0]
bonafide_score_cm = -1*bonafide_score_cm

spoof_score_cm = score_eval_without_gender[labels_eval_without_gender == 1]
spoof_score_cm = -1*spoof_score_cm

Prior_spoof = 0.05

ASV2019_target_scores = ASV2019_scores.loc[ASV2019_label == "target"].astype(float)
ASV2019_nontarget_scores = ASV2019_scores.loc[ASV2019_label == "nontarget"].astype(float)
ASV2019_spoof_scores = ASV2019_scores.loc[ASV2019_label == "spoof"].astype(float)

ASV2019_eer_scores_eval,ASV2019_thr_eer_scores_eval,_,_ = eval_metrics.compute_eer(ASV2019_target_scores.values.astype(float),ASV2019_nontarget_scores.values.astype(float))


list_asv_score = [ASV2019_thr_eer_scores_dev,ASV2019_thr_eer_scores_eval]
type = 'constrained'
list_tDCF_norm_without_gender ,list_CM_thresholds_without_gender,list_tDCF_without_gender  = compute_t_dcf(bonafide_score_cm,spoof_score_cm,Prior_spoof,ASV2019_target_scores,ASV2019_nontarget_scores,ASV2019_spoof_scores,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  2.43442 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  -3.548998
# the CM thresholds is:  [-0.99741258 -0.99641258 -0.99634379 ...  0.99961841  0.99963832
#   0.99964005]
# the CM threshold min is: 0.9918527603149414
# the tDCF_norm is: [1.         0.99998435 0.99996869 ... 2.43376118 2.43409217 2.43442316]
# the min tDCF_norm is: 0.29702179473283996
# the tDCF is: [0.37195924 0.37195341 0.37194759 ... 0.90525995 0.90538307 0.90550618]
# the min tdcf is: 0.11048000024332952
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  2.40595 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv evaluation set  -5.680051
# the CM thresholds is:  [-0.99741258 -0.99641258 -0.99634379 ...  0.99961841  0.99963832
#   0.99964005]
# the CM threshold min is: 0.9918527603149414
# the tDCF_norm is: [1.         0.99998435 0.99996869 ... 2.40529113 2.40561824 2.40594536]
# the min tDCF_norm is: 0.29564339967363423
# the tDCF is: [0.38032623 0.38032027 0.38031432 ... 0.9147953  0.91491971 0.91504412]
# the min tdcf is: 0.11244093858161325

# %%
cm_filesname = Eval_dataset_all.name
cm_scores = -1*score_eval_without_gender.flatten()
asv_scores = ASV2019_scores
asv_speakers =  results_eval_without_gender["speaker_id"].values
asv_filenames = results_eval_without_gender["file_name"].values
asv_labels = ASV2019_label
title = "Evaluation Set - Male & Female - ASV ASVSpoof2019  - min a-DCF vs CM Threshold"
val_thr =  0.9700000000000017
adjusted_scores_eval_without_gender2, adjusted_labels_eval_without_gender2, adjusted_speakers_eval_without_gender2, adjusted_filename_eval_without_gender2, global_min_a_dcf_eval_without_gender2, global_min_a_dcf_thresh_eval_without_gender2,all_a_dcf,all_a_dcf_thresh = compute_a_dcf(cm_filesname, cm_scores, asv_speakers,asv_scores,asv_labels, asv_filenames,title = title, val_CM_threshold = val_thr,gender= 'female')
# Out:
# a-DCF: 0.40665, threshold: -1.52404
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.39718, threshold: -1.52404
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.35561, threshold: -5.34931
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.31722, threshold: -5.34931
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.29517, threshold: -5.34931
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.28029, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.27015, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.26260, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.25746, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.25346, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.24996, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.24746, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.24510, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.24324, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.24165, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.24028, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.23900, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.23791, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.23707, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.23629, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.23552, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.23467, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.23397, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.23336, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.23280, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.23231, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.23183, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.23145, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.23101, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.23061, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.23022, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22989, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22954, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22922, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22885, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22852, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22817, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22784, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22752, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22728, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22706, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22678, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22658, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22633, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22612, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22604, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22578, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22574, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22552, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22525, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22503, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22484, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22467, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22445, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22423, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22408, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22392, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22373, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22359, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22340, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22321, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22301, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22285, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22284, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22260, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22240, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22221, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22209, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22189, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22178, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22167, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22156, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22150, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22133, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22120, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22103, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22087, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22074, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22055, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22043, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22029, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22014, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.22000, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21988, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21975, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21957, threshold: -6.76904
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21946, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21932, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21920, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21911, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21893, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21887, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21877, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21856, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21845, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21837, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21818, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21823, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21810, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21797, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21782, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21769, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21755, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21742, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21728, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21717, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21705, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21689, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21677, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21663, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21652, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21647, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21629, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21615, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21598, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21586, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21575, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21566, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21557, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21541, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21526, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21515, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21498, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21482, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21484, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21469, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21448, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21440, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21429, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21407, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21391, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21379, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21361, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21347, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21331, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21320, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21298, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21281, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21261, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21244, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21233, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21210, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21198, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21183, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21169, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21158, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21142, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21123, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21110, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21110, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21091, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21070, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21049, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21031, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.21000, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20978, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20950, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20924, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20908, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20879, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20859, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20837, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20813, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20775, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20739, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20707, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20668, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20639, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20609, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20581, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20547, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20513, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20477, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20443, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20404, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20361, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20310, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20253, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20195, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20154, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20075, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.20023, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19957, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19893, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19828, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19754, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19669, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19591, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19466, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19321, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.19146, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18935, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18683, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18452, threshold: -8.14609
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.18057, threshold: -8.42914
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.17558, threshold: -8.42914
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.16898, threshold: -8.42914
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.15986, threshold: -8.42914
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.14487, threshold: -9.97586
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.12328, threshold: -9.97586
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# a-DCF: 0.59500, threshold: -inf
# CostModel(Pspf=0.05, Pnontrg=0.0095, Ptrg=0.9405, Cmiss=1, Cfa_asv=10, Cfa_cm=10)
# Threshold: 0.9900000000000018 	Min a-dcf: 0.12327868300059487 	Min a-dcf threshold: -9.975863

# %%
min_index = np.unravel_index(np.nanargmin(all_a_dcf), all_a_dcf.shape)
point_x_index = min_index[0]
point_y_index = min_index[1]
cm_thresholds = np.array(np.arange(-1, 1.01, 0.01).tolist())
point_x_constrained = np.where(cm_thresholds == val_thr)[0][0]
point_y_constrained = np.nanargmin(np.array(all_a_dcf)[point_x_constrained])
heatmap_norm_adcf(list_aDCF_norm = np.array(all_a_dcf),cm_thresholds = cm_thresholds,sasv_thresholds = all_a_dcf_thresh,target_values =  [0,0.5,1],title ="Norm a-DCF - Male & Female on Evaluation Set",point_x_index= point_x_index, point_y_index= point_y_index,point_x_constrained=point_x_constrained,point_y_constrained=point_y_constrained,value = None,defualt_show = 'female')
