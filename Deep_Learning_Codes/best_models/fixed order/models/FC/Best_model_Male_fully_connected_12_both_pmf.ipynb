# %% [markdown]
# # Simple Deep Learning On Male Data - ASVspoof2019 Dataset:

# %%
import sys
sys.path.append('../')
import scipy.io as sio
import mat73
import pandas as pd
import torch
import numpy as np
import torch.optim as optim
import torch.nn
import sklearn
import sklearn.metrics
import matplotlib.pyplot as plt
from alive_progress import alive_bar
from  utils.my_classes import dataset 
from torch.utils.data import DataLoader
import utils.DNN_functions as DNN_functions
import scipy
import random
import utils.AMSloss
seed = 5  # You can choose any integer value as the seed
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
# Set seed for Python's random module
random.seed(seed)
# Set seed for NumPy
np.random.seed(seed)
# Set seed for PyTorch (CPU and GPU, if available)
if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
# Set deterministic flags for PyTorch (if available)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
#To get my GPU device - GTX 4070 :)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu');

if torch.cuda.is_available():
    print(torch.cuda.device_count())
    print(torch.cuda.device(0))
    print(torch.cuda.get_device_name(0))
    print(device)
# Out:
# 1
# <torch.cuda.device object at 0x00000239FF9EEFD0>
# NVIDIA GeForce RTX 4070
# cuda

# %%
from ASV_utils.data_loading import *


data_path_male = "Data/pmf_both/not_normalize/male/"


embedded_groups_1_1,embedded_groups_1_2,embedded_groups_1_3,chosen_labels_1_1_is_spoofed,chosen_labels_2_1_is_spoofed,chosen_labels_3_1_is_spoofed,chosen_labels_numeric_1_1,chosen_labels_numeric_2_1,chosen_labels_numeric_3_1,chosen_labels_1_1_attack_logical,chosen_labels_2_1_attack_logical,chosen_labels_3_1_attack_logical,chosen_labels_1_1_name,chosen_labels_2_1_name,chosen_labels_3_1_name,chosen_labels_1_1_speaker_id,chosen_labels_2_1_speaker_id,chosen_labels_3_1_speaker_id,male_chosen_labels_1_1_sex,male_chosen_labels_2_1_sex,male_chosen_labels_3_1_sex  = load_data_male(data_path_male)

# %% [markdown]
# ## Preprocessing channels

# %% [markdown]
# Here, I will perform preprocessing and rearrange the channel order before feeding it into the Deep Neural Network (DNN).

# %%
#order by this example:
#filter-gammatone-channel-1-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#       'filter-gammatone-channel-1-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#       'filter-gammatone-channel-1-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#       'filter-gammatone-channel-1-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#       'filter-gammatone-channel-1-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)

# get the real channel by the order of the features

import utils.my_functions as my_functions
columns_names,max_name_length = my_functions.get_columns_names_feature_importance(substruct=True)
true_channels_indexes = np.array(my_functions.get_real_channel(np.linspace(start=1, stop=len(columns_names), num=len(columns_names)),len(columns_names)))
true_channels_indexes = true_channels_indexes - 1
true_channels_indexes = true_channels_indexes.astype(int)
columns_names = np.array(columns_names)
embedded_groups_1_1 = embedded_groups_1_1[:,true_channels_indexes]
embedded_groups_1_2 = embedded_groups_1_2[:,true_channels_indexes]
embedded_groups_1_3 = embedded_groups_1_3[:,true_channels_indexes]

# %%
# order by metric type and then by channel number and then by gammatone and gammatone_inv, example:
#filter-gammatone-channel-1-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]
#filter-gammatone-channel-2-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]
#filter-gammatone-channel-3-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]
#filter-gammatone-channel-4-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]
#filter-gammatone-channel-5-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]
#filter-gammatone-channel-6-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]
#filter-gammatone-channel-7-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]
#filter-gammatone-channel-8-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]
#filter-gammatone-channel-9-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]
#filter-gammatone-channel-10-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]
#filter-gammatone-channel-1-distance-Correlation-[d_(p,p_s)-d(p,p_h)]
#filter-gammatone-channel-2-distance-Correlation-[d_(p,p_s)-d(p,p_h)]
import re


your_list = columns_names[true_channels_indexes]
index_mapping ={}

# Define the custom sorting order for distance metrics
distance_metrics = [
    'Chi-square',
    'Correlation',
    'Hellinger',
    'Intersection',
    'Jensen-Shannon',
    'Kullback-Leibler Divergence',
    'Modified Kolmogorov-Smirnov',
    'Symmetrised Kullback-Leibler'
]

def custom_sort_key(item):
    # Use regex to extract filter type, channel number, and distance metric
    match = re.search(r'filter-(gammatone|gammtone_inv)-channel-(\d+)-distance-(.+?)-\[d_', item)
    if match:
        filter_type = match.group(1)  # 'gammatone' or 'gammtone_inv'
        channel = int(match.group(2))
        distance_metric = match.group(3)
        
        # Prioritize 'gammatone' before 'gammtone_inv'
        filter_priority = 0 if filter_type == 'gammatone' else 1

        # Sort by filter type, then by distance metric, and finally by channel
        return (filter_priority, distance_metrics.index(distance_metric), channel)

    else:
        # If the regex doesn't match, push the item to the end
        return (999, 999, 999)

# Sort the list based on the custom order
sorted_list = sorted(your_list, key=custom_sort_key)

for new_index, item in enumerate(sorted_list):
    old_index = np.where(columns_names[true_channels_indexes] == item)[0][0]
    index_mapping[old_index] = new_index
    
embedded_groups_1_1 = embedded_groups_1_1[:,list(index_mapping.keys())]
embedded_groups_1_2 = embedded_groups_1_2[:,list(index_mapping.keys())]
embedded_groups_1_3 = embedded_groups_1_3[:,list(index_mapping.keys())]

# %%
sorted_list
# Out:
# ['filter-gammatone-channel-1-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-2-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-3-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-4-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-5-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-6-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-7-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-8-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-9-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-10-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-1-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-2-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-3-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-4-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-5-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-6-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-7-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-8-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-9-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-10-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-1-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-2-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-3-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-4-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-5-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-6-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-7-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-8-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-9-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-10-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-1-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-2-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-3-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-4-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-5-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-6-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-7-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-8-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-9-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-10-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-1-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-2-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-3-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-4-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-5-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-6-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-7-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-8-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-9-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-10-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-1-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-2-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-3-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-4-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-5-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-6-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-7-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-8-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-9-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-10-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-1-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-2-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-3-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-4-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-5-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-6-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-7-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-8-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-9-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-10-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-1-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-2-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-3-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-4-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-5-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-6-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-7-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-8-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-9-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-10-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-1-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-2-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-3-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-4-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-5-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-6-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-7-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-8-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-9-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-10-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-1-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-2-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-3-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-4-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-5-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-6-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-7-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-8-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-9-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-10-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-1-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-2-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-3-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-4-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-5-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-6-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-7-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-8-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-9-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-10-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-1-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-2-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-3-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-4-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-5-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-6-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-7-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-8-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-9-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-10-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-1-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-2-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-3-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-4-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-5-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-6-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-7-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-8-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-9-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-10-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-1-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-2-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-3-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-4-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-5-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-6-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-7-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-8-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-9-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-10-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-1-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-2-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-3-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-4-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-5-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-6-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-7-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-8-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-9-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-10-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-1-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-2-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-3-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-4-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-5-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-6-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-7-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-8-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-9-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-10-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]']

# %%
#create the datasets
train_dataset = dataset(data = embedded_groups_1_1 , is_spoofed = chosen_labels_1_1_is_spoofed , chosen_labels_numeric = chosen_labels_numeric_1_1,
                        attack_logical = chosen_labels_1_1_attack_logical, name = chosen_labels_1_1_name , speaker_id = chosen_labels_1_1_speaker_id,sex = male_chosen_labels_1_1_sex, data_transform = None , labels_transform = None);

validation_dataset = dataset(data = embedded_groups_1_2 , is_spoofed = chosen_labels_2_1_is_spoofed , chosen_labels_numeric = chosen_labels_numeric_2_1,
                        attack_logical = chosen_labels_2_1_attack_logical, name = chosen_labels_2_1_name , speaker_id = chosen_labels_2_1_speaker_id, sex = male_chosen_labels_2_1_sex ,data_transform = None , labels_transform = None);


test_dataset = dataset(data = embedded_groups_1_3 , is_spoofed = chosen_labels_3_1_is_spoofed , chosen_labels_numeric = chosen_labels_numeric_3_1,
                        attack_logical = chosen_labels_3_1_attack_logical, name = chosen_labels_3_1_name , speaker_id = chosen_labels_3_1_speaker_id, sex = male_chosen_labels_3_1_sex ,data_transform = None , labels_transform = None);

# %%
# normalize the train, validation and test datasets
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler(with_mean = True, with_std = True)
scaler.fit(train_dataset.data)
mean_features = scaler.mean_
std_features = scaler.scale_
train_dataset.data = scaler.transform(train_dataset.data)
validation_dataset.data = scaler.transform(validation_dataset.data)
test_dataset.data = scaler.transform(test_dataset.data)

# %%
# balanced the data with SVM SMOTE
import imblearn.over_sampling as over_sampling

sm = over_sampling.SVMSMOTE(sampling_strategy='minority', random_state=seed,k_neighbors=5)
train_dataset.data , train_dataset.is_spoofed  = sm.fit_resample(X = train_dataset.data , y = train_dataset.is_spoofed) # just on the train set

# %%
#check if the data now is balanced
print(f"|| train dataset length - {len(train_dataset)} ||");
print(f"|| train dataset - len_is_spoofed ? \nlength - \n{train_dataset.len_is_spoofed()} ||");
print(f"|| validation dataset length - {len(validation_dataset)} ||");
print(f"|| validation dataset - len_is_spoofed ? \nlength - \n{validation_dataset.len_is_spoofed()} ||");
print(f"|| test dataset length - {len(test_dataset)} ||");
print(f"|| test dataset - len_is_spoofed ? \nlength - \n{test_dataset.len_is_spoofed()} ||");
# Out:
# || train dataset length - 18816 ||
# || train dataset - len_is_spoofed ?
# length -
# 0    9408
# 1    9408
# Name: count, dtype: int64 ||
# || validation dataset length - 8260 ||
# || validation dataset - len_is_spoofed ?
# length -
# 1    7392
# 0     868
# Name: count, dtype: int64 ||
# || test dataset length - 21939 ||
# || test dataset - len_is_spoofed ?
# length -
# 1    19656
# 0     2283
# Name: count, dtype: int64 ||

# %%
# define the labels types
train_dataset.set_labels_format('is_spoofed')
validation_dataset.set_labels_format('is_spoofed')
test_dataset.set_labels_format('is_spoofed')

# %%
# define the dataloaders
train_dataloader = DataLoader(train_dataset, batch_size=256, shuffle=True);
validation_dataloader = DataLoader(validation_dataset, batch_size=256, shuffle=True);
test_dataloader = DataLoader(test_dataset, batch_size=256, shuffle=True);

print(f"|| train dataloader length - {len(train_dataloader)} ||");
print(f"|| validation dataloader length - {len(validation_dataloader)} ||");
print(f"|| test dataloader length - {len(test_dataloader)} ||");
# Out:
# || train dataloader length - 74 ||
# || validation dataloader length - 33 ||
# || test dataloader length - 86 ||

# %% [markdown]
# ## Deep Neural Network

# %% [markdown]
# Here I define the netwok and training the model.

# %%
# define the subchannel model network
import torch.nn as nn
class SubChannelNetwork(nn.Module):
    def __init__(self, input_channel_size, output_channel_size):
        super(SubChannelNetwork, self).__init__()
        self.input_layer = nn.Linear(input_channel_size, output_channel_size)
        self.sigmoid = nn.Sigmoid()
        self.dropout = nn.Dropout(p=0.2)
        self.BN_4 = nn.BatchNorm1d(output_channel_size) 

        
    def forward(self, x):
        x = self.input_layer(x)
        x = self.BN_4(x) 
        x = self.sigmoid(x)
        x = self.dropout(x)
        return x

# %%
import torch
import torch.nn as nn
from utils.AMSloss import AdMSoftmaxLoss

# define the model network
class DNN(nn.Module):
    def __init__(self, input_channel_size, num_subnetworks, output_channel_size, final_output_size):
        super(DNN, self).__init__()
        self.SubChannelNetwork = nn.ModuleList([
            SubChannelNetwork(input_channel_size, output_channel_size) for _ in range(num_subnetworks)
        ])
        self.fc_between_subnet = nn.Linear(num_subnetworks * output_channel_size,40)
        self.BN = nn.BatchNorm1d(40)
        self.fc = nn.Linear(40, final_output_size)
        self.sigmoid = nn.Sigmoid()
        self.droupout = nn.Dropout(p=0.2)
        self.loss = nn.BCEWithLogitsLoss()
        self.optimizer = None
        self.scheduler = None
        self.fc1 = nn.Linear(160, num_subnetworks * output_channel_size)
        self.BN1 = nn.BatchNorm1d(num_subnetworks * output_channel_size)
        self.sigmoid1 = nn.Sigmoid()
        self.dropout1 = nn.Dropout(p=0.2)
        
        
        
    def forward(self, x):
        #subnetwork_outputs = [self.SubChannelNetwork[idx](x[:, idx*input_channel_size:(idx+1)*input_channel_size].to(device)) for idx in range(len(self.SubChannelNetwork))]
        #combined_output = torch.cat(subnetwork_outputs, dim=1)
        combined_output = self.fc1(x)
        combined_output = self.BN1(combined_output)
        combined_output = self.sigmoid1(combined_output)
        combined_output = self.dropout1(combined_output)
        x = self.fc_between_subnet(combined_output)    
        x = self.BN(x)
        x = self.sigmoid(x)
        x = self.droupout(x)
        output = self.fc(x)
        return output 
    
    @staticmethod
    def count_parameters(model):
        return sum(p.numel() for p in model.parameters() if p.requires_grad)



# Just for checking the model and see the number of parameters
num_SubChannelNetwork = 16
input_channel_size = 10
output_channel_size = 5
final_output_size = 1
model = []
model = DNN(input_channel_size, num_SubChannelNetwork, output_channel_size, final_output_size)
model = model.to(device)
print(model)
n = DNN.count_parameters(model)
print("Number of parameters: %s" % n)
# Out:
# DNN(
#   (SubChannelNetwork): ModuleList(
#     (0-15): 16 x SubChannelNetwork(
#       (input_layer): Linear(in_features=10, out_features=5, bias=True)
#       (sigmoid): Sigmoid()
#       (dropout): Dropout(p=0.2, inplace=False)
#       (BN_4): BatchNorm1d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (fc_between_subnet): Linear(in_features=80, out_features=40, bias=True)
#   (BN): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc): Linear(in_features=40, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
#   (droupout): Dropout(p=0.2, inplace=False)
#   (loss): BCEWithLogitsLoss()
#   (fc1): Linear(in_features=160, out_features=80, bias=True)
#   (BN1): BatchNorm1d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (sigmoid1): Sigmoid()
#   (dropout1): Dropout(p=0.2, inplace=False)
# )
# Number of parameters: 17441

# %%
import utils.DNN_functions
model = [] # clear the model
model = DNN(input_channel_size, num_SubChannelNetwork, output_channel_size, final_output_size) # define the model
model = model.to(device) # send the model to the device

# define the hyperparameters
num_epoch = 300
learning_rate = 0.001
weight_decay = 0.000001
model.optimizer = torch.optim.SGD(model.parameters(),
                                lr=learning_rate,
                                weight_decay=weight_decay);
model.scheduler =  optim.lr_scheduler.StepLR(model.optimizer, step_size=num_epoch, gamma=0.1);


checkpoint_path = "Male_best_model_1_neorun_end_sigmoid.pkl"

training_type = '1_neorun_end_sigmoid'

model,train_losses,validation_losses,train_acc_percentage,validation_acc_percentage,f1_score_validation,validation_total_eer,train_total_err  = utils.DNN_functions.train_model_new(training_type,model,train_dataloader,validation_dataloader ,num_epoch,checkpoint_path=checkpoint_path,patience = None)
# Out:
# c:\Users\avish\OneDrive\Desktop\thesis_research\avishai_work\env\lib\site-packages\torch\onnx\_internal\_beartype.py:35: UserWarning: unhashable type: 'list'
#   warnings.warn(f"{e}")
# on 1:
#       Train Balanced Accuracy:  51.04%
# on 1: Train EER:  48.96%
# on 1:
#       Validation 1 ,Validation Loss 0.76251 , Validation Balanced Accuracy: 60.90%
# on 1: Validation EER:  39.14%
# on 1: Validation f1 Score: 60.87%
# on 1:
# on 1:
# on 2:
#       Train Balanced Accuracy:  67.75%
# on 2: Train EER:  32.26%
# on 2:
#       Validation 2 ,Validation Loss 0.73148 , Validation Balanced Accuracy: 75.77%
# on 2: Validation EER:  24.27%
# on 2: Validation f1 Score: 75.74%
# on 2:
# on 2:
# on 3:
#       Train Balanced Accuracy:  74.39%
# on 3: Train EER:  25.61%
# on 3:
#       Validation 3 ,Validation Loss 0.70714 , Validation Balanced Accuracy: 79.35%
# on 3: Validation EER:  20.67%
# on 3: Validation f1 Score: 79.33%
# on 3:
# on 3:
# on 4:
#       Train Balanced Accuracy:  76.66%
# on 4: Train EER:  23.33%
# on 4:
#       Validation 4 ,Validation Loss 0.68749 , Validation Balanced Accuracy: 80.77%
# on 4: Validation EER:  19.22%
# on 4: Validation f1 Score: 80.77%
# on 4:
# on 4:
# on 5:
#       Train Balanced Accuracy:  77.15%
# on 5: Train EER:  22.85%
# on 5:
#       Validation 5 ,Validation Loss 0.67086 , Validation Balanced Accuracy: 81.57%
# on 5: Validation EER:  18.43%
# on 5: Validation f1 Score: 81.49%
# on 5:
# on 5:
# on 6:
#       Train Balanced Accuracy:  77.44%
# on 6: Train EER:  22.56%
# on 6:
#       Validation 6 ,Validation Loss 0.65598 , Validation Balanced Accuracy: 82.37%
# on 6: Validation EER:  17.64%
# on 6: Validation f1 Score: 82.36%
# on 6:
# on 6:
# on 7:
#       Train Balanced Accuracy:  77.78%
# on 7: Train EER:  22.22%
# on 7:
#       Validation 7 ,Validation Loss 0.64253 , Validation Balanced Accuracy: 82.57%
# on 7: Validation EER:  17.46%
# on 7: Validation f1 Score: 82.54%
# on 7:
# on 7:
# on 8:
#       Train Balanced Accuracy:  78.05%
# on 8: Train EER:  21.96%
# on 8:
#       Validation 8 ,Validation Loss 0.63052 , Validation Balanced Accuracy: 82.96%
# on 8: Validation EER:  17.05%
# on 8: Validation f1 Score: 82.97%
# on 8:
# on 8:
# on 9:
#       Train Balanced Accuracy:  78.23%
# on 9: Train EER:  21.77%
# on 9:
#       Validation 9 ,Validation Loss 0.61825 , Validation Balanced Accuracy: 83.23%
# on 9: Validation EER:  16.82%
# on 9: Validation f1 Score: 83.18%
# on 9:
# on 9:
# on 10:
#        Train Balanced Accuracy:  78.41%
# on 10: Train EER:  21.59%
# on 10:
#        Validation 10 ,Validation Loss 0.60676 , Validation Balanced Accuracy: 83.60%
# on 10: Validation EER:  16.44%
# on 10: Validation f1 Score: 83.57%
# on 10:
# on 10:
# on 11:
#        Train Balanced Accuracy:  78.68%
# on 11: Train EER:  21.32%
# on 11:
#        Validation 11 ,Validation Loss 0.59629 , Validation Balanced Accuracy: 83.86%
# on 11: Validation EER:  16.15%
# on 11: Validation f1 Score: 83.85%
# on 11:
# on 11:
# on 12:
#        Train Balanced Accuracy:  78.90%
# on 12: Train EER:  21.11%
# on 12:
#        Validation 12 ,Validation Loss 0.58617 , Validation Balanced Accuracy: 84.32%
# on 12: Validation EER:  15.69%
# on 12: Validation f1 Score: 84.31%
# on 12:
# on 12:
# on 13:
#        Train Balanced Accuracy:  79.19%
# on 13: Train EER:  20.80%
# on 13:
#        Validation 13 ,Validation Loss 0.57628 , Validation Balanced Accuracy: 84.64%
# on 13: Validation EER:  15.40%
# on 13: Validation f1 Score: 84.61%
# on 13:
# on 13:
# on 14:
#        Train Balanced Accuracy:  79.59%
# on 14: Train EER:  20.41%
# on 14:
#        Validation 14 ,Validation Loss 0.56768 , Validation Balanced Accuracy: 84.97%
# on 14: Validation EER:  15.08%
# on 14: Validation f1 Score: 84.93%
# on 14:
# on 14:
# on 15:
#        Train Balanced Accuracy:  79.90%
# on 15: Train EER:  20.10%
# on 15:
#        Validation 15 ,Validation Loss 0.55788 , Validation Balanced Accuracy: 85.24%
# on 15: Validation EER:  14.75%
# on 15: Validation f1 Score: 85.15%
# on 15:
# on 15:
# on 16:
#        Train Balanced Accuracy:  80.29%
# on 16: Train EER:  19.73%
# on 16:
#        Validation 16 ,Validation Loss 0.54931 , Validation Balanced Accuracy: 85.63%
# on 16: Validation EER:  14.40%
# on 16: Validation f1 Score: 85.65%
# on 16:
# on 16:
# on 17:
#        Train Balanced Accuracy:  80.61%
# on 17: Train EER:  19.39%
# on 17:
#        Validation 17 ,Validation Loss 0.53948 , Validation Balanced Accuracy: 85.90%
# on 17: Validation EER:  14.17%
# on 17: Validation f1 Score: 85.96%
# on 17:
# on 17:
# on 18:
#        Train Balanced Accuracy:  80.86%
# on 18: Train EER:  19.14%
# on 18:
#        Validation 18 ,Validation Loss 0.53137 , Validation Balanced Accuracy: 86.03%
# on 18: Validation EER:  14.00%
# on 18: Validation f1 Score: 86.00%
# on 18:
# on 18:
# on 19:
#        Train Balanced Accuracy:  81.14%
# on 19: Train EER:  18.87%
# on 19:
#        Validation 19 ,Validation Loss 0.52428 , Validation Balanced Accuracy: 86.54%
# on 19: Validation EER:  13.56%
# on 19: Validation f1 Score: 86.46%
# on 19:
# on 19:
# on 20:
#        Train Balanced Accuracy:  81.53%
# on 20: Train EER:  18.47%
# on 20:
#        Validation 20 ,Validation Loss 0.51446 , Validation Balanced Accuracy: 87.00%
# on 20: Validation EER:  13.02%
# on 20: Validation f1 Score: 87.02%
# on 20:
# on 20:
# on 21:
#        Train Balanced Accuracy:  81.92%
# on 21: Train EER:  18.08%
# on 21:
#        Validation 21 ,Validation Loss 0.50592 , Validation Balanced Accuracy: 87.37%
# on 21: Validation EER:  12.67%
# on 21: Validation f1 Score: 87.40%
# on 21:
# on 21:
# on 22:
#        Train Balanced Accuracy:  82.22%
# on 22: Train EER:  17.78%
# on 22:
#        Validation 22 ,Validation Loss 0.49769 , Validation Balanced Accuracy: 87.52%
# on 22: Validation EER:  12.44%
# on 22: Validation f1 Score: 87.40%
# on 22:
# on 22:
# on 23:
#        Train Balanced Accuracy:  82.59%
# on 23: Train EER:  17.41%
# on 23:
#        Validation 23 ,Validation Loss 0.49084 , Validation Balanced Accuracy: 87.74%
# on 23: Validation EER:  12.21%
# on 23: Validation f1 Score: 87.60%
# on 23:
# on 23:
# on 24:
#        Train Balanced Accuracy:  82.94%
# on 24: Train EER:  17.06%
# on 24:
#        Validation 24 ,Validation Loss 0.48241 , Validation Balanced Accuracy: 88.18%
# on 24: Validation EER:  11.87%
# on 24: Validation f1 Score: 88.22%
# on 24:
# on 24:
# on 25:
#        Train Balanced Accuracy:  83.32%
# on 25: Train EER:  16.69%
# on 25:
#        Validation 25 ,Validation Loss 0.47670 , Validation Balanced Accuracy: 88.56%
# on 25: Validation EER:  11.47%
# on 25: Validation f1 Score: 88.54%
# on 25:
# on 25:
# on 26:
#        Train Balanced Accuracy:  83.65%
# on 26: Train EER:  16.35%
# on 26:
#        Validation 26 ,Validation Loss 0.46655 , Validation Balanced Accuracy: 89.17%
# on 26: Validation EER:  10.83%
# on 26: Validation f1 Score: 89.16%
# on 26:
# on 26:
# on 27:
#        Train Balanced Accuracy:  84.08%
# on 27: Train EER:  15.92%
# on 27:
#        Validation 27 ,Validation Loss 0.45892 , Validation Balanced Accuracy: 89.84%
# on 27: Validation EER:  10.19%
# on 27: Validation f1 Score: 89.82%
# on 27:
# on 27:
# on 28:
#        Train Balanced Accuracy:  84.55%
# on 28: Train EER:  15.45%
# on 28:
#        Validation 28 ,Validation Loss 0.45173 , Validation Balanced Accuracy: 90.32%
# on 28: Validation EER:  9.68%
# on 28: Validation f1 Score: 90.33%
# on 28:
# on 28:
# on 29:
#        Train Balanced Accuracy:  85.01%
# on 29: Train EER:  15.00%
# on 29:
#        Validation 29 ,Validation Loss 0.44227 , Validation Balanced Accuracy: 90.84%
# on 29: Validation EER:  9.21%
# on 29: Validation f1 Score: 90.80%
# on 29:
# on 29:
# on 30:
#        Train Balanced Accuracy:  85.43%
# on 30: Train EER:  14.57%
# on 30:
#        Validation 30 ,Validation Loss 0.43461 , Validation Balanced Accuracy: 91.48%
# on 30: Validation EER:  8.53%
# on 30: Validation f1 Score: 91.48%
# on 30:
# on 30:
# on 31:
#        Train Balanced Accuracy:  85.87%
# on 31: Train EER:  14.13%
# on 31:
#        Validation 31 ,Validation Loss 0.42631 , Validation Balanced Accuracy: 91.90%
# on 31: Validation EER:  8.14%
# on 31: Validation f1 Score: 91.86%
# on 31:
# on 31:
# on 32:
#        Train Balanced Accuracy:  86.27%
# on 32: Train EER:  13.72%
# on 32:
#        Validation 32 ,Validation Loss 0.41911 , Validation Balanced Accuracy: 92.42%
# on 32: Validation EER:  7.60%
# on 32: Validation f1 Score: 92.45%
# on 32:
# on 32:
# on 33:
#        Train Balanced Accuracy:  86.76%
# on 33: Train EER:  13.24%
# on 33:
#        Validation 33 ,Validation Loss 0.41336 , Validation Balanced Accuracy: 92.94%
# on 33: Validation EER:  7.09%
# on 33: Validation f1 Score: 92.92%
# on 33:
# on 33:
# on 34:
#        Train Balanced Accuracy:  87.21%
# on 34: Train EER:  12.79%
# on 34:
#        Validation 34 ,Validation Loss 0.40526 , Validation Balanced Accuracy: 93.71%
# on 34: Validation EER:  6.34%
# on 34: Validation f1 Score: 93.74%
# on 34:
# on 34:
# on 35:
#        Train Balanced Accuracy:  87.64%
# on 35: Train EER:  12.36%
# on 35:
#        Validation 35 ,Validation Loss 0.39706 , Validation Balanced Accuracy: 94.16%
# on 35: Validation EER:  5.88%
# on 35: Validation f1 Score: 94.19%
# on 35:
# on 35:
# on 36:
#        Train Balanced Accuracy:  88.09%
# on 36: Train EER:  11.92%
# on 36:
#        Validation 36 ,Validation Loss 0.39132 , Validation Balanced Accuracy: 94.65%
# on 36: Validation EER:  5.40%
# on 36: Validation f1 Score: 94.61%
# on 36:
# on 36:
# on 37:
#        Train Balanced Accuracy:  88.41%
# on 37: Train EER:  11.59%
# on 37:
#        Validation 37 ,Validation Loss 0.38293 , Validation Balanced Accuracy: 94.82%
# on 37: Validation EER:  5.18%
# on 37: Validation f1 Score: 94.83%
# on 37:
# on 37:
# on 38:
#        Train Balanced Accuracy:  88.63%
# on 38: Train EER:  11.37%
# on 38:
#        Validation 38 ,Validation Loss 0.37535 , Validation Balanced Accuracy: 95.26%
# on 38: Validation EER:  4.76%
# on 38: Validation f1 Score: 95.24%
# on 38:
# on 38:
# on 39:
#        Train Balanced Accuracy:  88.96%
# on 39: Train EER:  11.04%
# on 39:
#        Validation 39 ,Validation Loss 0.36839 , Validation Balanced Accuracy: 95.46%
# on 39: Validation EER:  4.59%
# on 39: Validation f1 Score: 95.42%
# on 39:
# on 39:
# on 40:
#        Train Balanced Accuracy:  89.20%
# on 40: Train EER:  10.81%
# on 40:
#        Validation 40 ,Validation Loss 0.36112 , Validation Balanced Accuracy: 95.82%
# on 40: Validation EER:  4.21%
# on 40: Validation f1 Score: 95.80%
# on 40:
# on 40:
# on 41:
#        Train Balanced Accuracy:  89.59%
# on 41: Train EER:  10.41%
# on 41:
#        Validation 41 ,Validation Loss 0.35451 , Validation Balanced Accuracy: 95.97%
# on 41: Validation EER:  4.03%
# on 41: Validation f1 Score: 95.98%
# on 41:
# on 41:
# on 42:
#        Train Balanced Accuracy:  90.01%
# on 42: Train EER:  9.99%
# on 42:
#        Validation 42 ,Validation Loss 0.34698 , Validation Balanced Accuracy: 96.18%
# on 42: Validation EER:  3.83%
# on 42: Validation f1 Score: 96.17%
# on 42:
# on 42:
# on 43:
#        Train Balanced Accuracy:  90.38%
# on 43: Train EER:  9.63%
# on 43:
#        Validation 43 ,Validation Loss 0.34028 , Validation Balanced Accuracy: 96.32%
# on 43: Validation EER:  3.69%
# on 43: Validation f1 Score: 96.23%
# on 43:
# on 43:
# on 44:
#        Train Balanced Accuracy:  90.62%
# on 44: Train EER:  9.39%
# on 44:
#        Validation 44 ,Validation Loss 0.33548 , Validation Balanced Accuracy: 96.63%
# on 44: Validation EER:  3.40%
# on 44: Validation f1 Score: 96.61%
# on 44:
# on 44:
# on 45:
#        Train Balanced Accuracy:  90.91%
# on 45: Train EER:  9.08%
# on 45:
#        Validation 45 ,Validation Loss 0.32829 , Validation Balanced Accuracy: 96.88%
# on 45: Validation EER:  3.14%
# on 45: Validation f1 Score: 96.86%
# on 45:
# on 45:
# on 46:
#        Train Balanced Accuracy:  91.20%
# on 46: Train EER:  8.80%
# on 46:
#        Validation 46 ,Validation Loss 0.32358 , Validation Balanced Accuracy: 96.99%
# on 46: Validation EER:  3.03%
# on 46: Validation f1 Score: 96.97%
# on 46:
# on 46:
# on 47:
#        Train Balanced Accuracy:  91.50%
# on 47: Train EER:  8.50%
# on 47:
#        Validation 47 ,Validation Loss 0.31716 , Validation Balanced Accuracy: 97.06%
# on 47: Validation EER:  3.00%
# on 47: Validation f1 Score: 97.01%
# on 47:
# on 47:
# on 48:
#        Train Balanced Accuracy:  91.80%
# on 48: Train EER:  8.20%
# on 48:
#        Validation 48 ,Validation Loss 0.30901 , Validation Balanced Accuracy: 97.19%
# on 48: Validation EER:  2.85%
# on 48: Validation f1 Score: 97.15%
# on 48:
# on 48:
# on 49:
#        Train Balanced Accuracy:  92.06%
# on 49: Train EER:  7.94%
# on 49:
#        Validation 49 ,Validation Loss 0.30407 , Validation Balanced Accuracy: 97.24%
# on 49: Validation EER:  2.76%
# on 49: Validation f1 Score: 97.15%
# on 49:
# on 49:
# on 50:
#        Train Balanced Accuracy:  92.31%
# on 50: Train EER:  7.70%
# on 50:
#        Validation 50 ,Validation Loss 0.29741 , Validation Balanced Accuracy: 97.32%
# on 50: Validation EER:  2.72%
# on 50: Validation f1 Score: 97.29%
# on 50:
# on 50:
# on 51:
#        Train Balanced Accuracy:  92.56%
# on 51: Train EER:  7.43%
# on 51:
#        Validation 51 ,Validation Loss 0.29219 , Validation Balanced Accuracy: 97.43%
# on 51: Validation EER:  2.60%
# on 51: Validation f1 Score: 97.41%
# on 51:
# on 51:
# on 52:
#        Train Balanced Accuracy:  92.81%
# on 52: Train EER:  7.19%
# on 52:
#        Validation 52 ,Validation Loss 0.28648 , Validation Balanced Accuracy: 97.57%
# on 52: Validation EER:  2.45%
# on 52: Validation f1 Score: 97.55%
# on 52:
# on 52:
# on 53:
#        Train Balanced Accuracy:  93.13%
# on 53: Train EER:  6.87%
# on 53:
#        Validation 53 ,Validation Loss 0.28143 , Validation Balanced Accuracy: 97.55%
# on 53: Validation EER:  2.49%
# on 53: Validation f1 Score: 97.52%
# on 53:
# on 53:
# on 54:
#        Train Balanced Accuracy:  93.37%
# on 54: Train EER:  6.63%
# on 54:
#        Validation 54 ,Validation Loss 0.27490 , Validation Balanced Accuracy: 97.58%
# on 54: Validation EER:  2.42%
# on 54: Validation f1 Score: 97.58%
# on 54:
# on 54:
# on 55:
#        Train Balanced Accuracy:  93.60%
# on 55: Train EER:  6.41%
# on 55:
#        Validation 55 ,Validation Loss 0.27164 , Validation Balanced Accuracy: 97.64%
# on 55: Validation EER:  2.42%
# on 55: Validation f1 Score: 97.59%
# on 55:
# on 55:
# on 56:
#        Train Balanced Accuracy:  93.85%
# on 56: Train EER:  6.15%
# on 56:
#        Validation 56 ,Validation Loss 0.26563 , Validation Balanced Accuracy: 97.68%
# on 56: Validation EER:  2.34%
# on 56: Validation f1 Score: 97.66%
# on 56:
# on 56:
# on 57:
#        Train Balanced Accuracy:  93.98%
# on 57: Train EER:  6.02%
# on 57:
#        Validation 57 ,Validation Loss 0.25983 , Validation Balanced Accuracy: 97.76%
# on 57: Validation EER:  2.30%
# on 57: Validation f1 Score: 97.71%
# on 57:
# on 57:
# on 58:
#        Train Balanced Accuracy:  94.15%
# on 58: Train EER:  5.85%
# on 58:
#        Validation 58 ,Validation Loss 0.25550 , Validation Balanced Accuracy: 97.80%
# on 58: Validation EER:  2.21%
# on 58: Validation f1 Score: 97.80%
# on 58:
# on 58:
# on 59:
#        Train Balanced Accuracy:  94.30%
# on 59: Train EER:  5.71%
# on 59:
#        Validation 59 ,Validation Loss 0.25048 , Validation Balanced Accuracy: 97.91%
# on 59: Validation EER:  2.10%
# on 59: Validation f1 Score: 97.91%
# on 59:
# on 59:
# on 60:
#        Train Balanced Accuracy:  94.47%
# on 60: Train EER:  5.53%
# on 60:
#        Validation 60 ,Validation Loss 0.24489 , Validation Balanced Accuracy: 98.01%
# on 60: Validation EER:  2.02%
# on 60: Validation f1 Score: 97.99%
# on 60:
# on 60:
# on 61:
#        Train Balanced Accuracy:  94.59%
# on 61: Train EER:  5.41%
# on 61:
#        Validation 61 ,Validation Loss 0.24164 , Validation Balanced Accuracy: 98.11%
# on 61: Validation EER:  1.93%
# on 61: Validation f1 Score: 98.08%
# on 61:
# on 61:
# on 62:
#        Train Balanced Accuracy:  94.70%
# on 62: Train EER:  5.30%
# on 62:
#        Validation 62 ,Validation Loss 0.23761 , Validation Balanced Accuracy: 98.16%
# on 62: Validation EER:  1.84%
# on 62: Validation f1 Score: 98.16%
# on 62:
# on 62:
# on 63:
#        Train Balanced Accuracy:  94.84%
# on 63: Train EER:  5.17%
# on 63:
#        Validation 63 ,Validation Loss 0.23389 , Validation Balanced Accuracy: 98.22%
# on 63: Validation EER:  1.83%
# on 63: Validation f1 Score: 98.18%
# on 63:
# on 63:
# on 64:
#        Train Balanced Accuracy:  94.97%
# on 64: Train EER:  5.04%
# on 64:
#        Validation 64 ,Validation Loss 0.22810 , Validation Balanced Accuracy: 98.33%
# on 64: Validation EER:  1.72%
# on 64: Validation f1 Score: 98.29%
# on 64:
# on 64:
# on 65:
#        Train Balanced Accuracy:  95.08%
# on 65: Train EER:  4.92%
# on 65:
#        Validation 65 ,Validation Loss 0.22546 , Validation Balanced Accuracy: 98.36%
# on 65: Validation EER:  1.66%
# on 65: Validation f1 Score: 98.34%
# on 65:
# on 65:
# on 66:
#        Train Balanced Accuracy:  95.22%
# on 66: Train EER:  4.78%
# on 66:
#        Validation 66 ,Validation Loss 0.22042 , Validation Balanced Accuracy: 98.45%
# on 66: Validation EER:  1.61%
# on 66: Validation f1 Score: 98.40%
# on 66:
# on 66:
# on 67:
#        Train Balanced Accuracy:  95.34%
# on 67: Train EER:  4.66%
# on 67:
#        Validation 67 ,Validation Loss 0.21673 , Validation Balanced Accuracy: 98.49%
# on 67: Validation EER:  1.52%
# on 67: Validation f1 Score: 98.49%
# on 67:
# on 67:
# on 68:
#        Train Balanced Accuracy:  95.52%
# on 68: Train EER:  4.49%
# on 68:
#        Validation 68 ,Validation Loss 0.21231 , Validation Balanced Accuracy: 98.55%
# on 68: Validation EER:  1.50%
# on 68: Validation f1 Score: 98.50%
# on 68:
# on 68:
# on 69:
#        Train Balanced Accuracy:  95.65%
# on 69: Train EER:  4.35%
# on 69:
#        Validation 69 ,Validation Loss 0.20897 , Validation Balanced Accuracy: 98.56%
# on 69: Validation EER:  1.49%
# on 69: Validation f1 Score: 98.52%
# on 69:
# on 69:
# on 70:
#        Train Balanced Accuracy:  95.71%
# on 70: Train EER:  4.28%
# on 70:
#        Validation 70 ,Validation Loss 0.20528 , Validation Balanced Accuracy: 98.61%
# on 70: Validation EER:  1.39%
# on 70: Validation f1 Score: 98.61%
# on 70:
# on 70:
# on 71:
#        Train Balanced Accuracy:  95.83%
# on 71: Train EER:  4.18%
# on 71:
#        Validation 71 ,Validation Loss 0.20175 , Validation Balanced Accuracy: 98.67%
# on 71: Validation EER:  1.38%
# on 71: Validation f1 Score: 98.62%
# on 71:
# on 71:
# on 72:
#        Train Balanced Accuracy:  95.91%
# on 72: Train EER:  4.09%
# on 72:
#        Validation 72 ,Validation Loss 0.19782 , Validation Balanced Accuracy: 98.70%
# on 72: Validation EER:  1.34%
# on 72: Validation f1 Score: 98.67%
# on 72:
# on 72:
# on 73:
#        Train Balanced Accuracy:  96.01%
# on 73: Train EER:  3.99%
# on 73:
#        Validation 73 ,Validation Loss 0.19449 , Validation Balanced Accuracy: 98.71%
# on 73: Validation EER:  1.31%
# on 73: Validation f1 Score: 98.69%
# on 73:
# on 73:
# on 74:
#        Train Balanced Accuracy:  96.10%
# on 74: Train EER:  3.89%
# on 74:
#        Validation 74 ,Validation Loss 0.19147 , Validation Balanced Accuracy: 98.74%
# on 74: Validation EER:  1.27%
# on 74: Validation f1 Score: 98.74%
# on 74:
# on 74:
# on 75:
#        Train Balanced Accuracy:  96.19%
# on 75: Train EER:  3.81%
# on 75:
#        Validation 75 ,Validation Loss 0.18792 , Validation Balanced Accuracy: 98.75%
# on 75: Validation EER:  1.27%
# on 75: Validation f1 Score: 98.77%
# on 75:
# on 75:
# on 76:
#        Train Balanced Accuracy:  96.27%
# on 76: Train EER:  3.73%
# on 76:
#        Validation 76 ,Validation Loss 0.18580 , Validation Balanced Accuracy: 98.79%
# on 76: Validation EER:  1.27%
# on 76: Validation f1 Score: 98.74%
# on 76:
# on 76:
# on 77:
#        Train Balanced Accuracy:  96.38%
# on 77: Train EER:  3.62%
# on 77:
#        Validation 77 ,Validation Loss 0.18199 , Validation Balanced Accuracy: 98.79%
# on 77: Validation EER:  1.26%
# on 77: Validation f1 Score: 98.75%
# on 77:
# on 77:
# on 78:
#        Train Balanced Accuracy:  96.43%
# on 78: Train EER:  3.57%
# on 78:
#        Validation 78 ,Validation Loss 0.18038 , Validation Balanced Accuracy: 98.82%
# on 78: Validation EER:  1.22%
# on 78: Validation f1 Score: 98.79%
# on 78:
# on 78:
# on 79:
#        Train Balanced Accuracy:  96.55%
# on 79: Train EER:  3.45%
# on 79:
#        Validation 79 ,Validation Loss 0.17712 , Validation Balanced Accuracy: 98.85%
# on 79: Validation EER:  1.15%
# on 79: Validation f1 Score: 98.85%
# on 79:
# on 79:
# on 80:
#        Train Balanced Accuracy:  96.64%
# on 80: Train EER:  3.37%
# on 80:
#        Validation 80 ,Validation Loss 0.17384 , Validation Balanced Accuracy: 98.93%
# on 80: Validation EER:  1.11%
# on 80: Validation f1 Score: 98.90%
# on 80:
# on 80:
# on 81:
#        Train Balanced Accuracy:  96.72%
# on 81: Train EER:  3.27%
# on 81:
#        Validation 81 ,Validation Loss 0.17204 , Validation Balanced Accuracy: 98.94%
# on 81: Validation EER:  1.08%
# on 81: Validation f1 Score: 98.92%
# on 81:
# on 81:
# on 82:
#        Train Balanced Accuracy:  96.78%
# on 82: Train EER:  3.22%
# on 82:
#        Validation 82 ,Validation Loss 0.16748 , Validation Balanced Accuracy: 98.95%
# on 82: Validation EER:  1.07%
# on 82: Validation f1 Score: 98.93%
# on 82:
# on 82:
# on 83:
#        Train Balanced Accuracy:  96.88%
# on 83: Train EER:  3.13%
# on 83:
#        Validation 83 ,Validation Loss 0.16538 , Validation Balanced Accuracy: 98.94%
# on 83: Validation EER:  1.08%
# on 83: Validation f1 Score: 98.92%
# on 83:
# on 83:
# on 84:
#        Train Balanced Accuracy:  96.93%
# on 84: Train EER:  3.07%
# on 84:
#        Validation 84 ,Validation Loss 0.16347 , Validation Balanced Accuracy: 98.95%
# on 84: Validation EER:  1.04%
# on 84: Validation f1 Score: 98.95%
# on 84:
# on 84:
# on 85:
#        Train Balanced Accuracy:  96.98%
# on 85: Train EER:  3.02%
# on 85:
#        Validation 85 ,Validation Loss 0.16082 , Validation Balanced Accuracy: 99.02%
# on 85: Validation EER:  1.04%
# on 85: Validation f1 Score: 98.97%
# on 85:
# on 85:
# on 86:
#        Train Balanced Accuracy:  97.07%
# on 86: Train EER:  2.93%
# on 86:
#        Validation 86 ,Validation Loss 0.15866 , Validation Balanced Accuracy: 99.06%
# on 86: Validation EER:  0.96%
# on 86: Validation f1 Score: 99.04%
# on 86:
# on 86:
# on 87:
#        Train Balanced Accuracy:  97.16%
# on 87: Train EER:  2.85%
# on 87:
#        Validation 87 ,Validation Loss 0.15658 , Validation Balanced Accuracy: 99.07%
# on 87: Validation EER:  0.95%
# on 87: Validation f1 Score: 99.06%
# on 87:
# on 87:
# on 88:
#        Train Balanced Accuracy:  97.19%
# on 88: Train EER:  2.81%
# on 88:
#        Validation 88 ,Validation Loss 0.15349 , Validation Balanced Accuracy: 99.07%
# on 88: Validation EER:  0.92%
# on 88: Validation f1 Score: 99.07%
# on 88:
# on 88:
# on 89:
#        Train Balanced Accuracy:  97.27%
# on 89: Train EER:  2.73%
# on 89:
#        Validation 89 ,Validation Loss 0.15036 , Validation Balanced Accuracy: 99.12%
# on 89: Validation EER:  0.92%
# on 89: Validation f1 Score: 99.06%
# on 89:
# on 89:
# on 90:
#        Train Balanced Accuracy:  97.34%
# on 90: Train EER:  2.67%
# on 90:
#        Validation 90 ,Validation Loss 0.14836 , Validation Balanced Accuracy: 99.09%
# on 90: Validation EER:  0.92%
# on 90: Validation f1 Score: 99.10%
# on 90:
# on 90:
# on 91:
#        Train Balanced Accuracy:  97.40%
# on 91: Train EER:  2.60%
# on 91:
#        Validation 91 ,Validation Loss 0.14570 , Validation Balanced Accuracy: 99.11%
# on 91: Validation EER:  0.92%
# on 91: Validation f1 Score: 99.04%
# on 91:
# on 91:
# on 92:
#        Train Balanced Accuracy:  97.45%
# on 92: Train EER:  2.55%
# on 92:
#        Validation 92 ,Validation Loss 0.14480 , Validation Balanced Accuracy: 99.11%
# on 92: Validation EER:  0.92%
# on 92: Validation f1 Score: 99.04%
# on 92:
# on 92:
# on 93:
#        Train Balanced Accuracy:  97.52%
# on 93: Train EER:  2.48%
# on 93:
#        Validation 93 ,Validation Loss 0.14281 , Validation Balanced Accuracy: 99.12%
# on 93: Validation EER:  0.92%
# on 93: Validation f1 Score: 99.06%
# on 93:
# on 93:
# on 94:
#        Train Balanced Accuracy:  97.57%
# on 94: Train EER:  2.43%
# on 94:
#        Validation 94 ,Validation Loss 0.13957 , Validation Balanced Accuracy: 99.14%
# on 94: Validation EER:  0.92%
# on 94: Validation f1 Score: 99.09%
# on 94:
# on 94:
# on 95:
#        Train Balanced Accuracy:  97.62%
# on 95: Train EER:  2.38%
# on 95:
#        Validation 95 ,Validation Loss 0.13715 , Validation Balanced Accuracy: 99.15%
# on 95: Validation EER:  0.89%
# on 95: Validation f1 Score: 99.12%
# on 95:
# on 95:
# on 96:
#        Train Balanced Accuracy:  97.66%
# on 96: Train EER:  2.34%
# on 96:
#        Validation 96 ,Validation Loss 0.13643 , Validation Balanced Accuracy: 99.16%
# on 96: Validation EER:  0.87%
# on 96: Validation f1 Score: 99.14%
# on 96:
# on 96:
# on 97:
#        Train Balanced Accuracy:  97.70%
# on 97: Train EER:  2.30%
# on 97:
#        Validation 97 ,Validation Loss 0.13398 , Validation Balanced Accuracy: 99.18%
# on 97: Validation EER:  0.83%
# on 97: Validation f1 Score: 99.18%
# on 97:
# on 97:
# on 98:
#        Train Balanced Accuracy:  97.76%
# on 98: Train EER:  2.24%
# on 98:
#        Validation 98 ,Validation Loss 0.13193 , Validation Balanced Accuracy: 99.19%
# on 98: Validation EER:  0.81%
# on 98: Validation f1 Score: 99.19%
# on 98:
# on 98:
# on 99:
#        Train Balanced Accuracy:  97.80%
# on 99: Train EER:  2.22%
# on 99:
#        Validation 99 ,Validation Loss 0.13034 , Validation Balanced Accuracy: 99.25%
# on 99: Validation EER:  0.81%
# on 99: Validation f1 Score: 99.20%
# on 99:
# on 99:
# on 100:
#         Train Balanced Accuracy:  97.83%
# on 100: Train EER:  2.18%
# on 100:
#         Validation 100 ,Validation Loss 0.12813 , Validation Balanced Accuracy: 99.20%
# on 100: Validation EER:  0.80%
# on 100: Validation f1 Score: 99.20%
# on 100:
# on 100:
# on 101:
#         Train Balanced Accuracy:  97.84%
# on 101: Train EER:  2.16%
# on 101:
#         Validation 101 ,Validation Loss 0.12544 , Validation Balanced Accuracy: 99.26%
# on 101: Validation EER:  0.80%
# on 101: Validation f1 Score: 99.21%
# on 101:
# on 101:
# on 102:
#         Train Balanced Accuracy:  97.94%
# on 102: Train EER:  2.06%
# on 102:
#         Validation 102 ,Validation Loss 0.12486 , Validation Balanced Accuracy: 99.26%
# on 102: Validation EER:  0.78%
# on 102: Validation f1 Score: 99.23%
# on 102:
# on 102:
# on 103:
#         Train Balanced Accuracy:  97.98%
# on 103: Train EER:  2.03%
# on 103:
#         Validation 103 ,Validation Loss 0.12251 , Validation Balanced Accuracy: 99.27%
# on 103: Validation EER:  0.77%
# on 103: Validation f1 Score: 99.24%
# on 103:
# on 103:
# on 104:
#         Train Balanced Accuracy:  98.04%
# on 104: Train EER:  1.97%
# on 104:
#         Validation 104 ,Validation Loss 0.12164 , Validation Balanced Accuracy: 99.29%
# on 104: Validation EER:  0.73%
# on 104: Validation f1 Score: 99.27%
# on 104:
# on 104:
# on 105:
#         Train Balanced Accuracy:  98.04%
# on 105: Train EER:  1.95%
# on 105:
#         Validation 105 ,Validation Loss 0.12037 , Validation Balanced Accuracy: 99.30%
# on 105: Validation EER:  0.72%
# on 105: Validation f1 Score: 99.29%
# on 105:
# on 105:
# on 106:
#         Train Balanced Accuracy:  98.11%
# on 106: Train EER:  1.89%
# on 106:
#         Validation 106 ,Validation Loss 0.11870 , Validation Balanced Accuracy: 99.30%
# on 106: Validation EER:  0.69%
# on 106: Validation f1 Score: 99.30%
# on 106:
# on 106:
# on 107:
#         Train Balanced Accuracy:  98.16%
# on 107: Train EER:  1.85%
# on 107:
#         Validation 107 ,Validation Loss 0.11708 , Validation Balanced Accuracy: 99.37%
# on 107: Validation EER:  0.69%
# on 107: Validation f1 Score: 99.32%
# on 107:
# on 107:
# on 108:
#         Train Balanced Accuracy:  98.20%
# on 108: Train EER:  1.81%
# on 108:
#         Validation 108 ,Validation Loss 0.11493 , Validation Balanced Accuracy: 99.32%
# on 108: Validation EER:  0.68%
# on 108: Validation f1 Score: 99.32%
# on 108:
# on 108:
# on 109:
#         Train Balanced Accuracy:  98.24%
# on 109: Train EER:  1.76%
# on 109:
#         Validation 109 ,Validation Loss 0.11381 , Validation Balanced Accuracy: 99.38%
# on 109: Validation EER:  0.66%
# on 109: Validation f1 Score: 99.35%
# on 109:
# on 109:
# on 110:
#         Train Balanced Accuracy:  98.25%
# on 110: Train EER:  1.74%
# on 110:
#         Validation 110 ,Validation Loss 0.11143 , Validation Balanced Accuracy: 99.39%
# on 110: Validation EER:  0.64%
# on 110: Validation f1 Score: 99.37%
# on 110:
# on 110:
# on 111:
#         Train Balanced Accuracy:  98.29%
# on 111: Train EER:  1.71%
# on 111:
#         Validation 111 ,Validation Loss 0.11150 , Validation Balanced Accuracy: 99.34%
# on 111: Validation EER:  0.62%
# on 111: Validation f1 Score: 99.37%
# on 111: EarlyStopping counter: 1 out of 300
# on 111:
# on 111:
# on 112:
#         Train Balanced Accuracy:  98.33%
# on 112: Train EER:  1.67%
# on 112:
#         Validation 112 ,Validation Loss 0.10922 , Validation Balanced Accuracy: 99.40%
# on 112: Validation EER:  0.62%
# on 112: Validation f1 Score: 99.38%
# on 112:
# on 112:
# on 113:
#         Train Balanced Accuracy:  98.35%
# on 113: Train EER:  1.66%
# on 113:
#         Validation 113 ,Validation Loss 0.10669 , Validation Balanced Accuracy: 99.41%
# on 113: Validation EER:  0.61%
# on 113: Validation f1 Score: 99.39%
# on 113:
# on 113:
# on 114:
#         Train Balanced Accuracy:  98.40%
# on 114: Train EER:  1.61%
# on 114:
#         Validation 114 ,Validation Loss 0.10501 , Validation Balanced Accuracy: 99.41%
# on 114: Validation EER:  0.60%
# on 114: Validation f1 Score: 99.41%
# on 114:
# on 114:
# on 115:
#         Train Balanced Accuracy:  98.43%
# on 115: Train EER:  1.57%
# on 115:
#         Validation 115 ,Validation Loss 0.10414 , Validation Balanced Accuracy: 99.41%
# on 115: Validation EER:  0.60%
# on 115: Validation f1 Score: 99.41%
# on 115:
# on 115:
# on 116:
#         Train Balanced Accuracy:  98.45%
# on 116: Train EER:  1.55%
# on 116:
#         Validation 116 ,Validation Loss 0.10374 , Validation Balanced Accuracy: 99.42%
# on 116: Validation EER:  0.58%
# on 116: Validation f1 Score: 99.42%
# on 116:
# on 116:
# on 117:
#         Train Balanced Accuracy:  98.50%
# on 117: Train EER:  1.51%
# on 117:
#         Validation 117 ,Validation Loss 0.10217 , Validation Balanced Accuracy: 99.42%
# on 117: Validation EER:  0.58%
# on 117: Validation f1 Score: 99.42%
# on 117:
# on 117:
# on 118:
#         Train Balanced Accuracy:  98.51%
# on 118: Train EER:  1.50%
# on 118:
#         Validation 118 ,Validation Loss 0.10067 , Validation Balanced Accuracy: 99.48%
# on 118: Validation EER:  0.58%
# on 118: Validation f1 Score: 99.43%
# on 118:
# on 118:
# on 119:
#         Train Balanced Accuracy:  98.54%
# on 119: Train EER:  1.47%
# on 119:
#         Validation 119 ,Validation Loss 0.09918 , Validation Balanced Accuracy: 99.48%
# on 119: Validation EER:  0.58%
# on 119: Validation f1 Score: 99.43%
# on 119:
# on 119:
# on 120:
#         Train Balanced Accuracy:  98.58%
# on 120: Train EER:  1.42%
# on 120:
#         Validation 120 ,Validation Loss 0.09870 , Validation Balanced Accuracy: 99.48%
# on 120: Validation EER:  0.58%
# on 120: Validation f1 Score: 99.43%
# on 120:
# on 120:
# on 121:
#         Train Balanced Accuracy:  98.61%
# on 121: Train EER:  1.39%
# on 121:
#         Validation 121 ,Validation Loss 0.09759 , Validation Balanced Accuracy: 99.43%
# on 121: Validation EER:  0.57%
# on 121: Validation f1 Score: 99.43%
# on 121:
# on 121:
# on 122:
#         Train Balanced Accuracy:  98.66%
# on 122: Train EER:  1.34%
# on 122:
#         Validation 122 ,Validation Loss 0.09699 , Validation Balanced Accuracy: 99.49%
# on 122: Validation EER:  0.57%
# on 122: Validation f1 Score: 99.44%
# on 122:
# on 122:
# on 123:
#         Train Balanced Accuracy:  98.71%
# on 123: Train EER:  1.30%
# on 123:
#         Validation 123 ,Validation Loss 0.09488 , Validation Balanced Accuracy: 99.49%
# on 123: Validation EER:  0.57%
# on 123: Validation f1 Score: 99.44%
# on 123:
# on 123:
# on 124:
#         Train Balanced Accuracy:  98.71%
# on 124: Train EER:  1.29%
# on 124:
#         Validation 124 ,Validation Loss 0.09432 , Validation Balanced Accuracy: 99.49%
# on 124: Validation EER:  0.57%
# on 124: Validation f1 Score: 99.44%
# on 124:
# on 124:
# on 125:
#         Train Balanced Accuracy:  98.72%
# on 125: Train EER:  1.29%
# on 125:
#         Validation 125 ,Validation Loss 0.09282 , Validation Balanced Accuracy: 99.49%
# on 125: Validation EER:  0.55%
# on 125: Validation f1 Score: 99.46%
# on 125:
# on 125:
# on 126:
#         Train Balanced Accuracy:  98.76%
# on 126: Train EER:  1.25%
# on 126:
#         Validation 126 ,Validation Loss 0.09218 , Validation Balanced Accuracy: 99.49%
# on 126: Validation EER:  0.55%
# on 126: Validation f1 Score: 99.46%
# on 126:
# on 126:
# on 127:
#         Train Balanced Accuracy:  98.77%
# on 127: Train EER:  1.23%
# on 127:
#         Validation 127 ,Validation Loss 0.09042 , Validation Balanced Accuracy: 99.45%
# on 127: Validation EER:  0.51%
# on 127: Validation f1 Score: 99.48%
# on 127:
# on 127:
# on 128:
#         Train Balanced Accuracy:  98.77%
# on 128: Train EER:  1.23%
# on 128:
#         Validation 128 ,Validation Loss 0.08937 , Validation Balanced Accuracy: 99.51%
# on 128: Validation EER:  0.51%
# on 128: Validation f1 Score: 99.49%
# on 128:
# on 128:
# on 129:
#         Train Balanced Accuracy:  98.80%
# on 129: Train EER:  1.20%
# on 129:
#         Validation 129 ,Validation Loss 0.08810 , Validation Balanced Accuracy: 99.51%
# on 129: Validation EER:  0.51%
# on 129: Validation f1 Score: 99.49%
# on 129:
# on 129:
# on 130:
#         Train Balanced Accuracy:  98.81%
# on 130: Train EER:  1.18%
# on 130:
#         Validation 130 ,Validation Loss 0.08717 , Validation Balanced Accuracy: 99.52%
# on 130: Validation EER:  0.50%
# on 130: Validation f1 Score: 99.50%
# on 130:
# on 130:
# on 131:
#         Train Balanced Accuracy:  98.84%
# on 131: Train EER:  1.17%
# on 131:
#         Validation 131 ,Validation Loss 0.08560 , Validation Balanced Accuracy: 99.52%
# on 131: Validation EER:  0.50%
# on 131: Validation f1 Score: 99.50%
# on 131:
# on 131:
# on 132:
#         Train Balanced Accuracy:  98.85%
# on 132: Train EER:  1.16%
# on 132:
#         Validation 132 ,Validation Loss 0.08480 , Validation Balanced Accuracy: 99.52%
# on 132: Validation EER:  0.50%
# on 132: Validation f1 Score: 99.50%
# on 132:
# on 132:
# on 133:
#         Train Balanced Accuracy:  98.88%
# on 133: Train EER:  1.12%
# on 133:
#         Validation 133 ,Validation Loss 0.08411 , Validation Balanced Accuracy: 99.53%
# on 133: Validation EER:  0.49%
# on 133: Validation f1 Score: 99.52%
# on 133:
# on 133:
# on 134:
#         Train Balanced Accuracy:  98.90%
# on 134: Train EER:  1.11%
# on 134:
#         Validation 134 ,Validation Loss 0.08308 , Validation Balanced Accuracy: 99.53%
# on 134: Validation EER:  0.47%
# on 134: Validation f1 Score: 99.53%
# on 134:
# on 134:
# on 135:
#         Train Balanced Accuracy:  98.91%
# on 135: Train EER:  1.09%
# on 135:
#         Validation 135 ,Validation Loss 0.08189 , Validation Balanced Accuracy: 99.53%
# on 135: Validation EER:  0.46%
# on 135: Validation f1 Score: 99.53%
# on 135:
# on 135:
# on 136:
#         Train Balanced Accuracy:  98.91%
# on 136: Train EER:  1.09%
# on 136:
#         Validation 136 ,Validation Loss 0.08176 , Validation Balanced Accuracy: 99.54%
# on 136: Validation EER:  0.46%
# on 136: Validation f1 Score: 99.54%
# on 136:
# on 136:
# on 137:
#         Train Balanced Accuracy:  98.92%
# on 137: Train EER:  1.08%
# on 137:
#         Validation 137 ,Validation Loss 0.08149 , Validation Balanced Accuracy: 99.54%
# on 137: Validation EER:  0.46%
# on 137: Validation f1 Score: 99.54%
# on 137:
# on 137:
# on 138:
#         Train Balanced Accuracy:  98.94%
# on 138: Train EER:  1.06%
# on 138:
#         Validation 138 ,Validation Loss 0.08172 , Validation Balanced Accuracy: 99.54%
# on 138: Validation EER:  0.46%
# on 138: Validation f1 Score: 99.54%
# on 138: EarlyStopping counter: 1 out of 300
# on 138:
# on 138:
# on 139:
#         Train Balanced Accuracy:  98.96%
# on 139: Train EER:  1.04%
# on 139:
#         Validation 139 ,Validation Loss 0.08055 , Validation Balanced Accuracy: 99.54%
# on 139: Validation EER:  0.46%
# on 139: Validation f1 Score: 99.54%
# on 139:
# on 139:
# on 140:
#         Train Balanced Accuracy:  98.98%
# on 140: Train EER:  1.02%
# on 140:
#         Validation 140 ,Validation Loss 0.08016 , Validation Balanced Accuracy: 99.55%
# on 140: Validation EER:  0.46%
# on 140: Validation f1 Score: 99.55%
# on 140:
# on 140:
# on 141:
#         Train Balanced Accuracy:  99.00%
# on 141: Train EER:  1.01%
# on 141:
#         Validation 141 ,Validation Loss 0.07745 , Validation Balanced Accuracy: 99.55%
# on 141: Validation EER:  0.46%
# on 141: Validation f1 Score: 99.55%
# on 141:
# on 141:
# on 142:
#         Train Balanced Accuracy:  99.00%
# on 142: Train EER:  1.00%
# on 142:
#         Validation 142 ,Validation Loss 0.07571 , Validation Balanced Accuracy: 99.55%
# on 142: Validation EER:  0.46%
# on 142: Validation f1 Score: 99.55%
# on 142:
# on 142:
# on 143:
#         Train Balanced Accuracy:  99.01%
# on 143: Train EER:  0.99%
# on 143:
#         Validation 143 ,Validation Loss 0.07528 , Validation Balanced Accuracy: 99.55%
# on 143: Validation EER:  0.46%
# on 143: Validation f1 Score: 99.55%
# on 143:
# on 143:
# on 144:
#         Train Balanced Accuracy:  99.03%
# on 144: Train EER:  0.98%
# on 144:
#         Validation 144 ,Validation Loss 0.07530 , Validation Balanced Accuracy: 99.55%
# on 144: Validation EER:  0.46%
# on 144: Validation f1 Score: 99.56%
# on 144: EarlyStopping counter: 1 out of 300
# on 144:
# on 144:
# on 145:
#         Train Balanced Accuracy:  99.04%
# on 145: Train EER:  0.96%
# on 145:
#         Validation 145 ,Validation Loss 0.07507 , Validation Balanced Accuracy: 99.55%
# on 145: Validation EER:  0.46%
# on 145: Validation f1 Score: 99.56%
# on 145:
# on 145:
# on 146:
#         Train Balanced Accuracy:  99.05%
# on 146: Train EER:  0.96%
# on 146:
#         Validation 146 ,Validation Loss 0.07372 , Validation Balanced Accuracy: 99.55%
# on 146: Validation EER:  0.46%
# on 146: Validation f1 Score: 99.56%
# on 146:
# on 146:
# on 147:
#         Train Balanced Accuracy:  99.05%
# on 147: Train EER:  0.94%
# on 147:
#         Validation 147 ,Validation Loss 0.07263 , Validation Balanced Accuracy: 99.55%
# on 147: Validation EER:  0.46%
# on 147: Validation f1 Score: 99.56%
# on 147:
# on 147:
# on 148:
#         Train Balanced Accuracy:  99.07%
# on 148: Train EER:  0.92%
# on 148:
#         Validation 148 ,Validation Loss 0.07113 , Validation Balanced Accuracy: 99.55%
# on 148: Validation EER:  0.46%
# on 148: Validation f1 Score: 99.56%
# on 148:
# on 148:
# on 149:
#         Train Balanced Accuracy:  99.08%
# on 149: Train EER:  0.92%
# on 149:
#         Validation 149 ,Validation Loss 0.07101 , Validation Balanced Accuracy: 99.55%
# on 149: Validation EER:  0.46%
# on 149: Validation f1 Score: 99.56%
# on 149:
# on 149:
# on 150:
#         Train Balanced Accuracy:  99.11%
# on 150: Train EER:  0.90%
# on 150:
#         Validation 150 ,Validation Loss 0.06971 , Validation Balanced Accuracy: 99.56%
# on 150: Validation EER:  0.46%
# on 150: Validation f1 Score: 99.58%
# on 150:
# on 150:
# on 151:
#         Train Balanced Accuracy:  99.11%
# on 151: Train EER:  0.89%
# on 151:
#         Validation 151 ,Validation Loss 0.06926 , Validation Balanced Accuracy: 99.57%
# on 151: Validation EER:  0.46%
# on 151: Validation f1 Score: 99.59%
# on 151:
# on 151:
# on 152:
#         Train Balanced Accuracy:  99.11%
# on 152: Train EER:  0.89%
# on 152:
#         Validation 152 ,Validation Loss 0.06883 , Validation Balanced Accuracy: 99.57%
# on 152: Validation EER:  0.46%
# on 152: Validation f1 Score: 99.60%
# on 152:
# on 152:
# on 153:
#         Train Balanced Accuracy:  99.11%
# on 153: Train EER:  0.89%
# on 153:
#         Validation 153 ,Validation Loss 0.06823 , Validation Balanced Accuracy: 99.57%
# on 153: Validation EER:  0.46%
# on 153: Validation f1 Score: 99.60%
# on 153:
# on 153:
# on 154:
#         Train Balanced Accuracy:  99.12%
# on 154: Train EER:  0.87%
# on 154:
#         Validation 154 ,Validation Loss 0.06841 , Validation Balanced Accuracy: 99.57%
# on 154: Validation EER:  0.46%
# on 154: Validation f1 Score: 99.60%
# on 154: EarlyStopping counter: 1 out of 300
# on 154:
# on 154:
# on 155:
#         Train Balanced Accuracy:  99.14%
# on 155: Train EER:  0.86%
# on 155:
#         Validation 155 ,Validation Loss 0.06756 , Validation Balanced Accuracy: 99.57%
# on 155: Validation EER:  0.46%
# on 155: Validation f1 Score: 99.60%
# on 155:
# on 155:
# on 156:
#         Train Balanced Accuracy:  99.15%
# on 156: Train EER:  0.86%
# on 156:
#         Validation 156 ,Validation Loss 0.06627 , Validation Balanced Accuracy: 99.57%
# on 156: Validation EER:  0.46%
# on 156: Validation f1 Score: 99.60%
# on 156:
# on 156:
# on 157:
#         Train Balanced Accuracy:  99.14%
# on 157: Train EER:  0.86%
# on 157:
#         Validation 157 ,Validation Loss 0.06534 , Validation Balanced Accuracy: 99.57%
# on 157: Validation EER:  0.46%
# on 157: Validation f1 Score: 99.60%
# on 157:
# on 157:
# on 158:
#         Train Balanced Accuracy:  99.14%
# on 158: Train EER:  0.86%
# on 158:
#         Validation 158 ,Validation Loss 0.06644 , Validation Balanced Accuracy: 99.58%
# on 158: Validation EER:  0.46%
# on 158: Validation f1 Score: 99.61%
# on 158: EarlyStopping counter: 1 out of 300
# on 158:
# on 158:
# on 159:
#         Train Balanced Accuracy:  99.15%
# on 159: Train EER:  0.85%
# on 159:
#         Validation 159 ,Validation Loss 0.06385 , Validation Balanced Accuracy: 99.59%
# on 159: Validation EER:  0.46%
# on 159: Validation f1 Score: 99.62%
# on 159:
# on 159:
# on 160:
#         Train Balanced Accuracy:  99.17%
# on 160: Train EER:  0.83%
# on 160:
#         Validation 160 ,Validation Loss 0.06511 , Validation Balanced Accuracy: 99.59%
# on 160: Validation EER:  0.46%
# on 160: Validation f1 Score: 99.62%
# on 160: EarlyStopping counter: 1 out of 300
# on 160:
# on 160:
# on 161:
#         Train Balanced Accuracy:  99.18%
# on 161: Train EER:  0.83%
# on 161:
#         Validation 161 ,Validation Loss 0.06296 , Validation Balanced Accuracy: 99.59%
# on 161: Validation EER:  0.46%
# on 161: Validation f1 Score: 99.64%
# on 161:
# on 161:
# on 162:
#         Train Balanced Accuracy:  99.17%
# on 162: Train EER:  0.83%
# on 162:
#         Validation 162 ,Validation Loss 0.06188 , Validation Balanced Accuracy: 99.59%
# on 162: Validation EER:  0.46%
# on 162: Validation f1 Score: 99.64%
# on 162:
# on 162:
# on 163:
#         Train Balanced Accuracy:  99.18%
# on 163: Train EER:  0.82%
# on 163:
#         Validation 163 ,Validation Loss 0.06224 , Validation Balanced Accuracy: 99.60%
# on 163: Validation EER:  0.46%
# on 163: Validation f1 Score: 99.65%
# on 163: EarlyStopping counter: 1 out of 300
# on 163:
# on 163:
# on 164:
#         Train Balanced Accuracy:  99.19%
# on 164: Train EER:  0.82%
# on 164:
#         Validation 164 ,Validation Loss 0.06108 , Validation Balanced Accuracy: 99.60%
# on 164: Validation EER:  0.46%
# on 164: Validation f1 Score: 99.65%
# on 164:
# on 164:
# on 165:
#         Train Balanced Accuracy:  99.19%
# on 165: Train EER:  0.81%
# on 165:
#         Validation 165 ,Validation Loss 0.06053 , Validation Balanced Accuracy: 99.60%
# on 165: Validation EER:  0.46%
# on 165: Validation f1 Score: 99.65%
# on 165:
# on 165:
# on 166:
#         Train Balanced Accuracy:  99.21%
# on 166: Train EER:  0.80%
# on 166:
#         Validation 166 ,Validation Loss 0.06076 , Validation Balanced Accuracy: 99.60%
# on 166: Validation EER:  0.46%
# on 166: Validation f1 Score: 99.65%
# on 166: EarlyStopping counter: 1 out of 300
# on 166:
# on 166:
# on 167:
#         Train Balanced Accuracy:  99.22%
# on 167: Train EER:  0.79%
# on 167:
#         Validation 167 ,Validation Loss 0.05937 , Validation Balanced Accuracy: 99.61%
# on 167: Validation EER:  0.46%
# on 167: Validation f1 Score: 99.66%
# on 167:
# on 167:
# on 168:
#         Train Balanced Accuracy:  99.22%
# on 168: Train EER:  0.78%
# on 168:
#         Validation 168 ,Validation Loss 0.05962 , Validation Balanced Accuracy: 99.61%
# on 168: Validation EER:  0.46%
# on 168: Validation f1 Score: 99.66%
# on 168: EarlyStopping counter: 1 out of 300
# on 168:
# on 168:
# on 169:
#         Train Balanced Accuracy:  99.22%
# on 169: Train EER:  0.78%
# on 169:
#         Validation 169 ,Validation Loss 0.05824 , Validation Balanced Accuracy: 99.61%
# on 169: Validation EER:  0.46%
# on 169: Validation f1 Score: 99.67%
# on 169:
# on 169:
# on 170:
#         Train Balanced Accuracy:  99.24%
# on 170: Train EER:  0.77%
# on 170:
#         Validation 170 ,Validation Loss 0.05825 , Validation Balanced Accuracy: 99.61%
# on 170: Validation EER:  0.46%
# on 170: Validation f1 Score: 99.67%
# on 170: EarlyStopping counter: 1 out of 300
# on 170:
# on 170:
# on 171:
#         Train Balanced Accuracy:  99.26%
# on 171: Train EER:  0.74%
# on 171:
#         Validation 171 ,Validation Loss 0.05731 , Validation Balanced Accuracy: 99.62%
# on 171: Validation EER:  0.46%
# on 171: Validation f1 Score: 99.69%
# on 171:
# on 171:
# on 172:
#         Train Balanced Accuracy:  99.27%
# on 172: Train EER:  0.73%
# on 172:
#         Validation 172 ,Validation Loss 0.05666 , Validation Balanced Accuracy: 99.62%
# on 172: Validation EER:  0.46%
# on 172: Validation f1 Score: 99.69%
# on 172:
# on 172:
# on 173:
#         Train Balanced Accuracy:  99.27%
# on 173: Train EER:  0.73%
# on 173:
#         Validation 173 ,Validation Loss 0.05621 , Validation Balanced Accuracy: 99.62%
# on 173: Validation EER:  0.46%
# on 173: Validation f1 Score: 99.69%
# on 173:
# on 173:
# on 174:
#         Train Balanced Accuracy:  99.28%
# on 174: Train EER:  0.72%
# on 174:
#         Validation 174 ,Validation Loss 0.05543 , Validation Balanced Accuracy: 99.62%
# on 174: Validation EER:  0.46%
# on 174: Validation f1 Score: 99.69%
# on 174:
# on 174:
# on 175:
#         Train Balanced Accuracy:  99.28%
# on 175: Train EER:  0.72%
# on 175:
#         Validation 175 ,Validation Loss 0.05487 , Validation Balanced Accuracy: 99.62%
# on 175: Validation EER:  0.46%
# on 175: Validation f1 Score: 99.69%
# on 175:
# on 175:
# on 176:
#         Train Balanced Accuracy:  99.29%
# on 176: Train EER:  0.71%
# on 176:
#         Validation 176 ,Validation Loss 0.05525 , Validation Balanced Accuracy: 99.62%
# on 176: Validation EER:  0.46%
# on 176: Validation f1 Score: 99.69%
# on 176: EarlyStopping counter: 1 out of 300
# on 176:
# on 176:
# on 177:
#         Train Balanced Accuracy:  99.30%
# on 177: Train EER:  0.70%
# on 177:
#         Validation 177 ,Validation Loss 0.05418 , Validation Balanced Accuracy: 99.62%
# on 177: Validation EER:  0.46%
# on 177: Validation f1 Score: 99.69%
# on 177:
# on 177:
# on 178:
#         Train Balanced Accuracy:  99.30%
# on 178: Train EER:  0.70%
# on 178:
#         Validation 178 ,Validation Loss 0.05370 , Validation Balanced Accuracy: 99.62%
# on 178: Validation EER:  0.46%
# on 178: Validation f1 Score: 99.69%
# on 178:
# on 178:
# on 179:
#         Train Balanced Accuracy:  99.32%
# on 179: Train EER:  0.68%
# on 179:
#         Validation 179 ,Validation Loss 0.05386 , Validation Balanced Accuracy: 99.62%
# on 179: Validation EER:  0.46%
# on 179: Validation f1 Score: 99.69%
# on 179: EarlyStopping counter: 1 out of 300
# on 179:
# on 179:
# on 180:
#         Train Balanced Accuracy:  99.32%
# on 180: Train EER:  0.68%
# on 180:
#         Validation 180 ,Validation Loss 0.05269 , Validation Balanced Accuracy: 99.62%
# on 180: Validation EER:  0.46%
# on 180: Validation f1 Score: 99.69%
# on 180:
# on 180:
# on 181:
#         Train Balanced Accuracy:  99.33%
# on 181: Train EER:  0.67%
# on 181:
#         Validation 181 ,Validation Loss 0.05250 , Validation Balanced Accuracy: 99.63%
# on 181: Validation EER:  0.46%
# on 181: Validation f1 Score: 99.70%
# on 181:
# on 181:
# on 182:
#         Train Balanced Accuracy:  99.33%
# on 182: Train EER:  0.66%
# on 182:
#         Validation 182 ,Validation Loss 0.05327 , Validation Balanced Accuracy: 99.63%
# on 182: Validation EER:  0.46%
# on 182: Validation f1 Score: 99.71%
# on 182: EarlyStopping counter: 1 out of 300
# on 182:
# on 182:
# on 183:
#         Train Balanced Accuracy:  99.34%
# on 183: Train EER:  0.66%
# on 183:
#         Validation 183 ,Validation Loss 0.05202 , Validation Balanced Accuracy: 99.63%
# on 183: Validation EER:  0.46%
# on 183: Validation f1 Score: 99.71%
# on 183:
# on 183:
# on 184:
#         Train Balanced Accuracy:  99.35%
# on 184: Train EER:  0.66%
# on 184:
#         Validation 184 ,Validation Loss 0.05198 , Validation Balanced Accuracy: 99.63%
# on 184: Validation EER:  0.46%
# on 184: Validation f1 Score: 99.71%
# on 184:
# on 184:
# on 185:
#         Train Balanced Accuracy:  99.36%
# on 185: Train EER:  0.64%
# on 185:
#         Validation 185 ,Validation Loss 0.05169 , Validation Balanced Accuracy: 99.63%
# on 185: Validation EER:  0.46%
# on 185: Validation f1 Score: 99.71%
# on 185:
# on 185:
# on 186:
#         Train Balanced Accuracy:  99.36%
# on 186: Train EER:  0.64%
# on 186:
#         Validation 186 ,Validation Loss 0.05052 , Validation Balanced Accuracy: 99.63%
# on 186: Validation EER:  0.46%
# on 186: Validation f1 Score: 99.71%
# on 186:
# on 186:
# on 187:
#         Train Balanced Accuracy:  99.37%
# on 187: Train EER:  0.64%
# on 187:
#         Validation 187 ,Validation Loss 0.05029 , Validation Balanced Accuracy: 99.63%
# on 187: Validation EER:  0.46%
# on 187: Validation f1 Score: 99.71%
# on 187:
# on 187:
# on 188:
#         Train Balanced Accuracy:  99.37%
# on 188: Train EER:  0.63%
# on 188:
#         Validation 188 ,Validation Loss 0.05001 , Validation Balanced Accuracy: 99.64%
# ...
# on 242:
#         Validation 242 ,Validation Loss 0.03383 , Validation Balanced Accuracy: 99.55%
# on 242: Validation EER:  0.46%
# on 242: Validation f1 Score: 99.47%
# on 242:
# on 242:
# on 243:
#         Train Balanced Accuracy:  99.64%
# on 243: Train EER:  0.35%
# on 243:
#         Validation 243 ,Validation Loss 0.03353 , Validation Balanced Accuracy: 99.55%
# on 243: Validation EER:  0.46%
# on 243: Validation f1 Score: 99.47%
# on 243:
# on 243:
# on 244:
#         Train Balanced Accuracy:  99.65%
# on 244: Train EER:  0.35%
# on 244:
#         Validation 244 ,Validation Loss 0.03328 , Validation Balanced Accuracy: 99.55%
# on 244: Validation EER:  0.46%
# on 244: Validation f1 Score: 99.47%
# on 244:
# on 244:
# on 245:
#         Train Balanced Accuracy:  99.66%
# on 245: Train EER:  0.34%
# on 245:
#         Validation 245 ,Validation Loss 0.03334 , Validation Balanced Accuracy: 99.55%
# on 245: Validation EER:  0.46%
# on 245: Validation f1 Score: 99.47%
# on 245: EarlyStopping counter: 1 out of 300
# on 245:
# on 245:
# on 246:
#         Train Balanced Accuracy:  99.66%
# on 246: Train EER:  0.34%
# on 246:
#         Validation 246 ,Validation Loss 0.03366 , Validation Balanced Accuracy: 99.56%
# on 246: Validation EER:  0.46%
# on 246: Validation f1 Score: 99.48%
# on 246: EarlyStopping counter: 2 out of 300
# on 246:
# on 246:
# on 247:
#         Train Balanced Accuracy:  99.66%
# on 247: Train EER:  0.34%
# on 247:
#         Validation 247 ,Validation Loss 0.03278 , Validation Balanced Accuracy: 99.56%
# on 247: Validation EER:  0.46%
# on 247: Validation f1 Score: 99.48%
# on 247:
# on 247:
# on 248:
#         Train Balanced Accuracy:  99.67%
# on 248: Train EER:  0.34%
# on 248:
#         Validation 248 ,Validation Loss 0.03320 , Validation Balanced Accuracy: 99.56%
# on 248: Validation EER:  0.46%
# on 248: Validation f1 Score: 99.48%
# on 248: EarlyStopping counter: 1 out of 300
# on 248:
# on 248:
# on 249:
#         Train Balanced Accuracy:  99.67%
# on 249: Train EER:  0.33%
# on 249:
#         Validation 249 ,Validation Loss 0.03265 , Validation Balanced Accuracy: 99.56%
# on 249: Validation EER:  0.46%
# on 249: Validation f1 Score: 99.48%
# on 249:
# on 249:
# on 250:
#         Train Balanced Accuracy:  99.67%
# on 250: Train EER:  0.33%
# on 250:
#         Validation 250 ,Validation Loss 0.03252 , Validation Balanced Accuracy: 99.56%
# on 250: Validation EER:  0.46%
# on 250: Validation f1 Score: 99.48%
# on 250:
# on 250:
# on 251:
#         Train Balanced Accuracy:  99.68%
# on 251: Train EER:  0.33%
# on 251:
#         Validation 251 ,Validation Loss 0.03246 , Validation Balanced Accuracy: 99.56%
# on 251: Validation EER:  0.46%
# on 251: Validation f1 Score: 99.48%
# on 251:
# on 251:
# on 252:
#         Train Balanced Accuracy:  99.68%
# on 252: Train EER:  0.33%
# on 252:
#         Validation 252 ,Validation Loss 0.03201 , Validation Balanced Accuracy: 99.56%
# on 252: Validation EER:  0.46%
# on 252: Validation f1 Score: 99.48%
# on 252:
# on 252:
# on 253:
#         Train Balanced Accuracy:  99.69%
# on 253: Train EER:  0.32%
# on 253:
#         Validation 253 ,Validation Loss 0.03150 , Validation Balanced Accuracy: 99.56%
# on 253: Validation EER:  0.46%
# on 253: Validation f1 Score: 99.48%
# on 253:
# on 253:
# on 254:
#         Train Balanced Accuracy:  99.69%
# on 254: Train EER:  0.31%
# on 254:
#         Validation 254 ,Validation Loss 0.03200 , Validation Balanced Accuracy: 99.56%
# on 254: Validation EER:  0.46%
# on 254: Validation f1 Score: 99.48%
# on 254: EarlyStopping counter: 1 out of 300
# on 254:
# on 254:
# on 255:
#         Train Balanced Accuracy:  99.70%
# on 255: Train EER:  0.31%
# on 255:
#         Validation 255 ,Validation Loss 0.03144 , Validation Balanced Accuracy: 99.56%
# on 255: Validation EER:  0.46%
# on 255: Validation f1 Score: 99.48%
# on 255:
# on 255:
# on 256:
#         Train Balanced Accuracy:  99.69%
# on 256: Train EER:  0.31%
# on 256:
#         Validation 256 ,Validation Loss 0.03117 , Validation Balanced Accuracy: 99.56%
# on 256: Validation EER:  0.46%
# on 256: Validation f1 Score: 99.48%
# on 256:
# on 256:
# on 257:
#         Train Balanced Accuracy:  99.69%
# on 257: Train EER:  0.31%
# on 257:
#         Validation 257 ,Validation Loss 0.03083 , Validation Balanced Accuracy: 99.56%
# on 257: Validation EER:  0.46%
# on 257: Validation f1 Score: 99.48%
# on 257:
# on 257:
# on 258:
#         Train Balanced Accuracy:  99.70%
# on 258: Train EER:  0.31%
# on 258:
#         Validation 258 ,Validation Loss 0.03049 , Validation Balanced Accuracy: 99.56%
# on 258: Validation EER:  0.46%
# on 258: Validation f1 Score: 99.48%
# on 258:
# on 258:
# on 259:
#         Train Balanced Accuracy:  99.71%
# on 259: Train EER:  0.30%
# on 259:
#         Validation 259 ,Validation Loss 0.03054 , Validation Balanced Accuracy: 99.56%
# on 259: Validation EER:  0.46%
# on 259: Validation f1 Score: 99.48%
# on 259: EarlyStopping counter: 1 out of 300
# on 259:
# on 259:
# on 260:
#         Train Balanced Accuracy:  99.70%
# on 260: Train EER:  0.30%
# on 260:
#         Validation 260 ,Validation Loss 0.03019 , Validation Balanced Accuracy: 99.56%
# on 260: Validation EER:  0.46%
# on 260: Validation f1 Score: 99.48%
# on 260:
# on 260:
# on 261:
#         Train Balanced Accuracy:  99.72%
# on 261: Train EER:  0.28%
# on 261:
#         Validation 261 ,Validation Loss 0.03007 , Validation Balanced Accuracy: 99.57%
# on 261: Validation EER:  0.46%
# on 261: Validation f1 Score: 99.50%
# on 261:
# on 261:
# on 262:
#         Train Balanced Accuracy:  99.72%
# on 262: Train EER:  0.29%
# on 262:
#         Validation 262 ,Validation Loss 0.02989 , Validation Balanced Accuracy: 99.57%
# on 262: Validation EER:  0.46%
# on 262: Validation f1 Score: 99.50%
# on 262:
# on 262:
# on 263:
#         Train Balanced Accuracy:  99.72%
# on 263: Train EER:  0.29%
# on 263:
#         Validation 263 ,Validation Loss 0.02990 , Validation Balanced Accuracy: 99.57%
# on 263: Validation EER:  0.46%
# on 263: Validation f1 Score: 99.50%
# on 263: EarlyStopping counter: 1 out of 300
# on 263:
# on 263:
# on 264:
#         Train Balanced Accuracy:  99.72%
# on 264: Train EER:  0.29%
# on 264:
#         Validation 264 ,Validation Loss 0.02957 , Validation Balanced Accuracy: 99.57%
# on 264: Validation EER:  0.46%
# on 264: Validation f1 Score: 99.50%
# on 264:
# on 264:
# on 265:
#         Train Balanced Accuracy:  99.72%
# on 265: Train EER:  0.29%
# on 265:
#         Validation 265 ,Validation Loss 0.03082 , Validation Balanced Accuracy: 99.57%
# on 265: Validation EER:  0.46%
# on 265: Validation f1 Score: 99.50%
# on 265: EarlyStopping counter: 1 out of 300
# on 265:
# on 265:
# on 266:
#         Train Balanced Accuracy:  99.72%
# on 266: Train EER:  0.28%
# on 266:
#         Validation 266 ,Validation Loss 0.02938 , Validation Balanced Accuracy: 99.58%
# on 266: Validation EER:  0.46%
# on 266: Validation f1 Score: 99.52%
# on 266:
# on 266:
# on 267:
#         Train Balanced Accuracy:  99.72%
# on 267: Train EER:  0.28%
# on 267:
#         Validation 267 ,Validation Loss 0.02920 , Validation Balanced Accuracy: 99.58%
# on 267: Validation EER:  0.46%
# on 267: Validation f1 Score: 99.53%
# on 267:
# on 267:
# on 268:
#         Train Balanced Accuracy:  99.72%
# on 268: Train EER:  0.29%
# on 268:
#         Validation 268 ,Validation Loss 0.02912 , Validation Balanced Accuracy: 99.58%
# on 268: Validation EER:  0.46%
# on 268: Validation f1 Score: 99.53%
# on 268:
# on 268:
# on 269:
#         Train Balanced Accuracy:  99.72%
# on 269: Train EER:  0.28%
# on 269:
#         Validation 269 ,Validation Loss 0.02871 , Validation Balanced Accuracy: 99.58%
# on 269: Validation EER:  0.46%
# on 269: Validation f1 Score: 99.53%
# on 269:
# on 269:
# on 270:
#         Train Balanced Accuracy:  99.72%
# on 270: Train EER:  0.28%
# on 270:
#         Validation 270 ,Validation Loss 0.02915 , Validation Balanced Accuracy: 99.58%
# on 270: Validation EER:  0.46%
# on 270: Validation f1 Score: 99.53%
# on 270: EarlyStopping counter: 1 out of 300
# on 270:
# on 270:
# on 271:
#         Train Balanced Accuracy:  99.72%
# on 271: Train EER:  0.28%
# on 271:
#         Validation 271 ,Validation Loss 0.02880 , Validation Balanced Accuracy: 99.58%
# on 271: Validation EER:  0.46%
# on 271: Validation f1 Score: 99.53%
# on 271: EarlyStopping counter: 2 out of 300
# on 271:
# on 271:
# on 272:
#         Train Balanced Accuracy:  99.73%
# on 272: Train EER:  0.28%
# on 272:
#         Validation 272 ,Validation Loss 0.02834 , Validation Balanced Accuracy: 99.59%
# on 272: Validation EER:  0.46%
# on 272: Validation f1 Score: 99.54%
# on 272:
# on 272:
# on 273:
#         Train Balanced Accuracy:  99.73%
# on 273: Train EER:  0.28%
# on 273:
#         Validation 273 ,Validation Loss 0.02821 , Validation Balanced Accuracy: 99.60%
# on 273: Validation EER:  0.46%
# on 273: Validation f1 Score: 99.55%
# on 273:
# on 273:
# on 274:
#         Train Balanced Accuracy:  99.72%
# on 274: Train EER:  0.28%
# on 274:
#         Validation 274 ,Validation Loss 0.02825 , Validation Balanced Accuracy: 99.60%
# on 274: Validation EER:  0.46%
# on 274: Validation f1 Score: 99.55%
# on 274: EarlyStopping counter: 1 out of 300
# on 274:
# on 274:
# on 275:
#         Train Balanced Accuracy:  99.73%
# on 275: Train EER:  0.28%
# on 275:
#         Validation 275 ,Validation Loss 0.02801 , Validation Balanced Accuracy: 99.60%
# on 275: Validation EER:  0.46%
# on 275: Validation f1 Score: 99.55%
# on 275:
# on 275:
# on 276:
#         Train Balanced Accuracy:  99.73%
# on 276: Train EER:  0.28%
# on 276:
#         Validation 276 ,Validation Loss 0.02789 , Validation Balanced Accuracy: 99.60%
# on 276: Validation EER:  0.46%
# on 276: Validation f1 Score: 99.55%
# on 276:
# on 276:
# on 277:
#         Train Balanced Accuracy:  99.73%
# on 277: Train EER:  0.28%
# on 277:
#         Validation 277 ,Validation Loss 0.02798 , Validation Balanced Accuracy: 99.60%
# on 277: Validation EER:  0.46%
# on 277: Validation f1 Score: 99.55%
# on 277: EarlyStopping counter: 1 out of 300
# on 277:
# on 277:
# on 278:
#         Train Balanced Accuracy:  99.73%
# on 278: Train EER:  0.28%
# on 278:
#         Validation 278 ,Validation Loss 0.02750 , Validation Balanced Accuracy: 99.60%
# on 278: Validation EER:  0.46%
# on 278: Validation f1 Score: 99.55%
# on 278:
# on 278:
# on 279:
#         Train Balanced Accuracy:  99.73%
# on 279: Train EER:  0.28%
# on 279:
#         Validation 279 ,Validation Loss 0.02764 , Validation Balanced Accuracy: 99.60%
# on 279: Validation EER:  0.46%
# on 279: Validation f1 Score: 99.55%
# on 279: EarlyStopping counter: 1 out of 300
# on 279:
# on 279:
# on 280:
#         Train Balanced Accuracy:  99.73%
# on 280: Train EER:  0.28%
# on 280:
#         Validation 280 ,Validation Loss 0.02787 , Validation Balanced Accuracy: 99.60%
# on 280: Validation EER:  0.45%
# on 280: Validation f1 Score: 99.56%
# on 280: EarlyStopping counter: 2 out of 300
# on 280:
# on 280:
# on 281:
#         Train Balanced Accuracy:  99.73%
# on 281: Train EER:  0.28%
# on 281:
#         Validation 281 ,Validation Loss 0.02729 , Validation Balanced Accuracy: 99.61%
# on 281: Validation EER:  0.43%
# on 281: Validation f1 Score: 99.58%
# on 281:
# on 281:
# on 282:
#         Train Balanced Accuracy:  99.74%
# on 282: Train EER:  0.27%
# on 282:
#         Validation 282 ,Validation Loss 0.02723 , Validation Balanced Accuracy: 99.61%
# on 282: Validation EER:  0.43%
# on 282: Validation f1 Score: 99.58%
# on 282:
# on 282:
# on 283:
#         Train Balanced Accuracy:  99.74%
# on 283: Train EER:  0.27%
# on 283:
#         Validation 283 ,Validation Loss 0.02722 , Validation Balanced Accuracy: 99.62%
# on 283: Validation EER:  0.42%
# on 283: Validation f1 Score: 99.59%
# on 283:
# on 283:
# on 284:
#         Train Balanced Accuracy:  99.74%
# on 284: Train EER:  0.27%
# on 284:
#         Validation 284 ,Validation Loss 0.02722 , Validation Balanced Accuracy: 99.62%
# on 284: Validation EER:  0.42%
# on 284: Validation f1 Score: 99.59%
# on 284: EarlyStopping counter: 1 out of 300
# on 284:
# on 284:
# on 285:
#         Train Balanced Accuracy:  99.74%
# on 285: Train EER:  0.26%
# on 285:
#         Validation 285 ,Validation Loss 0.02690 , Validation Balanced Accuracy: 99.62%
# on 285: Validation EER:  0.41%
# on 285: Validation f1 Score: 99.60%
# on 285:
# on 285:
# on 286:
#         Train Balanced Accuracy:  99.74%
# on 286: Train EER:  0.27%
# on 286:
#         Validation 286 ,Validation Loss 0.02642 , Validation Balanced Accuracy: 99.62%
# on 286: Validation EER:  0.41%
# on 286: Validation f1 Score: 99.60%
# on 286:
# on 286:
# on 287:
#         Train Balanced Accuracy:  99.74%
# on 287: Train EER:  0.26%
# on 287:
#         Validation 287 ,Validation Loss 0.02641 , Validation Balanced Accuracy: 99.63%
# on 287: Validation EER:  0.39%
# on 287: Validation f1 Score: 99.61%
# on 287:
# on 287:
# on 288:
#         Train Balanced Accuracy:  99.74%
# on 288: Train EER:  0.26%
# on 288:
#         Validation 288 ,Validation Loss 0.02634 , Validation Balanced Accuracy: 99.63%
# on 288: Validation EER:  0.39%
# on 288: Validation f1 Score: 99.61%
# on 288:
# on 288:
# on 289:
#         Train Balanced Accuracy:  99.75%
# on 289: Train EER:  0.26%
# on 289:
#         Validation 289 ,Validation Loss 0.02605 , Validation Balanced Accuracy: 99.63%
# on 289: Validation EER:  0.39%
# on 289: Validation f1 Score: 99.61%
# on 289:
# on 289:
# on 290:
#         Train Balanced Accuracy:  99.75%
# on 290: Train EER:  0.26%
# on 290:
#         Validation 290 ,Validation Loss 0.02576 , Validation Balanced Accuracy: 99.64%
# on 290: Validation EER:  0.38%
# on 290: Validation f1 Score: 99.62%
# on 290:
# on 290:
# on 291:
#         Train Balanced Accuracy:  99.75%
# on 291: Train EER:  0.26%
# on 291:
#         Validation 291 ,Validation Loss 0.02595 , Validation Balanced Accuracy: 99.64%
# on 291: Validation EER:  0.38%
# on 291: Validation f1 Score: 99.62%
# on 291: EarlyStopping counter: 1 out of 300
# on 291:
# on 291:
# on 292:
#         Train Balanced Accuracy:  99.75%
# on 292: Train EER:  0.26%
# on 292:
#         Validation 292 ,Validation Loss 0.02556 , Validation Balanced Accuracy: 99.64%
# on 292: Validation EER:  0.38%
# on 292: Validation f1 Score: 99.62%
# on 292:
# on 292:
# on 293:
#         Train Balanced Accuracy:  99.75%
# on 293: Train EER:  0.26%
# on 293:
#         Validation 293 ,Validation Loss 0.02535 , Validation Balanced Accuracy: 99.64%
# on 293: Validation EER:  0.38%
# on 293: Validation f1 Score: 99.62%
# on 293:
# on 293:
# on 294:
#         Train Balanced Accuracy:  99.74%
# on 294: Train EER:  0.26%
# on 294:
#         Validation 294 ,Validation Loss 0.02542 , Validation Balanced Accuracy: 99.64%
# on 294: Validation EER:  0.38%
# on 294: Validation f1 Score: 99.62%
# on 294: EarlyStopping counter: 1 out of 300
# on 294:
# on 294:
# on 295:
#         Train Balanced Accuracy:  99.75%
# on 295: Train EER:  0.26%
# on 295:
#         Validation 295 ,Validation Loss 0.02490 , Validation Balanced Accuracy: 99.64%
# on 295: Validation EER:  0.38%
# on 295: Validation f1 Score: 99.62%
# on 295:
# on 295:
# on 296:
#         Train Balanced Accuracy:  99.75%
# on 296: Train EER:  0.26%
# on 296:
#         Validation 296 ,Validation Loss 0.02500 , Validation Balanced Accuracy: 99.64%
# on 296: Validation EER:  0.37%
# on 296: Validation f1 Score: 99.64%
# on 296: EarlyStopping counter: 1 out of 300
# on 296:
# on 296:
# on 297:
#         Train Balanced Accuracy:  99.75%
# on 297: Train EER:  0.26%
# on 297:
#         Validation 297 ,Validation Loss 0.02481 , Validation Balanced Accuracy: 99.64%
# on 297: Validation EER:  0.37%
# on 297: Validation f1 Score: 99.64%
# on 297:
# on 297:
# on 298:
#         Train Balanced Accuracy:  99.74%
# on 298: Train EER:  0.26%
# on 298:
#         Validation 298 ,Validation Loss 0.02466 , Validation Balanced Accuracy: 99.64%
# on 298: Validation EER:  0.37%
# on 298: Validation f1 Score: 99.64%
# on 298:
# on 298:
# on 299:
#         Train Balanced Accuracy:  99.75%
# on 299: Train EER:  0.26%
# on 299:
#         Validation 299 ,Validation Loss 0.02470 , Validation Balanced Accuracy: 99.64%
# on 299: Validation EER:  0.37%
# on 299: Validation f1 Score: 99.64%
# on 299: EarlyStopping counter: 1 out of 300
# on 299:
# on 299:
# on 300:
#         Train Balanced Accuracy:  99.76%
# on 300: Train EER:  0.24%
# on 300:
#         Validation 300 ,Validation Loss 0.02476 , Validation Balanced Accuracy: 99.64%
# on 300: Validation EER:  0.37%
# on 300: Validation f1 Score: 99.64%
# on 300: EarlyStopping counter: 2 out of 300
# on 300:
# on 300:
# |████████████████████████████████████████| 300/300 [100%] in 2:43.1 (0.00/s)

# %%
import pickle
#file_path = 'Male_best_model_9_2.pkl'

# Open the file in binary write mode
#with open(file_path, 'wb') as f:
    # Serialize the object and write it to the file
#    pickle.dump(model, f)

# %%
import matplotlib.pyplot as plt
# Plot training & validation accuracy and eer values
DNN_functions.plot_loss_accuracy(num_epoch,train_losses,validation_losses,train_acc_percentage,validation_acc_percentage,f1_score_validation,validation_total_eer,train_total_err)
# Out:
# c:\Users\avish\OneDrive\Desktop\thesis_research\avishai_work\utils\DNN_functions.py:141: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Inference on The Test Set

# %% [markdown]
# Here, I will conduct inference to assess the outcomes on the test set.
# Additionally, I will evaluate the model's performance on the test set using metrics such as confusion matrix, Equal Error Rate (EER), and balanced accuracy.
# These assessments will involve utilizing thresholds derived from both the validation set and the test set.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import det_curve
import torch.nn.functional as F 

# get the validation probability
with torch.no_grad():
    if training_type == '1_neorun_end_sigmoid':
        validation_prob = torch.sigmoid(model(torch.Tensor(validation_dataset.data).to(device)).cpu())
    
valid_total_prob = validation_prob.cpu().numpy().copy() # copy the validation probability

valid_total_labels = validation_dataset.is_spoofed.copy() # copy the validation labels

eer, val_thresh = my_functions.compute_eer(valid_total_labels,valid_total_prob) # compute equal error rate

fpr, fnr, _ = det_curve(valid_total_labels, valid_total_prob) # compute false positive rate and false negative rate

my_functions.DETCurve(fpr = fpr, fnr = fnr, eer_fpr = eer,eer_fnr = eer, model_name = "Split Wave Channels Net - Validation Set",plot_type="step") # plot DET curve

# get the test probability
with torch.no_grad():
    model = model.to(device)
    if training_type == '1_neorun_end_sigmoid':
        test_prob = torch.sigmoid(model(torch.Tensor(test_dataset.data).to(device)).cpu()) # get the test probability

test_total_prob = test_prob.cpu().numpy().copy() # copy the test probability

test_total_labels = test_dataset.is_spoofed.copy() # copy the test labels


prediction = np.array([1 if total_prob_element > val_thresh else 0 for total_prob_element in test_total_prob]) # get the prediction with the validation threshold

valid_thr_prediction_dnn = prediction.copy() # copy the prediction with the validation threshold

# get the confusion matrix with the validation threshold on the test set
cm = sklearn.metrics.confusion_matrix(test_total_labels, valid_thr_prediction_dnn) 
cm = np.round(cm,2)

# print confusion matrix with the validation threshold on the test set
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                display_labels=["genuine human","spoof"])
disp.plot()
plt.title('Confusion Matrix - Split Wave Channels Net on the Test Set with Validation Threshold')
plt.show()

# Calculate the balanced accuracy for the test set with the validation threshold
balanced_acc= sklearn.metrics.balanced_accuracy_score(test_total_labels,valid_thr_prediction_dnn) # balanced accuracy per batch

# Calculate the f1 score for the test set with the validation threshold
f1_score =sklearn.metrics.f1_score(test_total_labels, valid_thr_prediction_dnn, average='micro') # f1 score  

print(f"\tTest Balanced Accuracy: ({balanced_acc:.5f}%) \tF1 Score: {f1_score:.5f}")
print("The validation threshold is: ",val_thresh)
# Out:
# 	Test Balanced Accuracy: (0.79958%) 	F1 Score: 0.64711
# The validation threshold is:  0.37318805876066174

# %%
import seaborn as sns
import matplotlib.pyplot as plt

bonafide_scores = valid_total_prob[validation_dataset.is_spoofed == 0].flatten()
spoof_scores = valid_total_prob[validation_dataset.is_spoofed == 1].flatten()

num_bins = 100

plt.figure()
sns.histplot([spoof_scores, bonafide_scores], kde=True, stat='probability', bins=num_bins, palette=['blue', 'orange'], linewidth=1)# Add labels and title
plt.legend(['bonafide','spoof'])
plt.xlabel('scores')
plt.ylabel('probability')
plt.title(f"Probability over bonafide and spoof samples vs Scores on Male  validation dataset")
# Add legend
# Show the plot
plt.show()

plt.figure()
sns.histplot([spoof_scores, bonafide_scores], kde=True, stat='probability', bins=num_bins, palette=['blue', 'orange'], linewidth=1)# Add labels and title
plt.legend(['bonafide','spoof'])
plt.xlim(0,0.1)
plt.xlabel('scores')
plt.ylabel('probability')
plt.title(f"Probability over bonafide and spoof samples vs Scores on Male validation dataset - zoom in [0,0.1]")
# Add legend
# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

bonafide_scores = valid_total_prob[validation_dataset.is_spoofed == 0].flatten()
spoof_scores = valid_total_prob[validation_dataset.is_spoofed == 1].flatten()

num_bins = 100

plt.figure()
sns.histplot(bonafide_scores, kde=True, stat='probability', bins=num_bins, color='green', linewidth=1)# Add labels and title
sns.histplot(spoof_scores, kde=True, stat='probability', bins=num_bins, color='red', linewidth=1)# Add labels and title
plt.legend(['bonafide','spoof'])
plt.xlabel('scores')
plt.ylabel('probability')
plt.title(f"Probability of bonafide samples and Probability of spoof samples vs Scores on Male validation dataset")
# Add legend
# Show the plot
plt.show()

plt.figure()
sns.histplot(bonafide_scores, kde=True, stat='probability', bins=num_bins, color='green', linewidth=1)# Add labels and title
sns.histplot(spoof_scores, kde=True, stat='probability', bins=num_bins, color='red', linewidth=1)# Add labels and title
plt.legend(['bonafide','spoof'])
plt.xlim(0,0.1)
plt.xlabel('scores')
plt.ylabel('probability')
plt.title(f"Probability of bonafide samples and Probability of spoof samples vs Scores on Male validation dataset - zoom in [0,0.1]")
# Add legend
# Show the plot
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import det_curve
import torch.nn.functional as F 
# Calculate the inference on the test set with the test threshold

with torch.no_grad():
    model = model.to(device)
    if training_type == '1_neorun_end_sigmoid': 
        test_prob = torch.sigmoid(model(torch.Tensor(test_dataset.data).to(device)).cpu()) # get the test probability
    
test_total_labels = torch.Tensor(test_dataset.is_spoofed.iloc[:]).cpu().numpy().copy() # copy the test labels

test_total_prob_dnn = test_prob.cpu().numpy().copy() # copy the test probability

eer, test_thresh = my_functions.compute_eer(test_total_labels,test_total_prob_dnn) # compute equal error rate

fpr, fnr, _ = det_curve(test_total_labels, test_total_prob_dnn) # compute false positive rate and false negative rate

my_functions.DETCurve(fpr = fpr, fnr = fnr, eer_fpr = eer,eer_fnr = eer, model_name = "Split Wave Channels Net - Test Set",plot_type="step") # plot DET curve
    
prediction = np.array([1 if total_prob_element > test_thresh else 0 for total_prob_element in test_total_prob_dnn]) # prediction with the test threshold

test_thr_prediction_dnn = prediction.copy() # copy the prediction with the test threshold

cm = sklearn.metrics.confusion_matrix(test_total_labels, test_thr_prediction_dnn) # confusion matrix
cm = np.round(cm,2)

disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                display_labels=["genuine human","spoof"])
disp.plot()
plt.title('Confusion Matrix - Split Wave Channels Net on the Test Set with Test Threshold')
plt.show()

#Calculate the balanced accuracy for the test set with the test threshold
balanced_acc= sklearn.metrics.balanced_accuracy_score(test_total_labels,test_thr_prediction_dnn) # balanced accuracy per batch

# Calculate the f1 score for the test set with the test threshold
f1_score =sklearn.metrics.f1_score(test_total_labels, test_thr_prediction_dnn, average='micro') # f1 score  
   
print(f"\tTest Balanced Accuracy: ({balanced_acc:.5f}%) \tF1 Score: {f1_score:.5f}")
print("The test threshold is: ",test_thresh)
# Out:
# 	Test Balanced Accuracy: (0.88037%) 	F1 Score: 0.88067
# The test threshold is:  0.023077974095929297

# %%
import seaborn as sns
import matplotlib.pyplot as plt


bonafide_scores = test_prob[test_dataset.is_spoofed == 0].flatten()
spoof_scores = test_prob[test_dataset.is_spoofed == 1].flatten()

bonafide_scores = bonafide_scores.cpu().numpy()
spoof_scores = spoof_scores.cpu().numpy()

num_bins = 100

plt.figure()
sns.histplot([spoof_scores, bonafide_scores], kde=True, stat='probability', bins=num_bins, palette=['blue', 'orange'], linewidth=1)# Add labels and title
plt.legend(['bonafide','spoof'])
plt.xlabel('scores')
plt.ylabel('probability')
plt.title(f"Probability over bonafide and spoof samples vs Scores on Male  test dataset")
# Add legend
# Show the plot
plt.show()

plt.figure()
sns.histplot([spoof_scores, bonafide_scores], kde=True, stat='probability', bins=num_bins, palette=['blue', 'orange'], linewidth=1)# Add labels and title
plt.legend(['bonafide','spoof'])
plt.xlim(0,0.1)
plt.xlabel('scores')
plt.ylabel('probability')
plt.title(f"Probability over bonafide and spoof samples vs Scores on Male test dataset - zoom in [0,0.1]")
# Add legend
# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

bonafide_scores = test_prob[test_dataset.is_spoofed == 0].flatten()
spoof_scores = test_prob[test_dataset.is_spoofed == 1].flatten()

bonafide_scores = bonafide_scores.cpu().numpy()
spoof_scores = spoof_scores.cpu().numpy()


num_bins = 100

plt.figure()
sns.histplot(bonafide_scores, kde=True, stat='probability', bins=num_bins, color='green', linewidth=1)# Add labels and title
sns.histplot(spoof_scores, kde=True, stat='probability', bins=num_bins, color='red', linewidth=1)# Add labels and title
plt.legend(['bonafide','spoof'])
plt.xlabel('scores')
plt.ylabel('probability')
plt.title(f"Probability of bonafide samples and Probability of spoof samples vs Scores on Male test dataset")
# Add legend
# Show the plot
plt.show()

plt.figure()
sns.histplot(bonafide_scores, kde=True, stat='probability', bins=num_bins, color='green', linewidth=1)# Add labels and title
sns.histplot(spoof_scores, kde=True, stat='probability', bins=num_bins, color='red', linewidth=1)# Add labels and title
plt.legend(['bonafide','spoof'])
plt.xlim(0,0.1)
plt.xlabel('scores')
plt.ylabel('probability')
plt.title(f"Probability of bonafide samples and Probability of spoof samples vs Scores on Male test dataset - zoom in [0,0.1]")
# Add legend
# Show the plot
plt.show()

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report,accuracy_score
from sklearn.metrics import balanced_accuracy_score


pred_proba_list = [test_total_prob_dnn] # list of the test probability
y_pred = [test_thr_prediction_dnn] # list of the test prediction

test_total_labels = [test_dataset.is_spoofed.iloc[:].astype('uint8')] # list of the test labels

eer_list = []
acc_list = []
balanced_acc_list = []
auc_list = []
f1_list = [] 
# calculate the metrics for the test set with the test threshold
for i in range(0,len(pred_proba_list)): #
     eer , _ = my_functions.compute_eer(test_total_labels[i],pred_proba_list[i])
     eer_list.append(eer)
     acc_list.append(accuracy_score(test_total_labels[i], y_pred[i]))
     balanced_acc_list.append(balanced_accuracy_score(test_total_labels[i], y_pred[i]))
     auc_list.append(roc_auc_score(test_total_labels[i],pred_proba_list[i]))
     f1_list.append(sklearn.metrics.f1_score(test_total_labels[i], y_pred[i]))
  
     
y_pred_with_valid_thr = [valid_thr_prediction_dnn] 

validation_pos_pred_proba_list = [valid_total_prob]    

valid_total_labels = [validation_dataset.is_spoofed.iloc[:].astype('uint8')]


eer_list_on_validaion = []
acc_list_with_valid_thr = []
balanced_acc_list_with_valid_thr = []
f1_list_with_valid_thr = []
# calculate the metrics for the test set with the validation threshold
for i in range(0,len(validation_pos_pred_proba_list)): 
     acc_list_with_valid_thr.append(accuracy_score(test_total_labels[i], y_pred_with_valid_thr[i]))
     balanced_acc_list_with_valid_thr.append(balanced_accuracy_score(test_total_labels[i], y_pred_with_valid_thr[i]))
     f1_list_with_valid_thr.append(sklearn.metrics.f1_score(test_total_labels[i], y_pred_with_valid_thr[i]))
     eer_val , _ = my_functions.compute_eer(valid_total_labels[i],validation_pos_pred_proba_list[i])
     eer_list_on_validaion.append(eer_val)

# %%
# define the names of the classifiers
names = ['Split Wave Channels Net']
metric_names = ['EER','Accuracy','Balanced Accuracy','F1','AUC']

#plot hisgogram of the results: EER, Accuracy, Balanced Accuracy, AUC
metrics_list = [eer_list,acc_list,balanced_acc_list,f1_list,auc_list] # list of the test metrics
validaion_metrics_list = [eer_list_on_validaion,acc_list_with_valid_thr,balanced_acc_list_with_valid_thr,f1_list_with_valid_thr] # list of the validation metrics

# define the diff for the bar names
diff_for_bar = 0.0001
X_axis = np.arange(len(names))

#Plot the results   
for i in range(0,len(validaion_metrics_list)):
    plt.figure(figsize=(12,12))
    plt.bar(X_axis+0.2, metrics_list[i],width=0.4,label = 'metric & threshold - Test')
    plt.bar(X_axis-0.2, validaion_metrics_list[i],width=0.4,label = 'metric & threshold - validation',color='orange')
    plt.ylabel(metric_names[i])
    plt.xlabel('Classifier')
    plt.title(f"{metric_names[i]} of the classifiers on Male Speakers")
    plt.legend(loc = 'lower left')
    plt.xticks(X_axis, names)
    for j, v in enumerate(metrics_list[i]):
        plt.text(j+0.2, v+diff_for_bar, '{:.3f}%'.format(v*100), ha='center')
    for j, v in enumerate(validaion_metrics_list[i]):
        plt.text(j-0.2, v+diff_for_bar, '{:.3f}%'.format(v*100), ha='center')
    plt.show()
    
plt.figure(figsize=(12,12))

i = len(validaion_metrics_list)   

#plot hisgogram of the results: AUC
plt.figure(figsize=(12,12))
plt.bar(X_axis, metrics_list[i],width=0.4,label = 'metric & threshold - Test')
plt.ylabel(metric_names[i])
plt.xlabel('Classifier')
plt.title(f"{metric_names[i]} of the DNN classifiers on Male Speakers")
plt.legend(loc = 'lower left')
plt.xticks(X_axis, names)
for j, v in enumerate(metrics_list[i]):
        plt.text(j, v+diff_for_bar, '{:.3f}%'.format(v*100), ha='center')   
plt.show()

# %%
'''
import pickle

filename = 'male_model_8.83.pkl'
pickle.dump(model, open(filename, 'wb'))
torch.save(model.state_dict(), 'male_model_8.83.pth')
'''
# Out:
# "\nimport pickle\n\nfilename = 'male_model_8.83.pkl'\npickle.dump(model, open(filename, 'wb'))\ntorch.save(model.state_dict(), 'male_model_8.83.pth')\n"
