# %% [markdown]
# # Simple Deep Learning On Male Data - ASVspoof2019 Dataset:

# %%
import sys
sys.path.append('../')
import scipy.io as sio
import mat73
import pandas as pd
import torch
import numpy as np
import torch.optim as optim
import torch.nn
import sklearn
import sklearn.metrics
import matplotlib.pyplot as plt
from alive_progress import alive_bar
from  utils.my_classes import dataset 
from torch.utils.data import DataLoader
import utils.DNN_functions as DNN_functions
import scipy
import random
import utils.AMSloss
seed = 5  # You can choose any integer value as the seed
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
# Set seed for Python's random module
random.seed(seed)
# Set seed for NumPy
np.random.seed(seed)
# Set seed for PyTorch (CPU and GPU, if available)
if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
# Set deterministic flags for PyTorch (if available)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
#To get my GPU device - GTX 4070 :)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu');

if torch.cuda.is_available():
    print(torch.cuda.device_count())
    print(torch.cuda.device(0))
    print(torch.cuda.get_device_name(0))
    print(device)
# Out:
# 1
# <torch.cuda.device object at 0x000001E17E8A1F10>
# NVIDIA GeForce RTX 4070
# cuda

# %%
from ASV_utils.data_loading import *


data_path_male = "Data/pmf_both/not_normalize/male/"


embedded_groups_1_1,embedded_groups_1_2,embedded_groups_1_3,chosen_labels_1_1_is_spoofed,chosen_labels_2_1_is_spoofed,chosen_labels_3_1_is_spoofed,chosen_labels_numeric_1_1,chosen_labels_numeric_2_1,chosen_labels_numeric_3_1,chosen_labels_1_1_attack_logical,chosen_labels_2_1_attack_logical,chosen_labels_3_1_attack_logical,chosen_labels_1_1_name,chosen_labels_2_1_name,chosen_labels_3_1_name,chosen_labels_1_1_speaker_id,chosen_labels_2_1_speaker_id,chosen_labels_3_1_speaker_id,male_chosen_labels_1_1_sex,male_chosen_labels_2_1_sex,male_chosen_labels_3_1_sex  = load_data_male(data_path_male)

# %% [markdown]
# ## Preprocessing channels

# %% [markdown]
# Here, I will perform preprocessing and rearrange the channel order before feeding it into the Deep Neural Network (DNN).

# %%
#order by this example:
#filter-gammatone-channel-1-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#       'filter-gammatone-channel-1-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#       'filter-gammatone-channel-1-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#       'filter-gammatone-channel-1-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#       'filter-gammatone-channel-1-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)

# get the real channel by the order of the features

import utils.my_functions as my_functions
columns_names,max_name_length = my_functions.get_columns_names_feature_importance(substruct=True)
true_channels_indexes = np.array(my_functions.get_real_channel(np.linspace(start=1, stop=len(columns_names), num=len(columns_names)),len(columns_names)))
true_channels_indexes = true_channels_indexes - 1
true_channels_indexes = true_channels_indexes.astype(int)
columns_names = np.array(columns_names)
embedded_groups_1_1 = embedded_groups_1_1[:,true_channels_indexes]
embedded_groups_1_2 = embedded_groups_1_2[:,true_channels_indexes]
embedded_groups_1_3 = embedded_groups_1_3[:,true_channels_indexes]

# %%
# order by metric type and then by channel number and then by gammatone and gammatone_inv, example:
#filter-gammatone-channel-1-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]
#filter-gammatone-channel-2-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]
#filter-gammatone-channel-3-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]
#filter-gammatone-channel-4-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]
#filter-gammatone-channel-5-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]
#filter-gammatone-channel-6-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]
#filter-gammatone-channel-7-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]
#filter-gammatone-channel-8-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]
#filter-gammatone-channel-9-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]
#filter-gammatone-channel-10-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]
#filter-gammatone-channel-1-distance-Correlation-[d_(p,p_s)-d(p,p_h)]
#filter-gammatone-channel-2-distance-Correlation-[d_(p,p_s)-d(p,p_h)]
import re


your_list = columns_names[true_channels_indexes]
index_mapping ={}

# Define the custom sorting order for distance metrics
distance_metrics = [
    'Chi-square',
    'Correlation',
    'Hellinger',
    'Intersection',
    'Jensen-Shannon',
    'Kullback-Leibler Divergence',
    'Modified Kolmogorov-Smirnov',
    'Symmetrised Kullback-Leibler'
]

def custom_sort_key(item):
    # Use regex to extract filter type, channel number, and distance metric
    match = re.search(r'filter-(gammatone|gammtone_inv)-channel-(\d+)-distance-(.+?)-\[d_', item)
    if match:
        filter_type = match.group(1)  # 'gammatone' or 'gammtone_inv'
        channel = int(match.group(2))
        distance_metric = match.group(3)
        
        # Prioritize 'gammatone' before 'gammtone_inv'
        filter_priority = 0 if filter_type == 'gammatone' else 1

        # Sort by filter type, then by distance metric, and finally by channel
        return (filter_priority, distance_metrics.index(distance_metric), channel)

    else:
        # If the regex doesn't match, push the item to the end
        return (999, 999, 999)

# Sort the list based on the custom order
sorted_list = sorted(your_list, key=custom_sort_key)

for new_index, item in enumerate(sorted_list):
    old_index = np.where(columns_names[true_channels_indexes] == item)[0][0]
    index_mapping[old_index] = new_index
    
embedded_groups_1_1 = embedded_groups_1_1[:,list(index_mapping.keys())]
embedded_groups_1_2 = embedded_groups_1_2[:,list(index_mapping.keys())]
embedded_groups_1_3 = embedded_groups_1_3[:,list(index_mapping.keys())]

# %%
sorted_list
# Out:
# ['filter-gammatone-channel-1-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-2-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-3-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-4-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-5-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-6-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-7-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-8-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-9-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-10-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-1-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-2-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-3-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-4-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-5-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-6-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-7-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-8-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-9-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-10-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-1-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-2-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-3-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-4-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-5-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-6-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-7-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-8-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-9-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-10-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-1-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-2-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-3-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-4-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-5-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-6-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-7-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-8-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-9-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-10-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-1-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-2-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-3-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-4-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-5-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-6-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-7-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-8-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-9-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-10-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-1-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-2-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-3-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-4-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-5-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-6-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-7-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-8-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-9-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-10-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-1-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-2-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-3-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-4-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-5-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-6-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-7-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-8-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-9-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-10-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-1-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-2-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-3-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-4-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-5-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-6-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-7-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-8-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-9-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammatone-channel-10-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-1-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-2-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-3-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-4-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-5-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-6-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-7-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-8-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-9-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-10-distance-Chi-square-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-1-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-2-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-3-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-4-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-5-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-6-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-7-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-8-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-9-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-10-distance-Correlation-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-1-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-2-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-3-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-4-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-5-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-6-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-7-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-8-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-9-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-10-distance-Hellinger-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-1-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-2-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-3-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-4-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-5-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-6-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-7-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-8-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-9-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-10-distance-Intersection-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-1-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-2-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-3-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-4-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-5-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-6-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-7-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-8-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-9-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-10-distance-Jensen-Shannon-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-1-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-2-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-3-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-4-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-5-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-6-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-7-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-8-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-9-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-10-distance-Kullback-Leibler Divergence-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-1-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-2-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-3-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-4-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-5-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-6-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-7-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-8-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-9-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-10-distance-Modified Kolmogorov-Smirnov-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-1-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-2-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-3-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-4-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-5-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-6-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-7-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-8-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-9-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]',
#  'filter-gammtone_inv-channel-10-distance-Symmetrised Kullback-Leibler-[d_(p,p_s)-d(p,p_h)]']

# %%
#create the datasets
train_dataset = dataset(data = embedded_groups_1_1 , is_spoofed = chosen_labels_1_1_is_spoofed , chosen_labels_numeric = chosen_labels_numeric_1_1,
                        attack_logical = chosen_labels_1_1_attack_logical, name = chosen_labels_1_1_name , speaker_id = chosen_labels_1_1_speaker_id,sex = male_chosen_labels_1_1_sex, data_transform = None , labels_transform = None);

validation_dataset = dataset(data = embedded_groups_1_2 , is_spoofed = chosen_labels_2_1_is_spoofed , chosen_labels_numeric = chosen_labels_numeric_2_1,
                        attack_logical = chosen_labels_2_1_attack_logical, name = chosen_labels_2_1_name , speaker_id = chosen_labels_2_1_speaker_id, sex = male_chosen_labels_2_1_sex ,data_transform = None , labels_transform = None);


test_dataset = dataset(data = embedded_groups_1_3 , is_spoofed = chosen_labels_3_1_is_spoofed , chosen_labels_numeric = chosen_labels_numeric_3_1,
                        attack_logical = chosen_labels_3_1_attack_logical, name = chosen_labels_3_1_name , speaker_id = chosen_labels_3_1_speaker_id, sex = male_chosen_labels_3_1_sex ,data_transform = None , labels_transform = None);

# %%
# normalize the train, validation and test datasets
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler(with_mean = True, with_std = True)
scaler.fit(train_dataset.data)
mean_features = scaler.mean_
std_features = scaler.scale_
train_dataset.data = scaler.transform(train_dataset.data)
validation_dataset.data = scaler.transform(validation_dataset.data)
test_dataset.data = scaler.transform(test_dataset.data)

# %%
# balanced the data with SVM SMOTE
import imblearn.over_sampling as over_sampling

sm = over_sampling.SVMSMOTE(sampling_strategy='minority', random_state=seed,k_neighbors=5)
train_dataset.data , train_dataset.is_spoofed  = sm.fit_resample(X = train_dataset.data , y = train_dataset.is_spoofed) # just on the train set

# %%
#check if the data now is balanced
print(f"|| train dataset length - {len(train_dataset)} ||");
print(f"|| train dataset - len_is_spoofed ? \nlength - \n{train_dataset.len_is_spoofed()} ||");
print(f"|| validation dataset length - {len(validation_dataset)} ||");
print(f"|| validation dataset - len_is_spoofed ? \nlength - \n{validation_dataset.len_is_spoofed()} ||");
print(f"|| test dataset length - {len(test_dataset)} ||");
print(f"|| test dataset - len_is_spoofed ? \nlength - \n{test_dataset.len_is_spoofed()} ||");
# Out:
# || train dataset length - 18816 ||
# || train dataset - len_is_spoofed ?
# length -
# 0    9408
# 1    9408
# Name: count, dtype: int64 ||
# || validation dataset length - 8260 ||
# || validation dataset - len_is_spoofed ?
# length -
# 1    7392
# 0     868
# Name: count, dtype: int64 ||
# || test dataset length - 21939 ||
# || test dataset - len_is_spoofed ?
# length -
# 1    19656
# 0     2283
# Name: count, dtype: int64 ||

# %%
# define the labels types
train_dataset.set_labels_format('is_spoofed')
validation_dataset.set_labels_format('is_spoofed')
test_dataset.set_labels_format('is_spoofed')

# %%
# define the dataloaders
train_dataloader = DataLoader(train_dataset, batch_size=256, shuffle=True);
validation_dataloader = DataLoader(validation_dataset, batch_size=256, shuffle=True);
test_dataloader = DataLoader(test_dataset, batch_size=256, shuffle=True);

print(f"|| train dataloader length - {len(train_dataloader)} ||");
print(f"|| validation dataloader length - {len(validation_dataloader)} ||");
print(f"|| test dataloader length - {len(test_dataloader)} ||");
# Out:
# || train dataloader length - 74 ||
# || validation dataloader length - 33 ||
# || test dataloader length - 86 ||

# %% [markdown]
# ## Deep Neural Network

# %% [markdown]
# Here I define the netwok and training the model.

# %%
# define the subchannel model network
import torch.nn as nn
class SubChannelNetwork(nn.Module):
    def __init__(self, input_channel_size, output_channel_size):
        super(SubChannelNetwork, self).__init__()
        self.input_layer = nn.Linear(input_channel_size, output_channel_size)
        self.sigmoid = nn.Sigmoid()
        self.dropout = nn.Dropout(p=0.2)
        self.BN_4 = nn.BatchNorm1d(output_channel_size) 

        
    def forward(self, x):
        x = self.input_layer(x)
        x = self.BN_4(x) 
        x = self.sigmoid(x)
        x = self.dropout(x)
        return x

# %%
import torch
import torch.nn as nn
from utils.AMSloss import AdMSoftmaxLoss

# define the model network
class DNN(nn.Module):
    def __init__(self, input_channel_size, num_subnetworks, output_channel_size, final_output_size):
        super(DNN, self).__init__()
        self.SubChannelNetwork = nn.ModuleList([
            SubChannelNetwork(input_channel_size, output_channel_size) for _ in range(num_subnetworks)
        ])
        self.fc_between_subnet = nn.Linear(num_subnetworks * output_channel_size,40)
        self.BN = nn.BatchNorm1d(40)
        self.fc = nn.Linear(40, final_output_size)
        self.sigmoid = nn.Sigmoid()
        self.droupout = nn.Dropout(p=0.2)
        self.loss = nn.BCEWithLogitsLoss()
        self.optimizer = None
        self.scheduler = None
        
        
    def forward(self, x):
        subnetwork_outputs = [self.SubChannelNetwork[idx](x[:, idx*input_channel_size:(idx+1)*input_channel_size].to(device)) for idx in range(len(self.SubChannelNetwork))]
        combined_output = torch.cat(subnetwork_outputs, dim=1)
        x = self.fc_between_subnet(combined_output)    
        x = self.BN(x)
        x = self.sigmoid(x)
        x = self.droupout(x)
        output = self.fc(x)
        return output 
    
    @staticmethod
    def count_parameters(model):
        return sum(p.numel() for p in model.parameters() if p.requires_grad)



# Just for checking the model and see the number of parameters
num_SubChannelNetwork = 16
input_channel_size = 10
output_channel_size = 5
final_output_size = 1
model = []
model = DNN(input_channel_size, num_SubChannelNetwork, output_channel_size, final_output_size)
model = model.to(device)
print(model)
n = DNN.count_parameters(model)
print("Number of parameters: %s" % n)
# Out:
# DNN(
#   (SubChannelNetwork): ModuleList(
#     (0-15): 16 x SubChannelNetwork(
#       (input_layer): Linear(in_features=10, out_features=5, bias=True)
#       (sigmoid): Sigmoid()
#       (dropout): Dropout(p=0.2, inplace=False)
#       (BN_4): BatchNorm1d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (fc_between_subnet): Linear(in_features=80, out_features=40, bias=True)
#   (BN): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc): Linear(in_features=40, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
#   (droupout): Dropout(p=0.2, inplace=False)
#   (loss): BCEWithLogitsLoss()
# )
# Number of parameters: 4401

# %%
import utils.DNN_functions
model = [] # clear the model
model = DNN(input_channel_size, num_SubChannelNetwork, output_channel_size, final_output_size) # define the model
model = model.to(device) # send the model to the device

# define the hyperparameters
num_epoch = 300
learning_rate = 0.001
weight_decay = 0.000001
model.optimizer = torch.optim.SGD(model.parameters(),
                                lr=learning_rate,
                                weight_decay=weight_decay);
model.scheduler =  optim.lr_scheduler.StepLR(model.optimizer, step_size=num_epoch, gamma=0.1);


checkpoint_path = "Male_best_model_1_neorun_end_sigmoid.pkl"

training_type = '1_neorun_end_sigmoid'

model,train_losses,validation_losses,train_acc_percentage,validation_acc_percentage,f1_score_validation,validation_total_eer,train_total_err  = utils.DNN_functions.train_model_new(training_type,model,train_dataloader,validation_dataloader ,num_epoch,checkpoint_path=checkpoint_path,patience = None)
# Out:
# c:\Users\avish\OneDrive\Desktop\thesis_research\avishai_work\env\lib\site-packages\torch\onnx\_internal\_beartype.py:35: UserWarning: unhashable type: 'list'
#   warnings.warn(f"{e}")
# on 1:
#       Train Balanced Accuracy:  57.07%
# on 1: Train EER:  42.93%
# on 1:
#       Validation 1 ,Validation Loss 0.73023 , Validation Balanced Accuracy: 81.04%
# on 1: Validation EER:  19.01%
# on 1: Validation f1 Score: 80.98%
# on 1:
# on 1:
# on 2:
#       Train Balanced Accuracy:  75.49%
# on 2: Train EER:  24.51%
# on 2:
#       Validation 2 ,Validation Loss 0.70326 , Validation Balanced Accuracy: 82.95%
# on 2: Validation EER:  17.05%
# on 2: Validation f1 Score: 82.94%
# on 2:
# on 2:
# on 3:
#       Train Balanced Accuracy:  77.67%
# on 3: Train EER:  22.33%
# on 3:
#       Validation 3 ,Validation Loss 0.68377 , Validation Balanced Accuracy: 83.63%
# on 3: Validation EER:  16.38%
# on 3: Validation f1 Score: 83.62%
# on 3:
# on 3:
# on 4:
#       Train Balanced Accuracy:  79.28%
# on 4: Train EER:  20.73%
# on 4:
#       Validation 4 ,Validation Loss 0.67002 , Validation Balanced Accuracy: 83.77%
# on 4: Validation EER:  16.33%
# on 4: Validation f1 Score: 83.69%
# on 4:
# on 4:
# on 5:
#       Train Balanced Accuracy:  79.57%
# on 5: Train EER:  20.44%
# on 5:
#       Validation 5 ,Validation Loss 0.65898 , Validation Balanced Accuracy: 83.73%
# on 5: Validation EER:  16.29%
# on 5: Validation f1 Score: 83.72%
# on 5:
# on 5:
# on 6:
#       Train Balanced Accuracy:  79.69%
# on 6: Train EER:  20.30%
# on 6:
#       Validation 6 ,Validation Loss 0.64980 , Validation Balanced Accuracy: 83.81%
# on 6: Validation EER:  16.24%
# on 6: Validation f1 Score: 83.77%
# on 6:
# on 6:
# on 7:
#       Train Balanced Accuracy:  79.82%
# on 7: Train EER:  20.18%
# on 7:
#       Validation 7 ,Validation Loss 0.64233 , Validation Balanced Accuracy: 83.72%
# on 7: Validation EER:  16.31%
# on 7: Validation f1 Score: 83.69%
# on 7:
# on 7:
# on 8:
#       Train Balanced Accuracy:  79.96%
# on 8: Train EER:  20.05%
# on 8:
#       Validation 8 ,Validation Loss 0.63568 , Validation Balanced Accuracy: 83.75%
# on 8: Validation EER:  16.26%
# on 8: Validation f1 Score: 83.74%
# on 8:
# on 8:
# on 9:
#       Train Balanced Accuracy:  80.02%
# on 9: Train EER:  19.98%
# on 9:
#       Validation 9 ,Validation Loss 0.62895 , Validation Balanced Accuracy: 83.46%
# on 9: Validation EER:  16.59%
# on 9: Validation f1 Score: 83.40%
# on 9:
# on 9:
# on 10:
#        Train Balanced Accuracy:  80.06%
# on 10: Train EER:  19.94%
# on 10:
#        Validation 10 ,Validation Loss 0.62246 , Validation Balanced Accuracy: 83.38%
# on 10: Validation EER:  16.65%
# on 10: Validation f1 Score: 83.35%
# on 10:
# on 10:
# on 11:
#        Train Balanced Accuracy:  79.94%
# on 11: Train EER:  20.06%
# on 11:
#        Validation 11 ,Validation Loss 0.61661 , Validation Balanced Accuracy: 83.15%
# on 11: Validation EER:  16.82%
# on 11: Validation f1 Score: 83.04%
# on 11:
# on 11:
# on 12:
#        Train Balanced Accuracy:  79.83%
# on 12: Train EER:  20.16%
# on 12:
#        Validation 12 ,Validation Loss 0.61105 , Validation Balanced Accuracy: 83.11%
# on 12: Validation EER:  16.94%
# on 12: Validation f1 Score: 83.05%
# on 12:
# on 12:
# on 13:
#        Train Balanced Accuracy:  79.72%
# on 13: Train EER:  20.28%
# on 13:
#        Validation 13 ,Validation Loss 0.60602 , Validation Balanced Accuracy: 83.18%
# on 13: Validation EER:  16.82%
# on 13: Validation f1 Score: 83.17%
# on 13:
# on 13:
# on 14:
#        Train Balanced Accuracy:  79.79%
# on 14: Train EER:  20.21%
# on 14:
#        Validation 14 ,Validation Loss 0.60083 , Validation Balanced Accuracy: 83.06%
# on 14: Validation EER:  16.94%
# on 14: Validation f1 Score: 83.06%
# on 14:
# on 14:
# on 15:
#        Train Balanced Accuracy:  79.79%
# on 15: Train EER:  20.22%
# on 15:
#        Validation 15 ,Validation Loss 0.59519 , Validation Balanced Accuracy: 83.12%
# on 15: Validation EER:  16.94%
# on 15: Validation f1 Score: 83.08%
# on 15:
# on 15:
# on 16:
#        Train Balanced Accuracy:  79.78%
# on 16: Train EER:  20.22%
# on 16:
#        Validation 16 ,Validation Loss 0.59020 , Validation Balanced Accuracy: 83.18%
# on 16: Validation EER:  16.82%
# on 16: Validation f1 Score: 83.17%
# on 16:
# on 16:
# on 17:
#        Train Balanced Accuracy:  79.72%
# on 17: Train EER:  20.28%
# on 17:
#        Validation 17 ,Validation Loss 0.58433 , Validation Balanced Accuracy: 82.97%
# on 17: Validation EER:  17.05%
# on 17: Validation f1 Score: 82.89%
# on 17:
# on 17:
# on 18:
#        Train Balanced Accuracy:  79.75%
# on 18: Train EER:  20.25%
# on 18:
#        Validation 18 ,Validation Loss 0.57925 , Validation Balanced Accuracy: 83.11%
# on 18: Validation EER:  16.94%
# on 18: Validation f1 Score: 83.15%
# on 18:
# on 18:
# on 19:
#        Train Balanced Accuracy:  79.75%
# on 19: Train EER:  20.25%
# on 19:
#        Validation 19 ,Validation Loss 0.57513 , Validation Balanced Accuracy: 83.06%
# on 19: Validation EER:  16.94%
# on 19: Validation f1 Score: 82.97%
# on 19:
# on 19:
# on 20:
#        Train Balanced Accuracy:  79.75%
# on 20: Train EER:  20.25%
# on 20:
#        Validation 20 ,Validation Loss 0.56906 , Validation Balanced Accuracy: 83.21%
# on 20: Validation EER:  16.82%
# on 20: Validation f1 Score: 83.23%
# on 20:
# on 20:
# on 21:
#        Train Balanced Accuracy:  79.76%
# on 21: Train EER:  20.24%
# on 21:
#        Validation 21 ,Validation Loss 0.56343 , Validation Balanced Accuracy: 83.25%
# on 21: Validation EER:  16.80%
# on 21: Validation f1 Score: 83.21%
# on 21:
# on 21:
# on 22:
#        Train Balanced Accuracy:  79.72%
# on 22: Train EER:  20.28%
# on 22:
#        Validation 22 ,Validation Loss 0.55887 , Validation Balanced Accuracy: 83.38%
# on 22: Validation EER:  16.65%
# on 22: Validation f1 Score: 83.35%
# on 22:
# on 22:
# on 23:
#        Train Balanced Accuracy:  79.74%
# on 23: Train EER:  20.27%
# on 23:
#        Validation 23 ,Validation Loss 0.55423 , Validation Balanced Accuracy: 83.48%
# on 23: Validation EER:  16.57%
# on 23: Validation f1 Score: 83.44%
# on 23:
# on 23:
# on 24:
#        Train Balanced Accuracy:  79.79%
# on 24: Train EER:  20.21%
# on 24:
#        Validation 24 ,Validation Loss 0.54920 , Validation Balanced Accuracy: 83.62%
# on 24: Validation EER:  16.52%
# on 24: Validation f1 Score: 83.51%
# on 24:
# on 24:
# on 25:
#        Train Balanced Accuracy:  79.79%
# on 25: Train EER:  20.21%
# on 25:
#        Validation 25 ,Validation Loss 0.54629 , Validation Balanced Accuracy: 83.63%
# on 25: Validation EER:  16.38%
# on 25: Validation f1 Score: 83.62%
# on 25:
# on 25:
# on 26:
#        Train Balanced Accuracy:  79.84%
# on 26: Train EER:  20.16%
# on 26:
#        Validation 26 ,Validation Loss 0.53946 , Validation Balanced Accuracy: 83.71%
# on 26: Validation EER:  16.34%
# on 26: Validation f1 Score: 83.67%
# on 26:
# on 26:
# on 27:
#        Train Balanced Accuracy:  79.80%
# on 27: Train EER:  20.17%
# on 27:
#        Validation 27 ,Validation Loss 0.53494 , Validation Balanced Accuracy: 83.86%
# on 27: Validation EER:  16.15%
# on 27: Validation f1 Score: 83.85%
# on 27:
# on 27:
# on 28:
#        Train Balanced Accuracy:  79.89%
# on 28: Train EER:  20.11%
# on 28:
#        Validation 28 ,Validation Loss 0.53022 , Validation Balanced Accuracy: 84.05%
# on 28: Validation EER:  16.00%
# on 28: Validation f1 Score: 84.01%
# on 28:
# on 28:
# on 29:
#        Train Balanced Accuracy:  79.92%
# on 29: Train EER:  20.09%
# on 29:
#        Validation 29 ,Validation Loss 0.52435 , Validation Balanced Accuracy: 84.15%
# on 29: Validation EER:  15.90%
# on 29: Validation f1 Score: 84.10%
# on 29:
# on 29:
# on 30:
#        Train Balanced Accuracy:  79.96%
# on 30: Train EER:  20.04%
# on 30:
#        Validation 30 ,Validation Loss 0.51956 , Validation Balanced Accuracy: 84.21%
# on 30: Validation EER:  15.80%
# on 30: Validation f1 Score: 84.20%
# on 30:
# on 30:
# on 31:
#        Train Balanced Accuracy:  80.06%
# on 31: Train EER:  19.94%
# on 31:
#        Validation 31 ,Validation Loss 0.51481 , Validation Balanced Accuracy: 84.38%
# on 31: Validation EER:  15.67%
# on 31: Validation f1 Score: 84.32%
# on 31:
# on 31:
# on 32:
#        Train Balanced Accuracy:  80.06%
# on 32: Train EER:  19.94%
# on 32:
#        Validation 32 ,Validation Loss 0.51043 , Validation Balanced Accuracy: 84.44%
# on 32: Validation EER:  15.57%
# on 32: Validation f1 Score: 84.43%
# on 32:
# on 32:
# on 33:
#        Train Balanced Accuracy:  80.14%
# on 33: Train EER:  19.87%
# on 33:
#        Validation 33 ,Validation Loss 0.50766 , Validation Balanced Accuracy: 84.48%
# on 33: Validation EER:  15.55%
# on 33: Validation f1 Score: 84.42%
# on 33:
# on 33:
# on 34:
#        Train Balanced Accuracy:  80.22%
# on 34: Train EER:  19.78%
# on 34:
#        Validation 34 ,Validation Loss 0.50250 , Validation Balanced Accuracy: 84.64%
# on 34: Validation EER:  15.40%
# on 34: Validation f1 Score: 84.61%
# on 34:
# on 34:
# on 35:
#        Train Balanced Accuracy:  80.28%
# on 35: Train EER:  19.73%
# on 35:
#        Validation 35 ,Validation Loss 0.49762 , Validation Balanced Accuracy: 84.77%
# on 35: Validation EER:  15.25%
# on 35: Validation f1 Score: 84.76%
# on 35:
# on 35:
# on 36:
#        Train Balanced Accuracy:  80.34%
# on 36: Train EER:  19.65%
# on 36:
#        Validation 36 ,Validation Loss 0.49383 , Validation Balanced Accuracy: 84.91%
# on 36: Validation EER:  15.09%
# on 36: Validation f1 Score: 84.92%
# on 36:
# on 36:
# on 37:
#        Train Balanced Accuracy:  80.39%
# on 37: Train EER:  19.60%
# on 37:
#        Validation 37 ,Validation Loss 0.48966 , Validation Balanced Accuracy: 84.96%
# on 37: Validation EER:  15.09%
# on 37: Validation f1 Score: 84.90%
# on 37:
# on 37:
# on 38:
#        Train Balanced Accuracy:  80.47%
# on 38: Train EER:  19.53%
# on 38:
#        Validation 38 ,Validation Loss 0.48493 , Validation Balanced Accuracy: 85.01%
# on 38: Validation EER:  14.98%
# on 38: Validation f1 Score: 84.90%
# on 38:
# on 38:
# on 39:
#        Train Balanced Accuracy:  80.58%
# on 39: Train EER:  19.43%
# on 39:
#        Validation 39 ,Validation Loss 0.48025 , Validation Balanced Accuracy: 85.19%
# on 39: Validation EER:  14.86%
# on 39: Validation f1 Score: 85.13%
# on 39:
# on 39:
# on 40:
#        Train Balanced Accuracy:  80.65%
# on 40: Train EER:  19.33%
# on 40:
#        Validation 40 ,Validation Loss 0.47610 , Validation Balanced Accuracy: 85.46%
# on 40: Validation EER:  14.57%
# on 40: Validation f1 Score: 85.44%
# on 40:
# on 40:
# on 41:
#        Train Balanced Accuracy:  80.72%
# on 41: Train EER:  19.28%
# on 41:
#        Validation 41 ,Validation Loss 0.47240 , Validation Balanced Accuracy: 85.73%
# on 41: Validation EER:  14.25%
# on 41: Validation f1 Score: 85.75%
# on 41:
# on 41:
# on 42:
#        Train Balanced Accuracy:  80.85%
# on 42: Train EER:  19.16%
# on 42:
#        Validation 42 ,Validation Loss 0.46750 , Validation Balanced Accuracy: 86.03%
# on 42: Validation EER:  14.00%
# on 42: Validation f1 Score: 86.00%
# on 42:
# on 42:
# on 43:
#        Train Balanced Accuracy:  80.97%
# on 43: Train EER:  19.04%
# on 43:
#        Validation 43 ,Validation Loss 0.46374 , Validation Balanced Accuracy: 86.19%
# on 43: Validation EER:  13.82%
# on 43: Validation f1 Score: 86.11%
# on 43:
# on 43:
# on 44:
#        Train Balanced Accuracy:  81.06%
# on 44: Train EER:  18.94%
# on 44:
#        Validation 44 ,Validation Loss 0.46099 , Validation Balanced Accuracy: 86.43%
# on 44: Validation EER:  13.59%
# on 44: Validation f1 Score: 86.44%
# on 44:
# on 44:
# on 45:
#        Train Balanced Accuracy:  81.16%
# on 45: Train EER:  18.85%
# on 45:
#        Validation 45 ,Validation Loss 0.45617 , Validation Balanced Accuracy: 86.73%
# on 45: Validation EER:  13.30%
# on 45: Validation f1 Score: 86.71%
# on 45:
# on 45:
# on 46:
#        Train Balanced Accuracy:  81.24%
# on 46: Train EER:  18.76%
# on 46:
#        Validation 46 ,Validation Loss 0.45369 , Validation Balanced Accuracy: 86.98%
# on 46: Validation EER:  13.02%
# on 46: Validation f1 Score: 86.99%
# on 46:
# on 46:
# on 47:
#        Train Balanced Accuracy:  81.38%
# on 47: Train EER:  18.62%
# on 47:
#        Validation 47 ,Validation Loss 0.44912 , Validation Balanced Accuracy: 87.06%
# on 47: Validation EER:  12.97%
# on 47: Validation f1 Score: 87.03%
# on 47:
# on 47:
# on 48:
#        Train Balanced Accuracy:  81.54%
# on 48: Train EER:  18.46%
# on 48:
#        Validation 48 ,Validation Loss 0.44331 , Validation Balanced Accuracy: 87.12%
# on 48: Validation EER:  12.90%
# on 48: Validation f1 Score: 87.13%
# on 48:
# on 48:
# on 49:
#        Train Balanced Accuracy:  81.63%
# on 49: Train EER:  18.38%
# on 49:
#        Validation 49 ,Validation Loss 0.43975 , Validation Balanced Accuracy: 87.29%
# on 49: Validation EER:  12.76%
# on 49: Validation f1 Score: 87.25%
# on 49:
# on 49:
# on 50:
#        Train Balanced Accuracy:  81.74%
# on 50: Train EER:  18.26%
# on 50:
#        Validation 50 ,Validation Loss 0.43543 , Validation Balanced Accuracy: 87.52%
# on 50: Validation EER:  12.53%
# on 50: Validation f1 Score: 87.48%
# on 50:
# on 50:
# on 51:
#        Train Balanced Accuracy:  81.81%
# on 51: Train EER:  18.20%
# on 51:
#        Validation 51 ,Validation Loss 0.43252 , Validation Balanced Accuracy: 87.75%
# on 51: Validation EER:  12.30%
# on 51: Validation f1 Score: 87.71%
# on 51:
# on 51:
# on 52:
#        Train Balanced Accuracy:  81.90%
# on 52: Train EER:  18.10%
# on 52:
#        Validation 52 ,Validation Loss 0.42725 , Validation Balanced Accuracy: 87.98%
# on 52: Validation EER:  12.07%
# on 52: Validation f1 Score: 87.94%
# on 52:
# on 52:
# on 53:
#        Train Balanced Accuracy:  82.02%
# on 53: Train EER:  17.98%
# on 53:
#        Validation 53 ,Validation Loss 0.42397 , Validation Balanced Accuracy: 88.23%
# on 53: Validation EER:  11.78%
# on 53: Validation f1 Score: 88.22%
# on 53:
# on 53:
# on 54:
#        Train Balanced Accuracy:  82.16%
# on 54: Train EER:  17.85%
# on 54:
#        Validation 54 ,Validation Loss 0.42034 , Validation Balanced Accuracy: 88.57%
# on 54: Validation EER:  11.46%
# on 54: Validation f1 Score: 88.55%
# on 54:
# on 54:
# on 55:
#        Train Balanced Accuracy:  82.33%
# on 55: Train EER:  17.67%
# on 55:
#        Validation 55 ,Validation Loss 0.41745 , Validation Balanced Accuracy: 88.83%
# on 55: Validation EER:  11.18%
# on 55: Validation f1 Score: 88.84%
# on 55:
# on 55:
# on 56:
#        Train Balanced Accuracy:  82.54%
# on 56: Train EER:  17.46%
# on 56:
#        Validation 56 ,Validation Loss 0.41237 , Validation Balanced Accuracy: 89.04%
# on 56: Validation EER:  10.98%
# on 56: Validation f1 Score: 89.02%
# on 56:
# on 56:
# on 57:
#        Train Balanced Accuracy:  82.74%
# on 57: Train EER:  17.26%
# on 57:
#        Validation 57 ,Validation Loss 0.40942 , Validation Balanced Accuracy: 89.37%
# on 57: Validation EER:  10.66%
# on 57: Validation f1 Score: 89.35%
# on 57:
# on 57:
# on 58:
#        Train Balanced Accuracy:  82.89%
# on 58: Train EER:  17.11%
# on 58:
#        Validation 58 ,Validation Loss 0.40551 , Validation Balanced Accuracy: 89.63%
# on 58: Validation EER:  10.37%
# on 58: Validation f1 Score: 89.64%
# on 58:
# on 58:
# on 59:
#        Train Balanced Accuracy:  83.07%
# on 59: Train EER:  16.93%
# on 59:
#        Validation 59 ,Validation Loss 0.40110 , Validation Balanced Accuracy: 89.81%
# on 59: Validation EER:  10.24%
# on 59: Validation f1 Score: 89.77%
# on 59:
# on 59:
# on 60:
#        Train Balanced Accuracy:  83.27%
# on 60: Train EER:  16.73%
# on 60:
#        Validation 60 ,Validation Loss 0.39694 , Validation Balanced Accuracy: 89.97%
# on 60: Validation EER:  10.02%
# on 60: Validation f1 Score: 89.88%
# on 60:
# on 60:
# on 61:
#        Train Balanced Accuracy:  83.57%
# on 61: Train EER:  16.43%
# on 61:
#        Validation 61 ,Validation Loss 0.39400 , Validation Balanced Accuracy: 90.22%
# on 61: Validation EER:  9.79%
# on 61: Validation f1 Score: 90.13%
# on 61:
# on 61:
# on 62:
#        Train Balanced Accuracy:  83.73%
# on 62: Train EER:  16.27%
# on 62:
#        Validation 62 ,Validation Loss 0.39057 , Validation Balanced Accuracy: 90.57%
# on 62: Validation EER:  9.45%
# on 62: Validation f1 Score: 90.58%
# on 62:
# on 62:
# on 63:
#        Train Balanced Accuracy:  83.99%
# on 63: Train EER:  16.01%
# on 63:
#        Validation 63 ,Validation Loss 0.38791 , Validation Balanced Accuracy: 90.68%
# on 63: Validation EER:  9.33%
# on 63: Validation f1 Score: 90.59%
# on 63:
# on 63:
# on 64:
#        Train Balanced Accuracy:  84.24%
# on 64: Train EER:  15.75%
# on 64:
#        Validation 64 ,Validation Loss 0.38255 , Validation Balanced Accuracy: 91.13%
# on 64: Validation EER:  8.87%
# on 64: Validation f1 Score: 91.13%
# on 64:
# on 64:
# on 65:
#        Train Balanced Accuracy:  84.42%
# on 65: Train EER:  15.58%
# on 65:
#        Validation 65 ,Validation Loss 0.37904 , Validation Balanced Accuracy: 91.42%
# on 65: Validation EER:  8.64%
# on 65: Validation f1 Score: 91.37%
# on 65:
# on 65:
# on 66:
#        Train Balanced Accuracy:  84.60%
# on 66: Train EER:  15.40%
# on 66:
#        Validation 66 ,Validation Loss 0.37575 , Validation Balanced Accuracy: 91.68%
# on 66: Validation EER:  8.35%
# on 66: Validation f1 Score: 91.66%
# on 66:
# on 66:
# on 67:
#        Train Balanced Accuracy:  84.74%
# on 67: Train EER:  15.26%
# on 67:
#        Validation 67 ,Validation Loss 0.37213 , Validation Balanced Accuracy: 92.03%
# on 67: Validation EER:  7.98%
# on 67: Validation f1 Score: 92.02%
# on 67:
# on 67:
# on 68:
#        Train Balanced Accuracy:  84.90%
# on 68: Train EER:  15.11%
# on 68:
#        Validation 68 ,Validation Loss 0.36679 , Validation Balanced Accuracy: 92.24%
# on 68: Validation EER:  7.79%
# on 68: Validation f1 Score: 92.22%
# on 68:
# on 68:
# on 69:
#        Train Balanced Accuracy:  85.06%
# on 69: Train EER:  14.96%
# on 69:
#        Validation 69 ,Validation Loss 0.36488 , Validation Balanced Accuracy: 92.58%
# on 69: Validation EER:  7.47%
# on 69: Validation f1 Score: 92.54%
# on 69:
# on 69:
# on 70:
#        Train Balanced Accuracy:  85.15%
# on 70: Train EER:  14.85%
# on 70:
#        Validation 70 ,Validation Loss 0.36035 , Validation Balanced Accuracy: 92.85%
# on 70: Validation EER:  7.14%
# on 70: Validation f1 Score: 92.85%
# on 70:
# on 70:
# on 71:
#        Train Balanced Accuracy:  85.27%
# on 71: Train EER:  14.73%
# on 71:
#        Validation 71 ,Validation Loss 0.35707 , Validation Balanced Accuracy: 93.04%
# on 71: Validation EER:  7.01%
# on 71: Validation f1 Score: 93.00%
# on 71:
# on 71:
# on 72:
#        Train Balanced Accuracy:  85.46%
# on 72: Train EER:  14.53%
# on 72:
#        Validation 72 ,Validation Loss 0.35269 , Validation Balanced Accuracy: 93.20%
# on 72: Validation EER:  6.80%
# on 72: Validation f1 Score: 93.20%
# on 72:
# on 72:
# on 73:
#        Train Balanced Accuracy:  85.63%
# on 73: Train EER:  14.37%
# on 73:
#        Validation 73 ,Validation Loss 0.34945 , Validation Balanced Accuracy: 93.51%
# on 73: Validation EER:  6.53%
# on 73: Validation f1 Score: 93.47%
# on 73:
# on 73:
# on 74:
#        Train Balanced Accuracy:  85.87%
# on 74: Train EER:  14.13%
# on 74:
#        Validation 74 ,Validation Loss 0.34694 , Validation Balanced Accuracy: 93.84%
# on 74: Validation EER:  6.21%
# on 74: Validation f1 Score: 93.80%
# on 74:
# on 74:
# on 75:
#        Train Balanced Accuracy:  86.05%
# on 75: Train EER:  13.96%
# on 75:
#        Validation 75 ,Validation Loss 0.34130 , Validation Balanced Accuracy: 94.10%
# on 75: Validation EER:  5.93%
# on 75: Validation f1 Score: 94.08%
# on 75:
# on 75:
# on 76:
#        Train Balanced Accuracy:  86.21%
# on 76: Train EER:  13.79%
# on 76:
#        Validation 76 ,Validation Loss 0.33939 , Validation Balanced Accuracy: 94.31%
# on 76: Validation EER:  5.74%
# on 76: Validation f1 Score: 94.27%
# on 76:
# on 76:
# on 77:
#        Train Balanced Accuracy:  86.46%
# on 77: Train EER:  13.54%
# on 77:
#        Validation 77 ,Validation Loss 0.33595 , Validation Balanced Accuracy: 94.58%
# on 77: Validation EER:  5.42%
# on 77: Validation f1 Score: 94.58%
# on 77:
# on 77:
# on 78:
#        Train Balanced Accuracy:  86.65%
# on 78: Train EER:  13.35%
# on 78:
#        Validation 78 ,Validation Loss 0.33323 , Validation Balanced Accuracy: 94.68%
# on 78: Validation EER:  5.34%
# on 78: Validation f1 Score: 94.66%
# on 78:
# on 78:
# on 79:
#        Train Balanced Accuracy:  86.90%
# on 79: Train EER:  13.10%
# on 79:
#        Validation 79 ,Validation Loss 0.32962 , Validation Balanced Accuracy: 94.90%
# on 79: Validation EER:  5.13%
# on 79: Validation f1 Score: 94.88%
# on 79:
# on 79:
# on 80:
#        Train Balanced Accuracy:  87.15%
# on 80: Train EER:  12.85%
# on 80:
#        Validation 80 ,Validation Loss 0.32590 , Validation Balanced Accuracy: 95.11%
# on 80: Validation EER:  4.94%
# on 80: Validation f1 Score: 95.07%
# on 80:
# on 80:
# on 81:
#        Train Balanced Accuracy:  87.29%
# on 81: Train EER:  12.70%
# on 81:
#        Validation 81 ,Validation Loss 0.32400 , Validation Balanced Accuracy: 95.30%
# on 81: Validation EER:  4.72%
# on 81: Validation f1 Score: 95.31%
# on 81:
# on 81:
# on 82:
#        Train Balanced Accuracy:  87.47%
# on 82: Train EER:  12.52%
# on 82:
#        Validation 82 ,Validation Loss 0.31842 , Validation Balanced Accuracy: 95.30%
# on 82: Validation EER:  4.72%
# on 82: Validation f1 Score: 95.23%
# on 82:
# on 82:
# on 83:
#        Train Balanced Accuracy:  87.69%
# on 83: Train EER:  12.32%
# on 83:
#        Validation 83 ,Validation Loss 0.31605 , Validation Balanced Accuracy: 95.47%
# on 83: Validation EER:  4.57%
# on 83: Validation f1 Score: 95.44%
# on 83:
# on 83:
# on 84:
#        Train Balanced Accuracy:  87.86%
# on 84: Train EER:  12.15%
# on 84:
#        Validation 84 ,Validation Loss 0.31352 , Validation Balanced Accuracy: 95.69%
# on 84: Validation EER:  4.36%
# on 84: Validation f1 Score: 95.65%
# on 84:
# on 84:
# on 85:
#        Train Balanced Accuracy:  88.11%
# on 85: Train EER:  11.89%
# on 85:
#        Validation 85 ,Validation Loss 0.30971 , Validation Balanced Accuracy: 95.80%
# on 85: Validation EER:  4.25%
# on 85: Validation f1 Score: 95.76%
# on 85:
# on 85:
# on 86:
#        Train Balanced Accuracy:  88.25%
# on 86: Train EER:  11.75%
# on 86:
#        Validation 86 ,Validation Loss 0.30804 , Validation Balanced Accuracy: 96.03%
# on 86: Validation EER:  4.02%
# on 86: Validation f1 Score: 95.99%
# on 86:
# on 86:
# on 87:
#        Train Balanced Accuracy:  88.41%
# on 87: Train EER:  11.59%
# on 87:
#        Validation 87 ,Validation Loss 0.30561 , Validation Balanced Accuracy: 96.17%
# on 87: Validation EER:  3.92%
# on 87: Validation f1 Score: 96.25%
# on 87:
# on 87:
# on 88:
#        Train Balanced Accuracy:  88.57%
# on 88: Train EER:  11.43%
# on 88:
#        Validation 88 ,Validation Loss 0.30186 , Validation Balanced Accuracy: 96.16%
# on 88: Validation EER:  3.88%
# on 88: Validation f1 Score: 96.13%
# on 88:
# on 88:
# on 89:
#        Train Balanced Accuracy:  88.80%
# on 89: Train EER:  11.20%
# on 89:
#        Validation 89 ,Validation Loss 0.29603 , Validation Balanced Accuracy: 96.35%
# on 89: Validation EER:  3.69%
# on 89: Validation f1 Score: 96.38%
# on 89:
# on 89:
# on 90:
#        Train Balanced Accuracy:  88.97%
# on 90: Train EER:  11.03%
# on 90:
#        Validation 90 ,Validation Loss 0.29325 , Validation Balanced Accuracy: 96.51%
# on 90: Validation EER:  3.53%
# on 90: Validation f1 Score: 96.48%
# on 90:
# on 90:
# on 91:
#        Train Balanced Accuracy:  89.14%
# on 91: Train EER:  10.86%
# on 91:
#        Validation 91 ,Validation Loss 0.29191 , Validation Balanced Accuracy: 96.63%
# on 91: Validation EER:  3.40%
# on 91: Validation f1 Score: 96.61%
# on 91:
# on 91:
# on 92:
#        Train Balanced Accuracy:  89.42%
# on 92: Train EER:  10.58%
# on 92:
#        Validation 92 ,Validation Loss 0.28978 , Validation Balanced Accuracy: 96.83%
# on 92: Validation EER:  3.22%
# on 92: Validation f1 Score: 96.79%
# on 92:
# on 92:
# on 93:
#        Train Balanced Accuracy:  89.66%
# on 93: Train EER:  10.34%
# on 93:
#        Validation 93 ,Validation Loss 0.28584 , Validation Balanced Accuracy: 96.89%
# on 93: Validation EER:  3.11%
# on 93: Validation f1 Score: 96.89%
# on 93:
# on 93:
# on 94:
#        Train Balanced Accuracy:  89.91%
# on 94: Train EER:  10.10%
# on 94:
#        Validation 94 ,Validation Loss 0.28290 , Validation Balanced Accuracy: 96.97%
# on 94: Validation EER:  3.06%
# on 94: Validation f1 Score: 96.95%
# on 94:
# on 94:
# on 95:
#        Train Balanced Accuracy:  90.16%
# on 95: Train EER:  9.84%
# on 95:
#        Validation 95 ,Validation Loss 0.27927 , Validation Balanced Accuracy: 97.09%
# on 95: Validation EER:  2.95%
# on 95: Validation f1 Score: 97.06%
# on 95:
# on 95:
# on 96:
#        Train Balanced Accuracy:  90.41%
# on 96: Train EER:  9.60%
# on 96:
#        Validation 96 ,Validation Loss 0.27838 , Validation Balanced Accuracy: 97.16%
# on 96: Validation EER:  2.88%
# on 96: Validation f1 Score: 97.09%
# on 96:
# on 96:
# on 97:
#        Train Balanced Accuracy:  90.56%
# on 97: Train EER:  9.44%
# on 97:
#        Validation 97 ,Validation Loss 0.27368 , Validation Balanced Accuracy: 97.24%
# on 97: Validation EER:  2.75%
# on 97: Validation f1 Score: 97.25%
# on 97:
# on 97:
# on 98:
#        Train Balanced Accuracy:  90.77%
# on 98: Train EER:  9.24%
# on 98:
#        Validation 98 ,Validation Loss 0.27081 , Validation Balanced Accuracy: 97.35%
# on 98: Validation EER:  2.65%
# on 98: Validation f1 Score: 97.35%
# on 98:
# on 98:
# on 99:
#        Train Balanced Accuracy:  90.92%
# on 99: Train EER:  9.08%
# on 99:
#        Validation 99 ,Validation Loss 0.26881 , Validation Balanced Accuracy: 97.37%
# on 99: Validation EER:  2.65%
# on 99: Validation f1 Score: 97.30%
# on 99:
# on 99:
# on 100:
#         Train Balanced Accuracy:  91.09%
# on 100: Train EER:  8.92%
# on 100:
#         Validation 100 ,Validation Loss 0.26516 , Validation Balanced Accuracy: 97.46%
# on 100: Validation EER:  2.54%
# on 100: Validation f1 Score: 97.46%
# on 100:
# on 100:
# on 101:
#         Train Balanced Accuracy:  91.20%
# on 101: Train EER:  8.79%
# on 101:
#         Validation 101 ,Validation Loss 0.26195 , Validation Balanced Accuracy: 97.53%
# on 101: Validation EER:  2.53%
# on 101: Validation f1 Score: 97.58%
# on 101:
# on 101:
# on 102:
#         Train Balanced Accuracy:  91.38%
# on 102: Train EER:  8.63%
# on 102:
#         Validation 102 ,Validation Loss 0.25967 , Validation Balanced Accuracy: 97.51%
# on 102: Validation EER:  2.53%
# on 102: Validation f1 Score: 97.46%
# on 102:
# on 102:
# on 103:
#         Train Balanced Accuracy:  91.50%
# on 103: Train EER:  8.50%
# on 103:
#         Validation 103 ,Validation Loss 0.25858 , Validation Balanced Accuracy: 97.59%
# on 103: Validation EER:  2.42%
# on 103: Validation f1 Score: 97.60%
# on 103:
# on 103:
# on 104:
#         Train Balanced Accuracy:  91.69%
# on 104: Train EER:  8.31%
# on 104:
#         Validation 104 ,Validation Loss 0.25519 , Validation Balanced Accuracy: 97.66%
# on 104: Validation EER:  2.42%
# on 104: Validation f1 Score: 97.72%
# on 104:
# on 104:
# on 105:
#         Train Balanced Accuracy:  91.82%
# on 105: Train EER:  8.18%
# on 105:
#         Validation 105 ,Validation Loss 0.25358 , Validation Balanced Accuracy: 97.60%
# on 105: Validation EER:  2.42%
# on 105: Validation f1 Score: 97.52%
# on 105:
# on 105:
# on 106:
#         Train Balanced Accuracy:  91.99%
# on 106: Train EER:  8.01%
# on 106:
#         Validation 106 ,Validation Loss 0.25137 , Validation Balanced Accuracy: 97.67%
# on 106: Validation EER:  2.35%
# on 106: Validation f1 Score: 97.65%
# on 106:
# on 106:
# on 107:
#         Train Balanced Accuracy:  92.12%
# on 107: Train EER:  7.89%
# on 107:
#         Validation 107 ,Validation Loss 0.24938 , Validation Balanced Accuracy: 97.70%
# on 107: Validation EER:  2.30%
# on 107: Validation f1 Score: 97.71%
# on 107:
# on 107:
# on 108:
#         Train Balanced Accuracy:  92.25%
# on 108: Train EER:  7.75%
# on 108:
#         Validation 108 ,Validation Loss 0.24534 , Validation Balanced Accuracy: 97.77%
# on 108: Validation EER:  2.27%
# on 108: Validation f1 Score: 97.74%
# on 108:
# on 108:
# on 109:
#         Train Balanced Accuracy:  92.35%
# on 109: Train EER:  7.65%
# on 109:
#         Validation 109 ,Validation Loss 0.24306 , Validation Balanced Accuracy: 97.87%
# on 109: Validation EER:  2.19%
# on 109: Validation f1 Score: 97.82%
# on 109:
# on 109:
# on 110:
#         Train Balanced Accuracy:  92.46%
# on 110: Train EER:  7.54%
# on 110:
#         Validation 110 ,Validation Loss 0.24065 , Validation Balanced Accuracy: 97.89%
# on 110: Validation EER:  2.15%
# on 110: Validation f1 Score: 97.86%
# on 110:
# on 110:
# on 111:
#         Train Balanced Accuracy:  92.56%
# on 111: Train EER:  7.44%
# on 111:
#         Validation 111 ,Validation Loss 0.23959 , Validation Balanced Accuracy: 97.93%
# on 111: Validation EER:  2.07%
# on 111: Validation f1 Score: 97.94%
# on 111:
# on 111:
# on 112:
#         Train Balanced Accuracy:  92.70%
# on 112: Train EER:  7.30%
# on 112:
#         Validation 112 ,Validation Loss 0.23619 , Validation Balanced Accuracy: 98.00%
# on 112: Validation EER:  2.04%
# on 112: Validation f1 Score: 97.97%
# on 112:
# on 112:
# on 113:
#         Train Balanced Accuracy:  92.84%
# on 113: Train EER:  7.16%
# on 113:
#         Validation 113 ,Validation Loss 0.23246 , Validation Balanced Accuracy: 98.03%
# on 113: Validation EER:  1.98%
# on 113: Validation f1 Score: 98.03%
# on 113:
# on 113:
# on 114:
#         Train Balanced Accuracy:  92.92%
# on 114: Train EER:  7.08%
# on 114:
#         Validation 114 ,Validation Loss 0.23130 , Validation Balanced Accuracy: 98.10%
# on 114: Validation EER:  1.95%
# on 114: Validation f1 Score: 98.06%
# on 114:
# on 114:
# on 115:
#         Train Balanced Accuracy:  93.06%
# on 115: Train EER:  6.94%
# on 115:
#         Validation 115 ,Validation Loss 0.22989 , Validation Balanced Accuracy: 98.14%
# on 115: Validation EER:  1.87%
# on 115: Validation f1 Score: 98.14%
# on 115:
# on 115:
# on 116:
#         Train Balanced Accuracy:  93.17%
# on 116: Train EER:  6.83%
# on 116:
#         Validation 116 ,Validation Loss 0.22658 , Validation Balanced Accuracy: 98.16%
# on 116: Validation EER:  1.84%
# on 116: Validation f1 Score: 98.16%
# on 116:
# on 116:
# on 117:
#         Train Balanced Accuracy:  93.25%
# on 117: Train EER:  6.75%
# on 117:
#         Validation 117 ,Validation Loss 0.22614 , Validation Balanced Accuracy: 98.22%
# on 117: Validation EER:  1.84%
# on 117: Validation f1 Score: 98.17%
# on 117:
# on 117:
# on 118:
#         Train Balanced Accuracy:  93.35%
# on 118: Train EER:  6.65%
# on 118:
#         Validation 118 ,Validation Loss 0.22193 , Validation Balanced Accuracy: 98.22%
# on 118: Validation EER:  1.83%
# on 118: Validation f1 Score: 98.18%
# on 118:
# on 118:
# on 119:
#         Train Balanced Accuracy:  93.44%
# on 119: Train EER:  6.57%
# on 119:
#         Validation 119 ,Validation Loss 0.22032 , Validation Balanced Accuracy: 98.24%
# on 119: Validation EER:  1.80%
# on 119: Validation f1 Score: 98.21%
# on 119:
# on 119:
# on 120:
#         Train Balanced Accuracy:  93.51%
# on 120: Train EER:  6.49%
# on 120:
#         Validation 120 ,Validation Loss 0.21754 , Validation Balanced Accuracy: 98.32%
# on 120: Validation EER:  1.75%
# on 120: Validation f1 Score: 98.27%
# on 120:
# on 120:
# on 121:
#         Train Balanced Accuracy:  93.55%
# on 121: Train EER:  6.45%
# on 121:
#         Validation 121 ,Validation Loss 0.21672 , Validation Balanced Accuracy: 98.30%
# on 121: Validation EER:  1.66%
# on 121: Validation f1 Score: 98.33%
# on 121:
# on 121:
# on 122:
#         Train Balanced Accuracy:  93.60%
# on 122: Train EER:  6.40%
# on 122:
#         Validation 122 ,Validation Loss 0.21320 , Validation Balanced Accuracy: 98.37%
# on 122: Validation EER:  1.65%
# on 122: Validation f1 Score: 98.35%
# on 122:
# on 122:
# on 123:
#         Train Balanced Accuracy:  93.69%
# on 123: Train EER:  6.31%
# on 123:
#         Validation 123 ,Validation Loss 0.20977 , Validation Balanced Accuracy: 98.38%
# on 123: Validation EER:  1.64%
# on 123: Validation f1 Score: 98.37%
# on 123:
# on 123:
# on 124:
#         Train Balanced Accuracy:  93.72%
# on 124: Train EER:  6.28%
# on 124:
#         Validation 124 ,Validation Loss 0.20905 , Validation Balanced Accuracy: 98.40%
# on 124: Validation EER:  1.61%
# on 124: Validation f1 Score: 98.40%
# on 124:
# on 124:
# on 125:
#         Train Balanced Accuracy:  93.75%
# on 125: Train EER:  6.25%
# on 125:
#         Validation 125 ,Validation Loss 0.20811 , Validation Balanced Accuracy: 98.44%
# on 125: Validation EER:  1.61%
# on 125: Validation f1 Score: 98.39%
# on 125:
# on 125:
# on 126:
#         Train Balanced Accuracy:  93.79%
# on 126: Train EER:  6.22%
# on 126:
#         Validation 126 ,Validation Loss 0.20562 , Validation Balanced Accuracy: 98.47%
# on 126: Validation EER:  1.56%
# on 126: Validation f1 Score: 98.45%
# on 126:
# on 126:
# on 127:
#         Train Balanced Accuracy:  93.87%
# on 127: Train EER:  6.13%
# on 127:
#         Validation 127 ,Validation Loss 0.20466 , Validation Balanced Accuracy: 98.49%
# on 127: Validation EER:  1.53%
# on 127: Validation f1 Score: 98.47%
# on 127:
# on 127:
# on 128:
#         Train Balanced Accuracy:  93.96%
# on 128: Train EER:  6.05%
# on 128:
#         Validation 128 ,Validation Loss 0.20242 , Validation Balanced Accuracy: 98.50%
# on 128: Validation EER:  1.50%
# on 128: Validation f1 Score: 98.50%
# on 128:
# on 128:
# on 129:
#         Train Balanced Accuracy:  94.02%
# on 129: Train EER:  5.98%
# on 129:
#         Validation 129 ,Validation Loss 0.19962 , Validation Balanced Accuracy: 98.56%
# on 129: Validation EER:  1.50%
# on 129: Validation f1 Score: 98.51%
# on 129:
# on 129:
# on 130:
#         Train Balanced Accuracy:  94.11%
# on 130: Train EER:  5.90%
# on 130:
#         Validation 130 ,Validation Loss 0.19711 , Validation Balanced Accuracy: 98.57%
# on 130: Validation EER:  1.47%
# on 130: Validation f1 Score: 98.54%
# on 130:
# on 130:
# on 131:
#         Train Balanced Accuracy:  94.21%
# on 131: Train EER:  5.79%
# on 131:
#         Validation 131 ,Validation Loss 0.19618 , Validation Balanced Accuracy: 98.60%
# on 131: Validation EER:  1.42%
# on 131: Validation f1 Score: 98.58%
# on 131:
# on 131:
# on 132:
#         Train Balanced Accuracy:  94.28%
# on 132: Train EER:  5.73%
# on 132:
#         Validation 132 ,Validation Loss 0.19573 , Validation Balanced Accuracy: 98.63%
# on 132: Validation EER:  1.38%
# on 132: Validation f1 Score: 98.64%
# on 132:
# on 132:
# on 133:
#         Train Balanced Accuracy:  94.41%
# on 133: Train EER:  5.59%
# on 133:
#         Validation 133 ,Validation Loss 0.19235 , Validation Balanced Accuracy: 98.67%
# on 133: Validation EER:  1.38%
# on 133: Validation f1 Score: 98.62%
# on 133:
# on 133:
# on 134:
#         Train Balanced Accuracy:  94.46%
# on 134: Train EER:  5.55%
# on 134:
#         Validation 134 ,Validation Loss 0.19182 , Validation Balanced Accuracy: 98.65%
# on 134: Validation EER:  1.33%
# on 134: Validation f1 Score: 98.67%
# on 134:
# on 134:
# on 135:
#         Train Balanced Accuracy:  94.51%
# on 135: Train EER:  5.50%
# on 135:
#         Validation 135 ,Validation Loss 0.18859 , Validation Balanced Accuracy: 98.70%
# on 135: Validation EER:  1.33%
# on 135: Validation f1 Score: 98.68%
# on 135:
# on 135:
# on 136:
#         Train Balanced Accuracy:  94.63%
# on 136: Train EER:  5.39%
# on 136:
#         Validation 136 ,Validation Loss 0.18715 , Validation Balanced Accuracy: 98.72%
# on 136: Validation EER:  1.29%
# on 136: Validation f1 Score: 98.72%
# on 136:
# on 136:
# on 137:
#         Train Balanced Accuracy:  94.72%
# on 137: Train EER:  5.28%
# on 137:
#         Validation 137 ,Validation Loss 0.18618 , Validation Balanced Accuracy: 98.73%
# on 137: Validation EER:  1.27%
# on 137: Validation f1 Score: 98.73%
# on 137:
# on 137:
# on 138:
#         Train Balanced Accuracy:  94.78%
# on 138: Train EER:  5.22%
# on 138:
#         Validation 138 ,Validation Loss 0.18402 , Validation Balanced Accuracy: 98.74%
# on 138: Validation EER:  1.27%
# on 138: Validation f1 Score: 98.74%
# on 138:
# on 138:
# on 139:
#         Train Balanced Accuracy:  94.84%
# on 139: Train EER:  5.16%
# on 139:
#         Validation 139 ,Validation Loss 0.18277 , Validation Balanced Accuracy: 98.75%
# on 139: Validation EER:  1.27%
# on 139: Validation f1 Score: 98.77%
# on 139:
# on 139:
# on 140:
#         Train Balanced Accuracy:  94.91%
# on 140: Train EER:  5.09%
# on 140:
#         Validation 140 ,Validation Loss 0.17988 , Validation Balanced Accuracy: 98.79%
# on 140: Validation EER:  1.27%
# on 140: Validation f1 Score: 98.74%
# on 140:
# on 140:
# on 141:
#         Train Balanced Accuracy:  94.99%
# on 141: Train EER:  5.02%
# on 141:
#         Validation 141 ,Validation Loss 0.17938 , Validation Balanced Accuracy: 98.79%
# on 141: Validation EER:  1.26%
# on 141: Validation f1 Score: 98.75%
# on 141:
# on 141:
# on 142:
#         Train Balanced Accuracy:  95.06%
# on 142: Train EER:  4.94%
# on 142:
#         Validation 142 ,Validation Loss 0.17751 , Validation Balanced Accuracy: 98.82%
# on 142: Validation EER:  1.22%
# on 142: Validation f1 Score: 98.79%
# on 142:
# on 142:
# on 143:
#         Train Balanced Accuracy:  95.09%
# on 143: Train EER:  4.91%
# on 143:
#         Validation 143 ,Validation Loss 0.17448 , Validation Balanced Accuracy: 98.84%
# on 143: Validation EER:  1.18%
# on 143: Validation f1 Score: 98.83%
# on 143:
# on 143:
# on 144:
#         Train Balanced Accuracy:  95.11%
# on 144: Train EER:  4.90%
# on 144:
#         Validation 144 ,Validation Loss 0.17388 , Validation Balanced Accuracy: 98.84%
# on 144: Validation EER:  1.15%
# on 144: Validation f1 Score: 98.84%
# on 144:
# on 144:
# on 145:
#         Train Balanced Accuracy:  95.17%
# on 145: Train EER:  4.83%
# on 145:
#         Validation 145 ,Validation Loss 0.17299 , Validation Balanced Accuracy: 98.86%
# on 145: Validation EER:  1.15%
# on 145: Validation f1 Score: 98.87%
# on 145:
# on 145:
# on 146:
#         Train Balanced Accuracy:  95.25%
# on 146: Train EER:  4.75%
# on 146:
#         Validation 146 ,Validation Loss 0.17199 , Validation Balanced Accuracy: 98.88%
# on 146: Validation EER:  1.15%
# on 146: Validation f1 Score: 98.90%
# on 146:
# on 146:
# on 147:
#         Train Balanced Accuracy:  95.32%
# on 147: Train EER:  4.68%
# on 147:
#         Validation 147 ,Validation Loss 0.16825 , Validation Balanced Accuracy: 98.88%
# on 147: Validation EER:  1.15%
# on 147: Validation f1 Score: 98.81%
# on 147:
# on 147:
# on 148:
#         Train Balanced Accuracy:  95.42%
# on 148: Train EER:  4.58%
# on 148:
#         Validation 148 ,Validation Loss 0.16798 , Validation Balanced Accuracy: 98.89%
# on 148: Validation EER:  1.15%
# on 148: Validation f1 Score: 98.83%
# on 148:
# on 148:
# on 149:
#         Train Balanced Accuracy:  95.49%
# on 149: Train EER:  4.52%
# on 149:
#         Validation 149 ,Validation Loss 0.16578 , Validation Balanced Accuracy: 98.90%
# on 149: Validation EER:  1.15%
# on 149: Validation f1 Score: 98.85%
# on 149:
# on 149:
# on 150:
#         Train Balanced Accuracy:  95.58%
# on 150: Train EER:  4.42%
# on 150:
#         Validation 150 ,Validation Loss 0.16705 , Validation Balanced Accuracy: 98.91%
# on 150: Validation EER:  1.14%
# on 150: Validation f1 Score: 98.87%
# on 150: EarlyStopping counter: 1 out of 300
# on 150:
# on 150:
# on 151:
#         Train Balanced Accuracy:  95.64%
# on 151: Train EER:  4.37%
# on 151:
#         Validation 151 ,Validation Loss 0.16359 , Validation Balanced Accuracy: 98.92%
# on 151: Validation EER:  1.12%
# on 151: Validation f1 Score: 98.89%
# on 151:
# on 151:
# on 152:
#         Train Balanced Accuracy:  95.70%
# on 152: Train EER:  4.30%
# on 152:
#         Validation 152 ,Validation Loss 0.16195 , Validation Balanced Accuracy: 98.93%
# on 152: Validation EER:  1.10%
# on 152: Validation f1 Score: 98.91%
# on 152:
# on 152:
# on 153:
#         Train Balanced Accuracy:  95.77%
# on 153: Train EER:  4.23%
# on 153:
#         Validation 153 ,Validation Loss 0.15931 , Validation Balanced Accuracy: 98.95%
# on 153: Validation EER:  1.06%
# on 153: Validation f1 Score: 98.95%
# on 153:
# on 153:
# on 154:
#         Train Balanced Accuracy:  95.82%
# on 154: Train EER:  4.19%
# on 154:
#         Validation 154 ,Validation Loss 0.15944 , Validation Balanced Accuracy: 98.95%
# on 154: Validation EER:  1.06%
# on 154: Validation f1 Score: 98.95%
# on 154: EarlyStopping counter: 1 out of 300
# on 154:
# on 154:
# on 155:
#         Train Balanced Accuracy:  95.88%
# on 155: Train EER:  4.12%
# on 155:
#         Validation 155 ,Validation Loss 0.15801 , Validation Balanced Accuracy: 98.96%
# on 155: Validation EER:  1.04%
# on 155: Validation f1 Score: 98.96%
# on 155:
# on 155:
# on 156:
#         Train Balanced Accuracy:  95.93%
# on 156: Train EER:  4.07%
# on 156:
#         Validation 156 ,Validation Loss 0.15643 , Validation Balanced Accuracy: 99.02%
# on 156: Validation EER:  1.04%
# on 156: Validation f1 Score: 98.97%
# on 156:
# on 156:
# on 157:
#         Train Balanced Accuracy:  95.98%
# on 157: Train EER:  4.02%
# on 157:
#         Validation 157 ,Validation Loss 0.15485 , Validation Balanced Accuracy: 99.03%
# on 157: Validation EER:  1.03%
# on 157: Validation f1 Score: 98.98%
# on 157:
# on 157:
# on 158:
#         Train Balanced Accuracy:  96.02%
# on 158: Train EER:  3.99%
# on 158:
#         Validation 158 ,Validation Loss 0.15507 , Validation Balanced Accuracy: 99.04%
# on 158: Validation EER:  1.00%
# on 158: Validation f1 Score: 99.01%
# on 158: EarlyStopping counter: 1 out of 300
# on 158:
# on 158:
# on 159:
#         Train Balanced Accuracy:  96.04%
# on 159: Train EER:  3.96%
# on 159:
#         Validation 159 ,Validation Loss 0.15274 , Validation Balanced Accuracy: 99.05%
# on 159: Validation EER:  0.97%
# on 159: Validation f1 Score: 99.03%
# on 159:
# on 159:
# on 160:
#         Train Balanced Accuracy:  96.07%
# on 160: Train EER:  3.93%
# on 160:
#         Validation 160 ,Validation Loss 0.15200 , Validation Balanced Accuracy: 99.06%
# on 160: Validation EER:  0.96%
# on 160: Validation f1 Score: 99.04%
# on 160:
# on 160:
# on 161:
#         Train Balanced Accuracy:  96.12%
# on 161: Train EER:  3.89%
# on 161:
#         Validation 161 ,Validation Loss 0.15014 , Validation Balanced Accuracy: 99.07%
# on 161: Validation EER:  0.95%
# on 161: Validation f1 Score: 99.06%
# on 161:
# on 161:
# on 162:
#         Train Balanced Accuracy:  96.14%
# on 162: Train EER:  3.86%
# on 162:
#         Validation 162 ,Validation Loss 0.14857 , Validation Balanced Accuracy: 99.07%
# on 162: Validation EER:  0.92%
# on 162: Validation f1 Score: 99.07%
# on 162:
# on 162:
# on 163:
#         Train Balanced Accuracy:  96.16%
# on 163: Train EER:  3.84%
# on 163:
#         Validation 163 ,Validation Loss 0.14865 , Validation Balanced Accuracy: 99.08%
# on 163: Validation EER:  0.92%
# on 163: Validation f1 Score: 99.08%
# on 163: EarlyStopping counter: 1 out of 300
# on 163:
# on 163:
# on 164:
#         Train Balanced Accuracy:  96.21%
# on 164: Train EER:  3.79%
# on 164:
#         Validation 164 ,Validation Loss 0.14591 , Validation Balanced Accuracy: 99.08%
# on 164: Validation EER:  0.92%
# on 164: Validation f1 Score: 99.08%
# on 164:
# on 164:
# on 165:
#         Train Balanced Accuracy:  96.24%
# on 165: Train EER:  3.76%
# on 165:
#         Validation 165 ,Validation Loss 0.14693 , Validation Balanced Accuracy: 99.13%
# on 165: Validation EER:  0.92%
# on 165: Validation f1 Score: 99.08%
# on 165: EarlyStopping counter: 1 out of 300
# on 165:
# on 165:
# on 166:
#         Train Balanced Accuracy:  96.28%
# on 166: Train EER:  3.72%
# on 166:
#         Validation 166 ,Validation Loss 0.14369 , Validation Balanced Accuracy: 99.14%
# on 166: Validation EER:  0.91%
# on 166: Validation f1 Score: 99.10%
# on 166:
# on 166:
# on 167:
#         Train Balanced Accuracy:  96.34%
# on 167: Train EER:  3.68%
# on 167:
#         Validation 167 ,Validation Loss 0.14201 , Validation Balanced Accuracy: 99.15%
# on 167: Validation EER:  0.89%
# on 167: Validation f1 Score: 99.12%
# on 167:
# on 167:
# on 168:
#         Train Balanced Accuracy:  96.35%
# on 168: Train EER:  3.65%
# on 168:
#         Validation 168 ,Validation Loss 0.14260 , Validation Balanced Accuracy: 99.18%
# on 168: Validation EER:  0.84%
# on 168: Validation f1 Score: 99.16%
# on 168: EarlyStopping counter: 1 out of 300
# on 168:
# on 168:
# on 169:
#         Train Balanced Accuracy:  96.38%
# on 169: Train EER:  3.62%
# on 169:
#         Validation 169 ,Validation Loss 0.14224 , Validation Balanced Accuracy: 99.19%
# on 169: Validation EER:  0.81%
# on 169: Validation f1 Score: 99.19%
# on 169: EarlyStopping counter: 2 out of 300
# on 169:
# on 169:
# on 170:
#         Train Balanced Accuracy:  96.41%
# on 170: Train EER:  3.59%
# on 170:
#         Validation 170 ,Validation Loss 0.13997 , Validation Balanced Accuracy: 99.19%
# on 170: Validation EER:  0.81%
# on 170: Validation f1 Score: 99.19%
# on 170:
# on 170:
# on 171:
#         Train Balanced Accuracy:  96.42%
# on 171: Train EER:  3.58%
# on 171:
#         Validation 171 ,Validation Loss 0.13852 , Validation Balanced Accuracy: 99.19%
# on 171: Validation EER:  0.81%
# on 171: Validation f1 Score: 99.19%
# on 171:
# on 171:
# on 172:
#         Train Balanced Accuracy:  96.46%
# on 172: Train EER:  3.55%
# on 172:
#         Validation 172 ,Validation Loss 0.13819 , Validation Balanced Accuracy: 99.19%
# on 172: Validation EER:  0.81%
# on 172: Validation f1 Score: 99.19%
# on 172:
# on 172:
# on 173:
#         Train Balanced Accuracy:  96.49%
# on 173: Train EER:  3.52%
# on 173:
#         Validation 173 ,Validation Loss 0.13618 , Validation Balanced Accuracy: 99.19%
# on 173: Validation EER:  0.81%
# on 173: Validation f1 Score: 99.19%
# on 173:
# on 173:
# on 174:
#         Train Balanced Accuracy:  96.50%
# on 174: Train EER:  3.50%
# on 174:
#         Validation 174 ,Validation Loss 0.13689 , Validation Balanced Accuracy: 99.19%
# on 174: Validation EER:  0.81%
# on 174: Validation f1 Score: 99.19%
# on 174: EarlyStopping counter: 1 out of 300
# on 174:
# on 174:
# on 175:
#         Train Balanced Accuracy:  96.53%
# on 175: Train EER:  3.47%
# on 175:
#         Validation 175 ,Validation Loss 0.13491 , Validation Balanced Accuracy: 99.19%
# on 175: Validation EER:  0.81%
# on 175: Validation f1 Score: 99.19%
# on 175:
# on 175:
# on 176:
#         Train Balanced Accuracy:  96.55%
# on 176: Train EER:  3.45%
# on 176:
#         Validation 176 ,Validation Loss 0.13408 , Validation Balanced Accuracy: 99.19%
# on 176: Validation EER:  0.81%
# on 176: Validation f1 Score: 99.19%
# on 176:
# on 176:
# on 177:
#         Train Balanced Accuracy:  96.58%
# on 177: Train EER:  3.42%
# on 177:
#         Validation 177 ,Validation Loss 0.13295 , Validation Balanced Accuracy: 99.19%
# on 177: Validation EER:  0.81%
# on 177: Validation f1 Score: 99.19%
# on 177:
# on 177:
# on 178:
#         Train Balanced Accuracy:  96.60%
# on 178: Train EER:  3.40%
# on 178:
#         Validation 178 ,Validation Loss 0.13203 , Validation Balanced Accuracy: 99.19%
# on 178: Validation EER:  0.81%
# on 178: Validation f1 Score: 99.19%
# on 178:
# on 178:
# on 179:
#         Train Balanced Accuracy:  96.63%
# on 179: Train EER:  3.37%
# on 179:
#         Validation 179 ,Validation Loss 0.12940 , Validation Balanced Accuracy: 99.19%
# on 179: Validation EER:  0.81%
# on 179: Validation f1 Score: 99.19%
# on 179:
# on 179:
# on 180:
#         Train Balanced Accuracy:  96.63%
# on 180: Train EER:  3.38%
# on 180:
#         Validation 180 ,Validation Loss 0.12944 , Validation Balanced Accuracy: 99.19%
# on 180: Validation EER:  0.81%
# on 180: Validation f1 Score: 99.19%
# on 180: EarlyStopping counter: 1 out of 300
# on 180:
# on 180:
# on 181:
#         Train Balanced Accuracy:  96.64%
# on 181: Train EER:  3.36%
# on 181:
#         Validation 181 ,Validation Loss 0.12856 , Validation Balanced Accuracy: 99.19%
# on 181: Validation EER:  0.81%
# on 181: Validation f1 Score: 99.19%
# on 181:
# on 181:
# on 182:
#         Train Balanced Accuracy:  96.69%
# on 182: Train EER:  3.32%
# on 182:
#         Validation 182 ,Validation Loss 0.12765 , Validation Balanced Accuracy: 99.19%
# on 182: Validation EER:  0.81%
# on 182: Validation f1 Score: 99.19%
# on 182:
# on 182:
# on 183:
#         Train Balanced Accuracy:  96.72%
# on 183: Train EER:  3.28%
# on 183:
#         Validation 183 ,Validation Loss 0.12638 , Validation Balanced Accuracy: 99.19%
# on 183: Validation EER:  0.81%
# on 183: Validation f1 Score: 99.19%
# on 183:
# on 183:
# on 184:
#         Train Balanced Accuracy:  96.73%
# on 184: Train EER:  3.27%
# on 184:
#         Validation 184 ,Validation Loss 0.12664 , Validation Balanced Accuracy: 99.19%
# on 184: Validation EER:  0.81%
# on 184: Validation f1 Score: 99.19%
# on 184: EarlyStopping counter: 1 out of 300
# on 184:
# on 184:
# on 185:
#         Train Balanced Accuracy:  96.77%
# on 185: Train EER:  3.23%
# on 185:
#         Validation 185 ,Validation Loss 0.12515 , Validation Balanced Accuracy: 99.19%
# on 185: Validation EER:  0.81%
# on 185: Validation f1 Score: 99.19%
# on 185:
# on 185:
# on 186:
#         Train Balanced Accuracy:  96.78%
# on 186: Train EER:  3.22%
# on 186:
#         Validation 186 ,Validation Loss 0.12380 , Validation Balanced Accuracy: 99.19%
# on 186: Validation EER:  0.81%
# on 186: Validation f1 Score: 99.19%
# on 186:
# on 186:
# on 187:
#         Train Balanced Accuracy:  96.81%
# on 187: Train EER:  3.20%
# on 187:
#         Validation 187 ,Validation Loss 0.12371 , Validation Balanced Accuracy: 99.25%
# on 187: Validation EER:  0.81%
# on 187: Validation f1 Score: 99.20%
# on 187:
# on 187:
# on 188:
#         Train Balanced Accuracy:  96.83%
# on 188: Train EER:  3.18%
# on 188:
#         Validation 188 ,Validation Loss 0.12183 , Validation Balanced Accuracy: 99.25%
# on 188: Validation EER:  0.81%
# on 188: Validation f1 Score: 99.20%
# ...
# on 243: Train EER:  2.32%
# on 243:
#         Validation 243 ,Validation Loss 0.08771 , Validation Balanced Accuracy: 99.38%
# on 243: Validation EER:  0.66%
# on 243: Validation f1 Score: 99.35%
# on 243:
# on 243:
# on 244:
#         Train Balanced Accuracy:  97.70%
# on 244: Train EER:  2.32%
# on 244:
#         Validation 244 ,Validation Loss 0.08601 , Validation Balanced Accuracy: 99.38%
# on 244: Validation EER:  0.66%
# on 244: Validation f1 Score: 99.35%
# on 244:
# on 244:
# on 245:
#         Train Balanced Accuracy:  97.71%
# on 245: Train EER:  2.29%
# on 245:
#         Validation 245 ,Validation Loss 0.08656 , Validation Balanced Accuracy: 99.38%
# on 245: Validation EER:  0.66%
# on 245: Validation f1 Score: 99.35%
# on 245: EarlyStopping counter: 1 out of 300
# on 245:
# on 245:
# on 246:
#         Train Balanced Accuracy:  97.72%
# on 246: Train EER:  2.29%
# on 246:
#         Validation 246 ,Validation Loss 0.08647 , Validation Balanced Accuracy: 99.38%
# on 246: Validation EER:  0.66%
# on 246: Validation f1 Score: 99.35%
# on 246: EarlyStopping counter: 2 out of 300
# on 246:
# on 246:
# on 247:
#         Train Balanced Accuracy:  97.74%
# on 247: Train EER:  2.26%
# on 247:
#         Validation 247 ,Validation Loss 0.08756 , Validation Balanced Accuracy: 99.39%
# on 247: Validation EER:  0.65%
# on 247: Validation f1 Score: 99.36%
# on 247: EarlyStopping counter: 3 out of 300
# on 247:
# on 247:
# on 248:
#         Train Balanced Accuracy:  97.74%
# on 248: Train EER:  2.26%
# on 248:
#         Validation 248 ,Validation Loss 0.08669 , Validation Balanced Accuracy: 99.39%
# on 248: Validation EER:  0.65%
# on 248: Validation f1 Score: 99.36%
# on 248: EarlyStopping counter: 4 out of 300
# on 248:
# on 248:
# on 249:
#         Train Balanced Accuracy:  97.76%
# on 249: Train EER:  2.24%
# on 249:
#         Validation 249 ,Validation Loss 0.08569 , Validation Balanced Accuracy: 99.39%
# on 249: Validation EER:  0.65%
# on 249: Validation f1 Score: 99.36%
# on 249:
# on 249:
# on 250:
#         Train Balanced Accuracy:  97.77%
# on 250: Train EER:  2.23%
# on 250:
#         Validation 250 ,Validation Loss 0.08525 , Validation Balanced Accuracy: 99.39%
# on 250: Validation EER:  0.65%
# on 250: Validation f1 Score: 99.36%
# on 250:
# on 250:
# on 251:
#         Train Balanced Accuracy:  97.79%
# on 251: Train EER:  2.21%
# on 251:
#         Validation 251 ,Validation Loss 0.08548 , Validation Balanced Accuracy: 99.39%
# on 251: Validation EER:  0.65%
# on 251: Validation f1 Score: 99.36%
# on 251: EarlyStopping counter: 1 out of 300
# on 251:
# on 251:
# on 252:
#         Train Balanced Accuracy:  97.79%
# on 252: Train EER:  2.21%
# on 252:
#         Validation 252 ,Validation Loss 0.08321 , Validation Balanced Accuracy: 99.39%
# on 252: Validation EER:  0.65%
# on 252: Validation f1 Score: 99.36%
# on 252:
# on 252:
# on 253:
#         Train Balanced Accuracy:  97.81%
# on 253: Train EER:  2.19%
# on 253:
#         Validation 253 ,Validation Loss 0.08437 , Validation Balanced Accuracy: 99.39%
# on 253: Validation EER:  0.65%
# on 253: Validation f1 Score: 99.36%
# on 253: EarlyStopping counter: 1 out of 300
# on 253:
# on 253:
# on 254:
#         Train Balanced Accuracy:  97.82%
# on 254: Train EER:  2.19%
# on 254:
#         Validation 254 ,Validation Loss 0.08301 , Validation Balanced Accuracy: 99.39%
# on 254: Validation EER:  0.65%
# on 254: Validation f1 Score: 99.36%
# on 254:
# on 254:
# on 255:
#         Train Balanced Accuracy:  97.83%
# on 255: Train EER:  2.18%
# on 255:
#         Validation 255 ,Validation Loss 0.08311 , Validation Balanced Accuracy: 99.39%
# on 255: Validation EER:  0.65%
# on 255: Validation f1 Score: 99.36%
# on 255: EarlyStopping counter: 1 out of 300
# on 255:
# on 255:
# on 256:
#         Train Balanced Accuracy:  97.85%
# on 256: Train EER:  2.15%
# on 256:
#         Validation 256 ,Validation Loss 0.08193 , Validation Balanced Accuracy: 99.39%
# on 256: Validation EER:  0.65%
# on 256: Validation f1 Score: 99.36%
# on 256:
# on 256:
# on 257:
#         Train Balanced Accuracy:  97.84%
# on 257: Train EER:  2.17%
# on 257:
#         Validation 257 ,Validation Loss 0.08241 , Validation Balanced Accuracy: 99.39%
# on 257: Validation EER:  0.65%
# on 257: Validation f1 Score: 99.36%
# on 257: EarlyStopping counter: 1 out of 300
# on 257:
# on 257:
# on 258:
#         Train Balanced Accuracy:  97.84%
# on 258: Train EER:  2.16%
# on 258:
#         Validation 258 ,Validation Loss 0.08162 , Validation Balanced Accuracy: 99.41%
# on 258: Validation EER:  0.61%
# on 258: Validation f1 Score: 99.39%
# on 258:
# on 258:
# on 259:
#         Train Balanced Accuracy:  97.85%
# on 259: Train EER:  2.15%
# on 259:
#         Validation 259 ,Validation Loss 0.08102 , Validation Balanced Accuracy: 99.41%
# on 259: Validation EER:  0.61%
# on 259: Validation f1 Score: 99.39%
# on 259:
# on 259:
# on 260:
#         Train Balanced Accuracy:  97.87%
# on 260: Train EER:  2.14%
# on 260:
#         Validation 260 ,Validation Loss 0.08141 , Validation Balanced Accuracy: 99.41%
# on 260: Validation EER:  0.61%
# on 260: Validation f1 Score: 99.39%
# on 260: EarlyStopping counter: 1 out of 300
# on 260:
# on 260:
# on 261:
#         Train Balanced Accuracy:  97.87%
# on 261: Train EER:  2.13%
# on 261:
#         Validation 261 ,Validation Loss 0.08191 , Validation Balanced Accuracy: 99.41%
# on 261: Validation EER:  0.61%
# on 261: Validation f1 Score: 99.39%
# on 261: EarlyStopping counter: 2 out of 300
# on 261:
# on 261:
# on 262:
#         Train Balanced Accuracy:  97.87%
# on 262: Train EER:  2.13%
# on 262:
#         Validation 262 ,Validation Loss 0.07939 , Validation Balanced Accuracy: 99.41%
# on 262: Validation EER:  0.61%
# on 262: Validation f1 Score: 99.39%
# on 262:
# on 262:
# on 263:
#         Train Balanced Accuracy:  97.88%
# on 263: Train EER:  2.12%
# on 263:
#         Validation 263 ,Validation Loss 0.07938 , Validation Balanced Accuracy: 99.41%
# on 263: Validation EER:  0.61%
# on 263: Validation f1 Score: 99.39%
# on 263:
# on 263:
# on 264:
#         Train Balanced Accuracy:  97.90%
# on 264: Train EER:  2.10%
# on 264:
#         Validation 264 ,Validation Loss 0.07994 , Validation Balanced Accuracy: 99.41%
# on 264: Validation EER:  0.61%
# on 264: Validation f1 Score: 99.39%
# on 264: EarlyStopping counter: 1 out of 300
# on 264:
# on 264:
# on 265:
#         Train Balanced Accuracy:  97.88%
# on 265: Train EER:  2.12%
# on 265:
#         Validation 265 ,Validation Loss 0.07890 , Validation Balanced Accuracy: 99.41%
# on 265: Validation EER:  0.61%
# on 265: Validation f1 Score: 99.39%
# on 265:
# on 265:
# on 266:
#         Train Balanced Accuracy:  97.90%
# on 266: Train EER:  2.10%
# on 266:
#         Validation 266 ,Validation Loss 0.07844 , Validation Balanced Accuracy: 99.41%
# on 266: Validation EER:  0.61%
# on 266: Validation f1 Score: 99.39%
# on 266:
# on 266:
# on 267:
#         Train Balanced Accuracy:  97.90%
# on 267: Train EER:  2.10%
# on 267:
#         Validation 267 ,Validation Loss 0.07863 , Validation Balanced Accuracy: 99.41%
# on 267: Validation EER:  0.60%
# on 267: Validation f1 Score: 99.41%
# on 267: EarlyStopping counter: 1 out of 300
# on 267:
# on 267:
# on 268:
#         Train Balanced Accuracy:  97.90%
# on 268: Train EER:  2.09%
# on 268:
#         Validation 268 ,Validation Loss 0.07776 , Validation Balanced Accuracy: 99.42%
# on 268: Validation EER:  0.58%
# on 268: Validation f1 Score: 99.42%
# on 268:
# on 268:
# on 269:
#         Train Balanced Accuracy:  97.92%
# on 269: Train EER:  2.08%
# on 269:
#         Validation 269 ,Validation Loss 0.07679 , Validation Balanced Accuracy: 99.42%
# on 269: Validation EER:  0.58%
# on 269: Validation f1 Score: 99.42%
# on 269:
# on 269:
# on 270:
#         Train Balanced Accuracy:  97.93%
# on 270: Train EER:  2.07%
# on 270:
#         Validation 270 ,Validation Loss 0.07663 , Validation Balanced Accuracy: 99.42%
# on 270: Validation EER:  0.58%
# on 270: Validation f1 Score: 99.42%
# on 270:
# on 270:
# on 271:
#         Train Balanced Accuracy:  97.93%
# on 271: Train EER:  2.07%
# on 271:
#         Validation 271 ,Validation Loss 0.07778 , Validation Balanced Accuracy: 99.42%
# on 271: Validation EER:  0.58%
# on 271: Validation f1 Score: 99.42%
# on 271: EarlyStopping counter: 1 out of 300
# on 271:
# on 271:
# on 272:
#         Train Balanced Accuracy:  97.93%
# on 272: Train EER:  2.07%
# on 272:
#         Validation 272 ,Validation Loss 0.07687 , Validation Balanced Accuracy: 99.42%
# on 272: Validation EER:  0.58%
# on 272: Validation f1 Score: 99.42%
# on 272: EarlyStopping counter: 2 out of 300
# on 272:
# on 272:
# on 273:
#         Train Balanced Accuracy:  97.96%
# on 273: Train EER:  2.04%
# on 273:
#         Validation 273 ,Validation Loss 0.07599 , Validation Balanced Accuracy: 99.42%
# on 273: Validation EER:  0.58%
# on 273: Validation f1 Score: 99.42%
# on 273:
# on 273:
# on 274:
#         Train Balanced Accuracy:  97.95%
# on 274: Train EER:  2.05%
# on 274:
#         Validation 274 ,Validation Loss 0.07587 , Validation Balanced Accuracy: 99.43%
# on 274: Validation EER:  0.58%
# on 274: Validation f1 Score: 99.43%
# on 274:
# on 274:
# on 275:
#         Train Balanced Accuracy:  97.99%
# on 275: Train EER:  2.02%
# on 275:
#         Validation 275 ,Validation Loss 0.07590 , Validation Balanced Accuracy: 99.43%
# on 275: Validation EER:  0.58%
# on 275: Validation f1 Score: 99.43%
# on 275: EarlyStopping counter: 1 out of 300
# on 275:
# on 275:
# on 276:
#         Train Balanced Accuracy:  97.99%
# on 276: Train EER:  2.02%
# on 276:
#         Validation 276 ,Validation Loss 0.07508 , Validation Balanced Accuracy: 99.43%
# on 276: Validation EER:  0.58%
# on 276: Validation f1 Score: 99.43%
# on 276:
# on 276:
# on 277:
#         Train Balanced Accuracy:  98.00%
# on 277: Train EER:  2.00%
# on 277:
#         Validation 277 ,Validation Loss 0.07537 , Validation Balanced Accuracy: 99.43%
# on 277: Validation EER:  0.58%
# on 277: Validation f1 Score: 99.43%
# on 277: EarlyStopping counter: 1 out of 300
# on 277:
# on 277:
# on 278:
#         Train Balanced Accuracy:  98.01%
# on 278: Train EER:  2.00%
# on 278:
#         Validation 278 ,Validation Loss 0.07440 , Validation Balanced Accuracy: 99.43%
# on 278: Validation EER:  0.58%
# on 278: Validation f1 Score: 99.43%
# on 278:
# on 278:
# on 279:
#         Train Balanced Accuracy:  98.03%
# on 279: Train EER:  1.97%
# on 279:
#         Validation 279 ,Validation Loss 0.07481 , Validation Balanced Accuracy: 99.43%
# on 279: Validation EER:  0.58%
# on 279: Validation f1 Score: 99.44%
# on 279: EarlyStopping counter: 1 out of 300
# on 279:
# on 279:
# on 280:
#         Train Balanced Accuracy:  98.03%
# on 280: Train EER:  1.98%
# on 280:
#         Validation 280 ,Validation Loss 0.07424 , Validation Balanced Accuracy: 99.47%
# on 280: Validation EER:  0.58%
# on 280: Validation f1 Score: 99.41%
# on 280:
# on 280:
# on 281:
#         Train Balanced Accuracy:  98.05%
# on 281: Train EER:  1.95%
# on 281:
#         Validation 281 ,Validation Loss 0.07387 , Validation Balanced Accuracy: 99.47%
# on 281: Validation EER:  0.58%
# on 281: Validation f1 Score: 99.41%
# on 281:
# on 281:
# on 282:
#         Train Balanced Accuracy:  98.05%
# on 282: Train EER:  1.95%
# on 282:
#         Validation 282 ,Validation Loss 0.07352 , Validation Balanced Accuracy: 99.47%
# on 282: Validation EER:  0.58%
# on 282: Validation f1 Score: 99.42%
# on 282:
# on 282:
# on 283:
#         Train Balanced Accuracy:  98.06%
# on 283: Train EER:  1.95%
# on 283:
#         Validation 283 ,Validation Loss 0.07197 , Validation Balanced Accuracy: 99.47%
# on 283: Validation EER:  0.58%
# on 283: Validation f1 Score: 99.42%
# on 283:
# on 283:
# on 284:
#         Train Balanced Accuracy:  98.05%
# on 284: Train EER:  1.93%
# on 284:
#         Validation 284 ,Validation Loss 0.07248 , Validation Balanced Accuracy: 99.47%
# on 284: Validation EER:  0.58%
# on 284: Validation f1 Score: 99.42%
# on 284: EarlyStopping counter: 1 out of 300
# on 284:
# on 284:
# on 285:
#         Train Balanced Accuracy:  98.07%
# on 285: Train EER:  1.93%
# on 285:
#         Validation 285 ,Validation Loss 0.07259 , Validation Balanced Accuracy: 99.48%
# on 285: Validation EER:  0.58%
# on 285: Validation f1 Score: 99.43%
# on 285: EarlyStopping counter: 2 out of 300
# on 285:
# on 285:
# on 286:
#         Train Balanced Accuracy:  98.07%
# on 286: Train EER:  1.93%
# on 286:
#         Validation 286 ,Validation Loss 0.07277 , Validation Balanced Accuracy: 99.48%
# on 286: Validation EER:  0.58%
# on 286: Validation f1 Score: 99.43%
# on 286: EarlyStopping counter: 3 out of 300
# on 286:
# on 286:
# on 287:
#         Train Balanced Accuracy:  98.09%
# on 287: Train EER:  1.91%
# on 287:
#         Validation 287 ,Validation Loss 0.07196 , Validation Balanced Accuracy: 99.48%
# on 287: Validation EER:  0.58%
# on 287: Validation f1 Score: 99.43%
# on 287:
# on 287:
# on 288:
#         Train Balanced Accuracy:  98.10%
# on 288: Train EER:  1.90%
# on 288:
#         Validation 288 ,Validation Loss 0.07169 , Validation Balanced Accuracy: 99.48%
# on 288: Validation EER:  0.58%
# on 288: Validation f1 Score: 99.43%
# on 288:
# on 288:
# on 289:
#         Train Balanced Accuracy:  98.12%
# on 289: Train EER:  1.88%
# on 289:
#         Validation 289 ,Validation Loss 0.07152 , Validation Balanced Accuracy: 99.48%
# on 289: Validation EER:  0.58%
# on 289: Validation f1 Score: 99.43%
# on 289:
# on 289:
# on 290:
#         Train Balanced Accuracy:  98.12%
# on 290: Train EER:  1.88%
# on 290:
#         Validation 290 ,Validation Loss 0.07306 , Validation Balanced Accuracy: 99.48%
# on 290: Validation EER:  0.58%
# on 290: Validation f1 Score: 99.43%
# on 290: EarlyStopping counter: 1 out of 300
# on 290:
# on 290:
# on 291:
#         Train Balanced Accuracy:  98.13%
# on 291: Train EER:  1.86%
# on 291:
#         Validation 291 ,Validation Loss 0.07098 , Validation Balanced Accuracy: 99.48%
# on 291: Validation EER:  0.58%
# on 291: Validation f1 Score: 99.43%
# on 291:
# on 291:
# on 292:
#         Train Balanced Accuracy:  98.15%
# on 292: Train EER:  1.85%
# on 292:
#         Validation 292 ,Validation Loss 0.07063 , Validation Balanced Accuracy: 99.48%
# on 292: Validation EER:  0.58%
# on 292: Validation f1 Score: 99.43%
# on 292:
# on 292:
# on 293:
#         Train Balanced Accuracy:  98.15%
# on 293: Train EER:  1.85%
# on 293:
#         Validation 293 ,Validation Loss 0.06966 , Validation Balanced Accuracy: 99.48%
# on 293: Validation EER:  0.58%
# on 293: Validation f1 Score: 99.43%
# on 293:
# on 293:
# on 294:
#         Train Balanced Accuracy:  98.15%
# on 294: Train EER:  1.85%
# on 294:
#         Validation 294 ,Validation Loss 0.07028 , Validation Balanced Accuracy: 99.48%
# on 294: Validation EER:  0.58%
# on 294: Validation f1 Score: 99.43%
# on 294: EarlyStopping counter: 1 out of 300
# on 294:
# on 294:
# on 295:
#         Train Balanced Accuracy:  98.16%
# on 295: Train EER:  1.84%
# on 295:
#         Validation 295 ,Validation Loss 0.06932 , Validation Balanced Accuracy: 99.48%
# on 295: Validation EER:  0.58%
# on 295: Validation f1 Score: 99.43%
# on 295:
# on 295:
# on 296:
#         Train Balanced Accuracy:  98.17%
# on 296: Train EER:  1.83%
# on 296:
#         Validation 296 ,Validation Loss 0.07175 , Validation Balanced Accuracy: 99.49%
# on 296: Validation EER:  0.55%
# on 296: Validation f1 Score: 99.46%
# on 296: EarlyStopping counter: 1 out of 300
# on 296:
# on 296:
# on 297:
#         Train Balanced Accuracy:  98.19%
# on 297: Train EER:  1.82%
# on 297:
#         Validation 297 ,Validation Loss 0.06890 , Validation Balanced Accuracy: 99.49%
# on 297: Validation EER:  0.55%
# on 297: Validation f1 Score: 99.46%
# on 297:
# on 297:
# on 298:
#         Train Balanced Accuracy:  98.20%
# on 298: Train EER:  1.81%
# on 298:
#         Validation 298 ,Validation Loss 0.06891 , Validation Balanced Accuracy: 99.49%
# on 298: Validation EER:  0.55%
# on 298: Validation f1 Score: 99.46%
# on 298: EarlyStopping counter: 1 out of 300
# on 298:
# on 298:
# on 299:
#         Train Balanced Accuracy:  98.19%
# on 299: Train EER:  1.82%
# on 299:
#         Validation 299 ,Validation Loss 0.06879 , Validation Balanced Accuracy: 99.49%
# on 299: Validation EER:  0.55%
# on 299: Validation f1 Score: 99.46%
# on 299:
# on 299:
# on 300:
#         Train Balanced Accuracy:  98.21%
# on 300: Train EER:  1.80%
# on 300:
#         Validation 300 ,Validation Loss 0.06833 , Validation Balanced Accuracy: 99.49%
# on 300: Validation EER:  0.55%
# on 300: Validation f1 Score: 99.46%
# on 300:
# on 300:
# |████████████████████████████████████████| 300/300 [100%] in 3:56.9 (0.00/s)

# %%
import pickle
#file_path = 'Male_best_model_9_2.pkl'

# Open the file in binary write mode
#with open(file_path, 'wb') as f:
    # Serialize the object and write it to the file
#    pickle.dump(model, f)

# %%
import matplotlib.pyplot as plt
# Plot training & validation accuracy and eer values
DNN_functions.plot_loss_accuracy(num_epoch,train_losses,validation_losses,train_acc_percentage,validation_acc_percentage,f1_score_validation,validation_total_eer,train_total_err)
# Out:
# c:\Users\avish\OneDrive\Desktop\thesis_research\avishai_work\utils\DNN_functions.py:141: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Inference on The Test Set

# %% [markdown]
# Here, I will conduct inference to assess the outcomes on the test set.
# Additionally, I will evaluate the model's performance on the test set using metrics such as confusion matrix, Equal Error Rate (EER), and balanced accuracy.
# These assessments will involve utilizing thresholds derived from both the validation set and the test set.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import det_curve
import torch.nn.functional as F 

# get the validation probability
with torch.no_grad():
    if training_type == '1_neorun_end_sigmoid':
        validation_prob = torch.sigmoid(model(torch.Tensor(validation_dataset.data)).cpu())
    
valid_total_prob = validation_prob.cpu().numpy().copy() # copy the validation probability

valid_total_labels = validation_dataset.is_spoofed.copy() # copy the validation labels

eer, val_thresh = my_functions.compute_eer(valid_total_labels,valid_total_prob) # compute equal error rate

fpr, fnr, _ = det_curve(valid_total_labels, valid_total_prob) # compute false positive rate and false negative rate

my_functions.DETCurve(fpr = fpr, fnr = fnr, eer_fpr = eer,eer_fnr = eer, model_name = "Split Wave Channels Net - Validation Set",plot_type="step") # plot DET curve

# get the test probability
with torch.no_grad():
    model = model.to(device)
    if training_type == '1_neorun_end_sigmoid':
        test_prob = torch.sigmoid(model(torch.Tensor(test_dataset.data).to(device)).cpu()) # get the test probability

test_total_prob = test_prob.cpu().numpy().copy() # copy the test probability

test_total_labels = test_dataset.is_spoofed.copy() # copy the test labels


prediction = np.array([1 if total_prob_element > val_thresh else 0 for total_prob_element in test_total_prob]) # get the prediction with the validation threshold

valid_thr_prediction_dnn = prediction.copy() # copy the prediction with the validation threshold

# get the confusion matrix with the validation threshold on the test set
cm = sklearn.metrics.confusion_matrix(test_total_labels, valid_thr_prediction_dnn) 
cm = np.round(cm,2)

# print confusion matrix with the validation threshold on the test set
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                display_labels=["genuine human","spoof"])
disp.plot()
plt.title('Confusion Matrix - Split Wave Channels Net on the Test Set with Validation Threshold')
plt.show()

# Calculate the balanced accuracy for the test set with the validation threshold
balanced_acc= sklearn.metrics.balanced_accuracy_score(test_total_labels,valid_thr_prediction_dnn) # balanced accuracy per batch

# Calculate the f1 score for the test set with the validation threshold
f1_score =sklearn.metrics.f1_score(test_total_labels, valid_thr_prediction_dnn, average='micro') # f1 score  

print(f"\tTest Balanced Accuracy: ({balanced_acc:.5f}%) \tF1 Score: {f1_score:.5f}")
print("The validation threshold is: ",val_thresh)
# Out:
# 	Test Balanced Accuracy: (0.87165%) 	F1 Score: 0.77729
# The validation threshold is:  0.1934174167726178

# %%
import seaborn as sns
import matplotlib.pyplot as plt

bonafide_scores = valid_total_prob[validation_dataset.is_spoofed == 0].flatten()
spoof_scores = valid_total_prob[validation_dataset.is_spoofed == 1].flatten()

num_bins = 100

plt.figure()
sns.histplot([spoof_scores, bonafide_scores], kde=True, stat='probability', bins=num_bins, palette=['blue', 'orange'], linewidth=1)# Add labels and title
plt.legend(['bonafide','spoof'])
plt.xlabel('scores')
plt.ylabel('probability')
plt.title(f"Probability over bonafide and spoof samples vs Scores on Male  validation dataset")
# Add legend
# Show the plot
plt.show()

plt.figure()
sns.histplot([spoof_scores, bonafide_scores], kde=True, stat='probability', bins=num_bins, palette=['blue', 'orange'], linewidth=1)# Add labels and title
plt.legend(['bonafide','spoof'])
plt.xlim(0,0.1)
plt.xlabel('scores')
plt.ylabel('probability')
plt.title(f"Probability over bonafide and spoof samples vs Scores on Male validation dataset - zoom in [0,0.1]")
# Add legend
# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

bonafide_scores = valid_total_prob[validation_dataset.is_spoofed == 0].flatten()
spoof_scores = valid_total_prob[validation_dataset.is_spoofed == 1].flatten()

num_bins = 100

plt.figure()
sns.histplot(bonafide_scores, kde=True, stat='probability', bins=num_bins, color='green', linewidth=1)# Add labels and title
sns.histplot(spoof_scores, kde=True, stat='probability', bins=num_bins, color='red', linewidth=1)# Add labels and title
plt.legend(['bonafide','spoof'])
plt.xlabel('scores')
plt.ylabel('probability')
plt.title(f"Probability of bonafide samples and Probability of spoof samples vs Scores on Male validation dataset")
# Add legend
# Show the plot
plt.show()

plt.figure()
sns.histplot(bonafide_scores, kde=True, stat='probability', bins=num_bins, color='green', linewidth=1)# Add labels and title
sns.histplot(spoof_scores, kde=True, stat='probability', bins=num_bins, color='red', linewidth=1)# Add labels and title
plt.legend(['bonafide','spoof'])
plt.xlim(0,0.1)
plt.xlabel('scores')
plt.ylabel('probability')
plt.title(f"Probability of bonafide samples and Probability of spoof samples vs Scores on Male validation dataset - zoom in [0,0.1]")
# Add legend
# Show the plot
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import det_curve
import torch.nn.functional as F 
# Calculate the inference on the test set with the test threshold

with torch.no_grad():
    model = model.to(device)
    if training_type == '1_neorun_end_sigmoid': 
        test_prob = torch.sigmoid(model(torch.Tensor(test_dataset.data).to(device)).cpu()) # get the test probability
    
test_total_labels = torch.Tensor(test_dataset.is_spoofed.iloc[:]).cpu().numpy().copy() # copy the test labels

test_total_prob_dnn = test_prob.cpu().numpy().copy() # copy the test probability

eer, test_thresh = my_functions.compute_eer(test_total_labels,test_total_prob_dnn) # compute equal error rate

fpr, fnr, _ = det_curve(test_total_labels, test_total_prob_dnn) # compute false positive rate and false negative rate

my_functions.DETCurve(fpr = fpr, fnr = fnr, eer_fpr = eer,eer_fnr = eer, model_name = "Split Wave Channels Net - Test Set",plot_type="step") # plot DET curve
    
prediction = np.array([1 if total_prob_element > test_thresh else 0 for total_prob_element in test_total_prob_dnn]) # prediction with the test threshold

test_thr_prediction_dnn = prediction.copy() # copy the prediction with the test threshold

cm = sklearn.metrics.confusion_matrix(test_total_labels, test_thr_prediction_dnn) # confusion matrix
cm = np.round(cm,2)

disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                display_labels=["genuine human","spoof"])
disp.plot()
plt.title('Confusion Matrix - Split Wave Channels Net on the Test Set with Test Threshold')
plt.show()

#Calculate the balanced accuracy for the test set with the test threshold
balanced_acc= sklearn.metrics.balanced_accuracy_score(test_total_labels,test_thr_prediction_dnn) # balanced accuracy per batch

# Calculate the f1 score for the test set with the test threshold
f1_score =sklearn.metrics.f1_score(test_total_labels, test_thr_prediction_dnn, average='micro') # f1 score  
   
print(f"\tTest Balanced Accuracy: ({balanced_acc:.5f}%) \tF1 Score: {f1_score:.5f}")
print("The test threshold is: ",test_thresh)
# Out:
# 	Test Balanced Accuracy: (0.91338%) 	F1 Score: 0.91312
# The test threshold is:  0.04048307612539639

# %%
import seaborn as sns
import matplotlib.pyplot as plt


bonafide_scores = test_prob[test_dataset.is_spoofed == 0].flatten()
spoof_scores = test_prob[test_dataset.is_spoofed == 1].flatten()

bonafide_scores = bonafide_scores.cpu().numpy()
spoof_scores = spoof_scores.cpu().numpy()

num_bins = 100

plt.figure()
sns.histplot([spoof_scores, bonafide_scores], kde=True, stat='probability', bins=num_bins, palette=['blue', 'orange'], linewidth=1)# Add labels and title
plt.legend(['bonafide','spoof'])
plt.xlabel('scores')
plt.ylabel('probability')
plt.title(f"Probability over bonafide and spoof samples vs Scores on Male  test dataset")
# Add legend
# Show the plot
plt.show()

plt.figure()
sns.histplot([spoof_scores, bonafide_scores], kde=True, stat='probability', bins=num_bins, palette=['blue', 'orange'], linewidth=1)# Add labels and title
plt.legend(['bonafide','spoof'])
plt.xlim(0,0.1)
plt.xlabel('scores')
plt.ylabel('probability')
plt.title(f"Probability over bonafide and spoof samples vs Scores on Male test dataset - zoom in [0,0.1]")
# Add legend
# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

bonafide_scores = test_prob[test_dataset.is_spoofed == 0].flatten()
spoof_scores = test_prob[test_dataset.is_spoofed == 1].flatten()

bonafide_scores = bonafide_scores.cpu().numpy()
spoof_scores = spoof_scores.cpu().numpy()


num_bins = 100

plt.figure()
sns.histplot(bonafide_scores, kde=True, stat='probability', bins=num_bins, color='green', linewidth=1)# Add labels and title
sns.histplot(spoof_scores, kde=True, stat='probability', bins=num_bins, color='red', linewidth=1)# Add labels and title
plt.legend(['bonafide','spoof'])
plt.xlabel('scores')
plt.ylabel('probability')
plt.title(f"Probability of bonafide samples and Probability of spoof samples vs Scores on Male test dataset")
# Add legend
# Show the plot
plt.show()

plt.figure()
sns.histplot(bonafide_scores, kde=True, stat='probability', bins=num_bins, color='green', linewidth=1)# Add labels and title
sns.histplot(spoof_scores, kde=True, stat='probability', bins=num_bins, color='red', linewidth=1)# Add labels and title
plt.legend(['bonafide','spoof'])
plt.xlim(0,0.1)
plt.xlabel('scores')
plt.ylabel('probability')
plt.title(f"Probability of bonafide samples and Probability of spoof samples vs Scores on Male test dataset - zoom in [0,0.1]")
# Add legend
# Show the plot
plt.show()

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report,accuracy_score
from sklearn.metrics import balanced_accuracy_score


pred_proba_list = [test_total_prob_dnn] # list of the test probability
y_pred = [test_thr_prediction_dnn] # list of the test prediction

test_total_labels = [test_dataset.is_spoofed.iloc[:].astype('uint8')] # list of the test labels

eer_list = []
acc_list = []
balanced_acc_list = []
auc_list = []
f1_list = [] 
# calculate the metrics for the test set with the test threshold
for i in range(0,len(pred_proba_list)): #
     eer , _ = my_functions.compute_eer(test_total_labels[i],pred_proba_list[i])
     eer_list.append(eer)
     acc_list.append(accuracy_score(test_total_labels[i], y_pred[i]))
     balanced_acc_list.append(balanced_accuracy_score(test_total_labels[i], y_pred[i]))
     auc_list.append(roc_auc_score(test_total_labels[i],pred_proba_list[i]))
     f1_list.append(sklearn.metrics.f1_score(test_total_labels[i], y_pred[i]))
  
     
y_pred_with_valid_thr = [valid_thr_prediction_dnn] 

validation_pos_pred_proba_list = [valid_total_prob]    

valid_total_labels = [validation_dataset.is_spoofed.iloc[:].astype('uint8')]


eer_list_on_validaion = []
acc_list_with_valid_thr = []
balanced_acc_list_with_valid_thr = []
f1_list_with_valid_thr = []
# calculate the metrics for the test set with the validation threshold
for i in range(0,len(validation_pos_pred_proba_list)): 
     acc_list_with_valid_thr.append(accuracy_score(test_total_labels[i], y_pred_with_valid_thr[i]))
     balanced_acc_list_with_valid_thr.append(balanced_accuracy_score(test_total_labels[i], y_pred_with_valid_thr[i]))
     f1_list_with_valid_thr.append(sklearn.metrics.f1_score(test_total_labels[i], y_pred_with_valid_thr[i]))
     eer_val , _ = my_functions.compute_eer(valid_total_labels[i],validation_pos_pred_proba_list[i])
     eer_list_on_validaion.append(eer_val)

# %%
# define the names of the classifiers
names = ['Split Wave Channels Net']
metric_names = ['EER','Accuracy','Balanced Accuracy','F1','AUC']

#plot hisgogram of the results: EER, Accuracy, Balanced Accuracy, AUC
metrics_list = [eer_list,acc_list,balanced_acc_list,f1_list,auc_list] # list of the test metrics
validaion_metrics_list = [eer_list_on_validaion,acc_list_with_valid_thr,balanced_acc_list_with_valid_thr,f1_list_with_valid_thr] # list of the validation metrics

# define the diff for the bar names
diff_for_bar = 0.0001
X_axis = np.arange(len(names))

#Plot the results   
for i in range(0,len(validaion_metrics_list)):
    plt.figure(figsize=(12,12))
    plt.bar(X_axis+0.2, metrics_list[i],width=0.4,label = 'metric & threshold - Test')
    plt.bar(X_axis-0.2, validaion_metrics_list[i],width=0.4,label = 'metric & threshold - validation',color='orange')
    plt.ylabel(metric_names[i])
    plt.xlabel('Classifier')
    plt.title(f"{metric_names[i]} of the classifiers on Male Speakers")
    plt.legend(loc = 'lower left')
    plt.xticks(X_axis, names)
    for j, v in enumerate(metrics_list[i]):
        plt.text(j+0.2, v+diff_for_bar, '{:.3f}%'.format(v*100), ha='center')
    for j, v in enumerate(validaion_metrics_list[i]):
        plt.text(j-0.2, v+diff_for_bar, '{:.3f}%'.format(v*100), ha='center')
    plt.show()
    
plt.figure(figsize=(12,12))

i = len(validaion_metrics_list)   

#plot hisgogram of the results: AUC
plt.figure(figsize=(12,12))
plt.bar(X_axis, metrics_list[i],width=0.4,label = 'metric & threshold - Test')
plt.ylabel(metric_names[i])
plt.xlabel('Classifier')
plt.title(f"{metric_names[i]} of the DNN classifiers on Male Speakers")
plt.legend(loc = 'lower left')
plt.xticks(X_axis, names)
for j, v in enumerate(metrics_list[i]):
        plt.text(j, v+diff_for_bar, '{:.3f}%'.format(v*100), ha='center')   
plt.show()

# %%
'''
import pickle

filename = 'male_model_8.83.pkl'
pickle.dump(model, open(filename, 'wb'))
torch.save(model.state_dict(), 'male_model_8.83.pth')
'''
# Out:
# "\nimport pickle\n\nfilename = 'male_model_8.83.pkl'\npickle.dump(model, open(filename, 'wb'))\ntorch.save(model.state_dict(), 'male_model_8.83.pth')\n"
