# %%
import sys
sys.path.append('../')
import scipy.io as sio
import mat73
import pandas as pd
import torch
import numpy as np
import torch.optim as optim
import torch.nn
import sklearn
import sklearn.metrics
import matplotlib.pyplot as plt
from alive_progress import alive_bar
from  utils.my_classes import dataset 
from torch.utils.data import DataLoader
import utils.DNN_functions as DNN_functions
import scipy
import random
import utils.AMSloss
from speechbrain.pretrained import SpeakerRecognition
import pickle
import os
from utils.my_classes import dataset
import utils.eval_metrics as eval_metrics
import copy
from speechbrain.pretrained import SpeakerRecognition

seed = 42  # You can choose any integer value as the seed
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
# Set seed for Python's random module
random.seed(seed)
# Set seed for NumPy
np.random.seed(seed)
# Set seed for PyTorch (CPU and GPU, if available)
if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
# Set deterministic flags for PyTorch (if available)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Out:
# The torchaudio backend is switched to 'soundfile'. Note that 'sox_io' is not supported on Windows.
# The torchaudio backend is switched to 'soundfile'. Note that 'sox_io' is not supported on Windows.

# %%
#To get my GPU device - GTX 4070 :)
seed = 42  # You can choose any integer value as the seed
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu');

if torch.cuda.is_available():
    print(torch.cuda.device_count())
    print(torch.cuda.device(0))
    print(torch.cuda.get_device_name(0))
    print(device)
# Out:
# 1
# <torch.cuda.device object at 0x0000021DC2684820>
# NVIDIA GeForce RTX 4070
# cuda

# %% [markdown]
# # loading the embedding for CM System:

# %%
from ASV_utils.data_loading import *



models_folder = "ECAPA_TDNN/inference_models/models_both_not_normalize/"

data_path_male = "Data/pmf_both/not_normalize/male/"

data_path_female = "Data/pmf_both/not_normalize/female/"

male_embedded_groups_1_1,male_embedded_groups_1_2,male_embedded_groups_1_3,male_chosen_labels_1_1_is_spoofed,male_chosen_labels_2_1_is_spoofed,male_chosen_labels_3_1_is_spoofed,male_chosen_labels_numeric_1_1,male_chosen_labels_numeric_2_1,male_chosen_labels_numeric_3_1,male_chosen_labels_1_1_attack_logical,male_chosen_labels_2_1_attack_logical,male_chosen_labels_3_1_attack_logical,male_chosen_labels_1_1_name,male_chosen_labels_2_1_name,male_chosen_labels_3_1_name,male_chosen_labels_1_1_speaker_id,male_chosen_labels_2_1_speaker_id,male_chosen_labels_3_1_speaker_id,male_chosen_labels_1_1_sex,male_chosen_labels_2_1_sex,male_chosen_labels_3_1_sex  = load_data_male(data_path_male)

female_embedded_groups_1_1,female_embedded_groups_1_2,female_embedded_groups_1_3,female_chosen_labels_1_1_is_spoofed,female_chosen_labels_2_1_is_spoofed,female_chosen_labels_3_1_is_spoofed,female_chosen_labels_numeric_1_1,female_chosen_labels_numeric_2_1,female_chosen_labels_numeric_3_1,female_chosen_labels_1_1_attack_logical,female_chosen_labels_2_1_attack_logical,female_chosen_labels_3_1_attack_logical,female_chosen_labels_1_1_name,female_chosen_labels_2_1_name,female_chosen_labels_3_1_name,female_chosen_labels_1_1_speaker_id,female_chosen_labels_2_1_speaker_id,female_chosen_labels_3_1_speaker_id,female_chosen_labels_1_1_sex,female_chosen_labels_2_1_sex,female_chosen_labels_3_1_sex  = load_data_female(data_path_female)

# %% [markdown]
# # Pre Processing the channels And loading the Models - Male & Female:

# %%
import utils.my_functions as my_functions

columns_names,max_name_length = my_functions.get_columns_names_feature_importance(substruct=True)
true_channels_indexes = np.array(my_functions.get_real_channel(np.linspace(start=1, stop=len(columns_names), num=len(columns_names)),len(columns_names)))
true_channels_indexes = true_channels_indexes - 1
true_channels_indexes = true_channels_indexes.astype(int)
columns_names = np.array(columns_names)

female_embedded_groups_1_1 = female_embedded_groups_1_1[:,true_channels_indexes]
female_embedded_groups_1_2 = female_embedded_groups_1_2[:,true_channels_indexes]
female_embedded_groups_1_3 = female_embedded_groups_1_3[:,true_channels_indexes]

male_embedded_groups_1_1 = male_embedded_groups_1_1[:,true_channels_indexes]
male_embedded_groups_1_2 = male_embedded_groups_1_2[:,true_channels_indexes]
male_embedded_groups_1_3 = male_embedded_groups_1_3[:,true_channels_indexes]

# %%
from sklearn.preprocessing import StandardScaler
import re

your_list = columns_names[true_channels_indexes]
index_mapping ={}

# Define the custom sorting order for distance metrics
distance_metrics = [
    'Chi-square',
    'Correlation',
    'Hellinger',
    'Intersection',
    'Jensen-Shannon',
    'Kullback-Leibler Divergence',
    'Modified Kolmogorov-Smirnov',
    'Symmetrised Kullback-Leibler'
]

def custom_sort_key(item):
    # Use regex to extract gammatone, gammatone_inv, channel number, and distance metric
    match = re.search(r'filter-(gammatone(?:_inv)?)-channel-(\d+)-distance-(.+?)-\[d_', item)
    if match:
        gammatone = match.group(1)
        channel = int(match.group(2))
        distance_metric = match.group(3)

        # Assign a higher priority to distance_order, a medium priority to channels,
        # and lower priority to 'gammatone' and 'gammatone_inv'
        return (distance_metrics.index(distance_metric), channel, gammatone)

    else:
        # If the regex doesn't match, return the original item to maintain its position
        return (999, 999, "")

# Sort the list based on the custom order
sorted_list = sorted(your_list, key=custom_sort_key)

for new_index, item in enumerate(sorted_list):
    old_index = np.where(columns_names[true_channels_indexes] == item)[0][0]
    index_mapping[old_index] = new_index
    
male_embedded_groups_1_1 = male_embedded_groups_1_1[:,list(index_mapping.keys())]
male_embedded_groups_1_2 = male_embedded_groups_1_2[:,list(index_mapping.keys())]
male_embedded_groups_1_3 = male_embedded_groups_1_3[:,list(index_mapping.keys())]

female_embedded_groups_1_1 = female_embedded_groups_1_1[:,list(index_mapping.keys())]
female_embedded_groups_1_2 = female_embedded_groups_1_2[:,list(index_mapping.keys())]
female_embedded_groups_1_3 = female_embedded_groups_1_3[:,list(index_mapping.keys())]

# %%
# define the subchannel model network
import torch
import torch.nn as nn
from utils.AMSloss import AdMSoftmaxLoss
import pickle
# define the subchannel model network
import torch.nn as nn
class SubChannelNetwork(nn.Module):
    def __init__(self, input_channel_size, output_channel_size):
        super(SubChannelNetwork, self).__init__()
        self.input_layer = nn.Linear(input_channel_size, output_channel_size)
        self.sigmoid = nn.Sigmoid()
        self.dropout = nn.Dropout(p=0.2)
        self.BN_4 = nn.BatchNorm1d(output_channel_size) 

        
    def forward(self, x):
        x = self.input_layer(x)
        x = self.BN_4(x) 
        x = self.sigmoid(x)
        x = self.dropout(x)
        return x

# define the model network
class DNN(nn.Module):
    def __init__(self, input_channel_size, num_subnetworks, output_channel_size, final_output_size):
        super(DNN, self).__init__()
        self.SubChannelNetwork = nn.ModuleList([
            SubChannelNetwork(input_channel_size, output_channel_size) for _ in range(num_subnetworks)
        ])
        self.fc_between_subnet = nn.Linear(num_subnetworks * output_channel_size,40)
        self.BN = nn.BatchNorm1d(40)
        self.fc = nn.Linear(40, final_output_size)
        self.sigmoid = nn.Sigmoid()
        self.droupout = nn.Dropout(p=0.2)
        self.loss = nn.BCEWithLogitsLoss()
        self.optimizer = None
        self.scheduler = None
        
        
    def forward(self, x):
        subnetwork_outputs = [self.SubChannelNetwork[idx](x[:, idx*input_channel_size:(idx+1)*input_channel_size].to(device)) for idx in range(len(self.SubChannelNetwork))]
        combined_output = torch.cat(subnetwork_outputs, dim=1)
        x = self.fc_between_subnet(combined_output)    
        x = self.BN(x)
        x = self.sigmoid(x)
        x = self.droupout(x)
        output = self.fc(x)
        return output 
    
    @staticmethod
    def count_parameters(model):
        return sum(p.numel() for p in model.parameters() if p.requires_grad)



# Just for checking the model and see the number of parameters
num_SubChannelNetwork = 16
input_channel_size = 10
output_channel_size = 5
final_output_size = 1
model = []
model = DNN(input_channel_size, num_SubChannelNetwork, output_channel_size, final_output_size)
model = model.to(device)
print(model)
n = DNN.count_parameters(model)
print("Number of parameters: %s" % n)
model = model.to(device) # send the model to the device

model = pickle.load(open(models_folder + "CM_both_male_9_2.pkl", 'rb'))

model.eval()

spoof_model_male = copy.deepcopy(model)
# Out:
# DNN(
#   (SubChannelNetwork): ModuleList(
#     (0-15): 16 x SubChannelNetwork(
#       (input_layer): Linear(in_features=10, out_features=5, bias=True)
#       (sigmoid): Sigmoid()
#       (dropout): Dropout(p=0.2, inplace=False)
#       (BN_4): BatchNorm1d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (fc_between_subnet): Linear(in_features=80, out_features=40, bias=True)
#   (BN): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc): Linear(in_features=40, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
#   (droupout): Dropout(p=0.2, inplace=False)
#   (loss): BCEWithLogitsLoss()
# )
# Number of parameters: 4401

# %%
import torch
import torch.nn as nn
from utils.AMSloss import AdMSoftmaxLoss
from utils.OCSoftmaxloss import OCSoftmax
import torch.nn as nn

class SubChannelNetwork(nn.Module):
    def __init__(self, input_channel_size, output_channel_size):
        super(SubChannelNetwork, self).__init__()
        self.input_layer = nn.Linear(input_channel_size, output_channel_size)
        self.sigmoid = nn.Sigmoid()
        self.dropout = nn.Dropout(p=0.2)
        self.BN_4 = nn.BatchNorm1d(output_channel_size) 
   
    def forward(self, x):
        res = x
        x = self.input_layer(x)
        x = self.BN_4(x) 
        x = self.sigmoid(x)
        x = self.dropout(x)
        x = res + x 
        return x

class DNN(nn.Module):
    def __init__(self, input_channel_size, num_subnetworks, output_channel_size, final_output_size, r_real , r_fake,alpha):
        super(DNN, self).__init__()
        self.SubChannelNetwork = nn.ModuleList([
            SubChannelNetwork(input_channel_size, output_channel_size) for _ in range(num_subnetworks)
        ])
        self.fc_between_subnet = nn.Linear(num_subnetworks * output_channel_size,40)
        self.BN = nn.BatchNorm1d(40)
        self.fc = nn.Linear(40, final_output_size)
        self.sigmoid = nn.Sigmoid()
        self.droupout = nn.Dropout(p=0.2)
        self.r_real = r_real
        self.r_fake = r_fake
        self.alpha = alpha
        self.loss = OCSoftmax(feat_dim = final_output_size, r_real = self.r_real, r_fake = self.r_fake, alpha = self.alpha)
        self.optimizer = None
        self.scheduler = None
        
        
    def forward(self, x):
        subnetwork_outputs = [self.SubChannelNetwork[idx](x[:, idx*input_channel_size:(idx+1)*input_channel_size].to(device)) for idx in range(len(self.SubChannelNetwork))]
        combined_output = torch.cat(subnetwork_outputs, dim=1)
        x = self.fc_between_subnet(combined_output)    
        x = self.BN(x)
        x = self.sigmoid(x)
        x = self.droupout(x)
        output = self.fc(x)
        return output 
    
    @staticmethod
    def count_parameters(model):
        return sum(p.numel() for p in model.parameters() if p.requires_grad)

r_real = 0.5 
r_fake = 0.1
alpha = 20
# Example usage
num_SubChannelNetwork = 16
input_channel_size = 10
output_channel_size = 10
final_output_size = 16*3
model = DNN(input_channel_size, num_SubChannelNetwork, output_channel_size, final_output_size,r_real = r_real , r_fake = r_fake,alpha = alpha)


model = model.to(device) # send the model to the device

model = pickle.load(open(models_folder + "CM_both_female_10_17.pkl", 'rb'))

model.eval()

spoof_model_female = copy.deepcopy(model)

# %%
scaler_male = StandardScaler(with_mean = True, with_std = True)
scaler_male.fit(male_embedded_groups_1_1)
mean_features = scaler_male.mean_
std_features = scaler_male.scale_
male_embedded_groups_1_1_norm = scaler_male.transform(male_embedded_groups_1_1)
male_embedded_groups_1_2_norm = scaler_male.transform(male_embedded_groups_1_2)
male_embedded_groups_1_3_norm = scaler_male.transform(male_embedded_groups_1_3)


scaler_female = StandardScaler(with_mean = True, with_std = True)
scaler_female.fit(female_embedded_groups_1_1)
mean_features = scaler_female.mean_
std_features = scaler_female.scale_
female_embedded_groups_1_1_norm = scaler_female.transform(female_embedded_groups_1_1)
female_embedded_groups_1_2_norm = scaler_female.transform(female_embedded_groups_1_2)
female_embedded_groups_1_3_norm = scaler_female.transform(female_embedded_groups_1_3)

# %%
embedded_groups_1_1_norm,embedded_groups_1_2_norm,embedded_groups_1_3_norm,chosen_labels_1_1_is_spoofed,chosen_labels_2_1_is_spoofed,chosen_labels_3_1_is_spoofed,chosen_labels_numeric_1_1,chosen_labels_numeric_2_1,chosen_labels_numeric_3_1,chosen_labels_1_1_attack_logical,chosen_labels_2_1_attack_logical,chosen_labels_3_1_attack_logical,chosen_labels_1_1_name,chosen_labels_2_1_name,chosen_labels_3_1_name,chosen_labels_1_1_speaker_id,chosen_labels_2_1_speaker_id,chosen_labels_3_1_speaker_id,chosen_labels_1_1_sex,chosen_labels_2_1_sex,chosen_labels_3_1_sex    =  concatenate_data(male_embedded_groups_1_1_norm,male_embedded_groups_1_2_norm,male_embedded_groups_1_3_norm,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    male_chosen_labels_1_1_is_spoofed,male_chosen_labels_2_1_is_spoofed,male_chosen_labels_3_1_is_spoofed,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    male_chosen_labels_numeric_1_1,male_chosen_labels_numeric_2_1,male_chosen_labels_numeric_3_1,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    male_chosen_labels_1_1_attack_logical,male_chosen_labels_2_1_attack_logical,male_chosen_labels_3_1_attack_logical,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    male_chosen_labels_1_1_name,male_chosen_labels_2_1_name,male_chosen_labels_3_1_name,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    male_chosen_labels_1_1_speaker_id,male_chosen_labels_2_1_speaker_id, male_chosen_labels_3_1_speaker_id,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    male_chosen_labels_1_1_sex,male_chosen_labels_2_1_sex,male_chosen_labels_3_1_sex,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    female_embedded_groups_1_1_norm,female_embedded_groups_1_2_norm,female_embedded_groups_1_3_norm,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    female_chosen_labels_1_1_is_spoofed,female_chosen_labels_2_1_is_spoofed,female_chosen_labels_3_1_is_spoofed,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    female_chosen_labels_numeric_1_1,female_chosen_labels_numeric_2_1,female_chosen_labels_numeric_3_1,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    female_chosen_labels_1_1_attack_logical,female_chosen_labels_2_1_attack_logical,female_chosen_labels_3_1_attack_logical,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    female_chosen_labels_1_1_name,female_chosen_labels_2_1_name,female_chosen_labels_3_1_name,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    female_chosen_labels_1_1_speaker_id,female_chosen_labels_2_1_speaker_id,female_chosen_labels_3_1_speaker_id,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    female_chosen_labels_1_1_sex,female_chosen_labels_2_1_sex,female_chosen_labels_3_1_sex)

# %%
embedded_groups_1_1,embedded_groups_1_2,embedded_groups_1_3,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_    =  concatenate_data(male_embedded_groups_1_1,male_embedded_groups_1_2,male_embedded_groups_1_3,
                                                                                                                        male_chosen_labels_1_1_is_spoofed,male_chosen_labels_2_1_is_spoofed,male_chosen_labels_3_1_is_spoofed,
                                                                                                                        male_chosen_labels_numeric_1_1,male_chosen_labels_numeric_2_1,male_chosen_labels_numeric_3_1,
                                                                                                                        male_chosen_labels_1_1_attack_logical,male_chosen_labels_2_1_attack_logical,male_chosen_labels_3_1_attack_logical,
                                                                                                                        male_chosen_labels_1_1_name,male_chosen_labels_2_1_name,male_chosen_labels_3_1_name,
                                                                                                                        male_chosen_labels_1_1_speaker_id,male_chosen_labels_2_1_speaker_id, male_chosen_labels_3_1_speaker_id,
                                                                                                                        male_chosen_labels_1_1_sex,male_chosen_labels_2_1_sex,male_chosen_labels_3_1_sex,
                                                                                                                        
                                                                                                                        female_embedded_groups_1_1,female_embedded_groups_1_2,female_embedded_groups_1_3,
                                                                                                                        female_chosen_labels_1_1_is_spoofed,female_chosen_labels_2_1_is_spoofed,female_chosen_labels_3_1_is_spoofed,
                                                                                                                        female_chosen_labels_numeric_1_1,female_chosen_labels_numeric_2_1,female_chosen_labels_numeric_3_1,
                                                                                                                        female_chosen_labels_1_1_attack_logical,female_chosen_labels_2_1_attack_logical,female_chosen_labels_3_1_attack_logical,
                                                                                                                        female_chosen_labels_1_1_name,female_chosen_labels_2_1_name,female_chosen_labels_3_1_name,
                                                                                                                        female_chosen_labels_1_1_speaker_id,female_chosen_labels_2_1_speaker_id,female_chosen_labels_3_1_speaker_id,
                                                                                                                        female_chosen_labels_1_1_sex,female_chosen_labels_2_1_sex,female_chosen_labels_3_1_sex)
scaler_all = StandardScaler(with_mean = True, with_std = True)
scaler_all.fit(embedded_groups_1_1)
mean_features = scaler_female.mean_
std_features = scaler_female.scale_
embedded_groups_1_1_all = scaler_all.transform(embedded_groups_1_1)
embedded_groups_1_2_all = scaler_all.transform(embedded_groups_1_2)
embedded_groups_1_3_all = scaler_all.transform(embedded_groups_1_3)

# %%
train_dataset_all = dataset(data = embedded_groups_1_1_norm , is_spoofed = chosen_labels_1_1_is_spoofed , chosen_labels_numeric = chosen_labels_numeric_1_1,
                        attack_logical = chosen_labels_1_1_attack_logical, name = chosen_labels_1_1_name , speaker_id = chosen_labels_1_1_speaker_id, sex = chosen_labels_1_1_sex ,data_transform = None , labels_transform = None,
                        data_for_gender_classification = None,data_without_separation = embedded_groups_1_1_all);

Dev_dataset_all = dataset(data = embedded_groups_1_2_norm , is_spoofed = chosen_labels_2_1_is_spoofed , chosen_labels_numeric = chosen_labels_numeric_2_1,
                        attack_logical = chosen_labels_2_1_attack_logical, name = chosen_labels_2_1_name , speaker_id = chosen_labels_2_1_speaker_id, sex = chosen_labels_2_1_sex ,  data_transform = None , labels_transform = None,
                        data_for_gender_classification = None,data_without_separation = embedded_groups_1_2_all);


Eval_dataset_all = dataset(data = embedded_groups_1_3_norm , is_spoofed = chosen_labels_3_1_is_spoofed , chosen_labels_numeric = chosen_labels_numeric_3_1,
                        attack_logical = chosen_labels_3_1_attack_logical, name = chosen_labels_3_1_name , speaker_id = chosen_labels_3_1_speaker_id, sex = chosen_labels_3_1_sex , data_transform = None , labels_transform = None,
                        data_for_gender_classification = None,data_without_separation = embedded_groups_1_3_all);

# %%
from ASV_utils.data_loading import *


models_folder = "ECAPA_TDNN/inference_models/models_both_not_normalize/"

data_path_male = "Data/male_vs_female_models_16_bits_ver5/male"

data_path_female = "Data/male_vs_female_models_16_bits_ver5/female"

g_male_embedded_groups_1_1,g_male_embedded_groups_1_2,g_male_embedded_groups_1_3,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_  = load_data_male(data_path_male)

g_female_embedded_groups_1_1,g_female_embedded_groups_1_2,g_female_embedded_groups_1_3,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_  = load_data_female(data_path_female)

embedded_groups_1_1,embedded_groups_1_2,embedded_groups_1_3,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_    =  concatenate_data(g_male_embedded_groups_1_1,g_male_embedded_groups_1_2,g_male_embedded_groups_1_3,
                                                                                                                    male_chosen_labels_1_1_is_spoofed,male_chosen_labels_2_1_is_spoofed,male_chosen_labels_3_1_is_spoofed,
                                                                                                                    male_chosen_labels_numeric_1_1,male_chosen_labels_numeric_2_1,male_chosen_labels_numeric_3_1,
                                                                                                                    male_chosen_labels_1_1_attack_logical,male_chosen_labels_2_1_attack_logical,male_chosen_labels_3_1_attack_logical,
                                                                                                                    male_chosen_labels_1_1_name,male_chosen_labels_2_1_name,male_chosen_labels_3_1_name,
                                                                                                                    male_chosen_labels_1_1_speaker_id,male_chosen_labels_2_1_speaker_id, male_chosen_labels_3_1_speaker_id,
                                                                                                                    male_chosen_labels_1_1_sex,male_chosen_labels_2_1_sex,male_chosen_labels_3_1_sex,
                                                                                                                    
                                                                                                                    g_female_embedded_groups_1_1,g_female_embedded_groups_1_2,g_female_embedded_groups_1_3,
                                                                                                                    female_chosen_labels_1_1_is_spoofed,female_chosen_labels_2_1_is_spoofed,female_chosen_labels_3_1_is_spoofed,
                                                                                                                    female_chosen_labels_numeric_1_1,female_chosen_labels_numeric_2_1,female_chosen_labels_numeric_3_1,
                                                                                                                    female_chosen_labels_1_1_attack_logical,female_chosen_labels_2_1_attack_logical,female_chosen_labels_3_1_attack_logical,
                                                                                                                    female_chosen_labels_1_1_name,female_chosen_labels_2_1_name,female_chosen_labels_3_1_name,
                                                                                                                    female_chosen_labels_1_1_speaker_id,female_chosen_labels_2_1_speaker_id,female_chosen_labels_3_1_speaker_id,
                                                                                                                    female_chosen_labels_1_1_sex,female_chosen_labels_2_1_sex,female_chosen_labels_3_1_sex)
chosen_labels_1_1_sex = np.array([elem[0] for elem in chosen_labels_1_1_sex])
                                 
chosen_labels_2_1_sex = np.array([elem[0] for elem in chosen_labels_2_1_sex])

chosen_labels_3_1_sex = np.array([elem[0] for elem in chosen_labels_3_1_sex])

# %%
import utils.my_functions as my_functions

columns_names,max_name_length = my_functions.get_columns_names_feature_importance(substruct=True)
true_channels_indexes = np.array(my_functions.get_real_channel(np.linspace(start=1, stop=len(columns_names), num=len(columns_names)),len(columns_names)))
true_channels_indexes = true_channels_indexes - 1
true_channels_indexes = true_channels_indexes.astype(int)
columns_names = np.array(columns_names)
'''
g_female_embedded_groups_1_1 = g_female_embedded_groups_1_1[:,true_channels_indexes]
g_female_embedded_groups_1_2 = g_female_embedded_groups_1_2[:,true_channels_indexes]
g_female_embedded_groups_1_3 = g_female_embedded_groups_1_3[:,true_channels_indexes]

g_male_embedded_groups_1_1 = g_male_embedded_groups_1_1[:,true_channels_indexes]
g_male_embedded_groups_1_2 = g_male_embedded_groups_1_2[:,true_channels_indexes]
g_male_embedded_groups_1_3 = g_male_embedded_groups_1_3[:,true_channels_indexes]
'''

embedded_groups_1_1 = embedded_groups_1_1[:,true_channels_indexes]
embedded_groups_1_2 = embedded_groups_1_2[:,true_channels_indexes]
embedded_groups_1_3 = embedded_groups_1_3[:,true_channels_indexes]

from sklearn.preprocessing import StandardScaler
import re

your_list = columns_names[true_channels_indexes]
index_mapping ={}

# Define the custom sorting order for distance metrics
distance_metrics = [
    'Chi-square',
    'Correlation',
    'Hellinger',
    'Intersection',
    'Jensen-Shannon',
    'Kullback-Leibler Divergence',
    'Modified Kolmogorov-Smirnov',
    'Symmetrised Kullback-Leibler'
]

def custom_sort_key(item):
    # Use regex to extract gammatone, gammatone_inv, channel number, and distance metric
    match = re.search(r'filter-(gammatone(?:_inv)?)-channel-(\d+)-distance-(.+?)-\[d_', item)
    if match:
        gammatone = match.group(1)
        channel = int(match.group(2))
        distance_metric = match.group(3)

        # Assign a higher priority to distance_order, a medium priority to channels,
        # and lower priority to 'gammatone' and 'gammatone_inv'
        return (distance_metrics.index(distance_metric), channel, gammatone)

    else:
        # If the regex doesn't match, return the original item to maintain its position
        return (999, 999, "")

# Sort the list based on the custom order
sorted_list = sorted(your_list, key=custom_sort_key)

for new_index, item in enumerate(sorted_list):
    old_index = np.where(columns_names[true_channels_indexes] == item)[0][0]
    index_mapping[old_index] = new_index
    

embedded_groups_1_1 = embedded_groups_1_1[:,list(index_mapping.keys())]
embedded_groups_1_2 = embedded_groups_1_2[:,list(index_mapping.keys())]
embedded_groups_1_3 = embedded_groups_1_3[:,list(index_mapping.keys())]

# %%
scaler = StandardScaler(with_mean = True, with_std = True)
scaler.fit(embedded_groups_1_1)
mean_features = scaler.mean_
std_features = scaler.scale_

embedded_groups_1_1 = scaler.transform(embedded_groups_1_1)
embedded_groups_1_2 = scaler.transform(embedded_groups_1_2)
embedded_groups_1_3 = scaler.transform(embedded_groups_1_3)

train_dataset_all.data_for_gender_classification = embedded_groups_1_1
Dev_dataset_all.data_for_gender_classification   = embedded_groups_1_2
Eval_dataset_all.data_for_gender_classification  = embedded_groups_1_3


train_dataset_all.sex = pd.Series([elem[0] for elem in train_dataset_all.sex])
Dev_dataset_all.sex = pd.Series([elem[0] for elem in Dev_dataset_all.sex])
Eval_dataset_all.sex = pd.Series([elem[0] for elem in Eval_dataset_all.sex])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
total_labels = torch.Tensor(Eval_dataset_all.is_spoofed[(Eval_dataset_all.sex == 'female').values].values).cpu().numpy().copy()
total_data = torch.Tensor(Eval_dataset_all.data[(Eval_dataset_all.sex == 'female').values]).cpu().numpy().copy()
with torch.no_grad():
    model = model.to(device)
    test_output = spoof_model_female(torch.Tensor(total_data).to(device))
    loss , test_score = spoof_model_female.loss(torch.Tensor(test_output).to(device),None)
    test_score = -1*test_score
    
test_score_total = test_score.cpu().numpy().copy()

eer, test_thresh = my_functions.compute_eer(total_labels,test_score_total) # compute equal error rate

print(f"\tTest EER: ({eer}%) \tTest Threshold: {test_thresh}")
# Out:
# 	Test EER: (0.10177271288382395%) 	Test Threshold: -0.8237718428358619

# %%
total_labels = torch.Tensor(Eval_dataset_all.is_spoofed[(Eval_dataset_all.sex == 'male').values].values).cpu().numpy().copy()
total_data = torch.Tensor(Eval_dataset_all.data[(Eval_dataset_all.sex == 'male').values]).cpu().numpy().copy()
with torch.no_grad():
    model = model.to(device)
    test_score = torch.sigmoid(spoof_model_male(torch.Tensor(total_data).to(device)))
    
test_score_total = test_score.cpu().numpy().copy()

eer, test_thresh = my_functions.compute_eer(total_labels,test_score_total) # compute equal error rate

print(f"\tTest EER: ({eer}%) \tTest Threshold: {test_thresh}")
# Out:
# 	Test EER: (0.09203296703296708%) 	Test Threshold: 0.04938841566627661

# %%
import torchaudio
from speechbrain.pretrained import EncoderClassifier

# load the model - the moodel that check if it's female or male
with open(os.path.join(models_folder,"gender_XGB_model_both_norm_male_vs_female_db_models.pkl"), 'rb') as fp:
#with open(os.path.join(models_folder,"gender_XGB_model_both_norm_male_vs_female_db_models.pkl"), 'rb') as fp:
    gender_model = pickle.load(fp)
    
# load the model - the model that check if it's the sampe speaker or not
verification_model = SpeakerRecognition.from_hparams(source="speechbrain/spkrec-ecapa-voxceleb", savedir='./ECAPA_TDNN/pretrained_models/spkrec-ecapa-voxceleb',run_opts={"device":"cuda"} )

classifier = EncoderClassifier.from_hparams(source="speechbrain/spkrec-ecapa-voxceleb", savedir='./ECAPA_TDNN/pretrained_models/spkrec-ecapa-voxceleb',run_opts={"device":"cuda"})

# %%
import pickle
from ASV_utils.ASV_my_functions import *
# Load the embeddings file:

with open('./ECAPA_TDNN/embeddings/dev_embedding_ecapa_voxceleb.pkl', 'rb') as file:
    list_dev_files,embeddings_dev = pickle.load(file)
    list_dev_files = [name.rstrip('.wav') for name in list_dev_files]
    
with open('./ECAPA_TDNN/embeddings/eval_embedding_ecapa_voxceleb.pkl', 'rb') as file:
    list_eval_files,embeddings_eval = pickle.load(file)
    list_eval_files = [name.rstrip('.wav') for name in list_eval_files]


embeddings_dev =[emb.cpu() for emb in embeddings_dev]
embeddings_dev = np.concatenate(embeddings_dev, axis=0)
embeddings_eval =[emb.cpu() for emb in embeddings_eval]
embeddings_eval = np.concatenate(embeddings_eval, axis=0)


path_enrollment_dev_female = "./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.dev.female.trn.txt"

path_enrollment_dev_male = "./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.dev.male.trn.txt"

path_enrollment_eval_female = "./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.eval.female.trn.txt"

path_enrollment_eval_male = "./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.eval.male.trn.txt"


enrollment_dev_female = make_enrollment(path_enrollment_dev_female,"female")

enrollment_dev_male = make_enrollment(path_enrollment_dev_male,"male")

enrollment_eval_female = make_enrollment(path_enrollment_eval_female,"female")

enrollment_eval_male = make_enrollment(path_enrollment_eval_male,"male")

enrollment_dev_female = extract_embeddings(list_dev_files,embeddings_dev,enrollment_dev_female)
list_dev_files,embeddings_dev = remove_enrollment_embeddings_from_embeddings_list(list_dev_files,embeddings_dev,enrollment_dev_female)

enrollment_dev_male = extract_embeddings(list_dev_files,embeddings_dev,enrollment_dev_male)
list_dev_files,embeddings_dev = remove_enrollment_embeddings_from_embeddings_list(list_dev_files,embeddings_dev,enrollment_dev_male)

enrollment_eval_female = extract_embeddings(list_eval_files,embeddings_eval,enrollment_eval_female)
list_eval_files,embeddings_eval = remove_enrollment_embeddings_from_embeddings_list(list_eval_files,embeddings_eval,enrollment_eval_female)

enrollment_eval_male = extract_embeddings(list_eval_files,embeddings_eval,enrollment_eval_male)
list_eval_files,embeddings_eval = remove_enrollment_embeddings_from_embeddings_list(list_eval_files,embeddings_eval,enrollment_eval_male)

# %%
path_trails_dev = "./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.dev.gi.trl.txt"
path_trails_eval = "./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.eval.gi.trl.txt"

def keys_to_values(key_list, input_dict):
    return [input_dict[key] for key in key_list if key in input_dict]

def read_trl_txt_file(path):
    speaker_id = []
    file_name = []
    spoof_label = []
    asv_label = []
    with open(path, 'r') as file:
        for line in file:
            parts = line.strip().split(' ')
            if len(parts) != 4:
                raise Exception("The line in the file is not in the right format")
            speaker_id.append(parts[0])
            file_name.append(parts[1])
            spoof_label.append(parts[2])
            asv_label.append(parts[3])
            
    return pd.Series(speaker_id), pd.Series(file_name), pd.Series(spoof_label),pd.Series(asv_label)

speaker_id_list,file_name_according_speaker_id , _, asv_label_dev = read_trl_txt_file(path_trails_dev)

speaker_id_dict_dev = dict(zip(file_name_according_speaker_id,speaker_id_list))

list_speaker_id_dev = keys_to_values(list_dev_files,speaker_id_dict_dev)


asv_label_dict_dev = dict(zip(file_name_according_speaker_id,asv_label_dev))

list_asv_label_dev = keys_to_values(list_dev_files,asv_label_dict_dev)



speaker_id_list,file_name_according_speaker_id , _, asv_label_eval = read_trl_txt_file(path_trails_eval)

speaker_id_dict_eval = dict(zip(file_name_according_speaker_id,speaker_id_list))

list_speaker_id_eval = keys_to_values(list_eval_files,speaker_id_dict_eval)


asv_label_dict_eval = dict(zip(file_name_according_speaker_id,asv_label_eval))

list_asv_label_eval = keys_to_values(list_eval_files,asv_label_dict_eval)

# %%
def CM_inferernce_time_embeddings(data_for_gender_classification,data,gender_model,spoof_model_male,spoof_model_female,device,thr_gender,thr_spoof_male,thr_spoof_female,verbose = False):
    its_spoof_male = None
    its_spoof_female = None
    its_male = None
    with torch.no_grad():
        if gender_model.predict_proba([data_for_gender_classification])[:,1] > thr_gender: #need to normalize the data
            its_male = True
        else:
            its_male = False

        spoof_score_male = torch.sigmoid(spoof_model_male(torch.Tensor(data).unsqueeze(0)).cpu())
        spoof_score_male = spoof_score_male.item()
        if verbose:
            print(f"it's male spoof with score: {spoof_score_male}")
        if spoof_score_male <= thr_spoof_male:
            its_spoof_male = False
            if verbose:
                print("it's not spoof")
        else:
            its_spoof_male = True
            if verbose:
                print("it's spoof")
            
      
            
        spoof_model_female = spoof_model_female.to(device)
        test_output = spoof_model_female(torch.Tensor(data).unsqueeze(0).to(device))
        _ , spoof_score_female = spoof_model_female.loss(torch.Tensor(test_output).to(device),None) # fix this tomorrow!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
        spoof_score_female = -1*spoof_score_female.item()
        if verbose:
            print(f"it's female spoof with prob: {spoof_score_female}")
        if spoof_score_female <= thr_spoof_female:
            its_spoof_female = False
            if verbose:
                print("it's not spoof")
        else:
            its_spoof_female = True
            if verbose:
                print("it's spoof")
                
                    
       
        if its_spoof_female is None or its_spoof_male is None:
            raise Exception("its_spoof is None, need to check the inference function")
        
        if its_male is None:
            raise Exception("its_male is None, need to check the inference function")
        
        return its_male,its_spoof_male,its_spoof_female, spoof_score_male, spoof_score_female

# %%
def inference_system_cm_asv_avg_score(list_speaker_id,list_asv_label,txt_file_path,csv_file_path,thr_gender,thr_spoof_male,thr_spoof_female,enrollment_male, enrollment_female, list_files, data_set, gender_model, spoof_model_male, spoof_model_female, asv_model, device, verbose = False, verbose_txt = False,verbose_csv = False):
    '''
    This function is recognize the speaker in the data set, when the speaker don't say who he is, this task is like recognize the speaker. (Recognition task).
    '''
    
    # Initialize the dictionary with empty lists of data
    results = {  
        "file_name": [],
        "its_male": [],
        "its_male_ground_truth" : [],
        "its_spoof_male": [],
        "spoof_score_male": [],
        "its_spoof_female": [],
        "spoof_score_female": [],
        "spoof_ground_truth": [],
        "asv_score_male": [],
        "asv_score_female": [],
        "speaker_id_male": [],
        "speaker_id_female": [],
        "pred_speaker_id_male": [],
        "pred_speaker_id_female": [],
        "find_speaker_in_enroll_male": [],
        "find_speaker_in_enroll_female": [],
        "asv_label": [],
        "attack_type": [],
    }
    
    if txt_file_path is None: # If the txt file path is None, then don't write to the txt file
        verbose_txt = False
        print("The output file path is None, so the results will not be saved in txt file")
    
    if csv_file_path is None: # If the csv file path is None, then don't write to the csv file
        verbose_csv = False
        print("The output file path is None, so the results will not be saved in csv file")

    if verbose_txt: # Open the txt file      
        txt_file = open(txt_file_path, 'w')
        
    if verbose_csv: # Open the csv file
        csv_file = open(csv_file_path, 'w', newline='')
        csv_writer = csv.writer(csv_file)
        csv_writer.writerow(results.keys())
        
    path_names = pd.Series(np.concatenate(data_set.name.values)) # Get the path names of the data set

    for  speaker_id,file_name,asv_label in tqdm.tqdm(zip(list_speaker_id,list_files,list_asv_label), total=len(list_files)): # Iterate over the list of the files
    
        try:
            index_time_embedding = path_names.str.contains(file_name) # Get the index of the file in the data set
            
            if index_time_embedding.size == 0 or index_time_embedding is None: # If the index is empty, then raise an error
                raise ValueError(f"File {file_name} in list files, is not present in in list paths.")

            if verbose: # Print the file name and the index
                print(f"File {file_name} in list files, is at {path_names[index_time_embedding]} in list paths.")
                
        except ValueError: # If the index is empty, then raise an error
            print(f"File {file_name} in list files, is not present in in list paths.")

        time_embedding_norm = data_set.data[index_time_embedding].squeeze() # Get the time embedding of the file
        time_embedding_for_gender = data_set.data_for_gender_classification[index_time_embedding].squeeze()
        gender_embedding = data_set.sex.values[index_time_embedding][0]
        attack_type = data_set.attack_logical.values[index_time_embedding][0][0]

        # this function calculate the CM inference of the time embedding 
        its_male,its_spoof_male,its_spoof_female, spoof_score_male, spoof_score_female  = CM_inferernce_time_embeddings(time_embedding_for_gender,time_embedding_norm, gender_model, spoof_model_male, spoof_model_female, device,thr_gender,thr_spoof_male,thr_spoof_female) # this function calculate

        if its_male is None: 
            raise Exception("its_male is None, need to check the inference function")

        if its_spoof_male is None or its_spoof_female is None:
            raise Exception("its_spoof is None, need to check the inference function")
        
        if spoof_score_male is None or spoof_score_female is None:
            raise Exception("spoof_score is None, need to check the inference function")
        
        # Append the results to the data dictionary
        results["file_name"].append(file_name)
        results["its_male"].append(its_male)
        results["its_male_ground_truth"].append(gender_embedding)
        
        # for spoofing CM system
        results["its_spoof_male"].append(its_spoof_male)
        results["its_spoof_female"].append(its_spoof_female)
        results["spoof_ground_truth"].append(bool(data_set.is_spoofed.values[index_time_embedding][0]))
        results["spoof_score_male"].append(spoof_score_male)
        results["spoof_score_female"].append(spoof_score_female)
        
        # for ASV system
        results["asv_label"].append(asv_label)
        
        results["attack_type"].append(attack_type)
                
        signal, fs = torchaudio.load(str(path_names.values[index_time_embedding][0])) # load the signal from the path
        
        if fs != 16000: # if the sample rate is not 16000, then raise an error
            raise Exception("The sample rate is not 16000, need to check the inference function")
        
        embeddings = asv_model.encode_batch(signal)  # encode the signal
       
        embeddings = embeddings.cpu().numpy().squeeze(0) # convert the embeddings to numpy and send to cpu

        # initialize the helps variables
        find_speaker_in_enroll = False
      
        max_cos_index = 0
        avg_score = 0
        list_scores_speaker = [];
        
        all_male_speakers_id = np.array(enrollment_male.get_all_speakers_id()) 

        for index_speaker,embedding_in_enroll_per_speaker in enumerate(np.array(enrollment_male.get_all_enrollment_embeddings())):
            for _,embedding_in_enroll in enumerate(embedding_in_enroll_per_speaker):
                if speaker_id == all_male_speakers_id[index_speaker]:
                    cos_score = cosine_similarity(embedding_in_enroll.squeeze().reshape(1, -1), embeddings.reshape(1, -1)) # calculate the cosine similarity between the embeddings
                    find_speaker_in_enroll = True
                    
                    if cos_score.shape != (1, 1): # if the cosine similarity is not scalar, then raise an error
                        raise Exception("cos_score shape is not (1,1) so is not scalar!, need to check the inference function")
                    
                    list_scores_speaker.append(cos_score.item()) 
        
        if len(list_scores_speaker) == 0:
            list_scores_speaker.append(0)  
            results["pred_speaker_id_male"].append(None)      
        else:
            results["pred_speaker_id_male"].append(all_male_speakers_id[max_cos_index])                    
        avg_score = np.mean(list_scores_speaker, axis = 0) # calculate the average score               
            
            #if find_speaker_in_enroll == False:
            #    print("The speaker id is not in the enrollment data set")
        
        
        results["asv_score_male"].append(avg_score) # the score of the current embedding with the enrollment embedding
        results["speaker_id_male"].append(speaker_id)         
        results["find_speaker_in_enroll_male"].append(find_speaker_in_enroll)
        
        
        find_speaker_in_enroll = False
     
        max_cos_index = 0
        avg_score = 0
        list_scores_speaker = [];
          
        all_female_speakers_id = np.array(enrollment_female.get_all_speakers_id()) 
        
        for index_speaker,embedding_in_enroll_per_speaker in enumerate(np.array(enrollment_female.get_all_enrollment_embeddings())):
            for _,embedding_in_enroll in enumerate(embedding_in_enroll_per_speaker):
                if speaker_id == all_female_speakers_id[index_speaker]:
                    cos_score = cosine_similarity(embedding_in_enroll.squeeze().reshape(1, -1), embeddings.reshape(1, -1)) # calculate the cosine similarity between the embeddings
                    find_speaker_in_enroll = True
                    
                    if cos_score.shape != (1, 1): # if the cosine similarity is not scalar, then raise an error
                        raise Exception("cos_score shape is not (1,1) so is not scalar!, need to check the inference function")
                    
                    list_scores_speaker.append(cos_score.item()) 
        
        
        if len(list_scores_speaker) == 0:
            list_scores_speaker.append(0)
            results["pred_speaker_id_female"].append(None)      
        else:
            results["pred_speaker_id_female"].append(all_female_speakers_id[max_cos_index])                 
        avg_score = np.mean(list_scores_speaker, axis = 0) # calculate the average score   
    
        
        results["asv_score_female"].append(avg_score) # the score of the current embedding with the enrollment embedding
        results["speaker_id_female"].append(speaker_id)         
        results["find_speaker_in_enroll_female"].append(find_speaker_in_enroll)
        
        
        if verbose: # Print the results
            print(f"file_name: {results['file_name'][-1]}, its_male: {results['its_male'][-1]}, its_spoof: {results['its_spoof'][-1]}, spoof_score: {results['spoof_score'][-1]}, spoof_ground_truth: {results['spoof_ground_truth'][-1]},asv_score: {results['asv_score'][-1]}, speaker_id: {results['speaker_id'][-1]} , pred_speaker_id: {results['pred_speaker_id'][-1]}, find_speaker_in_enroll: {results['find_speaker_in_enroll'][-1]} \n")
            
        if verbose_txt: # Write the results to the txt file
            txt_file.write(f"file_name: {results['file_name'][-1]}, its_male: {results['its_male'][-1]}, its_spoof: {results['its_spoof'][-1]}, spoof_score: {results['spoof_score'][-1]}, spoof_ground_truth: {results['spoof_ground_truth'][-1]},asv_score: {results['asv_score'][-1]}, speaker_id: {results['speaker_id'][-1]} , pred_speaker_id: {results['pred_speaker_id'][-1]}, find_speaker_in_enroll: {results['find_speaker_in_enroll'][-1]} \n")

        if verbose_csv: # Write the results to the csv file
            last_item = {key: list(values)[-1] for key, values in results.items()} # Get the last item of each list in the dictionary
            csv_writer.writerow(last_item.values()) # Write the last item to the csv file
        
    if verbose_txt: # Close the txt file
        txt_file.close()
        
    if verbose_csv:# Close the csv file
        csv_file.close() 
           
    results_df = pd.DataFrame(results)  # Return the DataFrame
    
    return results_df

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming list_tDCF_norm_male_dev, list_asv_score, and list_CM_thresholds_male_dev are defined
def heatmap_norm_tdcf(list_tDCF_norm,asv_scores,cm_thresholds,target_values,title,point_x_index=None, point_y_index=None,point_x_constrained=None,point_y_constrained=None):
    # Create a heatmap
    _, ax = plt.subplots(figsize=(10, 10))
    num_cm_to_plot = 10

    # Plot heatmap
    heatmap = ax.imshow(np.array(list_tDCF_norm).transpose(), cmap='viridis', aspect='auto', vmin=0, origin='lower', interpolation='none')

    # Set ticks and labels for x-axis (ASV scores)
    asv_indices = np.linspace(0, len(asv_scores) - 1, num_cm_to_plot, dtype=int)
    ax.set_xticks(asv_indices)
    ax.set_xticklabels(["{:.2f}".format(asv_scores[i]) for i in asv_indices])


    # Find the closest values
    cm_indices = [np.abs(cm_thresholds[0] - target).argmin() for target in target_values]
    
    #Set ticks and labels for y-axis (CM scores)
    ax.set_yticks(cm_indices)
    ax.set_yticklabels(["{:.3f}".format(cm_thresholds[0][i]) for i in cm_indices])
   
    '''
    defult_show = "female";
    if defult_show == "male":
        defult_indices = [cm_indices[0],cm_indices[-1]]
        ax.set_yticks(defult_indices)
        list_values = [0,1]
        #list_values = [cm_thresholds[0][0],cm_thresholds[0][-1]]
        ax.set_yticklabels(["{:.3f}".format(i) for i in list_values])
    else:
        defult_indices = [cm_indices[0],cm_indices[-1]]
        ax.set_yticks(defult_indices)
        list_values = [-1,1]
        #list_values = [cm_thresholds[0][0],cm_thresholds[0][-1]]
        ax.set_yticklabels(["{:.3f}".format(i) for i in list_values])
    '''  
    # Add colorbar
    cbar = plt.colorbar(heatmap)
    cbar.set_label('norm T-DCF Values', rotation=270, labelpad=15)

    # Set axis labels
    ax.set_xlabel('ASV Thresholds')
    ax.set_ylabel('CM Thresholds')
    ax.set_title(title)
    
    asv_indices, cm_indices = np.meshgrid(
        np.arange(np.array(cm_thresholds).shape[1]),
        np.arange(np.array(asv_scores).shape[0])
    )
    contour = ax.contour(np.array(list_tDCF_norm).transpose(), levels=5, colors='white', origin='lower')
    plt.clabel(contour, inline=True, fontsize=10, fmt='%.2f', colors='white',zorder=1)
    
     # Plot the point if provided
    if point_x_index is not None and point_y_index is not None:
        ax.scatter(point_x_index, point_y_index,zorder=2, color='red', marker='X', label=f'Min norm t-DCF Optimal at ({asv_scores[point_x_index]:.2f},{cm_thresholds[point_x_index][point_y_index]:.2f}), Value: {list_tDCF_norm[point_x_index][point_y_index]:.4f}')
    
    
    if point_x_constrained is not None and point_y_constrained is not None:
            ax.scatter(point_x_constrained, point_y_constrained, zorder=3,color='cyan', marker='X', label=f'Min norm t-DCF (fixed ASV Threshold) at ({asv_scores[point_x_constrained]:.2f},{cm_thresholds[point_x_constrained][point_y_constrained]:.2f}), Value: {list_tDCF_norm[point_x_constrained][point_y_constrained]:.4f}')
    
    
    # Show the plot
    ax.legend(loc="lower right")
    plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

def heatmap_norm_tdcf_3d(list_tDCF_norm, asv_scores, cm_thresholds, target_values, title,point_x_index=None, point_y_index=None):
    # Create a 3D plot
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111, projection='3d')

    # Create meshgrid for x and y based on dimensions of the data
    
    
    
    asv_indices, cm_indices = np.meshgrid(
        np.arange(np.array(cm_thresholds).shape[1]),
        np.arange(np.array(asv_scores).shape[0])
    )

    # Plot the 3D surface
    surface = ax.plot_surface(asv_indices, cm_indices, np.array(list_tDCF_norm), cmap='viridis', vmin=0, vmax=1, rstride=1, cstride=1, linewidth=0, antialiased=False)

    # Set ticks and labels for x-axis (ASV scores)
    ax.set_xticks(np.arange(len(asv_scores)))
    ax.set_xticklabels(["{:.2f}".format(asv_scores[i]) for i in range(len(asv_scores))])

    # Set ticks and labels for y-axis (CM scores)
    ax.set_yticks(np.arange(len(target_values)))
    ax.set_yticklabels(["{:.3f}".format(cm_thresholds[0][i]) for i in range(len(target_values))])

    # Add colorbar
    cbar = fig.colorbar(surface, ax=ax, shrink=0.6)
    cbar.set_label('norm T-DCF Values', rotation=270, labelpad=15)

    # Set axis labels
    ax.set_xlabel('ASV Thresholds')
    ax.set_ylabel('CM Thresholds')
    ax.set_zlabel('norm T-DCF Values')
    ax.set_title(title)

    # Show the plot
    if point_x_index is not None and point_y_index is not None:
        ax.scatter(point_x_index, point_y_index, color='red', marker='X', label=f'min norm t-DCF Optimal in ({asv_scores[point_x_index]:.2f},{cm_thresholds[point_x_index][point_y_index]:.2f})')
        
    # Show the plot
    ax.legend()
    plt.show()

# Example usage:
# heatmap_norm_tdcf_3d(list_tDCF_norm_male_dev, list_asv_score, list_CM_thresholds_male_dev, target_values, "Title")
#list_asv_score = list(np.arange(0.01, 1.01, 0.01))
#nan_indices = np.where(np.isnan(list_tDCF_norm_male_dev))
#first_nan_row = nan_indices[0][0] if len(nan_indices[0]) > 0 else len(list_tDCF_norm_male_dev)

#list_tDCF_norm_male_dev_show = list_tDCF_norm_male_dev[0:first_nan_row]
#list_asv_score_show = list_asv_score[0:first_nan_row]

#heatmap_norm_tdcf_3d(list_tDCF_norm_male_dev_show,list_asv_score_show,list_tDCF_norm_male_dev_show, target_values = [0,0.01,0.02,0.03,0.1,0.2,0.41, 0.85,0.99,1],title ="Norm t-DCF - Male Gender on Development Set")

# %%
from sklearn.metrics.pairwise import cosine_similarity
import torchaudio
import tqdm
from ASV_utils.config_thr import pmf_both_thr_gender_val ,pmf_both_thr_spoof_val_male,pmf_both_thr_spoof_val_female
from ASV_utils.tdcf_functions import compute_t_dcf

txt_file_path = "output.txt"
csv_file_path = "output.csv"
enrollment_male = enrollment_dev_male
enrollment_female = enrollment_dev_female
list_files = list_dev_files
data_set = Dev_dataset_all
asv_model = classifier

results = inference_system_cm_asv_avg_score(list_speaker_id_dev,list_asv_label_dev,txt_file_path,csv_file_path,pmf_both_thr_gender_val,pmf_both_thr_spoof_val_male,pmf_both_thr_spoof_val_female,enrollment_male, enrollment_female, list_files, data_set, gender_model, spoof_model_male, spoof_model_female, asv_model, device, verbose = False, verbose_txt = False,verbose_csv = False)
# Out:
#   0%|          | 0/24844 [00:00<?, ?it/s]
# 100%|██████████| 24844/24844 [4:36:43<00:00,  1.50it/s]

# %%
from ASV_utils.tdcf_functions import compute_t_dcf
import pickle
results = pickle.load(open("objects_asv_and_cm_time_embeddings_avg_score_both_2.pkl", 'rb'))

# %%
import pickle
'''
with open('objects_asv_and_cm_time_embeddings_avg_score_both_2.pkl', 'wb') as f:
    pickle.dump(results,f)
'''

# %% [markdown]
# # Male - DEV:

# %% [markdown]
# ### with labels of gender:

# %%
#check what happen when the gender classification is mistake!!

bonafide_score_cm_male_dev = 1-results.loc[(results['spoof_ground_truth'] == 0) & (results['its_male_ground_truth'] == 'male')]['spoof_score_male'].values
spoof_score_cm_male_dev = 1-results.loc[(results['spoof_ground_truth'] == 1)  & (results['its_male_ground_truth'] == 'male')]['spoof_score_male'].values
Prior_spoof = 0.05
target_scores_male_dev = results.loc[(results['asv_label'] ==  "target") & (results['its_male_ground_truth'] == 'male') ]["asv_score_male"].values
nontarget_scores_male_dev = results.loc[(results['asv_label'] == "nontarget") & (results['its_male_ground_truth'] == 'male') ]["asv_score_male"].values
spoof_scores_male_dev = results.loc[(results['asv_label'] ==  "spoof") & (results['its_male_ground_truth'] == 'male')]["asv_score_male"].values
list_asv_score = [0.326]
type = 'constrained'
list_tDCF_norm_male_dev ,list_CM_thresholds_male_dev,list_tDCF_male_dev = compute_t_dcf(bonafide_score_cm_male_dev,spoof_score_cm_male_dev,Prior_spoof,target_scores_male_dev,nontarget_scores_male_dev,spoof_scores_male_dev,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  5.01759 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  0.326
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [1.         0.99986472 0.99972944 ... 5.00602549 5.01180612 5.01758675]
# the min tDCF_norm is: 0.017144266261128815

# %% [markdown]
# ### with pred of gender:

# %%
bonafide_score_cm_male_dev = 1-results.loc[(results['spoof_ground_truth'] == 0) & (results['its_male'] == True)]['spoof_score_male'].values
spoof_score_cm_male_dev = 1-results.loc[(results['spoof_ground_truth'] == 1)  & (results['its_male'] == True)]['spoof_score_male'].values
Prior_spoof = 0.05
target_scores_male_dev = results.loc[(results['asv_label'] ==  "target") & (results['its_male'] == True) ]["asv_score_male"].values
nontarget_scores_male_dev = results.loc[(results['asv_label'] == "nontarget") & (results['its_male'] == True) ]["asv_score_male"].values
spoof_scores_male_dev = results.loc[(results['asv_label'] ==  "spoof") & (results['its_male'] == True)]["asv_score_male"].values
list_asv_score = [0.326]
type = 'constrained'
list_tDCF_norm_male_dev ,list_CM_thresholds_male_dev,list_tDCF_male_dev   = compute_t_dcf(bonafide_score_cm_male_dev,spoof_score_cm_male_dev,Prior_spoof,target_scores_male_dev,nontarget_scores_male_dev,spoof_scores_male_dev,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  5.01759 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  0.326
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [1.         0.99986472 0.99972944 ... 5.00602549 5.01180612 5.01758675]
# the min tDCF_norm is: 0.017144266261128815

# %%
bonafide_score_cm_male_dev = 1-results.loc[(results['spoof_ground_truth'] == 0) & (results['its_male'] == True)]['spoof_score_male'].values
spoof_score_cm_male_dev = 1-results.loc[(results['spoof_ground_truth'] == 1)  & (results['its_male'] == True)]['spoof_score_male'].values
Prior_spoof = 0.05
target_scores_male_dev = results.loc[(results['asv_label'] ==  "target") & (results['its_male'] == True) ]["asv_score_male"].values
nontarget_scores_male_dev = results.loc[(results['asv_label'] == "nontarget") & (results['its_male'] == True) ]["asv_score_male"].values
spoof_scores_male_dev = results.loc[(results['asv_label'] ==  "spoof") & (results['its_male'] == True)]["asv_score_male"].values
list_asv_score = [0.326]
type = 'constrained_ver2'
list_tDCF_norm_male_dev ,list_CM_thresholds_male_dev,list_tDCF_male_dev   = compute_t_dcf(bonafide_score_cm_male_dev,spoof_score_cm_male_dev,Prior_spoof,target_scores_male_dev,nontarget_scores_male_dev,spoof_scores_male_dev,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained_ver2
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv development set  0.326
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [1.         0.99988308 0.99976617 ... 4.46216042 4.46715626 4.4721521 ]
# the min tDCF_norm is: 0.15057849072922058

# %% [markdown]
# ### Grid Search:

# %%
bonafide_score_cm_male_dev = 1-results.loc[(results['spoof_ground_truth'] == 0) & (results['its_male'] == True)]['spoof_score_male'].values
spoof_score_cm_male_dev = 1-results.loc[(results['spoof_ground_truth'] == 1)  & (results['its_male'] == True)]['spoof_score_male'].values
Prior_spoof = 0.05
target_scores_male_dev = results.loc[(results['asv_label'] ==  "target") & (results['its_male'] == True) ]["asv_score_male"].values
nontarget_scores_male_dev = results.loc[(results['asv_label'] == "nontarget") & (results['its_male'] == True) ]["asv_score_male"].values
spoof_scores_male_dev = results.loc[(results['asv_label'] ==  "spoof") & (results['its_male'] == True)]["asv_score_male"].values
list_asv_score = list(np.arange(0.00, 1.01, 0.01))
type = 'unconstrained'

point_y_constrained = np.argmin(list_tDCF_norm_male_dev) 
point_x_constrained = (np.abs(np.array(list_asv_score)-[0.326])).argmin()

list_tDCF_norm_male_dev ,list_CM_thresholds_male_dev,list_tDCF_male_dev  = compute_t_dcf(bonafide_score_cm_male_dev,spoof_score_cm_male_dev,Prior_spoof,target_scores_male_dev,nontarget_scores_male_dev,spoof_scores_male_dev,list_asv_score,type)

tDCF_norm_male_dev = np.array(list_tDCF_norm_male_dev)

CM_thresholds_male_dev = np.array(list_CM_thresholds_male_dev)

min_index = np.unravel_index(np.nanargmin(tDCF_norm_male_dev), tDCF_norm_male_dev.shape)

# Print the results
print("tDCF - Minimum value:", tDCF_norm_male_dev[min_index])
print("Index of minimum value:", min_index)
print("The min asv score:", list_asv_score[min_index[0]])
print("The min CM thersholds:",CM_thresholds_male_dev[min_index])
# Out:
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv development set  0.0
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.96285787 0.96274487 0.96263186 ... 1.577324   1.57899813 1.58067227]
# the min tDCF_norm is: 0.13869030435802307
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv evaluation set  0.01
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.95373149 0.95361881 0.95350613 ... 1.57730847 1.57899037 1.58067227]
# the min tDCF_norm is: 0.1319318803710691
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.02
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.94244516 0.94233309 0.94222103 ... 1.57729294 1.57898261 1.58067227]
# the min tDCF_norm is: 0.1251489114421714
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.03
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.92929899 0.92918737 0.92907575 ... 1.57727025 1.57897126 1.58067227]
# the min tDCF_norm is: 0.11527340103501506
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.04
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.91404289 0.91393193 0.91382097 ... 1.57724636 1.57895932 1.58067227]
# the min tDCF_norm is: 0.10486201292986252
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.05
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.90599422 0.90588399 0.90577377 ... 1.57724039 1.57895633 1.58067227]
# the min tDCF_norm is: 0.10221104489897419
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.06
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.88969224 0.88958317 0.8894741  ... 1.57722247 1.57894737 1.58067227]
# the min tDCF_norm is: 0.09434727770073639
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.07
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.8719988  0.87189079 0.87178279 ... 1.57719978 1.57893602 1.58067227]
# the min tDCF_norm is: 0.08442009373159327
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.08
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.85039016 0.85028381 0.85017746 ... 1.57717828 1.57892527 1.58067227]
# the min tDCF_norm is: 0.07496031999081389
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.09
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.8319646  0.83185949 0.83175437 ... 1.57715678 1.57891452 1.58067227]
# the min tDCF_norm is: 0.06553671774342522
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.1
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.81230219 0.81219862 0.81209504 ... 1.57713767 1.57890497 1.58067227]
# the min tDCF_norm is: 0.05712286261764484
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.11
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.791603   0.79150096 0.79139893 ... 1.57711617 1.57889422 1.58067227]
# the min tDCF_norm is: 0.0476734235892628
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.12
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.77290462 0.77280455 0.77270447 ... 1.57710661 1.57888944 1.58067227]
# the min tDCF_norm is: 0.0433657325804984
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.13
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.75469733 0.75459895 0.75450057 ... 1.57709347 1.57888287 1.58067227]
# the min tDCF_norm is: 0.03752791882072554
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.14
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.73387537 0.73377903 0.7336827  ... 1.57708033 1.5788763  1.58067227]
# the min tDCF_norm is: 0.03166039276281027
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.15
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.71498599 0.71489144 0.71479689 ... 1.57706719 1.57886973 1.58067227]
# the min tDCF_norm is: 0.025814827968739393
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.16
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.69259977 0.69250775 0.69241574 ... 1.57705883 1.57886555 1.58067227]
# the min tDCF_norm is: 0.021977130866438058
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.17
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.67306923 0.67297951 0.67288979 ... 1.57705286 1.57886257 1.58067227]
# the min tDCF_norm is: 0.019195687091533114
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.18
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.65310092 0.65301372 0.65292652 ... 1.57704981 1.57886104 1.58067227]
# the min tDCF_norm is: 0.017660867051813682
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.19
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.63271095 0.63262609 0.63254122 ... 1.57704264 1.57885746 1.58067227]
# the min tDCF_norm is: 0.014357755808458888
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.2
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.60830573 0.60822396 0.60814219 ... 1.57703906 1.57885566 1.58067227]
# the min tDCF_norm is: 0.012544720305572812
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.21
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.58730519 0.58722658 0.58714796 ... 1.57704437 1.57885832 1.58067227]
# the min tDCF_norm is: 0.014581478523922805
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.22
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.56365937 0.56358395 0.56350854 ... 1.57704437 1.57885832 1.58067227]
# the min tDCF_norm is: 0.01431277600159156
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.23
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.54113095 0.54105896 0.54098697 ... 1.57705087 1.57886157 1.58067227]
# the min tDCF_norm is: 0.01684407306834834
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.24
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.5141247  0.51405629 0.51398788 ... 1.57704968 1.57886097 1.58067227]
# the min tDCF_norm is: 0.01602528261847452
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.25
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.4896831  0.489618   0.4895529  ... 1.57704968 1.57886097 1.58067227]
# the min tDCF_norm is: 0.015747537222795583
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.26
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.46399101 0.46392938 0.46386776 ... 1.57704968 1.57886097 1.58067227]
# the min tDCF_norm is: 0.015455581597570288
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.27
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.44496731 0.44490902 0.44485073 ... 1.57706269 1.57886748 1.58067227]
# the min tDCF_norm is: 0.020814006873458146
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.28
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.42257198 0.42251673 0.42246147 ... 1.57706269 1.57886748 1.58067227]
# the min tDCF_norm is: 0.020559514580673264
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.29
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.39585675 0.39580511 0.39575347 ... 1.57706269 1.57886748 1.58067227]
# the min tDCF_norm is: 0.020255932404000945
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.3
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.38147459 0.38142604 0.38137749 ... 1.5770822  1.57887723 1.58067227]
# the min tDCF_norm is: 0.028454404279516586
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.31
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.36857029 0.36852463 0.36847897 ... 1.57710171 1.57888699 1.58067227]
# the min tDCF_norm is: 0.03666967006267792
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.32
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.35723812 0.35719552 0.35715292 ... 1.57712772 1.5789     1.58067227]
# the min tDCF_norm is: 0.04769010279112597
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.33
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.34933583 0.34929544 0.34925505 ... 1.57714723 1.57890975 1.58067227]
# the min tDCF_norm is: 0.05596220949247277
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.34
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.34086512 0.34082702 0.34078893 ... 1.57716675 1.57891951 1.58067227]
# the min tDCF_norm is: 0.06422785699857123
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.35000000000000003
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.32888969 0.32885398 0.32881827 ... 1.57717975 1.57892601 1.58067227]
# the min tDCF_norm is: 0.0696663762955386
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.36
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.33511996 0.33508608 0.3350522  ... 1.57722528 1.57894877 1.58067227]
# the min tDCF_norm is: 0.08924828767245942
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.37
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.34112286 0.34109084 0.34105882 ... 1.57727081 1.57897154 1.58067227]
# the min tDCF_norm is: 0.10882761537128087
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.38
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.34530685 0.34527694 0.34524703 ... 1.57731633 1.5789943  1.58067227]
# the min tDCF_norm is: 0.1283862736453076
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.39
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.34420605 0.34417781 0.34414957 ... 1.57734235 1.57900731 1.58067227]
# the min tDCF_norm is: 0.13952297188822593
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.4
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.34672364 0.34669698 0.34667031 ... 1.57737487 1.57902357 1.58067227]
# the min tDCF_norm is: 0.15348809017932497
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.41000000000000003
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.35818327 0.35815773 0.35813218 ... 1.57742039 1.57904633 1.58067227]
# the min tDCF_norm is: 0.17312942615253057
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.42
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.38635131 0.38632692 0.38630253 ... 1.57750494 1.5790886  1.58067227]
# the min tDCF_norm is: 0.20968444149663523
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.43
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.41383726 0.41381412 0.41379097 ... 1.57758949 1.57913088 1.58067227]
# the min tDCF_norm is: 0.2462317058064419
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.44
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.43262796 0.43260609 0.43258422 ... 1.57765453 1.5791634  1.58067227]
# the min tDCF_norm is: 0.27431825491365003
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.45
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.47333702 0.47331613 0.47329525 ... 1.57776509 1.57921868 1.58067227]
# the min tDCF_norm is: 0.3221649891866333
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.46
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.50444137 0.50442162 0.50440187 ... 1.57785614 1.57926421 1.58067227]
# the min tDCF_norm is: 0.36154067354462066
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.47000000000000003
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.54230838 0.54229    0.54227162 ... 1.57796671 1.57931949 1.58067227]
# the min tDCF_norm is: 0.40935511184136225
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.48
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.7655535042285919
# the tDCF_norm is: [0.57521222 0.57519512 0.57517802 ... 1.57806426 1.57936827 1.58067227]
# the min tDCF_norm is: 0.45153854682273575
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
# ...
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.00032375955581665037
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.85
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.00032375955581665037
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.86
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.00032375955581665037
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.87
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.00032375955581665037
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.88
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.00032375955581665037
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.89
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.00032375955581665037
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.9
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.00032375955581665037
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.91
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.00032375955581665037
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.92
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.00032375955581665037
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.93
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.00032375955581665037
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.9400000000000001
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.00032375955581665037
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.9500000000000001
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.00032375955581665037
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.96
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.00032375955581665037
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.97
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.00032375955581665037
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.98
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.00032375955581665037
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.99
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.00032375955581665037
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=868, Nspoof=7392] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  1.0
# the CM thresholds is:  [3.23759556e-04 1.32375956e-03 1.48350000e-03 ... 9.96420886e-01
#  9.96460491e-01 9.96598294e-01]
# the CM threshold min is: 0.00032375955581665037
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# tDCF - Minimum value: 0.012544720305572812
# Index of minimum value: (20, 7309)
# The min asv score: 0.2
# The min CM thersholds: 0.7655535042285919

# %%
heatmap_norm_tdcf(list_tDCF_norm_male_dev,list_asv_score,list_CM_thresholds_male_dev, target_values = [0,0.5,1],title ="Norm t-DCF - Male on Development Set",point_x_index=min_index[0], point_y_index=min_index[1],point_x_constrained=point_x_constrained,point_y_constrained=point_y_constrained)

# %% [markdown]
# ## Female - DEV:

# %% [markdown]
# ### with labels of gender:

# %%
bonafide_score_cm_female_dev = results.loc[(results['spoof_ground_truth'] == 0) & (results['its_male_ground_truth'] == 'female')]['spoof_score_female'].values
bonafide_score_cm_female_dev = -1*bonafide_score_cm_female_dev

spoof_score_cm_female_dev = results.loc[(results['spoof_ground_truth'] == 1)  & (results['its_male_ground_truth'] == 'female')]['spoof_score_female'].values
spoof_score_cm_female_dev = -1*spoof_score_cm_female_dev
Prior_spoof = 0.05
target_scores_female_dev = results.loc[(results['asv_label'] ==  "target") & (results['its_male_ground_truth'] == 'female') ]["asv_score_female"].values
nontarget_scores_female_dev = results.loc[(results['asv_label'] == "nontarget") & (results['its_male_ground_truth'] == 'female') ]["asv_score_female"].values
spoof_scores_female_dev = results.loc[(results['asv_label'] ==  "spoof") & (results['its_male_ground_truth'] == 'female')]["asv_score_female"].values
list_asv_score = [0.432]
type = 'constrained'
list_tDCF_norm_female_dev ,list_CM_thresholds_female_dev,list_tDCF_female_dev  = compute_t_dcf(bonafide_score_cm_female_dev,spoof_score_cm_female_dev,Prior_spoof,target_scores_female_dev,nontarget_scores_female_dev,spoof_scores_female_dev,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  6.52548 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  0.432
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [1.         0.9999329  0.99986581 ... 6.5177121  6.52159632 6.52548053]
# the min tDCF_norm is: 0.0

# %% [markdown]
# ### with pred of gender:

# %%
bonafide_score_cm_female_dev = results.loc[(results['spoof_ground_truth'] == 0) & (results['its_male'] == False)]['spoof_score_female'].values
bonafide_score_cm_female_dev = -1*bonafide_score_cm_female_dev

spoof_score_cm_female_dev = results.loc[(results['spoof_ground_truth'] == 1)  & (results['its_male'] == False)]['spoof_score_female'].values
spoof_score_cm_female_dev = -1*spoof_score_cm_female_dev
Prior_spoof = 0.05
target_scores_female_dev = results.loc[(results['asv_label'] ==  "target") & (results['its_male'] == False) ]["asv_score_female"].values
nontarget_scores_female_dev = results.loc[(results['asv_label'] == "nontarget") & (results['its_male'] == False) ]["asv_score_female"].values
spoof_scores_female_dev = results.loc[(results['asv_label'] ==  "spoof") & (results['its_male'] == False)]["asv_score_female"].values
list_asv_score = [0.432]
type = 'constrained'
list_tDCF_norm_female_dev ,list_CM_thresholds_female_dev,list_tDCF_female_dev = compute_t_dcf(bonafide_score_cm_female_dev,spoof_score_cm_female_dev,Prior_spoof,target_scores_female_dev,nontarget_scores_female_dev,spoof_scores_female_dev,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  6.52548 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  0.432
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [1.         0.9999329  0.99986581 ... 6.5177121  6.52159632 6.52548053]
# the min tDCF_norm is: 0.0

# %%
bonafide_score_cm_female_dev = results.loc[(results['spoof_ground_truth'] == 0) & (results['its_male'] == False)]['spoof_score_female'].values
bonafide_score_cm_female_dev = -1*bonafide_score_cm_female_dev

spoof_score_cm_female_dev = results.loc[(results['spoof_ground_truth'] == 1)  & (results['its_male'] == False)]['spoof_score_female'].values
spoof_score_cm_female_dev = -1*spoof_score_cm_female_dev
Prior_spoof = 0.05
target_scores_female_dev = results.loc[(results['asv_label'] ==  "target") & (results['its_male'] == False) ]["asv_score_female"].values
nontarget_scores_female_dev = results.loc[(results['asv_label'] == "nontarget") & (results['its_male'] == False) ]["asv_score_female"].values
spoof_scores_female_dev = results.loc[(results['asv_label'] ==  "spoof") & (results['its_male'] == False)]["asv_score_female"].values
list_asv_score = [0.432]
type = 'constrained_ver2'
list_tDCF_norm_female_dev ,list_CM_thresholds_female_dev,list_tDCF_female_dev = compute_t_dcf(bonafide_score_cm_female_dev,spoof_score_cm_female_dev,Prior_spoof,target_scores_female_dev,nontarget_scores_female_dev,spoof_scores_female_dev,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained_ver2
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv development set  0.432
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [1.         0.999964   0.999928   ... 3.96067563 3.96275981 3.96484398]
# the min tDCF_norm is: 0.4634233228332024

# %% [markdown]
# ### Grid Search:

# %%
bonafide_score_cm_female_dev = results.loc[(results['spoof_ground_truth'] == 0) & (results['its_male'] == False)]['spoof_score_female'].values
bonafide_score_cm_female_dev = -1*bonafide_score_cm_female_dev

spoof_score_cm_female_dev = results.loc[(results['spoof_ground_truth'] == 1)  & (results['its_male'] == False)]['spoof_score_female'].values
spoof_score_cm_female_dev = -1*spoof_score_cm_female_dev
Prior_spoof = 0.05
target_scores_female_dev = results.loc[(results['asv_label'] ==  "target") & (results['its_male'] == False) ]["asv_score_female"].values
nontarget_scores_female_dev = results.loc[(results['asv_label'] == "nontarget") & (results['its_male'] == False) ]["asv_score_female"].values
spoof_scores_female_dev = results.loc[(results['asv_label'] ==  "spoof") & (results['its_male'] == False)]["asv_score_female"].values
list_asv_score = np.arange(0.00, 1.01, 0.01)
type = 'unconstrained'


point_y_constrained = np.argmin(list_tDCF_norm_female_dev)
point_x_constrained = (np.abs(np.array(list_asv_score)-[0.432])).argmin()

list_tDCF_norm_female_dev ,list_CM_thresholds_female_dev,list_tDCF_female_dev  = compute_t_dcf(bonafide_score_cm_female_dev,spoof_score_cm_female_dev,Prior_spoof,target_scores_female_dev,nontarget_scores_female_dev,spoof_scores_female_dev,list_asv_score,type)

tDCF_norm_female_dev = np.array(list_tDCF_norm_female_dev)

CM_thresholds_female_dev = np.array(list_CM_thresholds_female_dev)

min_index = np.unravel_index(np.nanargmin(tDCF_norm_female_dev), tDCF_norm_female_dev.shape)

# Print the results
print("tDCF - Minimum value:", tDCF_norm_female_dev[min_index])
print("Index of minimum value:", min_index)
print("The min asv score:", list_asv_score[min_index[0]])
print("The min CM thersholds:",CM_thresholds_female_dev[min_index])
# Out:
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv development set  0.0
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.99314138 0.9930851  0.99302882 ... 1.57897431 1.57982329 1.58067227]
# the min tDCF_norm is: 0.15438397581254726
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv evaluation set  0.01
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.99002886 0.98997264 0.98991641 ... 1.57897154 1.5798219  1.58067227]
# the min tDCF_norm is: 0.1520608243297319
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.02
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.98536725 0.9853111  0.98525495 ... 1.57896727 1.57981977 1.58067227]
# the min tDCF_norm is: 0.14847049931083545
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.03
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.97980352 0.9797475  0.97969148 ... 1.57896299 1.57981763 1.58067227]
# the min tDCF_norm is: 0.14488017429193903
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.04
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.97221191 0.97215605 0.97210018 ... 1.57895671 1.57981449 1.58067227]
# the min tDCF_norm is: 0.13960028455826776
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.05
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.96359204 0.96353636 0.96348067 ... 1.57894967 1.57981097 1.58067227]
# the min tDCF_norm is: 0.13368680805655594
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.06
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.94829607 0.9482407  0.94818533 ... 1.5789371  1.57980468 1.58067227]
# the min tDCF_norm is: 0.12312702858921347
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.07
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.93450617 0.93445115 0.93439613 ... 1.57892679 1.57979953 1.58067227]
# the min tDCF_norm is: 0.11446800942599264
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.08
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.92053279 0.92047814 0.92042349 ... 1.57891673 1.5797945  1.58067227]
# the min tDCF_norm is: 0.10602018585211864
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.09
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.90324809 0.90319397 0.90313984 ... 1.57890542 1.57978884 1.58067227]
# the min tDCF_norm is: 0.0965163843315104
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.1
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.88466755 0.88461398 0.8845604  ... 1.5788931  1.57978268 1.58067227]
# the min tDCF_norm is: 0.08616780045351474
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.11
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.86488863 0.8648357  0.86478277 ... 1.57888103 1.57977665 1.58067227]
# the min tDCF_norm is: 0.07603041216486595
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.12
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.84641892 0.84636665 0.84631438 ... 1.57887072 1.57977149 1.58067227]
# the min tDCF_norm is: 0.0673713930016451
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.13
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.82407504 0.82402356 0.82397208 ... 1.57885815 1.57976521 1.58067227]
# the min tDCF_norm is: 0.056811613534302606
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.14
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.80372938 0.80367876 0.80362813 ... 1.5788491  1.57976068 1.58067227]
# the min tDCF_norm is: 0.049208572317816016
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.15
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.78063625 0.78058659 0.78053693 ... 1.57883879 1.57975553 1.58067227]
# the min tDCF_norm is: 0.04054955315459517
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.16
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.75734626 0.75729755 0.75724885 ... 1.57882798 1.57975012 1.58067227]
# the min tDCF_norm is: 0.031468142812680636
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.17
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.73247367 0.73242625 0.73237883 ... 1.57882119 1.57974673 1.58067227]
# the min tDCF_norm is: 0.02576586190031568
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.18
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.70496443 0.70491852 0.70487261 ... 1.57881516 1.57974371 1.58067227]
# the min tDCF_norm is: 0.020697167755991286
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.19
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.67784795 0.67780363 0.67775931 ... 1.57881113 1.5797417  1.58067227]
# the min tDCF_norm is: 0.017318038326441687
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.2
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.64943465 0.64939201 0.64934937 ... 1.57880711 1.57973969 1.58067227]
# the min tDCF_norm is: 0.013938908896892092
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.21
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.62006381 0.62002285 0.6199819  ... 1.57880208 1.57973718 1.58067227]
# the min tDCF_norm is: 0.009714997109955093
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.22
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.59184737 0.59180811 0.59176885 ... 1.57879856 1.57973542 1.58067227]
# the min tDCF_norm is: 0.006758258859099195
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.23
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.56599806 0.56596039 0.56592273 ... 1.57879605 1.57973416 1.58067227]
# the min tDCF_norm is: 0.004646302965630697
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.24
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.54071646 0.54068054 0.54064462 ... 1.57879683 1.57973455 1.58067227]
# the min tDCF_norm is: 0.005301009292605931
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.25
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.51512621 0.51509196 0.51505771 ... 1.5787961  1.57973418 1.58067227]
# the min tDCF_norm is: 0.004688542083500067
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.26
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.48992386 0.48989125 0.48985863 ... 1.57879509 1.57973368 1.58067227]
# the min tDCF_norm is: 0.0038437597261126674
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.27
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.47103179 0.47100066 0.47096953 ... 1.57879891 1.57973559 1.58067227]
# the min tDCF_norm is: 0.007053932684184784
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.28
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.45131684 0.45128715 0.45125745 ... 1.57880095 1.57973661 1.58067227]
# the min tDCF_norm is: 0.008764616957894267
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.29
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.42769225 0.42766414 0.42763604 ... 1.57880095 1.57973661 1.58067227]
# the min tDCF_norm is: 0.008764616957894267
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.3
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.4096316  0.40960493 0.40957826 ... 1.57880502 1.57973865 1.58067227]
# the min tDCF_norm is: 0.012185985505313237
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.31
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.39399542 0.39397004 0.39394465 ... 1.5788091  1.57974068 1.58067227]
# the min tDCF_norm is: 0.015607354052732206
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.32
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.37597197 0.3759479  0.37592384 ... 1.57881113 1.5797417  1.58067227]
# the min tDCF_norm is: 0.017318038326441687
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.33
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.36259112 0.36256819 0.36254525 ... 1.57881521 1.57974374 1.58067227]
# the min tDCF_norm is: 0.02073940687386066
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.34
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.35092096 0.35089915 0.35087735 ... 1.57882132 1.57974679 1.58067227]
# the min tDCF_norm is: 0.025871459694989107
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.35000000000000003
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.33840021 0.33837945 0.3383587  ... 1.57882514 1.5797487  1.58067227]
# the min tDCF_norm is: 0.029081632653061226
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.36
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.33565897 0.3356392  0.33561943 ... 1.57883939 1.57975583 1.58067227]
# the min tDCF_norm is: 0.04105642256902762
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.37
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.33699651 0.33697757 0.33695863 ... 1.57885569 1.57976398 1.58067227]
# the min tDCF_norm is: 0.05474189675870348
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.38
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.33213071 0.33211267 0.33209463 ... 1.57886587 1.57976907 1.58067227]
# the min tDCF_norm is: 0.0632953181272509
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.39
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.33375017 0.33373294 0.33371571 ... 1.57888216 1.57977721 1.58067227]
# the min tDCF_norm is: 0.07698079231692678
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.4
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.34909229 0.34907576 0.34905922 ... 1.57891271 1.57979249 1.58067227]
# the min tDCF_norm is: 0.10264105642256903
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.41000000000000003
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.36368225 0.36366634 0.36365044 ... 1.57894122 1.57980674 1.58067227]
# the min tDCF_norm is: 0.1265906362545018
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.42
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.37406148 0.37404625 0.37403102 ... 1.57896566 1.57981896 1.58067227]
# the min tDCF_norm is: 0.1471188475390156
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.43
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.38558755 0.38557304 0.38555854 ... 1.57899213 1.5798322  1.58067227]
# the min tDCF_norm is: 0.1693577430972389
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.44
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.40634365 0.40632981 0.40631598 ... 1.57902879 1.57985053 1.58067227]
# the min tDCF_norm is: 0.2001500600240096
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.45
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.43975113 0.43973793 0.43972472 ... 1.5790797  1.57987599 1.58067227]
# the min tDCF_norm is: 0.2429171668667467
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.46
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.46913622 0.4691238  0.46911137 ... 1.57912858 1.57990042 1.58067227]
# the min tDCF_norm is: 0.28397358943577433
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.47000000000000003
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.50421719 0.50420552 0.50419384 ... 1.57918357 1.57992792 1.58067227]
# the min tDCF_norm is: 0.3301620648259304
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.48
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.54164825 0.54163739 0.54162653 ... 1.57924263 1.57995745 1.58067227]
# the min tDCF_norm is: 0.3797719087635054
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.49
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: 0.5543830394744873
# the tDCF_norm is: [0.59943837 0.59942834 0.59941831 ... 1.57932612 1.5799992  1.58067227]
# the min tDCF_norm is: 0.44990996398559424
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
# ...
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.84
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: -0.8287973532676697
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.85
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: -0.8287973532676697
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.86
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: -0.8287973532676697
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.87
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: -0.8287973532676697
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.88
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: -0.8287973532676697
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.89
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: -0.8287973532676697
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.9
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: -0.8287973532676697
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.91
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: -0.8287973532676697
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.92
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: -0.8287973532676697
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.93
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: -0.8287973532676697
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.9400000000000001
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: -0.8287973532676697
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.9500000000000001
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: -0.8287973532676697
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.96
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: -0.8287973532676697
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.97
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: -0.8287973532676697
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.98
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: -0.8287973532676697
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.99
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: -0.8287973532676697
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=1680, Nspoof=14904] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  1.0
# the CM thresholds is:  [-0.82879735 -0.82779735 -0.82524735 ...  0.9487645   0.94895041
#   0.95111579]
# the CM threshold min is: -0.8287973532676697
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# tDCF - Minimum value: 0.0038437597261126674
# Index of minimum value: (26, 14904)
# The min asv score: 0.26
# The min CM thersholds: 0.5543830394744873

# %%
heatmap_norm_tdcf(list_tDCF_norm_female_dev,list_asv_score,list_CM_thresholds_female_dev, target_values = [-1,0,0,1],title ="Norm t-DCF - Female on Development Set",point_x_index = min_index[0] ,point_y_index  = min_index[1],point_x_constrained = point_x_constrained, point_y_constrained = point_y_constrained)

# %% [markdown]
# ## Eval:

# %%
from sklearn.metrics.pairwise import cosine_similarity
import torchaudio
import tqdm
from ASV_utils.config_thr import pmf_both_thr_gender_val ,pmf_both_thr_spoof_test_male,pmf_both_thr_spoof_test_female

txt_file_path = "output.txt"
csv_file_path = "output.csv"
enrollment_male = enrollment_eval_male
enrollment_female = enrollment_eval_female
list_files = list_eval_files
data_set = Eval_dataset_all
asv_model = classifier
list_speaker_id = list_speaker_id_eval
list_asv_label = list_asv_label_eval

results_eval = inference_system_cm_asv_avg_score(list_speaker_id,list_asv_label,txt_file_path,csv_file_path,pmf_both_thr_gender_val,pmf_both_thr_spoof_test_male,pmf_both_thr_spoof_test_female,enrollment_male, enrollment_female, list_files, data_set, gender_model, spoof_model_male, spoof_model_female, asv_model, device, verbose = False, verbose_txt = False,verbose_csv = False)
# Out:
# 100%|██████████| 71237/71237 [15:14:53<00:00,  1.30it/s]

# %%
'''
import pickle
with open('objects_asv_and_cm_time_embeddings_eval_avg_score_both_2.pkl', 'wb') as f:
    pickle.dump(results_eval,f)
'''

# %%
from ASV_utils.tdcf_functions import compute_t_dcf


import pickle
with open('objects_asv_and_cm_time_embeddings_eval_avg_score_both_2.pkl', 'rb') as f:
    results_eval = pickle.load(f)

# %% [markdown]
# ## Male - Eval:

# %% [markdown]
# ### with labels of gender:

# %%
bonafide_score_cm_male_eval = 1-results_eval.loc[(results_eval['spoof_ground_truth'] == 0) & (results_eval['its_male_ground_truth'] == 'male')]['spoof_score_male'].values
spoof_score_cm_male_eval = 1-results_eval.loc[(results_eval['spoof_ground_truth'] == 1)  & (results_eval['its_male_ground_truth'] == 'male')]['spoof_score_male'].values
Prior_spoof = 0.05
target_scores_male_eval = results_eval.loc[(results_eval['asv_label'] ==  "target") & (results_eval['its_male_ground_truth'] == 'male') ]["asv_score_male"].values
nontarget_scores_male_eval = results_eval.loc[(results_eval['asv_label'] == "nontarget") & (results_eval['its_male_ground_truth'] == 'male') ]["asv_score_male"].values
spoof_scores_male_eval = results_eval.loc[(results_eval['asv_label'] ==  "spoof") & (results_eval['its_male_ground_truth'] == 'male')]["asv_score_male"].values
list_asv_score = [0.326,0.378]
type = 'constrained'
list_tDCF_norm_male_eval ,list_CM_thresholds_male_eval,list_tDCF_male_eval  = compute_t_dcf(bonafide_score_cm_male_eval,spoof_score_cm_male_eval,Prior_spoof,target_scores_male_eval,nontarget_scores_male_eval,spoof_scores_male_eval,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  2.83868 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  0.326
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8740580230951309
# the tDCF_norm is: [1.         0.99994912 0.99989825 ... 2.83619322 2.83743662 2.83868002]
# the min tDCF_norm is: 0.21891790381246728
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  3.09869 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv evaluation set  0.378
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.871832400560379
# the tDCF_norm is: [1.         0.99994912 0.99989825 ... 3.09597965 3.09733694 3.09869423]
# the min tDCF_norm is: 0.22355291465777777

# %% [markdown]
# ### with pred of gender:

# %%
bonafide_score_cm_male_eval = results_eval.loc[(results_eval['spoof_ground_truth'] == 0) & (results_eval['its_male'] == True)]['spoof_score_male'].values
bonafide_score_cm_male_eval = 1-bonafide_score_cm_male_eval
spoof_score_cm_male_eval = results_eval.loc[(results_eval['spoof_ground_truth'] == 1)  & (results_eval['its_male'] == True)]['spoof_score_male'].values
spoof_score_cm_male_eval = 1-spoof_score_cm_male_eval
Prior_spoof = 0.05
target_scores_male_eval = results_eval.loc[(results_eval['asv_label'] ==  "target") & (results_eval['its_male'] == True) ]["asv_score_male"].values
nontarget_scores_male_eval = results_eval.loc[(results_eval['asv_label'] == "nontarget") & (results_eval['its_male'] == True) ]["asv_score_male"].values
spoof_scores_male_eval = results_eval.loc[(results_eval['asv_label'] ==  "spoof") & (results_eval['its_male'] == True)]["asv_score_male"].values
list_asv_score = [0.326,0.378]
type = 'constrained'
list_tDCF_norm_male_eval ,list_CM_thresholds_male_eval,list_tDCF_male_eval  = compute_t_dcf(bonafide_score_cm_male_eval,spoof_score_cm_male_eval,Prior_spoof,target_scores_male_eval,nontarget_scores_male_eval,spoof_scores_male_eval,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=2288, Nspoof=20331] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  2.94244 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  0.326
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8740580230951309
# the tDCF_norm is: [1.         0.99995081 0.99990163 ... 2.93987006 2.94115609 2.94244212]
# the min tDCF_norm is: 0.22579956394381837
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=2288, Nspoof=20331] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  3.21123 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv evaluation set  0.378
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.871832400560379
# the tDCF_norm is: [1.         0.99995081 0.99990163 ... 3.20842714 3.20983065 3.21123416]
# the min tDCF_norm is: 0.23117729538360526

# %%
bonafide_score_cm_male_eval = results_eval.loc[(results_eval['spoof_ground_truth'] == 0) & (results_eval['its_male'] == True)]['spoof_score_male'].values
bonafide_score_cm_male_eval = 1-bonafide_score_cm_male_eval
spoof_score_cm_male_eval = results_eval.loc[(results_eval['spoof_ground_truth'] == 1)  & (results_eval['its_male'] == True)]['spoof_score_male'].values
spoof_score_cm_male_eval = 1-spoof_score_cm_male_eval
Prior_spoof = 0.05
target_scores_male_eval = results_eval.loc[(results_eval['asv_label'] ==  "target") & (results_eval['its_male'] == True) ]["asv_score_male"].values
nontarget_scores_male_eval = results_eval.loc[(results_eval['asv_label'] == "nontarget") & (results_eval['its_male'] == True) ]["asv_score_male"].values
spoof_scores_male_eval = results_eval.loc[(results_eval['asv_label'] ==  "spoof") & (results_eval['its_male'] == True)]["asv_score_male"].values
list_asv_score = [0.326,0.378]
type = 'constrained_ver2'
list_tDCF_norm_male_eval ,list_CM_thresholds_male_eval,list_tDCF_male_eval  = compute_t_dcf(bonafide_score_cm_male_eval,spoof_score_cm_male_eval,Prior_spoof,target_scores_male_eval,nontarget_scores_male_eval,spoof_scores_male_eval,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained_ver2
# t-DCF evaluation from [Nbona=2288, Nspoof=20331] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv development set  0.326
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8740580230951309
# the tDCF_norm is: [1.         0.99995307 0.99990614 ... 2.85090544 2.85213249 2.85335954]
# the min tDCF_norm is: 0.2613052667182561
# The t-DCF evaluation type is: constrained_ver2
# t-DCF evaluation from [Nbona=2288, Nspoof=20331] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv evaluation set  0.378
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.871832400560379
# the tDCF_norm is: [1.         0.99995678 0.99991356 ... 2.94046378 2.94169699 2.9429302 ]
# the min tDCF_norm is: 0.3244637397957241

# %%
bonafide_score_cm_male_eval = 1-results_eval.loc[(results_eval['spoof_ground_truth'] == 0) & (results_eval['its_male_ground_truth'] == 'male')]['spoof_score_male'].values
spoof_score_cm_male_eval = 1-results_eval.loc[(results_eval['spoof_ground_truth'] == 1)  & (results_eval['its_male_ground_truth'] == 'male')]['spoof_score_male'].values
Prior_spoof = 0.05
target_scores_male_eval = results_eval.loc[(results_eval['asv_label'] ==  "target") & (results_eval['its_male_ground_truth'] == 'male') ]["asv_score_male"].values
nontarget_scores_male_eval = results_eval.loc[(results_eval['asv_label'] == "nontarget") & (results_eval['its_male_ground_truth'] == 'male') ]["asv_score_male"].values
spoof_scores_male_eval = results_eval.loc[(results_eval['asv_label'] ==  "spoof") & (results_eval['its_male_ground_truth'] == 'male')]["asv_score_male"].values
list_asv_score = np.arange(0, 1.01, 0.01)
type = 'unconstrained'

point_y_constrained = np.argmin(list_tDCF_norm_male_eval[1])
point_x_constrained = (np.abs(np.array(list_asv_score)-[0.378])).argmin()

list_tDCF_norm_male_eval ,list_CM_thresholds_male_eval,list_tDCF_male_eval = compute_t_dcf(bonafide_score_cm_male_eval,spoof_score_cm_male_eval,Prior_spoof,target_scores_male_eval,nontarget_scores_male_eval,spoof_scores_male_eval,list_asv_score,type)

tDCF_norm_male_eval = np.array(list_tDCF_norm_male_eval)

CM_thresholds_male_eval = np.array(list_CM_thresholds_male_eval)

min_index = np.unravel_index(np.nanargmin(tDCF_norm_male_eval), tDCF_norm_male_eval.shape)

# Print the results
print("tDCF - Minimum value:", tDCF_norm_male_eval[min_index])
print("Index of minimum value:", min_index)
print("The min asv score:", list_asv_score[min_index[0]])
print("The min CM thersholds:",CM_thresholds_male_eval[min_index])
# Out:
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv development set  0.0
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8921448811888695
# the tDCF_norm is: [0.96230458 0.96226218 0.96221978 ... 1.57940042 1.58003634 1.58067227]
# the min tDCF_norm is: 0.29247507502633413
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv evaluation set  0.01
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8921448811888695
# the tDCF_norm is: [0.95512496 0.95508266 0.95504037 ... 1.579396   1.58003413 1.58067227]
# the min tDCF_norm is: 0.2872245758402437
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.02
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8921448811888695
# the tDCF_norm is: [0.94635906 0.94631692 0.94627479 ... 1.57939109 1.58003168 1.58067227]
# the min tDCF_norm is: 0.2812689729108276
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.03
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8921448811888695
# the tDCF_norm is: [0.93815783 0.93811588 0.93807394 ... 1.57938716 1.58002972 1.58067227]
# the min tDCF_norm is: 0.27632103828291665
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.04
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8921448811888695
# the tDCF_norm is: [0.92656139 0.9265197  0.926478   ... 1.57938128 1.58002677 1.58067227]
# the min tDCF_norm is: 0.26900801989113066
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.05
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8921448811888695
# the tDCF_norm is: [0.91283864 0.91279728 0.91275592 ... 1.57937506 1.58002366 1.58067227]
# the min tDCF_norm is: 0.261059957261248
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.06
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8921448811888695
# the tDCF_norm is: [0.90215779 0.90211674 0.9020757  ... 1.57937113 1.5800217  1.58067227]
# the min tDCF_norm is: 0.2557292804572963
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.07
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8921448811888695
# the tDCF_norm is: [0.88749004 0.88744935 0.88740867 ... 1.57936442 1.58001835 1.58067227]
# the min tDCF_norm is: 0.2471750991296157
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.08
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8921448811888695
# the tDCF_norm is: [0.8706262  0.87058597 0.87054575 ... 1.57935755 1.58001491 1.58067227]
# the min tDCF_norm is: 0.23812852210245433
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.09
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8902715221047401
# the tDCF_norm is: [0.85342034 0.85338059 0.85334084 ... 1.57935068 1.58001148 1.58067227]
# the min tDCF_norm is: 0.22901933777059597
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.1
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8902715221047401
# the tDCF_norm is: [0.83492063 0.83488145 0.83484226 ... 1.57934414 1.5800082  1.58067227]
# the min tDCF_norm is: 0.22000203089722997
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.11
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8902715221047401
# the tDCF_norm is: [0.81740867 0.81737002 0.81733137 ... 1.57933809 1.58000518 1.58067227]
# the min tDCF_norm is: 0.21159865025934396
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.12
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8902715221047401
# the tDCF_norm is: [0.79871538 0.79867734 0.7986393  ... 1.5793322  1.58000223 1.58067227]
# the min tDCF_norm is: 0.20316421085565936
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.13
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8902715221047401
# the tDCF_norm is: [0.77848541 0.77844798 0.77841055 ... 1.579325   1.57999863 1.58067227]
# the min tDCF_norm is: 0.1932638514750705
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.14
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8902715221047401
# the tDCF_norm is: [0.76248756 0.76245071 0.76241385 ... 1.57932091 1.57999659 1.58067227]
# the min tDCF_norm is: 0.18693594139821826
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.15
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8902715221047401
# the tDCF_norm is: [0.74617026 0.74613396 0.74609767 ... 1.57931617 1.57999422 1.58067227]
# the min tDCF_norm is: 0.17994511450834022
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.16
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8902715221047401
# the tDCF_norm is: [0.730852   0.73081621 0.73078043 ... 1.57931158 1.57999193 1.58067227]
# the min tDCF_norm is: 0.17326343856187737
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.17
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8902715221047401
# the tDCF_norm is: [0.71329489 0.71325972 0.71322455 ... 1.57930684 1.57998955 1.58067227]
# the min tDCF_norm is: 0.16607915909225038
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.18
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8740580230951309
# the tDCF_norm is: [0.69797423 0.69793965 0.69790508 ... 1.57930357 1.57998792 1.58067227]
# the min tDCF_norm is: 0.16050240425020507
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.19
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8740580230951309
# the tDCF_norm is: [0.68502067 0.68498658 0.68495248 ... 1.57930046 1.57998636 1.58067227]
# the min tDCF_norm is: 0.15543849661235118
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.2
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8740580230951309
# the tDCF_norm is: [0.67304358 0.67300995 0.67297633 ... 1.57929817 1.57998522 1.58067227]
# the min tDCF_norm is: 0.1512987072449159
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.21
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8740580230951309
# the tDCF_norm is: [0.66193725 0.66190407 0.66187089 ... 1.57929604 1.57998416 1.58067227]
# the min tDCF_norm is: 0.14745718130826255
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.22
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8740580230951309
# the tDCF_norm is: [0.65039212 0.65035942 0.65032672 ... 1.57929424 1.57998326 1.58067227]
# the min tDCF_norm is: 0.14384601586534965
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.23
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8740580230951309
# the tDCF_norm is: [0.64132642 0.64129416 0.6412619  ... 1.5792939  1.57998309 1.58067227]
# the min tDCF_norm is: 0.1420084629555579
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.24
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8740580230951309
# the tDCF_norm is: [0.63182655 0.63179472 0.63176289 ... 1.57929292 1.5799826  1.58067227]
# the min tDCF_norm is: 0.13950090910062413
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.25
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8740580230951309
# the tDCF_norm is: [0.6220387  0.6220073  0.62197589 ... 1.57929161 1.57998194 1.58067227]
# the min tDCF_norm is: 0.13664093929600873
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.26
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8740580230951309
# the tDCF_norm is: [0.61300911 0.6129781  0.6129471  ... 1.57929063 1.57998145 1.58067227]
# the min tDCF_norm is: 0.13421236250080157
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.27
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8740580230951309
# the tDCF_norm is: [0.60497391 0.60494332 0.60491273 ... 1.57929078 1.57998153 1.58067227]
# the min tDCF_norm is: 0.13300394977336616
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.28
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8740580230951309
# the tDCF_norm is: [0.59741806 0.59738784 0.59735761 ... 1.57929046 1.57998136 1.58067227]
# the min tDCF_norm is: 0.13143097926427305
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.29
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8740580230951309
# the tDCF_norm is: [0.59104535 0.5910156  0.59098585 ... 1.57929304 1.57998265 1.58067227]
# the min tDCF_norm is: 0.13276012558749523
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.3
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8740580230951309
# the tDCF_norm is: [0.58199983 0.58197056 0.58194129 ... 1.57929335 1.57998281 1.58067227]
# the min tDCF_norm is: 0.13153406805193524
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.31
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8740580230951309
# the tDCF_norm is: [0.57362041 0.57359156 0.57356272 ... 1.57929335 1.57998281 1.58067227]
# the min tDCF_norm is: 0.13012684044226083
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.32
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8740580230951309
# the tDCF_norm is: [0.56795856 0.56793022 0.56790189 ... 1.57929723 1.57998475 1.58067227]
# the min tDCF_norm is: 0.13278056148107134
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.33
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8740580230951309
# the tDCF_norm is: [0.56268147 0.56265363 0.5626258  ... 1.57930111 1.57998669 1.58067227]
# the min tDCF_norm is: 0.13549890011420362
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.34
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8740580230951309
# the tDCF_norm is: [0.55497216 0.55494488 0.55491761 ... 1.57930402 1.57998815 1.58067227]
# the min tDCF_norm is: 0.13690763254441546
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.35000000000000003
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8740580230951309
# the tDCF_norm is: [0.54972854 0.54970187 0.5496752  ... 1.57930984 1.57999105 1.58067227]
# the min tDCF_norm is: 0.14143387378801517
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.36
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8740580230951309
# the tDCF_norm is: [0.54853245 0.54850635 0.54848025 ... 1.57931857 1.57999542 1.58067227]
# the min tDCF_norm is: 0.1493432739549923
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.37
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.871832400560379
# the tDCF_norm is: [0.54499428 0.54496875 0.54494322 ... 1.57932535 1.57999881 1.58067227]
# the min tDCF_norm is: 0.1550473980414404
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.38
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.871832400560379
# the tDCF_norm is: [0.54668677 0.54666188 0.546637   ... 1.57933796 1.58000511 1.58067227]
# the min tDCF_norm is: 0.16703597335730516
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.39
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.871832400560379
# the tDCF_norm is: [0.54369509 0.54367086 0.54364664 ... 1.57934669 1.58000948 1.58067227]
# the min tDCF_norm is: 0.1746310536162388
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.4
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.871832400560379
# the tDCF_norm is: [0.5350787  0.53505519 0.53503169 ... 1.57935154 1.5800119  1.58067227]
# the min tDCF_norm is: 0.1776734405887894
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.41000000000000003
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.871832400560379
# the tDCF_norm is: [0.5340778  0.53405508 0.53403235 ... 1.57936414 1.58001821 1.58067227]
# the min tDCF_norm is: 0.18920613006576892
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.42
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.871832400560379
# the tDCF_norm is: [0.5301744  0.53015255 0.5301307  ... 1.57937578 1.58002402 1.58067227]
# the min tDCF_norm is: 0.19934737631066093
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.43
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.871832400560379
# the tDCF_norm is: [0.53104067 0.53101968 0.53099868 ... 1.57939129 1.58003178 1.58067227]
# the min tDCF_norm is: 0.2138965901787979
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.44
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.871832400560379
# the tDCF_norm is: [0.53403062 0.53401054 0.53399047 ... 1.57940972 1.58004099 1.58067227]
# the min tDCF_norm is: 0.23150574613703365
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.45
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.871832400560379
# the tDCF_norm is: [0.54144822 0.54142906 0.54140991 ... 1.57943202 1.58005215 1.58067227]
# the min tDCF_norm is: 0.2534649794532591
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.46
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.871832400560379
# the tDCF_norm is: [0.55626755 0.55624939 0.55623123 ... 1.57946208 1.58006718 1.58067227]
# the min tDCF_norm is: 0.2838783338581289
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.47000000000000003
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.840503916144371
# the tDCF_norm is: [0.56423165 0.56421449 0.56419733 ... 1.57948632 1.5800793  1.58067227]
# the min tDCF_norm is: 0.3076850128673426
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.48
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.8236037045717239
# the tDCF_norm is: [0.57708439 0.57706832 0.57705225 ... 1.57951639 1.58009433 1.58067227]
# the min tDCF_norm is: 0.3374028631655213
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
# ...
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.0003273954391479492
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.85
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.0003273954391479492
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.86
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.0003273954391479492
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.87
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.0003273954391479492
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.88
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.0003273954391479492
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.89
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.0003273954391479492
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.9
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.0003273954391479492
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.91
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.0003273954391479492
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.92
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.0003273954391479492
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.93
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.0003273954391479492
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.9400000000000001
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.0003273954391479492
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.9500000000000001
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.0003273954391479492
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.96
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.0003273954391479492
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.97
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.0003273954391479492
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.98
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.0003273954391479492
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.99
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.0003273954391479492
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2283, Nspoof=19656] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  1.0
# the CM thresholds is:  [3.27395439e-04 1.32739544e-03 1.33728981e-03 ... 9.96948715e-01
#  9.97036990e-01 9.97085323e-01]
# the CM threshold min is: 0.0003273954391479492
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# tDCF - Minimum value: 0.13012684044226083
# Index of minimum value: (31, 16396)
# The min asv score: 0.31
# The min CM thersholds: 0.8740580230951309

# %%
heatmap_norm_tdcf(list_tDCF_norm_male_eval,list_asv_score,list_CM_thresholds_male_eval, target_values = [0,0.5,1],title ="Norm t-DCF - Male on Evaluation Set",point_x_index=min_index[0], point_y_index=min_index[1],point_x_constrained=point_x_constrained,point_y_constrained=point_y_constrained)

# %%
# thr from validation set
list_asv_score = [0.326,0.378]
CM_thr = pmf_both_thr_spoof_test_male
ASV_thr = list_asv_score[0]
spoof_score_cm_male_eval = results_eval.loc[(results_eval['its_male'] == True)]['spoof_score_male']
think_is_geninue = spoof_score_cm_male_eval.loc[spoof_score_cm_male_eval<CM_thr] 
print(results_eval.loc[think_is_geninue.index]['asv_label'].value_counts())

to_asv = results_eval.loc[(think_is_geninue.index)]
print(to_asv.loc[to_asv['asv_score_male']>ASV_thr]['asv_label'].value_counts())
print("--------------------------------------------------")
## all the files inside the system cm -> inside -> asv
indexes = []
path_name = pd.Series(np.concatenate(Eval_dataset_all.name.values)) 
for file in results_eval.loc[think_is_geninue.index]['file_name'].values:
    index = path_name.str.contains(file)
    indexes.append(index.loc[index==True].index[0])
print(Eval_dataset_all.attack_logical[indexes].value_counts())
print("--------------------------------------------------")
## all the files inside the system cm -> asv -> inside
indexes = []
path_name = pd.Series(np.concatenate(Eval_dataset_all.name.values)) 
for file in to_asv.loc[to_asv['asv_score_male']>ASV_thr]['file_name'].values:
    index = path_name.str.contains(file)
    indexes.append(index.loc[index==True].index[0])
print(Eval_dataset_all.attack_logical[indexes].value_counts())
print("--------------------------------------------------")
# Out:
# asv_label
# spoof        1836
# target       1290
# nontarget     784
# Name: count, dtype: int64
# asv_label
# target    1272
# spoof      273
# Name: count, dtype: int64
# --------------------------------------------------
# [none]    2074
# [A17]      889
# [A18]      694
# [A15]      163
# [A10]       32
# [A11]       29
# [A14]       22
# [A09]        7
# Name: count, dtype: int64
# --------------------------------------------------
# [none]    1272
# [A15]      145
# [A18]       52
# [A10]       30
# [A11]       28
# [A14]       17
# [A17]        1
# Name: count, dtype: int64
# --------------------------------------------------

# %%
# thr from test set
CM_thr = pmf_both_thr_spoof_test_male
ASV_thr = list_asv_score[1]
spoof_score_cm_male_eval = results_eval.loc[(results_eval['its_male'] == True)]['spoof_score_male']
think_is_geninue = spoof_score_cm_male_eval.loc[spoof_score_cm_male_eval<CM_thr] 
print(results_eval.loc[think_is_geninue.index]['asv_label'].value_counts())

to_asv = results_eval.loc[(think_is_geninue.index)]
print(to_asv.loc[to_asv['asv_score_male']>ASV_thr]['asv_label'].value_counts())
print("--------------------------------------------------")
## all the files inside the system cm -> inside -> asv
indexes = []
path_name = pd.Series(np.concatenate(Eval_dataset_all.name.values)) 
for file in results_eval.loc[think_is_geninue.index]['file_name'].values:
    index = path_name.str.contains(file)
    indexes.append(index.loc[index==True].index[0])
print(Eval_dataset_all.attack_logical[indexes].value_counts())
print("--------------------------------------------------")
## all the files inside the system cm -> asv -> inside
indexes = []
path_name = pd.Series(np.concatenate(Eval_dataset_all.name.values)) 
for file in to_asv.loc[to_asv['asv_score_male']>ASV_thr]['file_name'].values:
    index = path_name.str.contains(file)
    indexes.append(index.loc[index==True].index[0])
print(Eval_dataset_all.attack_logical[indexes].value_counts())
print("--------------------------------------------------")
# Out:
# asv_label
# spoof        1836
# target       1290
# nontarget     784
# Name: count, dtype: int64
# asv_label
# target    1242
# spoof      210
# Name: count, dtype: int64
# --------------------------------------------------
# [none]    2074
# [A17]      889
# [A18]      694
# [A15]      163
# [A10]       32
# [A11]       29
# [A14]       22
# [A09]        7
# Name: count, dtype: int64
# --------------------------------------------------
# [none]    1242
# [A15]      122
# [A10]       29
# [A11]       24
# [A18]       21
# [A14]       14
# Name: count, dtype: int64
# --------------------------------------------------

# %%
list_asv_score = np.arange(0, 1.01, 0.01)
CM_thr = 1-CM_thresholds_male_eval[min_index]
ASV_thr = list_asv_score[min_index[0]]
spoof_score_cm_male_eval = results_eval.loc[(results_eval['its_male'] == True)]['spoof_score_male']
think_is_geninue = spoof_score_cm_male_eval.loc[spoof_score_cm_male_eval<CM_thr] 
print(results_eval.loc[think_is_geninue.index]['asv_label'].value_counts())

to_asv = results_eval.loc[(think_is_geninue.index)]
print(to_asv.loc[to_asv['asv_score_male']>ASV_thr]['asv_label'].value_counts())
print("--------------------------------------------------")
## all the files inside the system cm -> inside -> asv
indexes = []
path_name = pd.Series(np.concatenate(Eval_dataset_all.name.values)) 
for file in results_eval.loc[think_is_geninue.index]['file_name'].values:
    index = path_name.str.contains(file)
    indexes.append(index.loc[index==True].index[0])
print(Eval_dataset_all.attack_logical[indexes].value_counts())
print("--------------------------------------------------")
## all the files inside the system cm -> asv -> inside
indexes = []
path_name = pd.Series(np.concatenate(Eval_dataset_all.name.values)) 
for file in to_asv.loc[to_asv['asv_score_male']>ASV_thr]['file_name'].values:
    index = path_name.str.contains(file)
    indexes.append(index.loc[index==True].index[0])
print(Eval_dataset_all.attack_logical[indexes].value_counts())
print("--------------------------------------------------")
# Out:
# asv_label
# spoof        3388
# target       1401
# nontarget     841
# Name: count, dtype: int64
# asv_label
# target    1391
# spoof     1034
# Name: count, dtype: int64
# --------------------------------------------------
# [none]    2242
# [A18]     1236
# [A17]     1140
# [A15]      447
# [A10]      195
# [A11]      168
# [A14]      132
# [A09]       51
# [A12]       14
# [A19]        3
# [A13]        2
# Name: count, dtype: int64
# --------------------------------------------------
# [none]    1391
# [A15]      420
# [A10]      191
# [A11]      165
# [A18]      125
# [A14]      119
# [A12]       10
# [A13]        2
# [A17]        1
# [A09]        1
# Name: count, dtype: int64
# --------------------------------------------------

# %% [markdown]
# ## Female - Eval:

# %% [markdown]
# ### with labels of gender:

# %%
bonafide_score_cm_female_eval = results_eval.loc[(results_eval['spoof_ground_truth'] == 0) & (results_eval['its_male_ground_truth'] == 'female')]['spoof_score_female'].values
bonafide_score_cm_female_eval = -1*bonafide_score_cm_female_eval

spoof_score_cm_female_eval = results_eval.loc[(results_eval['spoof_ground_truth'] == 1)  & (results_eval['its_male_ground_truth'] == 'female')]['spoof_score_female'].values
spoof_score_cm_female_eval  = -1*spoof_score_cm_female_eval

Prior_spoof = 0.05

target_scores_female_eval = results_eval.loc[(results_eval['asv_label'] ==  "target") & (results_eval['its_male_ground_truth'] == 'female') ]["asv_score_female"].values
nontarget_scores_female_eval = results_eval.loc[(results_eval['asv_label'] == "nontarget") & (results_eval['its_male_ground_truth'] == 'female') ]["asv_score_female"].values
spoof_scores_female_eval = results_eval.loc[(results_eval['asv_label'] ==  "spoof") & (results_eval['its_male_ground_truth'] == 'female')]["asv_score_female"].values

list_asv_score = [0.432,0.417]
type = 'constrained'
list_tDCF_norm_female_eval ,list_CM_thresholds_female_eval,list_tDCF_female_eval  = compute_t_dcf(bonafide_score_cm_female_eval,spoof_score_cm_female_eval,Prior_spoof,target_scores_female_eval,nontarget_scores_female_eval,spoof_scores_female_eval,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=5072, Nspoof=44226] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  4.21751 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  0.432
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7031137347221375
# the tDCF_norm is: [1.         0.99997739 0.99995478 ... 4.21584845 4.21667998 4.2175115 ]
# the min tDCF_norm is: 0.3106276641239822
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=5072, Nspoof=44226] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  4.03723 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv evaluation set  0.417
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7075192332267761
# the tDCF_norm is: [1.         0.99997739 0.99995478 ... 4.03563475 4.03643073 4.03722672]
# the min tDCF_norm is: 0.3066017461815798

# %% [markdown]
# ### with pred of gender:

# %%
bonafide_score_cm_female_eval = results_eval.loc[(results_eval['spoof_ground_truth'] == 0) & (results_eval['its_male'] == False)]['spoof_score_female'].values
bonafide_score_cm_female_eval = -1*bonafide_score_cm_female_eval

spoof_score_cm_female_eval = results_eval.loc[(results_eval['spoof_ground_truth'] == 1)  & (results_eval['its_male'] == False)]['spoof_score_female'].values
spoof_score_cm_female_eval  = -1*spoof_score_cm_female_eval

Prior_spoof = 0.05

target_scores_female_eval = results_eval.loc[(results_eval['asv_label'] ==  "target") & (results_eval['its_male'] == False) ]["asv_score_female"].values
nontarget_scores_female_eval = results_eval.loc[(results_eval['asv_label'] == "nontarget") & (results_eval['its_male'] == False) ]["asv_score_female"].values
spoof_scores_female_eval = results_eval.loc[(results_eval['asv_label'] ==  "spoof") & (results_eval['its_male'] == False)]["asv_score_female"].values

list_asv_score = [0.432,0.417]
type = 'constrained'
list_tDCF_norm_female_eval ,list_CM_thresholds_female_eval,list_tDCF_female_eval  = compute_t_dcf(bonafide_score_cm_female_eval,spoof_score_cm_female_eval,Prior_spoof,target_scores_female_eval,nontarget_scores_female_eval,spoof_scores_female_eval,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  4.18963 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  0.432
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.697165846824646
# the tDCF_norm is: [1.         0.99997704 0.99995408 ... 4.18797219 4.18879903 4.18962588]
# the min tDCF_norm is: 0.31225607284566875
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  4.01401 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv evaluation set  0.417
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.700048565864563
# the tDCF_norm is: [1.         0.99997704 0.99995408 ... 4.01242656 4.01321875 4.01401094]
# the min tDCF_norm is: 0.3085017321280177

# %%
bonafide_score_cm_female_eval = results_eval.loc[(results_eval['spoof_ground_truth'] == 0) & (results_eval['its_male'] == False)]['spoof_score_female'].values
bonafide_score_cm_female_eval = -1*bonafide_score_cm_female_eval

spoof_score_cm_female_eval = results_eval.loc[(results_eval['spoof_ground_truth'] == 1)  & (results_eval['its_male'] == False)]['spoof_score_female'].values
spoof_score_cm_female_eval  = -1*spoof_score_cm_female_eval

Prior_spoof = 0.05

target_scores_female_eval = results_eval.loc[(results_eval['asv_label'] ==  "target") & (results_eval['its_male'] == False) ]["asv_score_female"].values
nontarget_scores_female_eval = results_eval.loc[(results_eval['asv_label'] == "nontarget") & (results_eval['its_male'] == False) ]["asv_score_female"].values
spoof_scores_female_eval = results_eval.loc[(results_eval['asv_label'] ==  "spoof") & (results_eval['its_male'] == False)]["asv_score_female"].values

list_asv_score = [0.432,0.417]
type = 'constrained_ver2'
list_tDCF_norm_female_eval ,list_CM_thresholds_female_eval,list_tDCF_female_eval  = compute_t_dcf(bonafide_score_cm_female_eval,spoof_score_cm_female_eval,Prior_spoof,target_scores_female_eval,nontarget_scores_female_eval,spoof_scores_female_eval,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained_ver2
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv development set  0.432
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.697165846824646
# the tDCF_norm is: [1.         0.999986   0.99997201 ... 2.94325837 2.94376238 2.94426639]
# the min tDCF_norm is: 0.5807792350079624
# The t-DCF evaluation type is: constrained_ver2
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv evaluation set  0.417
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.700048565864563
# the tDCF_norm is: [1.         0.99998416 0.99996832 ... 3.07820417 3.07875069 3.0792972 ]
# the min tDCF_norm is: 0.5229511635786536

# %%
bonafide_score_cm_female_eval = results_eval.loc[(results_eval['spoof_ground_truth'] == 0) & (results_eval['its_male'] == False)]['spoof_score_female'].values
bonafide_score_cm_female_eval = -1*bonafide_score_cm_female_eval

spoof_score_cm_female_eval = results_eval.loc[(results_eval['spoof_ground_truth'] == 1)  & (results_eval['its_male'] == False)]['spoof_score_female'].values
spoof_score_cm_female_eval  = -1*spoof_score_cm_female_eval

Prior_spoof = 0.05

target_scores_female_eval = results_eval.loc[(results_eval['asv_label'] ==  "target") & (results_eval['its_male'] == False) ]["asv_score_female"].values
nontarget_scores_female_eval = results_eval.loc[(results_eval['asv_label'] == "nontarget") & (results_eval['its_male'] == False) ]["asv_score_female"].values
spoof_scores_female_eval = results_eval.loc[(results_eval['asv_label'] ==  "spoof") & (results_eval['its_male'] == False)]["asv_score_female"].values

list_asv_score = np.arange(0, 1.01, 0.01)
type = 'unconstrained'

point_y_constrained = np.argmin(list_tDCF_norm_female_eval[1])
point_x_constrained = (np.abs(np.array(list_asv_score)-[0.417])).argmin()

list_tDCF_norm_female_eval ,list_CM_thresholds_female_eval,list_tDCF_female_eval  = compute_t_dcf(bonafide_score_cm_female_eval,spoof_score_cm_female_eval,Prior_spoof,target_scores_female_eval,nontarget_scores_female_eval,spoof_scores_female_eval,list_asv_score,type)


tDCF_norm_female_eval = np.array(list_tDCF_norm_female_eval)

CM_thresholds_female_eval = np.array(list_CM_thresholds_female_eval)

min_index = np.unravel_index(np.nanargmin(tDCF_norm_female_eval), tDCF_norm_female_eval.shape)

# Print the results
print("tDCF - Minimum value:", tDCF_norm_female_eval[min_index])
print("Index of minimum value:", min_index)
print("The min asv score:", list_asv_score[min_index[0]])
print("The min CM thersholds:",CM_thresholds_female_eval[min_index])
# Out:
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv development set  0.0
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7781609296798706
# the tDCF_norm is: [0.98035378 0.98033469 0.9803156  ... 1.58010719 1.58038973 1.58067227]
# the min tDCF_norm is: 0.3481804636911179
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv evaluation set  0.01
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7781609296798706
# the tDCF_norm is: [0.97175538 0.97173645 0.97171753 ... 1.58010658 1.58038942 1.58067227]
# the min tDCF_norm is: 0.34565622675170843
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.02
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7781609296798706
# the tDCF_norm is: [0.96573437 0.96571553 0.96569668 ... 1.58010557 1.58038892 1.58067227]
# the min tDCF_norm is: 0.34272417669473004
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.03
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7781609296798706
# the tDCF_norm is: [0.95942393 0.95940517 0.95938641 ... 1.58010457 1.58038842 1.58067227]
# the min tDCF_norm is: 0.33974896209050265
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.04
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7781609296798706
# the tDCF_norm is: [0.95109339 0.95107473 0.95105607 ... 1.58010295 1.58038761 1.58067227]
# the min tDCF_norm is: 0.33522941585568317
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.05
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7781609296798706
# the tDCF_norm is: [0.94333552 0.94331696 0.94329839 ... 1.5801016  1.58038694 1.58067227]
# the min tDCF_norm is: 0.3313603026904777
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.06
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7781609296798706
# the tDCF_norm is: [0.93254137 0.93252294 0.93250452 ... 1.58009971 1.58038599 1.58067227]
# the min tDCF_norm is: 0.32590831501068346
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.07
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7781609296798706
# the tDCF_norm is: [0.92047978 0.92046149 0.92044321 ... 1.58009736 1.58038481 1.58067227]
# the min tDCF_norm is: 0.31936326143551086
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.08
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7781609296798706
# the tDCF_norm is: [0.90818907 0.90817093 0.90815279 ... 1.58009506 1.58038366 1.58067227]
# the min tDCF_norm is: 0.3128784012798019
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.09
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7781609296798706
# the tDCF_norm is: [0.89535607 0.89533812 0.89532018 ... 1.58009322 1.58038274 1.58067227]
# the min tDCF_norm is: 0.30723535598239743
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.1
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7781609296798706
# the tDCF_norm is: [0.88212016 0.8821024  0.88208464 ... 1.58009125 1.58038176 1.58067227]
# the min tDCF_norm is: 0.30128756746374086
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.11
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7781609296798706
# the tDCF_norm is: [0.86562655 0.86560899 0.86559144 ... 1.58008829 1.58038028 1.58067227]
# the min tDCF_norm is: 0.2928384776975673
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.12
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7781609296798706
# the tDCF_norm is: [0.84925546 0.84923813 0.8492208  ... 1.58008572 1.58037899 1.58067227]
# the min tDCF_norm is: 0.28519870142464254
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.13
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7704252600669861
# the tDCF_norm is: [0.8312375  0.83122041 0.83120333 ... 1.58008276 1.58037751 1.58067227]
# the min tDCF_norm is: 0.27644902420157247
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.14
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7704252600669861
# the tDCF_norm is: [0.81277561 0.81275876 0.81274192 ... 1.58007963 1.58037595 1.58067227]
# the min tDCF_norm is: 0.2672479232941152
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.15
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7704252600669861
# the tDCF_norm is: [0.79326515 0.79324856 0.79323197 ... 1.58007628 1.58037427 1.58067227]
# the min tDCF_norm is: 0.2574321083912632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.16
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7704252600669861
# the tDCF_norm is: [0.77451424 0.77449793 0.77448161 ... 1.58007365 1.58037296 1.58067227]
# the min tDCF_norm is: 0.24919738868059965
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.17
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7316397428512573
# the tDCF_norm is: [0.75371071 0.75369466 0.75367861 ... 1.58006996 1.58037112 1.58067227]
# the min tDCF_norm is: 0.23819979939044256
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.18
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7316397428512573
# the tDCF_norm is: [0.73453111 0.73451533 0.73449956 ... 1.58006716 1.58036972 1.58067227]
# the min tDCF_norm is: 0.22898556745987
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.19
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7316397428512573
# the tDCF_norm is: [0.71767818 0.71766269 0.71764719 ... 1.58006526 1.58036877 1.58067227]
# the min tDCF_norm is: 0.22199463986122883
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.2
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7316397428512573
# the tDCF_norm is: [0.70188935 0.70187413 0.70185892 ... 1.58006391 1.58036809 1.58067227]
# the min tDCF_norm is: 0.21628837681183782
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.21
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7316397428512573
# the tDCF_norm is: [0.68690836 0.6868934  0.68687844 ... 1.58006235 1.58036731 1.58067227]
# the min tDCF_norm is: 0.21031783628634468
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.22
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7316397428512573
# the tDCF_norm is: [0.67134837 0.67133366 0.67131896 ... 1.58006062 1.58036644 1.58067227]
# the min tDCF_norm is: 0.20390619053243358
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.23
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7316397428512573
# the tDCF_norm is: [0.65595826 0.65594382 0.65592939 ... 1.58005921 1.58036574 1.58067227]
# the min tDCF_norm is: 0.19816741716997274
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.24
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7316397428512573
# the tDCF_norm is: [0.64149096 0.64147683 0.6414627  ... 1.58005863 1.58036545 1.58067227]
# the min tDCF_norm is: 0.1942343722238941
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.25
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7316397428512573
# the tDCF_norm is: [0.62711987 0.62710601 0.62709216 ... 1.58005772 1.58036499 1.58067227]
# the min tDCF_norm is: 0.1896618595253115
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.26
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7075192332267761
# the tDCF_norm is: [0.61201732 0.61200377 0.61199021 ... 1.58005694 1.5803646  1.58067227]
# the min tDCF_norm is: 0.18505456434149375
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.27
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7075192332267761
# the tDCF_norm is: [0.59787171 0.59785845 0.5978452  ... 1.58005647 1.58036437 1.58067227]
# the min tDCF_norm is: 0.18112676744995243
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.28
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7075192332267761
# the tDCF_norm is: [0.58319067 0.58317773 0.58316479 ... 1.5800561  1.58036418 1.58067227]
# the min tDCF_norm is: 0.17726448676257872
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.29
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7075192332267761
# the tDCF_norm is: [0.57103141 0.57101877 0.57100612 ... 1.58005634 1.58036431 1.58067227]
# the min tDCF_norm is: 0.175128933963735
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.3
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7075192332267761
# the tDCF_norm is: [0.55839839 0.55838604 0.55837368 ... 1.58005635 1.58036431 1.58067227]
# the min tDCF_norm is: 0.17244260027759623
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.31
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7075192332267761
# the tDCF_norm is: [0.54865184 0.5486398  0.54862775 ... 1.58005781 1.58036504 1.58067227]
# the min tDCF_norm is: 0.1731626414914224
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.32
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7075192332267761
# the tDCF_norm is: [0.53625427 0.53624257 0.53623086 ... 1.58005878 1.58036553 1.58067227]
# the min tDCF_norm is: 0.17239743606139554
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.33
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7075192332267761
# the tDCF_norm is: [0.52484077 0.52482938 0.524818   ... 1.58005976 1.58036602 1.58067227]
# the min tDCF_norm is: 0.17184295868833435
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.34
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7075192332267761
# the tDCF_norm is: [0.51420136 0.51419033 0.5141793  ... 1.58006175 1.58036701 1.58067227]
# the min tDCF_norm is: 0.17339724310890461
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.35000000000000003
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7075192332267761
# the tDCF_norm is: [0.50538718 0.50537649 0.5053658  ... 1.58006405 1.58036816 1.58067227]
# the min tDCF_norm is: 0.17595408772676716
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.36
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7075192332267761
# the tDCF_norm is: [0.49874932 0.49873898 0.49872864 ... 1.58006747 1.58036987 1.58067227]
# the min tDCF_norm is: 0.1811357332457078
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.37
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7075192332267761
# the tDCF_norm is: [0.49527777 0.4952678  0.49525783 ... 1.58007252 1.58037239 1.58067227]
# the min tDCF_norm is: 0.19014402066094083
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.38
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.7075192332267761
# the tDCF_norm is: [0.49866184 0.49865224 0.49864264 ... 1.58008017 1.58037622 1.58067227]
# the min tDCF_norm is: 0.20563969238930072
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.39
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.700048565864563
# the tDCF_norm is: [0.4971043  0.49709508 0.49708586 ... 1.58008602 1.58037914 1.58067227]
# the min tDCF_norm is: 0.21654936804292135
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.4
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.700048565864563
# the tDCF_norm is: [0.49896796 0.49895913 0.4989503  ... 1.58009351 1.58038289 1.58067227]
# the min tDCF_norm is: 0.23133727716624328
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.41000000000000003
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.700048565864563
# the tDCF_norm is: [0.50928699 0.50927856 0.50927014 ... 1.5801046  1.58038843 1.58067227]
# the min tDCF_norm is: 0.2548923055763552
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.42
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.700048565864563
# the tDCF_norm is: [0.5143828  0.51437478 0.51436676 ... 1.58011357 1.58039292 1.58067227]
# the min tDCF_norm is: 0.27323622073614917
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.43
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.697165846824646
# the tDCF_norm is: [0.53454997 0.53454237 0.53453477 ... 1.58012872 1.5804005  1.58067227]
# the min tDCF_norm is: 0.30673663799548934
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.44
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.697165846824646
# the tDCF_norm is: [0.5540225  0.55401534 0.55400817 ... 1.58014387 1.58040807 1.58067227]
# the min tDCF_norm is: 0.3400765508935452
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.45
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.697165846824646
# the tDCF_norm is: [0.5691992  0.56919248 0.56918576 ... 1.58015749 1.58041488 1.58067227]
# the min tDCF_norm is: 0.3695318876264946
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.46
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.697165846824646
# the tDCF_norm is: [0.59392963 0.59392335 0.59391708 ... 1.58017492 1.58042359 1.58067227]
# the min tDCF_norm is: 0.40839748112609076
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.47000000000000003
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.697165846824646
# the tDCF_norm is: [0.62376102 0.62375519 0.62374937 ... 1.5801944  1.58043333 1.58067227]
# the min tDCF_norm is: 0.45234374468686567
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.48
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.697165846824646
# the tDCF_norm is: [0.65756278 0.65755741 0.65755204 ... 1.58021562 1.58044395 1.58067227]
# the min tDCF_norm is: 0.5005116448177508
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.49
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: 0.697165846824646
# the tDCF_norm is: [0.70280893 0.70280403 0.70279912 ... 1.58024144 1.58045685 1.58067227]
# the min tDCF_norm is: 0.5600279621803603
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
# ...
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.84
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: -0.8395433554649353
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.85
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: -0.8395433554649353
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.86
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: -0.8395433554649353
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.87
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: -0.8395433554649353
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.88
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: -0.8395433554649353
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.89
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: -0.8395433554649353
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.9
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: -0.8395433554649353
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.91
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: -0.8395433554649353
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.92
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: -0.8395433554649353
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.93
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: -0.8395433554649353
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.9400000000000001
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: -0.8395433554649353
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.9500000000000001
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: -0.8395433554649353
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.96
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: -0.8395433554649353
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.97
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: -0.8395433554649353
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.98
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: -0.8395433554649353
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.99
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: -0.8395433554649353
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=5067, Nspoof=43551] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  1.0
# the CM thresholds is:  [-0.83954336 -0.83854336 -0.83505869 ...  0.95363569  0.95442975
#   0.95455211]
# the CM threshold min is: -0.8395433554649353
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# tDCF - Minimum value: 0.17184295868833435
# Index of minimum value: (33, 34345)
# The min asv score: 0.33
# The min CM thersholds: 0.7075192332267761

# %%
heatmap_norm_tdcf(list_tDCF_norm_female_eval,list_asv_score,list_CM_thresholds_female_eval, target_values = [-1,0,1],title ="Norm t-DCF - Female on Evaluation Set",point_x_index = min_index[0] ,point_y_index  = min_index[1],point_x_constrained = point_x_constrained, point_y_constrained = point_y_constrained)

# %%
#thr from validation set
list_asv_score = [0.432,0.417]
CM_thr = pmf_both_thr_spoof_test_female
ASV_thr = list_asv_score[0]
spoof_score_cm_female_eval = results_eval.loc[(results_eval['its_male'] == False)]['spoof_score_female']
think_is_geninue = spoof_score_cm_female_eval.loc[spoof_score_cm_female_eval<CM_thr] 
results_eval.loc[think_is_geninue.index]['asv_label'].value_counts()

print(results_eval.loc[think_is_geninue.index]['asv_label'].value_counts())

to_asv = results_eval.loc[(think_is_geninue.index)]
print(to_asv.loc[to_asv['asv_score_female']>ASV_thr]['asv_label'].value_counts())

print("--------------------------------------------------------")

## all the files inside the system cm -> inside -> asv
indexes = []
path_name = pd.Series(np.concatenate(Eval_dataset_all.name.values)) 
for file in results_eval.loc[think_is_geninue.index]['file_name'].values:
    index = path_name.str.contains(file)
    indexes.append(index.loc[index==True].index[0])
print(Eval_dataset_all.attack_logical[indexes].value_counts())

print("--------------------------------------------------------")

## all the files inside the system cm -> asv -> inside
indexes = []
path_name = pd.Series(np.concatenate(Eval_dataset_all.name.values)) # Get the path names of the data set
for file in to_asv.loc[to_asv['asv_score_female']>ASV_thr]['file_name'].values:
    index = path_name.str.contains(file)
    indexes.append(index.loc[index==True].index[0])
print(Eval_dataset_all.attack_logical[indexes].value_counts())
# Out:
# asv_label
# spoof        4494
# target       3523
# nontarget    1022
# Name: count, dtype: int64
# asv_label
# target    3069
# spoof      911
# Name: count, dtype: int64
# --------------------------------------------------------
# [none]    4545
# [A17]     2368
# [A15]     1305
# [A18]      433
# [A10]      260
# [A14]       91
# [A11]       37
# Name: count, dtype: int64
# --------------------------------------------------------
# [none]    3069
# [A15]      733
# [A10]      151
# [A11]       19
# [A14]        8
# Name: count, dtype: int64

# %%
#thr from test set

CM_thr = pmf_both_thr_spoof_test_female
ASV_thr = list_asv_score[1]
spoof_score_cm_female_eval = results_eval.loc[(results_eval['its_male'] == False)]['spoof_score_female']
think_is_geninue = spoof_score_cm_female_eval.loc[spoof_score_cm_female_eval<CM_thr] 
results_eval.loc[think_is_geninue.index]['asv_label'].value_counts()

print(results_eval.loc[think_is_geninue.index]['asv_label'].value_counts())

to_asv = results_eval.loc[(think_is_geninue.index)]
print(to_asv.loc[to_asv['asv_score_female']>ASV_thr]['asv_label'].value_counts())

print("--------------------------------------------------------")

## all the files inside the system cm -> inside -> asv
indexes = []
path_name = pd.Series(np.concatenate(Eval_dataset_all.name.values)) 
for file in results_eval.loc[think_is_geninue.index]['file_name'].values:
    index = path_name.str.contains(file)
    indexes.append(index.loc[index==True].index[0])
print(Eval_dataset_all.attack_logical[indexes].value_counts())

print("--------------------------------------------------------")

## all the files inside the system cm -> asv -> inside
indexes = []
path_name = pd.Series(np.concatenate(Eval_dataset_all.name.values)) # Get the path names of the data set
for file in to_asv.loc[to_asv['asv_score_female']>ASV_thr]['file_name'].values:
    index = path_name.str.contains(file)
    indexes.append(index.loc[index==True].index[0])
print(Eval_dataset_all.attack_logical[indexes].value_counts())
# Out:
# asv_label
# spoof        4494
# target       3523
# nontarget    1022
# Name: count, dtype: int64
# asv_label
# target       3176
# spoof        1008
# nontarget       1
# Name: count, dtype: int64
# --------------------------------------------------------
# [none]    4545
# [A17]     2368
# [A15]     1305
# [A18]      433
# [A10]      260
# [A14]       91
# [A11]       37
# Name: count, dtype: int64
# --------------------------------------------------------
# [none]    3177
# [A15]      818
# [A10]      160
# [A11]       21
# [A14]        9
# Name: count, dtype: int64

# %%
#thr from 2 optimazation thresholds
list_asv_score = np.arange(0, 1.01, 0.01)
CM_thr = 1-CM_thresholds_female_eval[min_index]
ASV_thr = list_asv_score[min_index[0]]
spoof_score_cm_female_eval = results_eval.loc[(results_eval['its_male'] == False)]['spoof_score_female']
think_is_geninue = spoof_score_cm_female_eval.loc[spoof_score_cm_female_eval<CM_thr] 
results_eval.loc[think_is_geninue.index]['asv_label'].value_counts()

print(results_eval.loc[think_is_geninue.index]['asv_label'].value_counts())

to_asv = results_eval.loc[(think_is_geninue.index)]
print(to_asv.loc[to_asv['asv_score_female']>ASV_thr]['asv_label'].value_counts())

print("--------------------------------------------------------")

## all the files inside the system cm -> inside -> asv
indexes = []
path_name = pd.Series(np.concatenate(Eval_dataset_all.name.values)) 
for file in results_eval.loc[think_is_geninue.index]['file_name'].values:
    index = path_name.str.contains(file)
    indexes.append(index.loc[index==True].index[0])
print(Eval_dataset_all.attack_logical[indexes].value_counts())

print("--------------------------------------------------------")

## all the files inside the system cm -> asv -> inside
indexes = []
path_name = pd.Series(np.concatenate(Eval_dataset_all.name.values)) # Get the path names of the data set
for file in to_asv.loc[to_asv['asv_score_female']>ASV_thr]['file_name'].values:
    index = path_name.str.contains(file)
    indexes.append(index.loc[index==True].index[0])
print(Eval_dataset_all.attack_logical[indexes].value_counts())
# Out:
# asv_label
# spoof        25316
# target        3939
# nontarget     1128
# Name: count, dtype: int64
# asv_label
# spoof        15257
# target        3879
# nontarget       34
# Name: count, dtype: int64
# --------------------------------------------------------
# [none]    5067
# [A17]     3438
# [A15]     3415
# [A10]     3380
# [A11]     3379
# [A14]     3265
# [A18]     3126
# [A13]     3020
# [A12]     1399
# [A19]      467
# [A08]      272
# [A09]      109
# [A16]       39
# [A07]        7
# Name: count, dtype: int64
# --------------------------------------------------------
# [none]    3913
# [A15]     3279
# [A10]     3148
# [A11]     3131
# [A14]     2926
# [A13]     1241
# [A12]     1141
# [A08]      149
# [A18]      118
# [A19]       54
# [A16]       32
# [A17]       31
# [A07]        6
# [A09]        1
# Name: count, dtype: int64

# %% [markdown]
# ## without Gender speration:

# %%
import torch
import torch.nn as nn
from utils.AMSloss import AdMSoftmaxLoss
from utils.OCSoftmaxloss import OCSoftmax
import torch.nn as nn

import torch.nn as nn
class SubChannelNetwork(nn.Module):
    def __init__(self, input_channel_size, output_channel_size):
        super(SubChannelNetwork, self).__init__()
        self.input_layer = nn.Linear(input_channel_size, output_channel_size)
        self.sigmoid = nn.Sigmoid()
        self.dropout = nn.Dropout(p=0.2)
        self.BN_4 = nn.BatchNorm1d(output_channel_size) 
   
    def forward(self, x):
        res = x
        x = self.input_layer(x)
        x = self.BN_4(x) 
        x = self.sigmoid(x)
        x = self.dropout(x)
        x = res + x 
        return x

class DNN(nn.Module):
    def __init__(self, input_channel_size, num_subnetworks, output_channel_size, final_output_size, r_real , r_fake,alpha):
        super(DNN, self).__init__()
        self.SubChannelNetwork = nn.ModuleList([
            SubChannelNetwork(input_channel_size, output_channel_size) for _ in range(num_subnetworks)
        ])
        self.fc_between_subnet = nn.Linear(num_subnetworks * output_channel_size,80)
        self.BN = nn.BatchNorm1d(80)
        self.fc = nn.Linear(80, final_output_size)
        self.sigmoid = nn.Sigmoid()
        self.droupout = nn.Dropout(p=0.2)
        self.r_real = r_real
        self.r_fake = r_fake
        self.alpha = alpha
        self.loss = OCSoftmax(feat_dim = final_output_size, r_real = self.r_real, r_fake = self.r_fake, alpha = self.alpha)
        self.optimizer = None
        self.scheduler = None
        
        
    def forward(self, x):
        subnetwork_outputs = [self.SubChannelNetwork[idx](x[:, idx*input_channel_size:(idx+1)*input_channel_size].to(device)) for idx in range(len(self.SubChannelNetwork))]
        combined_output = torch.cat(subnetwork_outputs, dim=1)
        x = self.fc_between_subnet(combined_output)    
        x = self.BN(x)
        x = self.sigmoid(x)
        x = self.droupout(x)
        output = self.fc(x)
        return output 
    
    @staticmethod
    def count_parameters(model):
        return sum(p.numel() for p in model.parameters() if p.requires_grad)


r_real = 0.9 
r_fake = 0.5
alpha = 20
final_output_size = 16*2
model = DNN(input_channel_size, num_SubChannelNetwork, output_channel_size, final_output_size,r_real = r_real , r_fake = r_fake,alpha = alpha)
model = model.to(device)


model = model.to(device) # send the model to the device

file_path = 'ECAPA_TDNN/inference_models/models_both_not_normalize/male_and_female_2_neorun_end_OCS_both_10_6.pkl'

# Load the variable from the pickle file
with open(file_path, 'rb') as file:
    model = pickle.load(file)

model.eval()

spoof_model = copy.deepcopy(model)

# %%
total_labels = torch.Tensor(Dev_dataset_all.is_spoofed.values).cpu().numpy().copy()
total_data = torch.Tensor(Dev_dataset_all.data_without_separation).cpu().numpy().copy()
with torch.no_grad():
    spoof_model = spoof_model.to(device)
    validation_output = spoof_model(torch.Tensor(total_data).to(device)).cpu()
    loss , validation_score = spoof_model.loss(torch.Tensor(validation_output).to(device),torch.LongTensor(total_labels).to(device))
    validation_score = -1*validation_score


test_score_total = validation_score.cpu().numpy().copy()

eer, test_thresh = my_functions.compute_eer(total_labels,test_score_total) # compute equal error rate
print(f"\tTest EER: ({100*eer}%) \tTest Threshold: {test_thresh}")
# Out:
# 	Test EER: (0.05830642267671654%) 	Test Threshold: -0.9158978623153919

# %%
total_labels = torch.Tensor(Eval_dataset_all.is_spoofed.values).cpu().numpy().copy()
total_data = torch.Tensor(Eval_dataset_all.data_without_separation).cpu().numpy().copy()
with torch.no_grad():
    spoof_model = spoof_model.to(device)
    test_output = spoof_model(torch.Tensor(total_data).to(device))
    _ , test_score = spoof_model.loss(torch.Tensor(test_output).to(device),torch.LongTensor(total_labels).to(device))
    test_score = -1*test_score
    
test_score_total = test_score.cpu().numpy().copy()

eer, test_thresh = my_functions.compute_eer(total_labels,test_score_total) # compute equal error rate


print(f"\tTest EER: ({100*eer}%) \tTest Threshold: {test_thresh}")
# Out:
# 	Test EER: (10.622710622710645%) 	Test Threshold: -0.995716148680383

# %%
def CM_inferernce_time_embeddings_without_gender(data,spoof_model,device,thr_spoof,verbose = False):
    its_spoof = None
    with torch.no_grad():
            spoof_model = spoof_model.to(device)
            test_output = spoof_model(torch.Tensor(data).unsqueeze(0).to(device))
            _ , spoof_score = spoof_model.loss(torch.Tensor(test_output).to(device),None) # fix this tomorrow!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
            spoof_score = -1*spoof_score.item()
            if verbose:
                print(f"it's male spoof with score: {spoof_score}")
            if spoof_score <= thr_spoof:
                its_spoof = False
                if verbose:
                    print("it's not spoof")
            else:
                its_spoof = True
                if verbose:
                    print("it's spoof")
            
            if its_spoof is None:
                raise Exception("its_spoof is None, need to check the inference function")
        
    return its_spoof, spoof_score

# %%
def inference_system_cm_asv_avg_score_without_gender(list_speaker_id,list_asv_label,txt_file_path,csv_file_path,thr_spoof,enrollment, list_files, data_set, spoof_model, asv_model, device, verbose = False, verbose_txt = False,verbose_csv = False):
    '''
    This function is recognize the speaker in the data set, when the speaker don't say who he is, this task is like recognize the speaker. (Recognition task).
    '''
    
    # Initialize the dictionary with empty lists of data
    results = {  
        "file_name": [],
        "its_spoof": [],
        "spoof_score": [],
        "spoof_ground_truth": [],
        "asv_score": [],
        "speaker_id": [],
        "pred_speaker_id": [],
        "find_speaker_in_enroll": [],
        "asv_label": [],
        "attack_type": [],
    }
    
    if txt_file_path is None: # If the txt file path is None, then don't write to the txt file
        verbose_txt = False
        print("The output file path is None, so the results will not be saved in txt file")
    
    if csv_file_path is None: # If the csv file path is None, then don't write to the csv file
        verbose_csv = False
        print("The output file path is None, so the results will not be saved in csv file")

    if verbose_txt: # Open the txt file      
        txt_file = open(txt_file_path, 'w')
        
    if verbose_csv: # Open the csv file
        csv_file = open(csv_file_path, 'w', newline='')
        csv_writer = csv.writer(csv_file)
        csv_writer.writerow(results.keys())
        
    path_names = pd.Series(np.concatenate(data_set.name.values)) # Get the path names of the data set

    for  speaker_id,file_name,asv_label in tqdm.tqdm(zip(list_speaker_id,list_files,list_asv_label), total=len(list_files)): # Iterate over the list of the files
        try:
            index_time_embedding = path_names.str.contains(file_name) # Get the index of the file in the data set
            
            if index_time_embedding.size == 0 or index_time_embedding is None: # If the index is empty, then raise an error
                raise ValueError(f"File {file_name} in list files, is not present in in list paths.")

            if verbose: # Print the file name and the index
                print(f"File {file_name} in list files, is at {path_names[index_time_embedding]} in list paths.")
                
        except ValueError: # If the index is empty, then raise an error
            print(f"File {file_name} in list files, is not present in in list paths.")

        time_embedding = data_set.data_without_separation[index_time_embedding].squeeze() # Get the time embedding of the file
        attack_type = data_set.attack_logical.values[index_time_embedding][0][0]

        # this function calculate the CM inference of the time embedding 
        its_spoof, spoof_score = CM_inferernce_time_embeddings_without_gender(time_embedding, spoof_model, device,thr_spoof) # this function calculate

       
        if its_spoof is None:
            raise Exception("its_spoof is None, need to check the inference function")
        
        if spoof_score is None:
            raise Exception("spoof_score is None, need to check the inference function")
        
        # Append the results to the data dictionary
        results["file_name"].append(file_name)
        
        # for spoofing CM system
        results["its_spoof"].append(its_spoof)
        results["spoof_ground_truth"].append(bool(data_set.is_spoofed.values[index_time_embedding][0]))
        results["spoof_score"].append(spoof_score)
        
        # for ASV system
        results["asv_label"].append(asv_label)
        results["attack_type"].append(attack_type)
                
        signal, fs = torchaudio.load(str(path_names.values[index_time_embedding][0])) # load the signal from the path
        
        if fs != 16000: # if the sample rate is not 16000, then raise an error
            raise Exception("The sample rate is not 16000, need to check the inference function")
        
        embeddings = asv_model.encode_batch(signal)  # encode the signal
       
        embeddings = embeddings.cpu().numpy().squeeze(0) # convert the embeddings to numpy and send to cpu

        # initialize the helps variables
        find_speaker_in_enroll = False
        max_cos_score = -1
        max_cos_index = 0
        avg_score = None
        list_scores_speaker = []
        all_speakers_id = np.array(enrollment.get_all_speakers_id()) 

        for index_speaker,embedding_in_enroll_per_speaker in enumerate(enrollment.get_all_enrollment_embeddings()):
            embedding_in_enroll_per_speaker = np.array(embedding_in_enroll_per_speaker)
            for _,embedding_in_enroll in enumerate(embedding_in_enroll_per_speaker):
                if speaker_id == all_speakers_id[index_speaker]:
                    cos_score = cosine_similarity(embedding_in_enroll.squeeze().reshape(1, -1), embeddings.reshape(1, -1)) # calculate the cosine similarity between the embeddings
                    find_speaker_in_enroll = True
                    
                    if cos_score.shape != (1, 1): # if the cosine similarity is not scalar, then raise an error
                        raise Exception("cos_score shape is not (1,1) so is not scalar!, need to check the inference function")
                    
                    list_scores_speaker.append(cos_score.item())
                        
            #if find_speaker_in_enroll == False:
            #    print("The speaker id is not in the enrollment data set")
        
        asv_score = np.average(list_scores_speaker, axis = 0) # calculate the average score
        
        results["asv_score"].append(asv_score) # the score of the current embedding with the enrollment embedding
        results["speaker_id"].append(speaker_id)         
        results["pred_speaker_id"].append(all_speakers_id[max_cos_index])
        results["find_speaker_in_enroll"].append(find_speaker_in_enroll)
            
        if verbose: # Print the results
            print(f"file_name: {results['file_name'][-1]}, its_spoof: {results['its_spoof'][-1]}, spoof_score: {results['spoof_score'][-1]}, spoof_ground_truth: {results['spoof_ground_truth'][-1]},asv_score: {results['asv_score'][-1]}, speaker_id: {results['speaker_id'][-1]} , pred_speaker_id: {results['pred_speaker_id'][-1]}, find_speaker_in_enroll: {results['find_speaker_in_enroll'][-1]} \n")
            
        if verbose_txt: # Write the results to the txt file
            txt_file.write(f"file_name: {results['file_name'][-1]}, its_spoof: {results['its_spoof'][-1]}, spoof_score: {results['spoof_score'][-1]}, spoof_ground_truth: {results['spoof_ground_truth'][-1]},asv_score: {results['asv_score'][-1]}, speaker_id: {results['speaker_id'][-1]} , pred_speaker_id: {results['pred_speaker_id'][-1]}, find_speaker_in_enroll: {results['find_speaker_in_enroll'][-1]} \n")

        if verbose_csv: # Write the results to the csv file
            last_item = {key: list(values)[-1] for key, values in results.items()} # Get the last item of each list in the dictionary
            csv_writer.writerow(last_item.values()) # Write the last item to the csv file
        
    if verbose_txt: # Close the txt file
        txt_file.close()
        
    if verbose_csv:# Close the csv file
        csv_file.close() 
           
    results_df = pd.DataFrame(results)  # Return the DataFrame
    
    return results_df

# %% [markdown]
# ## Dev:

# %%
from sklearn.metrics.pairwise import cosine_similarity
import torchaudio
import tqdm
from ASV_utils.config_thr import pmf_both_thr_spoof_val_all

txt_file_path = "output.txt"
csv_file_path = "output.csv"
enrollment_all  = enrollment_dev_male + enrollment_dev_female
list_files = list_dev_files
data_set = Dev_dataset_all
asv_model = classifier
list_speaker_id = list_speaker_id_dev
list_asv_label = list_asv_label_dev

results_dev_without_gender = inference_system_cm_asv_avg_score_without_gender(list_speaker_id,list_asv_label,txt_file_path,csv_file_path,pmf_both_thr_spoof_val_all,enrollment_all, list_files, data_set, spoof_model, asv_model, device, verbose = False, verbose_txt = False,verbose_csv = False)
# Out:
# 100%|██████████| 24844/24844 [3:31:29<00:00,  1.96it/s]

# %%
'''
import pickle
with open('results_dev_without_gender_avg_score_both_2.pkl', 'wb') as f:
    pickle.dump(results_dev_without_gender,f)
'''
import pickle
file_path = "results_dev_without_gender_avg_score_both_2.pkl"
with open(file_path, 'rb') as file:
    results_dev_without_gender = pickle.load(file)

# %%
from ASV_utils.tdcf_functions import compute_t_dcf

bonafide_score_cm = results_dev_without_gender.loc[results_dev_without_gender['spoof_ground_truth'] == 0]['spoof_score'].values
bonafide_score_cm = -1*bonafide_score_cm

spoof_score_cm = results_dev_without_gender.loc[(results_dev_without_gender['spoof_ground_truth'] == 1)]['spoof_score'].values
spoof_score_cm = -1*spoof_score_cm

Prior_spoof = 0.05

target_scores = results_dev_without_gender.loc[results_dev_without_gender['asv_label'] == "target"]["asv_score"].values
nontarget_scores = results_dev_without_gender.loc[results_dev_without_gender['asv_label'] == "nontarget"]["asv_score"].values
spoof_scores = results_dev_without_gender.loc[results_dev_without_gender['asv_label'] ==  "spoof"]["asv_score"].values

list_asv_score = [0.408]
type = 'constrained'
list_tDCF_norm_without_gender ,list_CM_thresholds_without_gender,list_tDCF_without_gender  = compute_t_dcf(bonafide_score_cm,spoof_score_cm,Prior_spoof,target_scores,nontarget_scores,spoof_scores,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  6.45930 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  0.408
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [1.         0.99995515 0.9999103  ... 6.45423004 6.45676509 6.45930014]
# the min tDCF_norm is: 0.0007624686042339433

# %%
from ASV_utils.tdcf_functions import compute_t_dcf

bonafide_score_cm = results_dev_without_gender.loc[results_dev_without_gender['spoof_ground_truth'] == 0]['spoof_score'].values
bonafide_score_cm = -1*bonafide_score_cm

spoof_score_cm = results_dev_without_gender.loc[(results_dev_without_gender['spoof_ground_truth'] == 1)]['spoof_score'].values
spoof_score_cm = -1*spoof_score_cm

Prior_spoof = 0.05

target_scores = results_dev_without_gender.loc[results_dev_without_gender['asv_label'] == "target"]["asv_score"].values
nontarget_scores = results_dev_without_gender.loc[results_dev_without_gender['asv_label'] == "nontarget"]["asv_score"].values
spoof_scores = results_dev_without_gender.loc[results_dev_without_gender['asv_label'] ==  "spoof"]["asv_score"].values

list_asv_score = [0.408]
type = 'constrained_ver2'
list_tDCF_norm_without_gender ,list_CM_thresholds_without_gender,list_tDCF_without_gender  = compute_t_dcf(bonafide_score_cm,spoof_score_cm,Prior_spoof,target_scores,nontarget_scores,spoof_scores,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained_ver2
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv development set  0.408
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [1.         0.99997232 0.99994463 ... 4.36645718 4.36802186 4.36958654]
# the min tDCF_norm is: 0.3832511027627439

# %%
from ASV_utils.tdcf_functions import compute_t_dcf

bonafide_score_cm = results_dev_without_gender.loc[results_dev_without_gender['spoof_ground_truth'] == 0]['spoof_score'].values
bonafide_score_cm = -1*bonafide_score_cm

spoof_score_cm = results_dev_without_gender.loc[(results_dev_without_gender['spoof_ground_truth'] == 1)]['spoof_score'].values
spoof_score_cm = -1*spoof_score_cm

Prior_spoof = 0.05

target_scores = results_dev_without_gender.loc[results_dev_without_gender['asv_label'] == "target"]["asv_score"].values
nontarget_scores = results_dev_without_gender.loc[results_dev_without_gender['asv_label'] == "nontarget"]["asv_score"].values
spoof_scores = results_dev_without_gender.loc[results_dev_without_gender['asv_label'] ==  "spoof"]["asv_score"].values

list_asv_score = np.arange(0, 1.01, 0.01)
type = 'unconstrained'

point_y_constrained = np.argmin(list_tDCF_norm_without_gender)
point_x_constrained = (np.abs(np.array(list_asv_score)-[0.408])).argmin()

list_tDCF_norm_without_gender ,list_CM_thresholds_without_gender,list_tDCF_without_gender  = compute_t_dcf(bonafide_score_cm,spoof_score_cm,Prior_spoof,target_scores,nontarget_scores,spoof_scores,list_asv_score,type)

tDCF_norm_without_gender = np.array(list_tDCF_norm_without_gender)

CM_thresholds_without_gender = np.array(list_CM_thresholds_without_gender)

min_index = np.unravel_index(np.nanargmin(tDCF_norm_without_gender), tDCF_norm_without_gender.shape)

# Print the results
print("tDCF - Minimum value:", tDCF_norm_without_gender[min_index])
print("Index of minimum value:", min_index)
print("The min asv score:", list_asv_score[min_index[0]])
print("The min CM thersholds:",CM_thresholds_without_gender[min_index])
# Out:
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv development set  0.0
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.9842311  0.98419353 0.98415596 ... 1.57954663 1.58010945 1.58067227]
# the min tDCF_norm is: 0.1472473042813652
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv evaluation set  0.01
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.97931051 0.979273   0.97923549 ... 1.5795438  1.58010804 1.58067227]
# the min tDCF_norm is: 0.14364485789480178
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.02
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.972585   0.97254759 0.97251018 ... 1.57954027 1.58010627 1.58067227]
# the min tDCF_norm is: 0.1391413616656667
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.03
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.96477068 0.96473338 0.96469607 ... 1.57953603 1.58010415 1.58067227]
# the min tDCF_norm is: 0.13373736160528357
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.04
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.95485202 0.95481486 0.9547777  ... 1.57953073 1.5801015  1.58067227]
# the min tDCF_norm is: 0.12698224658005233
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.05
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.9462818  0.9462448  0.9462078  ... 1.57952684 1.58009956 1.58067227]
# the min tDCF_norm is: 0.12202750699367933
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.06
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.93053519 0.93049846 0.93046173 ... 1.57951919 1.58009573 1.58067227]
# the min tDCF_norm is: 0.11226903618039971
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.07
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.91550118 0.91546473 0.91542827 ... 1.57951212 1.58009219 1.58067227]
# the min tDCF_norm is: 0.10326083674973001
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.08
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.89903356 0.89899745 0.89896135 ... 1.57950529 1.58008878 1.58067227]
# the min tDCF_norm is: 0.09455143544492765
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.09
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.88136336 0.88132762 0.88129188 ... 1.57949787 1.58008507 1.58067227]
# the min tDCF_norm is: 0.08509138917082026
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.1
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.86233772 0.8623024  0.86226707 ... 1.57949021 1.58008124 1.58067227]
# the min tDCF_norm is: 0.07533041820042731
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.11
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.84221977 0.84218491 0.84215004 ... 1.57948244 1.58007735 1.58067227]
# the min tDCF_norm is: 0.06541866877007264
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.12
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.82348445 0.8234501  0.82341574 ... 1.57947667 1.58007447 1.58067227]
# the min tDCF_norm is: 0.05805704888730064
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.13
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.80230768 0.80227387 0.80224005 ... 1.57946948 1.58007087 1.58067227]
# the min tDCF_norm is: 0.04889422017996597
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.14
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.78172415 0.78169094 0.78165773 ... 1.57946394 1.58006811 1.58067227]
# the min tDCF_norm is: 0.04183108231124237
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.15
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.75990035 0.75986777 0.75983519 ... 1.57945782 1.58006504 1.58067227]
# the min tDCF_norm is: 0.03401727073577567
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.16
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.73668062 0.73664875 0.73661687 ... 1.57945193 1.5800621  1.58067227]
# the min tDCF_norm is: 0.02650228602361438
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.17
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.7134483  0.71341725 0.7133862  ... 1.57944816 1.58006021 1.58067227]
# the min tDCF_norm is: 0.021686312648083902
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.18
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.68852974 0.68849964 0.68846954 ... 1.57944523 1.58005875 1.58067227]
# the min tDCF_norm is: 0.0179333844779207
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.19
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.66363205 0.66360292 0.66357379 ... 1.57944264 1.58005745 1.58067227]
# the min tDCF_norm is: 0.014615597397687197
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.2
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.63647087 0.63644283 0.63641478 ... 1.5794404  1.58005633 1.58067227]
# the min tDCF_norm is: 0.011745921293940441
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.21
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.60984856 0.60982162 0.60979468 ... 1.57943876 1.58005551 1.58067227]
# the min tDCF_norm is: 0.00964109575589339
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.22
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.58302308 0.58299725 0.58297142 ... 1.57943711 1.58005469 1.58067227]
# the min tDCF_norm is: 0.007521403660375729
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.23
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.55831527 0.55829053 0.55826578 ... 1.57943677 1.58005452 1.58067227]
# the min tDCF_norm is: 0.0070674395485009105
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.24
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.53236089 0.53233732 0.53231374 ... 1.5794369  1.58005458 1.58067227]
# the min tDCF_norm is: 0.0072123073981983825
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.25
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.50697535 0.50695289 0.50693043 ... 1.57943644 1.58005435 1.58067227]
# the min tDCF_norm is: 0.0066078809381807805
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.26
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.4815751  0.48155375 0.4815324  ... 1.57943597 1.58005412 1.58067227]
# the min tDCF_norm is: 0.005988731607882991
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.27
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.4627324  0.46271208 0.46269177 ... 1.5794392  1.58005573 1.58067227]
# the min tDCF_norm is: 0.010081742637469795
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.28
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.44205042 0.44203107 0.44201173 ... 1.57944003 1.58005615 1.58067227]
# the min tDCF_norm is: 0.011130304174042652
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.29
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.41740116 0.41738292 0.41736469 ... 1.57944003 1.58005615 1.58067227]
# the min tDCF_norm is: 0.011111509889535616
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.3
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.4007913  0.40077404 0.40075679 ... 1.57944421 1.58005824 1.58067227]
# the min tDCF_norm is: 0.01642049989230771
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.31
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.38629207 0.38627571 0.38625935 ... 1.57944839 1.58006033 1.58067227]
# the min tDCF_norm is: 0.021731099191612514
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.32
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.37092598 0.37091055 0.37089511 ... 1.57945257 1.58006242 1.58067227]
# the min tDCF_norm is: 0.027041037529841383
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.33
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.35959272 0.35957803 0.35956334 ... 1.57945675 1.58006451 1.58067227]
# the min tDCF_norm is: 0.032354050773945264
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.34
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.34913615 0.34912222 0.34910829 ... 1.57946177 1.58006702 1.58067227]
# the min tDCF_norm is: 0.03873206336920613
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.35000000000000003
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.3368892  0.33687601 0.33686281 ... 1.579465   1.58006863 1.58067227]
# the min tDCF_norm is: 0.042830103450457666
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.36
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.33747901 0.33746645 0.3374539  ... 1.5794767  1.58007448 1.58067227]
# the min tDCF_norm is: 0.05773118576084949
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.37
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.34064156 0.34062957 0.34061759 ... 1.57948924 1.58008076 1.58067227]
# the min tDCF_norm is: 0.07369856060711209
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.38
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.33928952 0.33927818 0.33926683 ... 1.57949927 1.58008577 1.58067227]
# the min tDCF_norm is: 0.0864695005279995
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.39
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.33989737 0.33988657 0.33987577 ... 1.57950931 1.58009079 1.58067227]
# the min tDCF_norm is: 0.09924193479566729
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.4
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.35045858 0.35044826 0.35043794 ... 1.57952603 1.58009915 1.58067227]
# the min tDCF_norm is: 0.1205366053927616
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.41000000000000003
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.36381868 0.36380876 0.36379885 ... 1.57954359 1.58010793 1.58067227]
# the min tDCF_norm is: 0.1428977409503552
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.42
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.38083631 0.38082682 0.38081734 ... 1.57956449 1.58011838 1.58067227]
# the min tDCF_norm is: 0.16951898886232908
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.43
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.39831604 0.39830701 0.39829798 ... 1.57958622 1.58012925 1.58067227]
# the min tDCF_norm is: 0.19720492001364107
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.44
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.41830295 0.41829437 0.41828578 ... 1.57960963 1.58014095 1.58067227]
# the min tDCF_norm is: 0.22702142461602876
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.45
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.45437026 0.45436206 0.45435387 ... 1.57964475 1.58015851 1.58067227]
# the min tDCF_norm is: 0.27175082261586075
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.46
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.48425481 0.48424709 0.48423936 ... 1.57967652 1.58017439 1.58067227]
# the min tDCF_norm is: 0.3122181828529609
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.47000000000000003
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.52034176 0.52033453 0.52032729 ... 1.57971331 1.58019279 1.58067227]
# the min tDCF_norm is: 0.35907625763295503
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.48
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.55593875 0.55593202 0.55592528 ... 1.57975009 1.58021118 1.58067227]
# the min tDCF_norm is: 0.4059339588262541
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.49
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [0.60732443 0.60731821 0.60731199 ... 1.57979942 1.58023584 1.58067227]
# the min tDCF_norm is: 0.46876866190757405
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
# ...
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.84
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: -0.9990682134628296
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.85
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: -0.9990682134628296
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.86
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: -0.9990682134628296
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.87
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: -0.9990682134628296
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.88
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: -0.9990682134628296
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.89
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: -0.9990682134628296
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.9
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: -0.9990682134628296
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.91
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: -0.9990682134628296
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.92
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: -0.9990682134628296
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.93
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: -0.9990682134628296
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.9400000000000001
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: -0.9990682134628296
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.9500000000000001
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: -0.9990682134628296
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.96
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: -0.9990682134628296
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.97
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: -0.9990682134628296
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.98
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: -0.9990682134628296
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.99
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: -0.9990682134628296
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  1.0
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: -0.9990682134628296
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# tDCF - Minimum value: 0.005988731607882991
# Index of minimum value: (26, 22279)
# The min asv score: 0.26
# The min CM thersholds: 0.8903427720069885

# %%
heatmap_norm_tdcf(list_tDCF_norm_without_gender,list_asv_score,list_CM_thresholds_without_gender, target_values = [-1,1],title ="Norm t-DCF -  Male&Female on Development Set",point_x_index = min_index[0] ,point_y_index  = min_index[1],point_x_constrained = point_x_constrained, point_y_constrained = point_y_constrained)

# %% [markdown]
# ## Eval:

# %%
from sklearn.metrics.pairwise import cosine_similarity
import torchaudio
import tqdm
from ASV_utils.config_thr import pmf_both_thr_spoof_test_all

txt_file_path = "output.txt"
csv_file_path = "output.csv"
enrollment_all  = enrollment_eval_male + enrollment_eval_female
list_files = list_eval_files
data_set = Eval_dataset_all
asv_model = classifier
list_speaker_id = list_speaker_id_eval
list_asv_label = list_asv_label_eval
results_eval_without_gender = inference_system_cm_asv_avg_score_without_gender(list_speaker_id,list_asv_label,txt_file_path,csv_file_path,pmf_both_thr_spoof_test_all,enrollment_all, list_files, data_set, spoof_model, asv_model, device, verbose = False, verbose_txt = False,verbose_csv = False)
# Out:
# 100%|██████████| 71237/71237 [9:30:14<00:00,  2.08it/s]

# %%
results_eval_without_gender
# Out:
#           file_name  its_spoof  spoof_score  spoof_ground_truth  asv_score  \
# 0      LA_E_1000147       True    -0.981741                True   0.642701
# 1      LA_E_1000273       True    -0.947986                True   0.509524
# 2      LA_E_1000791       True     0.893599                True   0.553254
# 3      LA_E_1000841       True     0.934752                True   0.233006
# 4      LA_E_1000989      False    -0.997609                True   0.226672
# ...             ...        ...          ...                 ...        ...
# 71232  LA_E_9999542       True    -0.940095                True   0.343625
# 71233  LA_E_9999640       True    -0.944023                True   0.295403
# 71234  LA_E_9999789       True     0.933456                True   0.320406
# 71235  LA_E_9999988       True     0.982452                True   0.481895
# 71236  LA_E_9999993      False    -0.998975               False   0.036219
#
#       speaker_id pred_speaker_id  find_speaker_in_enroll  asv_label  \
# 0        LA_0044         LA_0007                    True      spoof
# 1        LA_0001         LA_0007                    True      spoof
# 2        LA_0023         LA_0007                    True      spoof
# 3        LA_0043         LA_0007                    True      spoof
# 4        LA_0014         LA_0007                    True      spoof
# ...          ...             ...                     ...        ...
# 71232    LA_0017         LA_0007                    True      spoof
# 71233    LA_0035         LA_0007                    True      spoof
# 71234    LA_0016         LA_0007                    True      spoof
# 71235    LA_0047         LA_0007                    True      spoof
# 71236    LA_0020         LA_0007                    True  nontarget
#
#       attack_type
# 0             A10
# 1             A15
# 2             A11
# 3             A09
# 4             A14
# ...           ...
# 71232         A14
# 71233         A14
# 71234         A19
# 71235         A16
# 71236        none
#
# [71237 rows x 10 columns]

# %%
'''
import pickle
with open('results_eval_without_gender_avg_score_both.pkl', 'wb') as f:
    pickle.dump(results_eval_without_gender,f)
'''

# %%
 
import pickle
file_path = "results_eval_without_gender_avg_score_both_2.pkl"
with open(file_path, 'rb') as file:
    results_eval_without_gender = pickle.load(file)

# %%
from ASV_utils.tdcf_functions import compute_t_dcf

bonafide_score_cm = results_eval_without_gender.loc[results_eval_without_gender['spoof_ground_truth'] == 0]['spoof_score'].values
bonafide_score_cm = -1*bonafide_score_cm

spoof_score_cm = results_eval_without_gender.loc[(results_eval_without_gender['spoof_ground_truth'] == 1)]['spoof_score'].values
spoof_score_cm = -1*spoof_score_cm

Prior_spoof = 0.05

target_scores = results_eval_without_gender.loc[results_eval_without_gender['asv_label'] == "target"]["asv_score"].values
nontarget_scores = results_eval_without_gender.loc[results_eval_without_gender['asv_label'] == "nontarget"]["asv_score"].values
spoof_scores = results_eval_without_gender.loc[results_eval_without_gender['asv_label'] ==  "spoof"]["asv_score"].values

list_asv_score = [0.408,0.403]
type = 'constrained'
list_tDCF_norm_without_gender ,list_CM_thresholds_without_gender,list_tDCF_without_gender  = compute_t_dcf(bonafide_score_cm,spoof_score_cm,Prior_spoof,target_scores,nontarget_scores,spoof_scores,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  3.70812 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  0.408
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9912895560264587
# the tDCF_norm is: [1.         0.99998435 0.99996869 ... 3.70711127 3.70761544 3.7081196 ]
# the min tDCF_norm is: 0.3588191145546576
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  3.66150 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv evaluation set  0.403
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9912895560264587
# the tDCF_norm is: [1.         0.99998435 0.99996869 ... 3.66049974 3.66099756 3.66149539]
# the min tDCF_norm is: 0.35710121353112184

# %%
from ASV_utils.tdcf_functions import compute_t_dcf

bonafide_score_cm = results_eval_without_gender.loc[results_eval_without_gender['spoof_ground_truth'] == 0]['spoof_score'].values
bonafide_score_cm = -1*bonafide_score_cm

spoof_score_cm = results_eval_without_gender.loc[(results_eval_without_gender['spoof_ground_truth'] == 1)]['spoof_score'].values
spoof_score_cm = -1*spoof_score_cm

Prior_spoof = 0.05

target_scores = results_eval_without_gender.loc[results_eval_without_gender['asv_label'] == "target"]["asv_score"].values
nontarget_scores = results_eval_without_gender.loc[results_eval_without_gender['asv_label'] == "nontarget"]["asv_score"].values
spoof_scores = results_eval_without_gender.loc[results_eval_without_gender['asv_label'] ==  "spoof"]["asv_score"].values

list_asv_score = [0.408,0.403]
type = 'constrained_ver2'
list_tDCF_norm_without_gender ,list_CM_thresholds_without_gender,list_tDCF_without_gender  = compute_t_dcf(bonafide_score_cm,spoof_score_cm,Prior_spoof,target_scores,nontarget_scores,spoof_scores,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained_ver2
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv development set  0.408
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9912895560264587
# the tDCF_norm is: [1.         0.99998803 0.99997606 ... 3.0696705  3.07005595 3.07044139]
# the min tDCF_norm is: 0.5097973345329267
# The t-DCF evaluation type is: constrained_ver2
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv evaluation set  0.403
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9912895560264587
# the tDCF_norm is: [1.         0.99998766 0.99997532 ... 3.09743983 3.09783229 3.09822476]
# the min tDCF_norm is: 0.49316231807365407

# %%
from ASV_utils.tdcf_functions import compute_t_dcf

bonafide_score_cm = results_eval_without_gender.loc[results_eval_without_gender['spoof_ground_truth'] == 0]['spoof_score'].values
bonafide_score_cm = -1*bonafide_score_cm

spoof_score_cm = results_eval_without_gender.loc[(results_eval_without_gender['spoof_ground_truth'] == 1)]['spoof_score'].values
spoof_score_cm = -1*spoof_score_cm

Prior_spoof = 0.05

target_scores = results_eval_without_gender.loc[results_eval_without_gender['asv_label'] == "target"]["asv_score"].values
nontarget_scores = results_eval_without_gender.loc[results_eval_without_gender['asv_label'] == "nontarget"]["asv_score"].values
spoof_scores = results_eval_without_gender.loc[results_eval_without_gender['asv_label'] ==  "spoof"]["asv_score"].values

list_asv_score = np.arange(0, 1.01, 0.01)
type = 'unconstrained'

point_y_constrained = np.argmin(list_tDCF_norm_without_gender[1])
point_x_constrained = (np.abs(np.array(list_asv_score)-[0.403])).argmin()

list_tDCF_norm_without_gender ,list_CM_thresholds_without_gender,list_tDCF_without_gender  = compute_t_dcf(bonafide_score_cm,spoof_score_cm,Prior_spoof,target_scores,nontarget_scores,spoof_scores,list_asv_score,type)

tDCF_norm_without_gender = np.array(list_tDCF_norm_without_gender)

CM_thresholds_without_gender = np.array(list_CM_thresholds_without_gender)

min_index = np.unravel_index(np.nanargmin(tDCF_norm_without_gender), tDCF_norm_without_gender.shape)

# Print the results
print("tDCF - Minimum value:", tDCF_norm_without_gender[min_index])
print("Index of minimum value:", min_index)
print("The min asv score:", list_asv_score[min_index[0]])
print("The min CM thersholds:",CM_thresholds_without_gender[min_index])
# Out:
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv development set  0.0
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9943753480911255
# the tDCF_norm is: [0.97208949 0.97207647 0.97206345 ... 1.58028057 1.58047642 1.58067227]
# the min tDCF_norm is: 0.36324886655182986
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv evaluation set  0.01
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9943753480911255
# the tDCF_norm is: [0.96556319 0.96555021 0.96553724 ... 1.5802796  1.58047593 1.58067227]
# the min tDCF_norm is: 0.3594961492744393
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.02
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9943753480911255
# the tDCF_norm is: [0.95817388 0.95816095 0.95814803 ... 1.58027851 1.58047539 1.58067227]
# the min tDCF_norm is: 0.35526003023506164
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.03
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9943753480911255
# the tDCF_norm is: [0.95104656 0.9510337  0.95102083 ... 1.58027759 1.58047493 1.58067227]
# the min tDCF_norm is: 0.35156630189954563
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.04
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9943753480911255
# the tDCF_norm is: [0.9413589  0.9413461  0.94133331 ... 1.58027617 1.58047422 1.58067227]
# the min tDCF_norm is: 0.3460473487532272
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.05
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9943753480911255
# the tDCF_norm is: [0.93125481 0.9312421  0.93122938 ... 1.58027481 1.58047354 1.58067227]
# the min tDCF_norm is: 0.3406560764419273
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.06
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9940211176872253
# the tDCF_norm is: [0.92028706 0.92027444 0.92026182 ... 1.58027352 1.58047289 1.58067227]
# the min tDCF_norm is: 0.3352879563139793
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.07
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9940211176872253
# the tDCF_norm is: [0.90712425 0.90711174 0.90709922 ... 1.58027168 1.58047198 1.58067227]
# the min tDCF_norm is: 0.32796130027177817
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.08
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9939256310462952
# the tDCF_norm is: [0.89322674 0.89321434 0.89320193 ... 1.58026988 1.58047108 1.58067227]
# the min tDCF_norm is: 0.32062061531982156
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.09
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9939256310462952
# the tDCF_norm is: [0.87855159 0.87853932 0.87852705 ... 1.58026824 1.58047025 1.58067227]
# the min tDCF_norm is: 0.3135900965316741
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.1
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9939256310462952
# the tDCF_norm is: [0.86341646 0.86340433 0.86339221 ... 1.58026661 1.58046944 1.58067227]
# the min tDCF_norm is: 0.30652745183833074
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.11
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9939256310462952
# the tDCF_norm is: [0.84658766 0.84657568 0.84656371 ... 1.58026465 1.58046846 1.58067227]
# the min tDCF_norm is: 0.2982154568366516
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.12
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9939256310462952
# the tDCF_norm is: [0.829309   0.8292972  0.82928539 ... 1.58026283 1.58046755 1.58067227]
# the min tDCF_norm is: 0.29026943345554274
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.13
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9939256310462952
# the tDCF_norm is: [0.81050962 0.81049799 0.81048635 ... 1.58026071 1.58046649 1.58067227]
# the min tDCF_norm is: 0.28120541518154246
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.14
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9933891892433167
# the tDCF_norm is: [0.79299721 0.79298574 0.79297428 ... 1.58025894 1.5804656  1.58067227]
# the min tDCF_norm is: 0.2733080428035554
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.15
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9933891892433167
# the tDCF_norm is: [0.77446996 0.77445867 0.77444739 ... 1.58025695 1.58046461 1.58067227]
# the min tDCF_norm is: 0.2644470064850459
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.16
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9933891892433167
# the tDCF_norm is: [0.75678243 0.75677133 0.75676022 ... 1.58025531 1.58046379 1.58067227]
# the min tDCF_norm is: 0.25672296759168833
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.17
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9933891892433167
# the tDCF_norm is: [0.7373415  0.73733057 0.73731965 ... 1.58025323 1.58046275 1.58067227]
# the min tDCF_norm is: 0.2474551436456788
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.18
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9933891892433167
# the tDCF_norm is: [0.71971455 0.71970382 0.71969309 ... 1.58025171 1.58046199 1.58067227]
# the min tDCF_norm is: 0.24009211457201365
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.19
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9933891892433167
# the tDCF_norm is: [0.70392814 0.70391759 0.70390703 ... 1.58025055 1.58046141 1.58067227]
# the min tDCF_norm is: 0.23406142932312382
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.2
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9925150275230408
# the tDCF_norm is: [0.68928291 0.68927254 0.68926217 ... 1.58024974 1.580461   1.58067227]
# the min tDCF_norm is: 0.22897159061889447
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.21
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9925150275230408
# the tDCF_norm is: [0.67551408 0.67550388 0.67549367 ... 1.58024884 1.58046055 1.58067227]
# the min tDCF_norm is: 0.2237851198157918
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.22
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9925150275230408
# the tDCF_norm is: [0.66134911 0.66133907 0.66132903 ... 1.58024792 1.58046009 1.58067227]
# the min tDCF_norm is: 0.21846037916428462
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.23
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9925150275230408
# the tDCF_norm is: [0.64807129 0.64806142 0.64805156 ... 1.58024729 1.58045978 1.58067227]
# the min tDCF_norm is: 0.21412076460055496
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.24
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9925150275230408
# the tDCF_norm is: [0.6351566  0.63514692 0.63513724 ... 1.58024697 1.58045962 1.58067227]
# the min tDCF_norm is: 0.2107055362405261
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.25
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9925150275230408
# the tDCF_norm is: [0.62228246 0.62227296 0.62226345 ... 1.58024648 1.58045937 1.58067227]
# the min tDCF_norm is: 0.2068104931756135
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.26
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9923402070999146
# the tDCF_norm is: [0.60905833 0.609049   0.60903968 ... 1.58024604 1.58045915 1.58067227]
# the min tDCF_norm is: 0.2029981619289575
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.27
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.991479754447937
# the tDCF_norm is: [0.5969687  0.59695955 0.5969504  ... 1.58024586 1.58045907 1.58067227]
# the min tDCF_norm is: 0.19993215249067128
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.28
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.991479754447937
# the tDCF_norm is: [0.58476412 0.58475516 0.5847462  ... 1.58024575 1.58045901 1.58067227]
# the min tDCF_norm is: 0.19694092601758445
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.29
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.991479754447937
# the tDCF_norm is: [0.57427477 0.57426599 0.57425721 ... 1.58024611 1.58045919 1.58067227]
# the min tDCF_norm is: 0.1956389693786126
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.3
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.991479754447937
# the tDCF_norm is: [0.562754   0.5627454  0.56273681 ... 1.5802462  1.58045923 1.58067227]
# the min tDCF_norm is: 0.19335449144115288
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.31
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9914579391479492
# the tDCF_norm is: [0.55365899 0.55365058 0.55364218 ... 1.58024698 1.58045963 1.58067227]
# the min tDCF_norm is: 0.1935088110809518
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.32
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9914579391479492
# the tDCF_norm is: [0.54341134 0.54340314 0.54339495 ... 1.58024785 1.58046006 1.58067227]
# the min tDCF_norm is: 0.1936273529767345
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.33
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9914579391479492
# the tDCF_norm is: [0.53392665 0.53391865 0.53391065 ... 1.58024871 1.58046049 1.58067227]
# the min tDCF_norm is: 0.19391314872321982
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.34
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9914040565490723
# the tDCF_norm is: [0.52441562 0.52440784 0.52440007 ... 1.58025    1.58046113 1.58067227]
# the min tDCF_norm is: 0.1953361974377984
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.35000000000000003
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9912895560264587
# the tDCF_norm is: [0.51679729 0.51678973 0.51678217 ... 1.58025169 1.58046198 1.58067227]
# the min tDCF_norm is: 0.19825207999122413
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.36
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9912895560264587
# the tDCF_norm is: [0.51174058 0.51173324 0.5117259  ... 1.58025416 1.58046322 1.58067227]
# the min tDCF_norm is: 0.2038694650490673
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.37
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9912895560264587
# the tDCF_norm is: [0.50865914 0.50865203 0.50864493 ... 1.58025731 1.58046479 1.58067227]
# the min tDCF_norm is: 0.21176947830860937
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.38
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9912895560264587
# the tDCF_norm is: [0.51176513 0.51175826 0.51175139 ... 1.58026223 1.58046725 1.58067227]
# the min tDCF_norm is: 0.22586287214680317
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.39
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9912895560264587
# the tDCF_norm is: [0.51004655 0.51003991 0.51003328 ... 1.58026593 1.5804691  1.58067227]
# the min tDCF_norm is: 0.23555312273626478
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.4
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9912895560264587
# the tDCF_norm is: [0.50928    0.50927362 0.50926724 ... 1.58027013 1.5804712  1.58067227]
# the min tDCF_norm is: 0.2468231342202435
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.41000000000000003
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9912895560264587
# the tDCF_norm is: [0.51657093 0.51656482 0.51655871 ... 1.58027677 1.58047452 1.58067227]
# the min tDCF_norm is: 0.26654577199132584
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.42
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9912895560264587
# the tDCF_norm is: [0.51925269 0.51924686 0.51924102 ... 1.58028227 1.58047727 1.58067227]
# the min tDCF_norm is: 0.2821312364070984
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.43
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9890645146369934
# the tDCF_norm is: [0.53431537 0.53430981 0.53430426 ... 1.58029121 1.58048174 1.58067227]
# the min tDCF_norm is: 0.3096031622774525
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.44
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9890645146369934
# the tDCF_norm is: [0.54954256 0.5495373  0.54953203 ... 1.58030048 1.58048637 1.58067227]
# the min tDCF_norm is: 0.33784540098510535
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.45
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9890645146369934
# the tDCF_norm is: [0.56265817 0.56265321 0.56264824 ... 1.5803092  1.58049073 1.58067227]
# the min tDCF_norm is: 0.3641269591677223
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.46
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9890645146369934
# the tDCF_norm is: [0.58500069 0.58499603 0.58499137 ... 1.58032057 1.58049642 1.58067227]
# the min tDCF_norm is: 0.3997327096692027
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.47000000000000003
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9890217185020447
# the tDCF_norm is: [0.60925898 0.60925463 0.60925028 ... 1.58033249 1.58050238 1.58067227]
# the min tDCF_norm is: 0.43730108054916794
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.48
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9884291291236877
# the tDCF_norm is: [0.63742449 0.63742045 0.63741642 ... 1.5803457  1.58050898 1.58067227]
# the min tDCF_norm is: 0.47920075740401225
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.49
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9884291291236877
# the tDCF_norm is: [0.67478069 0.67477697 0.67477326 ... 1.58036139 1.58051683 1.58067227]
# the min tDCF_norm is: 0.5299756393153632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
# ...
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.84
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: -0.9985764155387878
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.85
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: -0.9985764155387878
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.86
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: -0.9985764155387878
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.87
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: -0.9985764155387878
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.88
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: -0.9985764155387878
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.89
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: -0.9985764155387878
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.9
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: -0.9985764155387878
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.91
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: -0.9985764155387878
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.92
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: -0.9985764155387878
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.93
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: -0.9985764155387878
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.9400000000000001
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: -0.9985764155387878
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.9500000000000001
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: -0.9985764155387878
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.96
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: -0.9985764155387878
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.97
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: -0.9985764155387878
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.98
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: -0.9985764155387878
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  0.99
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: -0.9985764155387878
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# The t-DCF evaluation type is: unconstrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv set  1.0
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: -0.9985764155387878
# the tDCF_norm is: [1.58067227 1.58067227 1.58067227 ... 1.58067227 1.58067227 1.58067227]
# the min tDCF_norm is: 1.5806722689075632
# tDCF - Minimum value: 0.19335449144115288
# Index of minimum value: (30, 50182)
# The min asv score: 0.3
# The min CM thersholds: 0.991479754447937

# %%
heatmap_norm_tdcf(list_tDCF_norm_without_gender,list_asv_score,list_CM_thresholds_without_gender, target_values = [-1,1],title ="Norm t-DCF -  Male&Female on Evaluation Set",point_x_index = min_index[0] ,point_y_index  = min_index[1],point_x_constrained = point_x_constrained, point_y_constrained = point_y_constrained)

# %%
list_asv_score = [0.408,0.403]
CM_thr = pmf_both_thr_spoof_test_all
ASV_thr =  list_asv_score[0]
spoof_score_cm_all_eval = results_eval_without_gender['spoof_score']
think_is_geninue = spoof_score_cm_all_eval.loc[spoof_score_cm_all_eval<CM_thr] 
print(results_eval_without_gender.loc[think_is_geninue.index]['asv_label'].value_counts())
print("--------------------------------------------------------")
to_asv = results_eval_without_gender.loc[(think_is_geninue.index)]
print(to_asv.loc[to_asv['asv_score']>ASV_thr]['asv_label'].value_counts())
print("--------------------------------------------------------")
## all the files inside the system cm -> inside -> asv
indexes = []
path_name = pd.Series(np.concatenate(Eval_dataset_all.name.values)) 
for file in results_eval_without_gender.loc[think_is_geninue.index]['file_name'].values:
    index = path_name.str.contains(file)
    indexes.append(index.loc[index==True].index[0])
print(Eval_dataset_all.attack_logical[indexes].value_counts())
print("--------------------------------------------------------")
## all the files inside the system cm -> asv -> inside
indexes = []
path_name = pd.Series(np.concatenate(Eval_dataset_all.name.values)) # Get the path names of the data set
for file in to_asv.loc[to_asv['asv_score']>ASV_thr]['file_name'].values:
    index = path_name.str.contains(file)
    indexes.append(index.loc[index==True].index[0])
print(Eval_dataset_all.attack_logical[indexes].value_counts())
print("--------------------------------------------------------")
# Out:
# asv_label
# spoof        6787
# target       4816
# nontarget    1758
# Name: count, dtype: int64
# --------------------------------------------------------
# asv_label
# target       4472
# spoof        2083
# nontarget       2
# Name: count, dtype: int64
# --------------------------------------------------------
# [none]    6574
# [A17]     2862
# [A15]     1940
# [A18]     1041
# [A10]      518
# [A14]      346
# [A11]       80
# Name: count, dtype: int64
# --------------------------------------------------------
# [none]    4474
# [A15]     1440
# [A10]      400
# [A14]      181
# [A11]       55
# [A18]        7
# Name: count, dtype: int64
# --------------------------------------------------------

# %%
CM_thr = pmf_both_thr_spoof_test_all
ASV_thr =  list_asv_score[1]
spoof_score_cm_all_eval = results_eval_without_gender['spoof_score']
think_is_geninue = spoof_score_cm_all_eval.loc[spoof_score_cm_all_eval<CM_thr] 
print(results_eval_without_gender.loc[think_is_geninue.index]['asv_label'].value_counts())
print("--------------------------------------------------------")
to_asv = results_eval_without_gender.loc[(think_is_geninue.index)]
print(to_asv.loc[to_asv['asv_score']>ASV_thr]['asv_label'].value_counts())
print("--------------------------------------------------------")
## all the files inside the system cm -> inside -> asv
indexes = []
path_name = pd.Series(np.concatenate(Eval_dataset_all.name.values)) 
for file in results_eval_without_gender.loc[think_is_geninue.index]['file_name'].values:
    index = path_name.str.contains(file)
    indexes.append(index.loc[index==True].index[0])
print(Eval_dataset_all.attack_logical[indexes].value_counts())
print("--------------------------------------------------------")
## all the files inside the system cm -> asv -> inside
indexes = []
path_name = pd.Series(np.concatenate(Eval_dataset_all.name.values)) # Get the path names of the data set
for file in to_asv.loc[to_asv['asv_score']>ASV_thr]['file_name'].values:
    index = path_name.str.contains(file)
    indexes.append(index.loc[index==True].index[0])
print(Eval_dataset_all.attack_logical[indexes].value_counts())
print("--------------------------------------------------------")
# Out:
# asv_label
# spoof        6787
# target       4816
# nontarget    1758
# Name: count, dtype: int64
# --------------------------------------------------------
# asv_label
# target       4510
# spoof        2134
# nontarget       2
# Name: count, dtype: int64
# --------------------------------------------------------
# [none]    6574
# [A17]     2862
# [A15]     1940
# [A18]     1041
# [A10]      518
# [A14]      346
# [A11]       80
# Name: count, dtype: int64
# --------------------------------------------------------
# [none]    4512
# [A15]     1480
# [A10]      404
# [A14]      187
# [A11]       56
# [A18]        7
# Name: count, dtype: int64
# --------------------------------------------------------

# %%
list_asv_score = np.arange(0, 1.01, 0.01)
CM_thr = 1-CM_thresholds_without_gender[min_index]
ASV_thr = list_asv_score[min_index[0]]
spoof_score_cm_all_eval = results_eval_without_gender['spoof_score']
think_is_geninue = spoof_score_cm_all_eval.loc[spoof_score_cm_all_eval<CM_thr] 
print(results_eval_without_gender.loc[think_is_geninue.index]['asv_label'].value_counts())
print("--------------------------------------------------------")
to_asv = results_eval_without_gender.loc[(think_is_geninue.index)]
print(to_asv.loc[to_asv['asv_score']>ASV_thr]['asv_label'].value_counts())
print("--------------------------------------------------------")
## all the files inside the system cm -> inside -> asv
indexes = []
path_name = pd.Series(np.concatenate(Eval_dataset_all.name.values)) 
for file in results_eval_without_gender.loc[think_is_geninue.index]['file_name'].values:
    index = path_name.str.contains(file)
    indexes.append(index.loc[index==True].index[0])
print(Eval_dataset_all.attack_logical[indexes].value_counts())
print("--------------------------------------------------------")
## all the files inside the system cm -> asv -> inside
indexes = []
path_name = pd.Series(np.concatenate(Eval_dataset_all.name.values)) # Get the path names of the data set
for file in to_asv.loc[to_asv['asv_score']>ASV_thr]['file_name'].values:
    index = path_name.str.contains(file)
    indexes.append(index.loc[index==True].index[0])
print(Eval_dataset_all.attack_logical[indexes].value_counts())
print("--------------------------------------------------------")
# Out:
# asv_label
# spoof        33282
# target        5368
# nontarget     1984
# Name: count, dtype: int64
# --------------------------------------------------------
# asv_label
# spoof        21477
# target        5337
# nontarget       58
# Name: count, dtype: int64
# --------------------------------------------------------
# [none]    7352
# [A15]     4905
# [A18]     4838
# [A10]     4793
# [A17]     4793
# [A14]     4633
# [A11]     4577
# [A13]     3693
# [A12]      547
# [A09]      377
# [A19]       99
# [A08]       25
# [A07]        1
# [A16]        1
# Name: count, dtype: int64
# --------------------------------------------------------
# [none]    5395
# [A15]     4819
# [A10]     4631
# [A11]     4420
# [A14]     4407
# [A13]     2164
# [A18]      467
# [A12]      448
# [A17]       91
# [A19]       11
# [A09]       10
# [A08]        7
# [A07]        1
# [A16]        1
# Name: count, dtype: int64
# --------------------------------------------------------

# %% [markdown]
# ### read from ASVspoof2019 scores:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import utils.eval_metrics as eval_metrics 
def read_txt_ASV2019_scores(file_path):
    is_spoofed = []
    label = []
    score = []
    
    with open(file_path, 'r') as file:
        for line in file:
            parts = line.strip().split(' ')
            if len(parts) != 3:
                raise Exception("The line in the file is not in the right format")
            is_spoofed.append(parts[0])
            label.append(parts[1])
            score.append(parts[2])
            
    return pd.Series(is_spoofed), pd.Series(label), pd.Series(score)

# %% [markdown]
# ### Dev

# %%
file_path ="./2019_data_tests/2019/LA/ASVspoof2019_LA_asv_scores/ASVspoof2019.LA.asv.dev.gi.trl.scores.txt"
 
ASV2019_attack_type ,ASV2019_label,ASV2019_scores  = read_txt_ASV2019_scores(file_path)

bonafide_score_cm = results_dev_without_gender.loc[results_dev_without_gender['spoof_ground_truth'] == 0]['spoof_score'].values
bonafide_score_cm = -1*bonafide_score_cm

spoof_score_cm = results_dev_without_gender.loc[(results_dev_without_gender['spoof_ground_truth'] == 1)]['spoof_score'].values
spoof_score_cm = -1*spoof_score_cm

Prior_spoof = 0.05

ASV2019_target_scores = ASV2019_scores.loc[ASV2019_label == "target"].astype(float)
ASV2019_nontarget_scores = ASV2019_scores.loc[ASV2019_label == "nontarget"].astype(float)
ASV2019_spoof_scores = ASV2019_scores.loc[ASV2019_label == "spoof"].astype(float)

ASV2019_eer_scores_dev,ASV2019_thr_eer_scores_dev = eval_metrics.compute_eer(ASV2019_target_scores.values.astype(float),ASV2019_nontarget_scores.values.astype(float))

list_asv_score = [ASV2019_thr_eer_scores_dev]
type = 'constrained'
list_tDCF_norm_without_gender ,list_CM_thresholds_without_gender,list_tDCF_without_gender = compute_t_dcf(bonafide_score_cm,spoof_score_cm,Prior_spoof,ASV2019_target_scores,ASV2019_nontarget_scores,ASV2019_spoof_scores,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  2.40799 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  -3.548998
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [1.         0.99995515 0.9999103  ... 2.40609984 2.40704489 2.40798994]
# the min tDCF_norm is: 0.0007624686042339433

# %%
file_path ="./2019_data_tests/2019/LA/ASVspoof2019_LA_asv_scores/ASVspoof2019.LA.asv.dev.gi.trl.scores.txt"
 
ASV2019_attack_type ,ASV2019_label,ASV2019_scores  = read_txt_ASV2019_scores(file_path)

bonafide_score_cm = results_dev_without_gender.loc[results_dev_without_gender['spoof_ground_truth'] == 0]['spoof_score'].values
bonafide_score_cm = -1*bonafide_score_cm

spoof_score_cm = results_dev_without_gender.loc[(results_dev_without_gender['spoof_ground_truth'] == 1)]['spoof_score'].values
spoof_score_cm = -1*spoof_score_cm

Prior_spoof = 0.05

ASV2019_target_scores = ASV2019_scores.loc[ASV2019_label == "target"].astype(float)
ASV2019_nontarget_scores = ASV2019_scores.loc[ASV2019_label == "nontarget"].astype(float)
ASV2019_spoof_scores = ASV2019_scores.loc[ASV2019_label == "spoof"].astype(float)

ASV2019_eer_scores_dev,ASV2019_thr_eer_scores_dev = eval_metrics.compute_eer(ASV2019_target_scores.values.astype(float),ASV2019_nontarget_scores.values.astype(float))

list_asv_score = [ASV2019_thr_eer_scores_dev]
type = 'constrained_ver2'
list_tDCF_norm_without_gender ,list_CM_thresholds_without_gender,list_tDCF_without_gender  = compute_t_dcf(bonafide_score_cm,spoof_score_cm,Prior_spoof,ASV2019_target_scores,ASV2019_nontarget_scores,ASV2019_spoof_scores,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained_ver2
# t-DCF evaluation from [Nbona=2548, Nspoof=22296] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv development set  -3.548998
# the CM thresholds is:  [-0.99906821 -0.99806821 -0.99745762 ...  0.99947584  0.99949557
#   0.9995724 ]
# the CM threshold min is: 0.8903427720069885
# the tDCF_norm is: [1.         0.99995793 0.99991586 ... 2.31888443 2.31977087 2.3206573 ]
# the min tDCF_norm is: 0.06274164272864087

# %% [markdown]
# ### Eval

# %%
file_path ="./2019_data_tests/2019/LA/ASVspoof2019_LA_asv_scores/ASVspoof2019.LA.asv.eval.gi.trl.scores.txt"
 
ASV2019_attack_type ,ASV2019_label,ASV2019_scores  = read_txt_ASV2019_scores(file_path)

bonafide_score_cm = results_eval_without_gender.loc[results_eval_without_gender['spoof_ground_truth'] == 0]['spoof_score'].values
bonafide_score_cm = -1*bonafide_score_cm

spoof_score_cm = results_eval_without_gender.loc[(results_eval_without_gender['spoof_ground_truth'] == 1)]['spoof_score'].values
spoof_score_cm = -1*spoof_score_cm

Prior_spoof = 0.05

ASV2019_target_scores = ASV2019_scores.loc[ASV2019_label == "target"].astype(float)
ASV2019_nontarget_scores = ASV2019_scores.loc[ASV2019_label == "nontarget"].astype(float)
ASV2019_spoof_scores = ASV2019_scores.loc[ASV2019_label == "spoof"].astype(float)

ASV2019_eer_scores_eval,ASV2019_thr_eer_scores_eval = eval_metrics.compute_eer(ASV2019_target_scores.values.astype(float),ASV2019_nontarget_scores.values.astype(float))


list_asv_score = [ASV2019_thr_eer_scores_dev,ASV2019_thr_eer_scores_eval]
type = 'constrained'
list_tDCF_norm_without_gender ,list_CM_thresholds_without_gender,list_tDCF_without_gender  = compute_t_dcf(bonafide_score_cm,spoof_score_cm,Prior_spoof,ASV2019_target_scores,ASV2019_nontarget_scores,ASV2019_spoof_scores,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  2.43442 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv development set  -3.548998
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9925150275230408
# the tDCF_norm is: [1.         0.99998435 0.99996869 ... 2.43376118 2.43409217 2.43442316]
# the min tDCF_norm is: 0.30933220231708514
# The t-DCF evaluation type is: constrained
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa_asv      = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss_asv    =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_cm       = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#    Cmiss_cm     =  1.00000 (Cost of CM falsely blocking target utterance which never reaches ASV)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
#    tDCF_norm(s) =  2.40595 x Pmiss_cm(s) + Pfa_cm(s)
#
# the asv threshold is from eer on asv evaluation set  -5.680051
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9925150275230408
# the tDCF_norm is: [1.         0.99998435 0.99996869 ... 2.40529113 2.40561824 2.40594536]
# the min tDCF_norm is: 0.3079963981164504

# %%
file_path ="./2019_data_tests/2019/LA/ASVspoof2019_LA_asv_scores/ASVspoof2019.LA.asv.eval.gi.trl.scores.txt"
 
ASV2019_attack_type ,ASV2019_label,ASV2019_scores  = read_txt_ASV2019_scores(file_path)

bonafide_score_cm = results_eval_without_gender.loc[results_eval_without_gender['spoof_ground_truth'] == 0]['spoof_score'].values
bonafide_score_cm = -1*bonafide_score_cm

spoof_score_cm = results_eval_without_gender.loc[(results_eval_without_gender['spoof_ground_truth'] == 1)]['spoof_score'].values
spoof_score_cm = -1*spoof_score_cm

Prior_spoof = 0.05

ASV2019_target_scores = ASV2019_scores.loc[ASV2019_label == "target"].astype(float)
ASV2019_nontarget_scores = ASV2019_scores.loc[ASV2019_label == "nontarget"].astype(float)
ASV2019_spoof_scores = ASV2019_scores.loc[ASV2019_label == "spoof"].astype(float)

ASV2019_eer_scores_eval,ASV2019_thr_eer_scores_eval = eval_metrics.compute_eer(ASV2019_target_scores.values.astype(float),ASV2019_nontarget_scores.values.astype(float))


list_asv_score = [ASV2019_thr_eer_scores_dev,ASV2019_thr_eer_scores_eval]
type = 'constrained_ver2'
list_tDCF_norm_without_gender ,list_CM_thresholds_without_gender,list_tDCF_without_gender  = compute_t_dcf(bonafide_score_cm,spoof_score_cm,Prior_spoof,ASV2019_target_scores,ASV2019_nontarget_scores,ASV2019_spoof_scores,list_asv_score,type)
# Out:
# The t-DCF evaluation type is: constrained_ver2
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv development set  -3.548998
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9925150275230408
# the tDCF_norm is: [1.         0.99998569 0.99997138 ... 2.31047232 2.31077484 2.31107737]
# the min tDCF_norm is: 0.3687226000912288
# The t-DCF evaluation type is: constrained_ver2
# t-DCF evaluation from [Nbona=7355, Nspoof=63882] trials
#
# t-DCF MODEL
#    Ptar         =  0.94050 (Prior probability of target user)
#    Pnon         =  0.00950 (Prior probability of nontarget user)
#    Pspoof       =  0.05000 (Prior probability of spoofing attack)
#    Cfa          = 10.00000 (Cost of ASV falsely accepting a nontarget)
#    Cmiss        =  1.00000 (Cost of ASV falsely rejecting target speaker)
#    Cfa_spoof    = 10.00000 (Cost of CM falsely passing a spoof to ASV system)
#
#    Implied normalized t-DCF function (depends on t-DCF parameters and ASV errors), s=CM threshold)
# the asv threshold is from eer on asv evaluation set  -5.680051
# the CM thresholds is:  [-0.99857642 -0.99757642 -0.99740851 ...  0.99954319  0.99956065
#   0.99961752]
# the CM threshold min is: 0.9925150275230408
# the tDCF_norm is: [1.         0.99998533 0.99997066 ... 2.31713317 2.31743976 2.31774636]
# the min tDCF_norm is: 0.3514077764955439
