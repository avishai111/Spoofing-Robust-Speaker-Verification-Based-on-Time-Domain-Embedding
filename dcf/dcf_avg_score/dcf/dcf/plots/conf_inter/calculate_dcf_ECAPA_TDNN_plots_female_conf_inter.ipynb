# %%
import sys
sys.path.append('../')
import scipy.io as sio
import mat73
import pandas as pd
import torch
import numpy as np
import torch.optim as optim
import torch.nn
import sklearn
import sklearn.metrics
import matplotlib.pyplot as plt
from alive_progress import alive_bar
from  utils.my_classes import dataset 
from torch.utils.data import DataLoader
import utils.DNN_functions as DNN_functions
import scipy
import random
import utils.AMSloss
from speechbrain.pretrained import SpeakerRecognition
import pickle
import os
from utils.my_classes import dataset
import utils.eval_metrics as eval_metrics
import copy
from speechbrain.pretrained import SpeakerRecognition

seed = 42  # You can choose any integer value as the seed
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
# Set seed for Python's random module
random.seed(seed)
# Set seed for NumPy
np.random.seed(seed)
# Set seed for PyTorch (CPU and GPU, if available)
if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
# Set deterministic flags for PyTorch (if available)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
#To get my GPU device - GTX 4070 :)
seed = 42  # You can choose any integer value as the seed
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu');

if torch.cuda.is_available():
    print(torch.cuda.device_count())
    print(torch.cuda.device(0))
    print(torch.cuda.get_device_name(0))
    print(device)
# Out:
# 1
# <torch.cuda.device object at 0x0000025314F6AD30>
# NVIDIA GeForce RTX 4070
# cuda

# %%
from ASV_utils.data_loading import *

models_folder = "ECAPA_TDNN/inference_models/"

data_path_male = "Data/not_normalize_all_features/male/"

data_path_female = "Data/not_normalize_all_features/female/"

male_embedded_groups_1_1,male_embedded_groups_1_2,male_embedded_groups_1_3,male_chosen_labels_1_1_is_spoofed,male_chosen_labels_2_1_is_spoofed,male_chosen_labels_3_1_is_spoofed,male_chosen_labels_numeric_1_1,male_chosen_labels_numeric_2_1,male_chosen_labels_numeric_3_1,male_chosen_labels_1_1_attack_logical,male_chosen_labels_2_1_attack_logical,male_chosen_labels_3_1_attack_logical,male_chosen_labels_1_1_name,male_chosen_labels_2_1_name,male_chosen_labels_3_1_name,male_chosen_labels_1_1_speaker_id,male_chosen_labels_2_1_speaker_id,male_chosen_labels_3_1_speaker_id,male_chosen_labels_1_1_sex,male_chosen_labels_2_1_sex,male_chosen_labels_3_1_sex  = load_data_male(data_path_male)

female_embedded_groups_1_1,female_embedded_groups_1_2,female_embedded_groups_1_3,female_chosen_labels_1_1_is_spoofed,female_chosen_labels_2_1_is_spoofed,female_chosen_labels_3_1_is_spoofed,female_chosen_labels_numeric_1_1,female_chosen_labels_numeric_2_1,female_chosen_labels_numeric_3_1,female_chosen_labels_1_1_attack_logical,female_chosen_labels_2_1_attack_logical,female_chosen_labels_3_1_attack_logical,female_chosen_labels_1_1_name,female_chosen_labels_2_1_name,female_chosen_labels_3_1_name,female_chosen_labels_1_1_speaker_id,female_chosen_labels_2_1_speaker_id,female_chosen_labels_3_1_speaker_id,female_chosen_labels_1_1_sex,female_chosen_labels_2_1_sex,female_chosen_labels_3_1_sex  = load_data_female(data_path_female)

# %%
import utils.my_functions as my_functions

columns_names,max_name_length = my_functions.get_columns_names_feature_importance(substruct=True)
true_channels_indexes = np.array(my_functions.get_real_channel(np.linspace(start=1, stop=len(columns_names), num=len(columns_names)),len(columns_names)))
true_channels_indexes = true_channels_indexes - 1
true_channels_indexes = true_channels_indexes.astype(int)
columns_names = np.array(columns_names)

female_embedded_groups_1_1 = female_embedded_groups_1_1[:,true_channels_indexes]
female_embedded_groups_1_2 = female_embedded_groups_1_2[:,true_channels_indexes]
female_embedded_groups_1_3 = female_embedded_groups_1_3[:,true_channels_indexes]

male_embedded_groups_1_1 = male_embedded_groups_1_1[:,true_channels_indexes]
male_embedded_groups_1_2 = male_embedded_groups_1_2[:,true_channels_indexes]
male_embedded_groups_1_3 = male_embedded_groups_1_3[:,true_channels_indexes]

# %%
from sklearn.preprocessing import StandardScaler
import re

your_list = columns_names[true_channels_indexes]
index_mapping ={}

# Define the custom sorting order for distance metrics
distance_metrics = [
    'Chi-square',
    'Correlation',
    'Hellinger',
    'Intersection',
    'Jensen-Shannon',
    'Kullback-Leibler Divergence',
    'Modified Kolmogorov-Smirnov',
    'Symmetrised Kullback-Leibler'
]

def custom_sort_key(item):
    # Use regex to extract gammatone, gammatone_inv, channel number, and distance metric
    match = re.search(r'filter-(gammatone(?:_inv)?)-channel-(\d+)-distance-(.+?)-\[d_', item)
    if match:
        gammatone = match.group(1)
        channel = int(match.group(2))
        distance_metric = match.group(3)

        # Assign a higher priority to distance_order, a medium priority to channels,
        # and lower priority to 'gammatone' and 'gammatone_inv'
        return (distance_metrics.index(distance_metric), channel, gammatone)

    else:
        # If the regex doesn't match, return the original item to maintain its position
        return (999, 999, "")

# Sort the list based on the custom order
sorted_list = sorted(your_list, key=custom_sort_key)

for new_index, item in enumerate(sorted_list):
    old_index = np.where(columns_names[true_channels_indexes] == item)[0][0]
    index_mapping[old_index] = new_index
    
male_embedded_groups_1_1 = male_embedded_groups_1_1[:,list(index_mapping.keys())]
male_embedded_groups_1_2 = male_embedded_groups_1_2[:,list(index_mapping.keys())]
male_embedded_groups_1_3 = male_embedded_groups_1_3[:,list(index_mapping.keys())]

female_embedded_groups_1_1 = female_embedded_groups_1_1[:,list(index_mapping.keys())]
female_embedded_groups_1_2 = female_embedded_groups_1_2[:,list(index_mapping.keys())]
female_embedded_groups_1_3 = female_embedded_groups_1_3[:,list(index_mapping.keys())]

# %%
scaler_male = StandardScaler(with_mean = True, with_std = True)
scaler_male.fit(male_embedded_groups_1_1)
mean_features = scaler_male.mean_
std_features = scaler_male.scale_
male_embedded_groups_1_1 = scaler_male.transform(male_embedded_groups_1_1)
male_embedded_groups_1_2 = scaler_male.transform(male_embedded_groups_1_2)
male_embedded_groups_1_3 = scaler_male.transform(male_embedded_groups_1_3)


scaler_female = StandardScaler(with_mean = True, with_std = True)
scaler_female.fit(female_embedded_groups_1_1)
mean_features = scaler_female.mean_
std_features = scaler_female.scale_
female_embedded_groups_1_1 = scaler_female.transform(female_embedded_groups_1_1)
female_embedded_groups_1_2 = scaler_female.transform(female_embedded_groups_1_2)
female_embedded_groups_1_3 = scaler_female.transform(female_embedded_groups_1_3)

# %%
embedded_groups_1_1,embedded_groups_1_2,embedded_groups_1_3,chosen_labels_1_1_is_spoofed,chosen_labels_2_1_is_spoofed,chosen_labels_3_1_is_spoofed,chosen_labels_numeric_1_1,chosen_labels_numeric_2_1,chosen_labels_numeric_3_1,chosen_labels_1_1_attack_logical,chosen_labels_2_1_attack_logical,chosen_labels_3_1_attack_logical,chosen_labels_1_1_name,chosen_labels_2_1_name,chosen_labels_3_1_name,chosen_labels_1_1_speaker_id,chosen_labels_2_1_speaker_id,chosen_labels_3_1_speaker_id,chosen_labels_1_1_sex,chosen_labels_2_1_sex,chosen_labels_3_1_sex    =  concatenate_data(male_embedded_groups_1_1,male_embedded_groups_1_2,male_embedded_groups_1_3,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    male_chosen_labels_1_1_is_spoofed,male_chosen_labels_2_1_is_spoofed,male_chosen_labels_3_1_is_spoofed,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    male_chosen_labels_numeric_1_1,male_chosen_labels_numeric_2_1,male_chosen_labels_numeric_3_1,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    male_chosen_labels_1_1_attack_logical,male_chosen_labels_2_1_attack_logical,male_chosen_labels_3_1_attack_logical,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    male_chosen_labels_1_1_name,male_chosen_labels_2_1_name,male_chosen_labels_3_1_name,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    male_chosen_labels_1_1_speaker_id,male_chosen_labels_2_1_speaker_id, male_chosen_labels_3_1_speaker_id,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    male_chosen_labels_1_1_sex,male_chosen_labels_2_1_sex,male_chosen_labels_3_1_sex,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    female_embedded_groups_1_1,female_embedded_groups_1_2,female_embedded_groups_1_3,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    female_chosen_labels_1_1_is_spoofed,female_chosen_labels_2_1_is_spoofed,female_chosen_labels_3_1_is_spoofed,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    female_chosen_labels_numeric_1_1,female_chosen_labels_numeric_2_1,female_chosen_labels_numeric_3_1,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    female_chosen_labels_1_1_attack_logical,female_chosen_labels_2_1_attack_logical,female_chosen_labels_3_1_attack_logical,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    female_chosen_labels_1_1_name,female_chosen_labels_2_1_name,female_chosen_labels_3_1_name,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    female_chosen_labels_1_1_speaker_id,female_chosen_labels_2_1_speaker_id,female_chosen_labels_3_1_speaker_id,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    female_chosen_labels_1_1_sex,female_chosen_labels_2_1_sex,female_chosen_labels_3_1_sex)

# %%
train_dataset_all = dataset(data = embedded_groups_1_1 , is_spoofed = chosen_labels_1_1_is_spoofed , chosen_labels_numeric = chosen_labels_numeric_1_1,
                        attack_logical = chosen_labels_1_1_attack_logical, name = chosen_labels_1_1_name , speaker_id = chosen_labels_1_1_speaker_id, sex = chosen_labels_1_1_sex ,data_transform = None , labels_transform = None);

Dev_dataset_all = dataset(data = embedded_groups_1_2 , is_spoofed = chosen_labels_2_1_is_spoofed , chosen_labels_numeric = chosen_labels_numeric_2_1,
                        attack_logical = chosen_labels_2_1_attack_logical, name = chosen_labels_2_1_name , speaker_id = chosen_labels_2_1_speaker_id, sex = chosen_labels_2_1_sex ,  data_transform = None , labels_transform = None);


Eval_dataset_all = dataset(data = embedded_groups_1_3 , is_spoofed = chosen_labels_3_1_is_spoofed , chosen_labels_numeric = chosen_labels_numeric_3_1,
                        attack_logical = chosen_labels_3_1_attack_logical, name = chosen_labels_3_1_name , speaker_id = chosen_labels_3_1_speaker_id, sex = chosen_labels_3_1_sex , data_transform = None , labels_transform = None);

# %%
from ASV_utils.data_loading import *


models_folder = "ECAPA_TDNN/inference_models/models_both_not_normalize/"

data_path_male = "Data/male_vs_female_DB_models/16_bits/none/male/"

data_path_female = "Data/male_vs_female_DB_models/16_bits/none/female/"

g_male_embedded_groups_1_1,g_male_embedded_groups_1_2,g_male_embedded_groups_1_3,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_  = load_data_male(data_path_male)

g_female_embedded_groups_1_1,g_female_embedded_groups_1_2,g_female_embedded_groups_1_3,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_  = load_data_female(data_path_female)

embedded_groups_1_1,embedded_groups_1_2,embedded_groups_1_3,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_,_    =  concatenate_data(g_male_embedded_groups_1_1,g_male_embedded_groups_1_2,g_male_embedded_groups_1_3,
                                                                                                                    male_chosen_labels_1_1_is_spoofed,male_chosen_labels_2_1_is_spoofed,male_chosen_labels_3_1_is_spoofed,
                                                                                                                    male_chosen_labels_numeric_1_1,male_chosen_labels_numeric_2_1,male_chosen_labels_numeric_3_1,
                                                                                                                    male_chosen_labels_1_1_attack_logical,male_chosen_labels_2_1_attack_logical,male_chosen_labels_3_1_attack_logical,
                                                                                                                    male_chosen_labels_1_1_name,male_chosen_labels_2_1_name,male_chosen_labels_3_1_name,
                                                                                                                    male_chosen_labels_1_1_speaker_id,male_chosen_labels_2_1_speaker_id, male_chosen_labels_3_1_speaker_id,
                                                                                                                    male_chosen_labels_1_1_sex,male_chosen_labels_2_1_sex,male_chosen_labels_3_1_sex,
                                                                                                                    
                                                                                                                    g_female_embedded_groups_1_1,g_female_embedded_groups_1_2,g_female_embedded_groups_1_3,
                                                                                                                    female_chosen_labels_1_1_is_spoofed,female_chosen_labels_2_1_is_spoofed,female_chosen_labels_3_1_is_spoofed,
                                                                                                                    female_chosen_labels_numeric_1_1,female_chosen_labels_numeric_2_1,female_chosen_labels_numeric_3_1,
                                                                                                                    female_chosen_labels_1_1_attack_logical,female_chosen_labels_2_1_attack_logical,female_chosen_labels_3_1_attack_logical,
                                                                                                                    female_chosen_labels_1_1_name,female_chosen_labels_2_1_name,female_chosen_labels_3_1_name,
                                                                                                                    female_chosen_labels_1_1_speaker_id,female_chosen_labels_2_1_speaker_id,female_chosen_labels_3_1_speaker_id,
                                                                                                                    female_chosen_labels_1_1_sex,female_chosen_labels_2_1_sex,female_chosen_labels_3_1_sex)

# %%
import utils.my_functions as my_functions

columns_names,max_name_length = my_functions.get_columns_names_feature_importance(substruct=True)
true_channels_indexes = np.array(my_functions.get_real_channel(np.linspace(start=1, stop=len(columns_names), num=len(columns_names)),len(columns_names)))
true_channels_indexes = true_channels_indexes - 1
true_channels_indexes = true_channels_indexes.astype(int)
columns_names = np.array(columns_names)

embedded_groups_1_1 = embedded_groups_1_1[:,true_channels_indexes]
embedded_groups_1_2 = embedded_groups_1_2[:,true_channels_indexes]
embedded_groups_1_3 = embedded_groups_1_3[:,true_channels_indexes]

from sklearn.preprocessing import StandardScaler
import re

your_list = columns_names[true_channels_indexes]
index_mapping ={}

# Define the custom sorting order for distance metrics
distance_metrics = [
    'Chi-square',
    'Correlation',
    'Hellinger',
    'Intersection',
    'Jensen-Shannon',
    'Kullback-Leibler Divergence',
    'Modified Kolmogorov-Smirnov',
    'Symmetrised Kullback-Leibler'
]

def custom_sort_key(item):
    # Use regex to extract gammatone, gammatone_inv, channel number, and distance metric
    match = re.search(r'filter-(gammatone(?:_inv)?)-channel-(\d+)-distance-(.+?)-\[d_', item)
    if match:
        gammatone = match.group(1)
        channel = int(match.group(2))
        distance_metric = match.group(3)

        # Assign a higher priority to distance_order, a medium priority to channels,
        # and lower priority to 'gammatone' and 'gammatone_inv'
        return (distance_metrics.index(distance_metric), channel, gammatone)

    else:
        # If the regex doesn't match, return the original item to maintain its position
        return (999, 999, "")

# Sort the list based on the custom order
sorted_list = sorted(your_list, key=custom_sort_key)

for new_index, item in enumerate(sorted_list):
    old_index = np.where(columns_names[true_channels_indexes] == item)[0][0]
    index_mapping[old_index] = new_index
    

embedded_groups_1_1 = embedded_groups_1_1[:,list(index_mapping.keys())]
embedded_groups_1_2 = embedded_groups_1_2[:,list(index_mapping.keys())]
embedded_groups_1_3 = embedded_groups_1_3[:,list(index_mapping.keys())]


scaler = StandardScaler(with_mean = True, with_std = True)
scaler.fit(embedded_groups_1_1)
mean_features = scaler.mean_
std_features = scaler.scale_

embedded_groups_1_1 = scaler.transform(embedded_groups_1_1)
embedded_groups_1_2 = scaler.transform(embedded_groups_1_2)
embedded_groups_1_3 = scaler.transform(embedded_groups_1_3)

train_dataset_all.data_for_gender_classification = embedded_groups_1_1
Dev_dataset_all.data_for_gender_classification   = embedded_groups_1_2
Eval_dataset_all.data_for_gender_classification  = embedded_groups_1_3


train_dataset_all.sex = pd.Series([elem[0] for elem in train_dataset_all.sex])
Dev_dataset_all.sex = pd.Series([elem[0] for elem in Dev_dataset_all.sex])
Eval_dataset_all.sex = pd.Series([elem[0] for elem in Eval_dataset_all.sex])


train_dataset_all.name = pd.Series([name[0] for name in train_dataset_all.name])
Dev_dataset_all.name = pd.Series([name[0] for name in Dev_dataset_all.name])
Eval_dataset_all.name = pd.Series([name[0] for name in Eval_dataset_all.name])

# %%
import torchaudio
from speechbrain.pretrained import EncoderClassifier

# load the model - the moodel that check if it's female or male
with open(os.path.join(models_folder,"gender_XGB_model_both_norm_male_vs_female_db_models.pkl"), 'rb') as fp:
#with open(os.path.join(models_folder,"gender_XGB_model_both_norm_male_vs_female_db_models.pkl"), 'rb') as fp:
    gender_model = pickle.load(fp)
    
# load the model - the model that check if it's the sampe speaker or not
verification_model = SpeakerRecognition.from_hparams(source="speechbrain/spkrec-ecapa-voxceleb", savedir='./ECAPA_TDNN/pretrained_models/spkrec-ecapa-voxceleb',run_opts={"device":"cuda"} )

classifier = EncoderClassifier.from_hparams(source="speechbrain/spkrec-ecapa-voxceleb", savedir='./ECAPA_TDNN/pretrained_models/spkrec-ecapa-voxceleb',run_opts={"device":"cuda"})

# %%
import pickle
from ASV_utils.ASV_my_functions import *
# Load the embeddings file:

with open('./ECAPA_TDNN/embeddings/dev_embedding_ecapa_voxceleb_flac.pkl', 'rb') as file:
    list_dev_files,embeddings_dev = pickle.load(file)
    list_dev_files = [name.rstrip('.flac') for name in list_dev_files]
    
with open('./ECAPA_TDNN/embeddings/eval_embedding_ecapa_voxceleb_flac.pkl', 'rb') as file:
    list_eval_files,embeddings_eval = pickle.load(file)
    list_eval_files = [name.rstrip('.flac') for name in list_eval_files]


embeddings_dev =[emb.cpu() for emb in embeddings_dev]
embeddings_dev = np.concatenate(embeddings_dev, axis=0)
embeddings_eval =[emb.cpu() for emb in embeddings_eval]
embeddings_eval = np.concatenate(embeddings_eval, axis=0)


path_enrollment_dev_female = "./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.dev.female.trn.txt"

path_enrollment_dev_male = "./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.dev.male.trn.txt"

path_enrollment_eval_female = "./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.eval.female.trn.txt"

path_enrollment_eval_male = "./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.eval.male.trn.txt"


# enrollment_dev_female = make_enrollment(path_enrollment_dev_female,"female")

# enrollment_dev_male = make_enrollment(path_enrollment_dev_male,"male")

# enrollment_eval_female = make_enrollment(path_enrollment_eval_female,"female")

# enrollment_eval_male = make_enrollment(path_enrollment_eval_male,"male")

# enrollment_dev_female = extract_embeddings(list_dev_files,embeddings_dev,enrollment_dev_female)
# list_dev_files,embeddings_dev = remove_enrollment_embeddings_from_embeddings_list(list_dev_files,embeddings_dev,enrollment_dev_female)

# enrollment_dev_male = extract_embeddings(list_dev_files,embeddings_dev,enrollment_dev_male)
# list_dev_files,embeddings_dev = remove_enrollment_embeddings_from_embeddings_list(list_dev_files,embeddings_dev,enrollment_dev_male)

# enrollment_eval_female = extract_embeddings(list_eval_files,embeddings_eval,enrollment_eval_female)
# list_eval_files,embeddings_eval = remove_enrollment_embeddings_from_embeddings_list(list_eval_files,embeddings_eval,enrollment_eval_female)

# enrollment_eval_male = extract_embeddings(list_eval_files,embeddings_eval,enrollment_eval_male)
# list_eval_files,embeddings_eval = remove_enrollment_embeddings_from_embeddings_list(list_eval_files,embeddings_eval,enrollment_eval_male)

# %%
from ASV_utils.dcf_my_functions import dcf_formula

# read the protocol files

path_dev_female_protocol ="./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.dev.female.trl.txt"

path_dev_male_protocol ="./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.dev.male.trl.txt"

path_eval_female_protocol ="./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.eval.female.trl.txt"

path_eval_male_protocol ="./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.eval.male.trl.txt"

path_dev_all_protocol ="./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.dev.gi.trl.txt"

path_eval_all_protocol ="./ECAPA_TDNN/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.eval.gi.trl.txt"

df_dev_female_protocol = pd.read_csv(path_dev_female_protocol, delimiter=' ', names=['speaker_id', 'audio_filename', 'attack_type', 'label'])

df_dev_male_protocol = pd.read_csv(path_dev_male_protocol, delimiter=' ', names=['speaker_id', 'audio_filename', 'attack_type', 'label'])

df_dev_all_protocol = pd.read_csv(path_dev_all_protocol, delimiter=' ', names=['speaker_id', 'audio_filename', 'attack_type', 'label'])

df_eval_female_protocol = pd.read_csv(path_eval_female_protocol, delimiter=' ', names=['speaker_id', 'audio_filename', 'attack_type', 'label'])

df_eval_male_protocol = pd.read_csv(path_eval_male_protocol, delimiter=' ', names=['speaker_id', 'audio_filename', 'attack_type', 'label'])

df_eval_all_protocol = pd.read_csv(path_eval_all_protocol, delimiter=' ', names=['speaker_id', 'audio_filename', 'attack_type', 'label'])


# False alarm rate of the ASV system (nontarget trials that were falsely accepted) - depent on the ASV system result
Pfa_asv = 0.5 #number of nontarget that were falsely accepted / number of nontarget samples

# Miss rate of the ASV system (fraction of genuine cases falsely rejected) - depent on the ASV system result
Pmiss_asv = 0.5  #number of target that were falsely rejected / number of target samples

Prior_target =  0.99

Prior_non_target = 1-Prior_target

cost_model_dcf = {
    'Cmiss_asv': 1,      # Cost of ASV falsely rejecting target
    'Cfa_asv': 10,       # Cost of ASV falsely accepting nontarget
}


## check the DCF for the eval set
dcf_formula(Pfa_asv,Pmiss_asv,Prior_target,Prior_non_target,cost_model_dcf,is_print=True)
# Out:
# The DCF is:  0.545
# 0.545

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plotting_probability_histogram(nontarget_scores,target_scores,spoof_scores = None,num_bins=100,colors=['yellow', 'purple'],data_name=None):
    if data_name is None:
        raise Exception("Please insert data name")
    if spoof_scores is None:
        if len(colors) != 2:
            raise Exception("Please insert 2 colors")
        plt.figure()
        sns.histplot(nontarget_scores, kde=True, stat='probability', bins=num_bins, color=colors[0], linewidth=1)# Add labels and title
        sns.histplot(target_scores, kde=True, stat='probability', bins=num_bins, color=colors[1], linewidth=1)# Add labels and title
        plt.legend(['bonafide','spoof'])
        plt.xlabel('scores')
        plt.ylabel('probability')
        
        plt.title(f"Probability of target scores and Probability of Non-target scores on " + data_name)
        # Add legend
        # Show the plot
        plt.show()

        plt.figure()
        sns.histplot([nontarget_scores.to_numpy(), target_scores.to_numpy()], kde=True, stat='probability', bins=num_bins, palette=colors, linewidth=1)# Add labels and title
        plt.legend(['target_scores','nontarget scores'])
        plt.xlabel('scores')
        plt.ylabel('probability')
        plt.title(f"Probability over target scores and Non-target scores on " + data_name)
        # Add legend
        # Show the plot
        plt.show()
    else:
        if len(colors) != 3:
            raise Exception("Please insert 2 colors")
        plt.figure()
        sns.histplot(nontarget_scores, kde=True, stat='probability', bins=num_bins, color=colors[0], linewidth=1)# Add labels and title
        sns.histplot(target_scores, kde=True, stat='probability', bins=num_bins, color=colors[1], linewidth=1)# Add labels and title
        sns.histplot(spoof_scores, kde=True, stat='probability', bins=num_bins, color=colors[2], linewidth=1)# Add labels and title
        plt.legend(['nontarget scores','target scores','spoof scores'])
        plt.xlabel('scores')
        plt.ylabel('probability')
        plt.title(f"Probability of target scores and Probability of Non-target scores and Probability of spoof scores on " + data_name)
        plt.show()
        
        plt.figure()
        sns.histplot([nontarget_scores.to_numpy(), target_scores.to_numpy(),spoof_scores.to_numpy()], kde=True, stat='probability', bins=100, palette=colors, linewidth=1)# Add labels and title
        plt.legend(['spoof scores','target_scores','nontarget scores'])
        plt.xlabel('scores')
        plt.ylabel('probability')
        plt.title(f"Probability over target scores and Non-target scores and Probability of spoof scores on " + data_name)
        # Show the plot
        plt.show()

        
def plotting_eer_and_dcf(asv_score_list,dcf_list,frr,far,eer,thr_eer,data_name = None):
    if data_name is None:
        raise Exception("Please insert data name")
    plt.figure()
    plt.plot(asv_score_list,dcf_list, label = 'DCF vs threshold')
    minDCF_index = np.argmin(np.array(dcf_list))
    plt.plot(asv_score_list[minDCF_index],dcf_list[minDCF_index],color ='red', marker = 'o',label =f'minDCF={dcf_list[minDCF_index]:.3f}, threshold={asv_score_list[minDCF_index]:.3f}')
    plt.title(f"DCF metric on " + data_name)
    plt.ylabel("DCF metric")
    plt.xlabel("ASV threshold")
    plt.legend(loc = 'lower right')
    plt.show()

    plt.figure()
    plt.plot(frr,far,label ='DET curve')
    plt.plot(eer,eer,color ='red', marker = 'o',label =f'EER ({100*eer:.3f}%,{100*eer:.3f}%), threshold err = {thr_eer:.3f}')
    plt.ylabel("False Rejection Rate (FRR)")
    plt.xlabel("False Acceptance Rate (FAR)")
    plt.title("DET curve on " + data_name)
    plt.legend(loc = 'upper right')
    plt.show()

# %%
def plotting_probability_histogram_TTS_and_VC(nontarget_scores,target_scores,TTS_scores,VC_scores,combine_TTS_VC_scores,num_bins=100,colors=['yellow', 'purple'],data_name=None):
        if data_name is None:
            raise Exception("Please insert data name")
        if len(colors) != 5:
            raise Exception("Please insert 5 colors")
        if combine_TTS_VC_scores is None:
            plt.figure()
            sns.histplot(nontarget_scores, kde=True, stat='probability', bins=num_bins, color=colors[0], linewidth=1)# Add labels and title
            sns.histplot(target_scores, kde=True, stat='probability', bins=num_bins, color=colors[1], linewidth=1)# Add labels and title
            sns.histplot(TTS_scores, kde=True, stat='probability', bins=num_bins, color=colors[2], linewidth=1)# Add labels and title
            sns.histplot(VC_scores, kde=True, stat='probability', bins=num_bins, color=colors[3], linewidth=1)# Add labels and title
            plt.legend(['Non-Target scores','Target scores','TTS scores','VC scores'])
            plt.xlabel('scores')
            plt.ylabel('probability')
            plt.title(f"Scores for Target and Non-Target, TTS, VC " + data_name)
            plt.show()
            
            plt.figure()
            sns.histplot([nontarget_scores.to_numpy(), target_scores.to_numpy(),TTS_scores.to_numpy(),VC_scores.to_numpy()], kde=True, stat='probability', bins=100, palette=colors, linewidth=1)# Add labels and title
            plt.legend(['VC scores','TTS scores','Target scores','Non-Target scores'])
            plt.xlabel('scores')
            plt.ylabel('probability')
            plt.title(f"Scores for Target and Non-Target, TTS, VC " + data_name)
            # Show the plot
            plt.show()
        else:
            plt.figure()
            sns.histplot(nontarget_scores, kde=True, stat='probability', bins=num_bins, color=colors[0], linewidth=1)# Add labels and title
            sns.histplot(target_scores, kde=True, stat='probability', bins=num_bins, color=colors[1], linewidth=1)# Add labels and title
            sns.histplot(TTS_scores, kde=True, stat='probability', bins=num_bins, color=colors[2], linewidth=1)# Add labels and title
            sns.histplot(VC_scores, kde=True, stat='probability', bins=num_bins, color=colors[3], linewidth=1)# Add labels and title
            sns.histplot(combine_TTS_VC_scores, kde=True, stat='probability', bins=num_bins, color=colors[4], linewidth=1)# Add labels and title
            
            plt.legend(['Non-Target scores','Target scores','TTS scores','VC scores','combine TTS and VC scores'])
            plt.xlabel('scores')
            plt.ylabel('probability')
            plt.title(f"Scores for Target and Non-Target, TTS, VC, and Combined TTS-VC  " + data_name)
            plt.show()
            
            plt.figure()
            sns.histplot([nontarget_scores.to_numpy(), target_scores.to_numpy(),TTS_scores.to_numpy(),VC_scores.to_numpy(),combine_TTS_VC_scores.to_numpy()], kde=True, stat='probability', bins=100, palette=colors, linewidth=1)# Add labels and title
            plt.legend(['combine TTS and VC scores','VC scores','TTS scores','Target scores','Non-Target scores'])
            plt.xlabel('scores')
            plt.ylabel('probability')
            plt.title(f"Scores for Target and Non-Target, TTS, VC, and Combined TTS-VC  " + data_name)
            # Show the plot
            plt.show()

# %%
'''
import torch
import torchaudio
def calculate_dcf_avg_score(list_files,df_protocol,enrollment,embeddings,dataset_all): # CALCULATE THE DCF FOR THE ASV SYSTEM
    
    thr_gender = 0.5
    
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu');
    #path_names = pd.Series(np.array(list_files)) # Get the path names of the data set # Get the path names of the data set
    all_speakers_id_enroll = np.array(enrollment.get_all_speakers_id())  # Get all the speakers id in the enrollment data set
    
    labels_list = []; avg_scores_pred_list = []; # labels_list and scores_list for each asv score
    gender_list = [];
    gender_pred_list =[]
    audio_filename_list = []; speaker_id_list = []; attack_type_list = [];  # audio_filename_list and speaker_id_list for each asv score
    for _, row in tqdm.tqdm(df_protocol.iterrows(), total=len(df_protocol)): # over each row in the protocol file
        
        audio_filename = row['audio_filename'] # Get the audio filename
        speaker_id = row['speaker_id'] # Get the speaker id
        attack_type = row['attack_type'] # Get the attack type
        try:
            #index_embeddings = path_names.str.contains(audio_filename) # Get the index of the current audio filename
            index_time_embeddings = dataset_all.name.str.contains(audio_filename) # Get the index of the current audio filename
            index_time_embeddings = np.where(index_time_embeddings.values == True)
            if len(index_time_embeddings) > 1 or len(index_time_embeddings) == 0: #problem with the index
                raise Exception("The audio filename is not in the embeddings data set")
        except Exception as e:    
            raise Exception("The speaker id is not in the enrollment data set")
        
        with torch.no_grad():
            if gender_model.predict_proba([dataset_all.data_for_gender_classification[index_time_embeddings[0][0]]])[:,1] > thr_gender: #need to normalize the data
                its_male = True
            else:
                its_male = False
        
        gender = dataset_all.sex.values[index_time_embeddings[0][0]]
        curr_signal,_ = torchaudio.load(str(dataset_all.name.values[index_time_embeddings[0][0]]))
        
        label = row['label'] # Get the label of the current audio filename
        find_speaker_in_enroll = False # initialize the find_speaker_in_enroll flag
        list_scores_speaker = [] # initialize the list of scores speaker
        for index_speaker,embedding_in_enroll_per_speaker in enumerate(enrollment.get_all_enrollment_embeddings()): # over each speaker in the enrollment data set
            embedding_in_enroll_per_speaker = np.array(embedding_in_enroll_per_speaker)
            for _,embedding_in_enroll in enumerate(embedding_in_enroll_per_speaker):
                if speaker_id == all_speakers_id_enroll[index_speaker]: # i know that the speaker id of the inferece input
                    find_speaker_in_enroll = True
                    
                    curr_embedding = classifier.encode_batch(curr_signal.to(device)).cpu().numpy().squeeze(0)
                    
                    score = cosine_similarity(embedding_in_enroll.squeeze().reshape(1, -1), curr_embedding.reshape(1, -1)) # calculate the cosine similarity between the current embedding and the enrollment embedding
                    list_scores_speaker.append(score.item()) # append the score to the list of scores
        
        avg_score_pred = np.average(list_scores_speaker, axis = 0) # calculate the average score 
        
        if find_speaker_in_enroll == False:
            raise Exception("The speaker id is not in the enrollment data set")
        
        gender_list.append(gender)
        labels_list.append(label) # the current embedding is in the enrollment embeddings
        avg_scores_pred_list.append(avg_score_pred) # the score of the current embedding with the enrollment embedding
        audio_filename_list.append(audio_filename)
        speaker_id_list.append(speaker_id)  
        attack_type_list.append(attack_type)                      
        gender_pred_list.append(its_male)
        
    df_results = pd.DataFrame({'label_ground_truth': labels_list,'pred_scores': avg_scores_pred_list,'audio_filename': audio_filename_list,'speaker_id': speaker_id_list,'attack_type': attack_type_list, 'gender': gender_list,'gender_pred': gender_pred_list})
    
        
    return df_results
'''
# Out:
# '\nimport torch\nimport torchaudio\ndef calculate_dcf_avg_score(list_files,df_protocol,enrollment,embeddings,dataset_all): # CALCULATE THE DCF FOR THE ASV SYSTEM\n    \n    thr_gender = 0.5\n    \n    device = torch.device(\'cuda\' if torch.cuda.is_available() else \'cpu\');\n    #path_names = pd.Series(np.array(list_files)) # Get the path names of the data set # Get the path names of the data set\n    all_speakers_id_enroll = np.array(enrollment.get_all_speakers_id())  # Get all the speakers id in the enrollment data set\n    \n    labels_list = []; avg_scores_pred_list = []; # labels_list and scores_list for each asv score\n    gender_list = [];\n    gender_pred_list =[]\n    audio_filename_list = []; speaker_id_list = []; attack_type_list = [];  # audio_filename_list and speaker_id_list for each asv score\n    for _, row in tqdm.tqdm(df_protocol.iterrows(), total=len(df_protocol)): # over each row in the protocol file\n        \n        audio_filename = row[\'audio_filename\'] # Get the audio filename\n        speaker_id = row[\'speaker_id\'] # Get the speaker id\n        attack_type = row[\'attack_type\'] # Get the attack type\n        try:\n            #index_embeddings = path_names.str.contains(audio_filename) # Get the index of the current audio filename\n            index_time_embeddings = dataset_all.name.str.contains(audio_filename) # Get the index of the current audio filename\n            index_time_embeddings = np.where(index_time_embeddings.values == True)\n            if len(index_time_embeddings) > 1 or len(index_time_embeddings) == 0: #problem with the index\n                raise Exception("The audio filename is not in the embeddings data set")\n        except Exception as e:    \n            raise Exception("The speaker id is not in the enrollment data set")\n        \n        with torch.no_grad():\n            if gender_model.predict_proba([dataset_all.data_for_gender_classification[index_time_embeddings[0][0]]])[:,1] > thr_gender: #need to normalize the data\n                its_male = True\n            else:\n                its_male = False\n        \n        gender = dataset_all.sex.values[index_time_embeddings[0][0]]\n        curr_signal,_ = torchaudio.load(str(dataset_all.name.values[index_time_embeddings[0][0]]))\n        \n        label = row[\'label\'] # Get the label of the current audio filename\n        find_speaker_in_enroll = False # initialize the find_speaker_in_enroll flag\n        list_scores_speaker = [] # initialize the list of scores speaker\n        for index_speaker,embedding_in_enroll_per_speaker in enumerate(enrollment.get_all_enrollment_embeddings()): # over each speaker in the enrollment data set\n            embedding_in_enroll_per_speaker = np.array(embedding_in_enroll_per_speaker)\n            for _,embedding_in_enroll in enumerate(embedding_in_enroll_per_speaker):\n                if speaker_id == all_speakers_id_enroll[index_speaker]: # i know that the speaker id of the inferece input\n                    find_speaker_in_enroll = True\n                    \n                    curr_embedding = classifier.encode_batch(curr_signal.to(device)).cpu().numpy().squeeze(0)\n                    \n                    score = cosine_similarity(embedding_in_enroll.squeeze().reshape(1, -1), curr_embedding.reshape(1, -1)) # calculate the cosine similarity between the current embedding and the enrollment embedding\n                    list_scores_speaker.append(score.item()) # append the score to the list of scores\n        \n        avg_score_pred = np.average(list_scores_speaker, axis = 0) # calculate the average score \n        \n        if find_speaker_in_enroll == False:\n            raise Exception("The speaker id is not in the enrollment data set")\n        \n        gender_list.append(gender)\n        labels_list.append(label) # the current embedding is in the enrollment embeddings\n        avg_scores_pred_list.append(avg_score_pred) # the score of the current embedding with the enr ...

# %%
import torch
import torchaudio
def calculate_dcf_avg_score(list_files,df_protocol,enrollment,embeddings,dataset_all): # CALCULATE THE DCF FOR THE ASV SYSTEM
    
    thr_gender = 0.5
    
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu');
    path_names = pd.Series(np.array(list_files)) # Get the path names of the data set # Get the path names of the data set
    all_speakers_id_enroll = np.array(enrollment.get_all_speakers_id())  # Get all the speakers id in the enrollment data set
    
    labels_list = []; avg_scores_pred_list = []; # labels_list and scores_list for each asv score
    gender_list = [];
    gender_pred_list =[]
    audio_filename_list = []; speaker_id_list = []; attack_type_list = [];  # audio_filename_list and speaker_id_list for each asv score
    for _, row in tqdm.tqdm(df_protocol.iterrows(), total=len(df_protocol)): # over each row in the protocol file
        
        audio_filename = row['audio_filename'] # Get the audio filename
        speaker_id = row['speaker_id'] # Get the speaker id
        attack_type = row['attack_type'] # Get the attack type
        try:
            #index_embeddings = path_names.str.contains(audio_filename) # Get the index of the current audio filename
            index_time_embeddings = dataset_all.name.str.contains(audio_filename) # Get the index of the current audio filename
            index_time_embeddings = np.where(index_time_embeddings.values == True)
            if len(index_time_embeddings) > 1 or len(index_time_embeddings) == 0: #problem with the index
                raise Exception("The audio filename is not in the embeddings data set")
        except Exception as e:    
            raise Exception("The speaker id is not in the enrollment data set")
        

        try:
            index_embeddings = path_names.str.contains(audio_filename) # Get the index of the current audio filename
        except Exception as e:    
            raise Exception("The speaker id is not in the enrollment data set")
    
        curr_embedding = embeddings[index_embeddings] # Get the current embedding
        with torch.no_grad():
            if gender_model.predict_proba([dataset_all.data_for_gender_classification[index_time_embeddings[0][0]]])[:,1] > thr_gender: #need to normalize the data
                its_male = True
            else:
                its_male = False
        
        gender = dataset_all.sex.values[index_time_embeddings[0][0]]
        
        
        label = row['label'] # Get the label of the current audio filename
        find_speaker_in_enroll = False # initialize the find_speaker_in_enroll flag
        list_scores_speaker = [] # initialize the list of scores speaker
        for index_speaker,embedding_in_enroll_per_speaker in enumerate(enrollment.get_all_enrollment_embeddings()): # over each speaker in the enrollment data set
            embedding_in_enroll_per_speaker = np.array(embedding_in_enroll_per_speaker)
            for _,embedding_in_enroll in enumerate(embedding_in_enroll_per_speaker):
                if speaker_id == all_speakers_id_enroll[index_speaker]: # i know that the speaker id of the inferece input
                    find_speaker_in_enroll = True
                    
                    
                    score = cosine_similarity(embedding_in_enroll.squeeze().reshape(1, -1), curr_embedding.reshape(1, -1)) # calculate the cosine similarity between the current embedding and the enrollment embedding
                    list_scores_speaker.append(score.item()) # append the score to the list of scores
        
        avg_score_pred = np.average(list_scores_speaker, axis = 0) # calculate the average score 
        
        if find_speaker_in_enroll == False:
            raise Exception("The speaker id is not in the enrollment data set")
        
        gender_list.append(gender)
        labels_list.append(label) # the current embedding is in the enrollment embeddings
        avg_scores_pred_list.append(avg_score_pred) # the score of the current embedding with the enrollment embedding
        audio_filename_list.append(audio_filename)
        speaker_id_list.append(speaker_id)  
        attack_type_list.append(attack_type)                      
        gender_pred_list.append(its_male)
        
    df_results = pd.DataFrame({'label_ground_truth': labels_list,'pred_scores': avg_scores_pred_list,'audio_filename': audio_filename_list,'speaker_id': speaker_id_list,'attack_type': attack_type_list, 'gender': gender_list,'gender_pred': gender_pred_list})
    
        
    return df_results

# %%
from ASV_utils.dcf_my_functions import calculate_dcf
import matplotlib.pyplot as plt

Prior_target =  0.99

Prior_non_target = 1 - Prior_target

dcf_list_dev_female = []
is_print = True

cost_model_dcf = {
    'Cmiss_asv': 1,      # Cost of ASV falsely rejecting target
    'Cfa_asv': 10,       # Cost of ASV falsely accepting nontarget
}

 

# for all eval
asv_thr_list = np.arange(0, 1.01, 0.001).tolist()

# results_list_dev_female = calculate_dcf_avg_score(list_dev_files,df_dev_female_protocol,enrollment_dev_female,embeddings_dev,Dev_dataset_all)


import pickle
file_path = 'asv_results_dev_fixed_female.pkl'

# # Open the file in binary write mode and dump the data
# with open(file_path, 'wb') as f:
#     pickle.dump(results_list_dev_female, f)

results_list_dev_female = pickle.load(open(file_path, 'rb'))

# %%
from sklearn.metrics import roc_auc_score
from utils.my_functions import timing
import sklearn.metrics
from my_conf_inter import evaluate_with_conf_int

alpha = 5 

# Number of bootstrap samples to use (the run time will be proportional to this number). We set it to
# 50/alpha*100 to get enough samples in the tails.
num_bootstraps = int(50/alpha*100)

print(" Number of bootstraps: ", num_bootstraps)
print(" Alpha: ", alpha)
# Out:
#  Number of bootstraps:  1000
#  Alpha:  5

# %%
target_scores = results_list_dev_female.loc[results_list_dev_female['label_ground_truth'] == "target"]["pred_scores"]
nontarget_scores = results_list_dev_female.loc[results_list_dev_female['label_ground_truth'] == "nontarget"]["pred_scores"]

eer, thr_eer, frr, far = eval_metrics.compute_eer(target_scores,nontarget_scores)
    
for asv_thr in asv_thr_list: # over each asv score

    print("current asv score is: ",asv_thr)

    Pfa_asv, Pmiss_asv, _, _  = eval_metrics.obtain_asv_error_rates(target_scores,nontarget_scores,np.array([]),asv_thr)
    dcf = dcf_formula(Pfa_asv,Pmiss_asv,Prior_target = Prior_target,Prior_non_target= Prior_non_target,cost_model_dcf=cost_model_dcf,is_print=is_print)
    dcf_list_dev_female.append(dcf)
    
    
print("the EER is: ",eer)
print("the threshold of the EER is: ",thr_eer)
minDCF_index = np.argmin(np.array(dcf_list_dev_female))
print("the minDCF is:",dcf_list_dev_female[minDCF_index])
print("the threshold of the minDCF is: ",asv_thr_list[minDCF_index])
# Out:
# current asv score is:  0.0
# The DCF is:  0.09534832451499127
# current asv score is:  0.001
# The DCF is:  0.09532627865961209
# current asv score is:  0.002
# The DCF is:  0.09523809523809532
# current asv score is:  0.003
# The DCF is:  0.09514991181657856
# current asv score is:  0.004
# The DCF is:  0.09501763668430344
# current asv score is:  0.005
# The DCF is:  0.09497354497354506
# current asv score is:  0.006
# The DCF is:  0.09486331569664912
# current asv score is:  0.007
# The DCF is:  0.0947089947089948
# current asv score is:  0.008
# The DCF is:  0.09459876543209884
# current asv score is:  0.009000000000000001
# The DCF is:  0.09444444444444453
# current asv score is:  0.01
# The DCF is:  0.09440035273368615
# current asv score is:  0.011
# The DCF is:  0.0942901234567902
# current asv score is:  0.012
# The DCF is:  0.09417989417989425
# current asv score is:  0.013000000000000001
# The DCF is:  0.09402557319223995
# current asv score is:  0.014
# The DCF is:  0.09382716049382724
# current asv score is:  0.015
# The DCF is:  0.09376102292768967
# current asv score is:  0.016
# The DCF is:  0.09356261022927698
# current asv score is:  0.017
# The DCF is:  0.09347442680776022
# current asv score is:  0.018000000000000002
# The DCF is:  0.0933421516754851
# current asv score is:  0.019
# The DCF is:  0.09325396825396834
# current asv score is:  0.02
# The DCF is:  0.0931216931216932
# current asv score is:  0.021
# The DCF is:  0.09305555555555564
# current asv score is:  0.022
# The DCF is:  0.09303350970017644
# current asv score is:  0.023
# The DCF is:  0.09285714285714294
# current asv score is:  0.024
# The DCF is:  0.09281305114638456
# current asv score is:  0.025
# The DCF is:  0.092746913580247
# current asv score is:  0.026000000000000002
# The DCF is:  0.0925485008818343
# current asv score is:  0.027
# The DCF is:  0.09237213403880079
# current asv score is:  0.028
# The DCF is:  0.09221781305114646
# current asv score is:  0.029
# The DCF is:  0.09204144620811296
# current asv score is:  0.03
# The DCF is:  0.09190917107583783
# current asv score is:  0.031
# The DCF is:  0.09166666666666674
# current asv score is:  0.032
# The DCF is:  0.09151234567901242
# current asv score is:  0.033
# The DCF is:  0.09138007054673729
# current asv score is:  0.034
# The DCF is:  0.09122574955908297
# current asv score is:  0.035
# The DCF is:  0.09107142857142865
# current asv score is:  0.036000000000000004
# The DCF is:  0.09080687830687838
# current asv score is:  0.037
# The DCF is:  0.09060846560846568
# current asv score is:  0.038
# The DCF is:  0.09034391534391543
# current asv score is:  0.039
# The DCF is:  0.0901895943562611
# current asv score is:  0.04
# The DCF is:  0.09003527336860678
# current asv score is:  0.041
# The DCF is:  0.08992504409171084
# current asv score is:  0.042
# The DCF is:  0.08977072310405652
# current asv score is:  0.043000000000000003
# The DCF is:  0.08948412698412707
# current asv score is:  0.044
# The DCF is:  0.08935185185185193
# current asv score is:  0.045
# The DCF is:  0.08924162257495598
# current asv score is:  0.046
# The DCF is:  0.08910934744268086
# current asv score is:  0.047
# The DCF is:  0.0888007054673722
# current asv score is:  0.048
# The DCF is:  0.08866843033509708
# current asv score is:  0.049
# The DCF is:  0.08847001763668438
# current asv score is:  0.05
# The DCF is:  0.08822751322751331
# current asv score is:  0.051000000000000004
# The DCF is:  0.08802910052910061
# current asv score is:  0.052000000000000005
# The DCF is:  0.08776455026455035
# current asv score is:  0.053
# The DCF is:  0.0874559082892417
# current asv score is:  0.054
# The DCF is:  0.0872354497354498
# current asv score is:  0.055
# The DCF is:  0.08710317460317468
# current asv score is:  0.056
# The DCF is:  0.08694885361552036
# current asv score is:  0.057
# The DCF is:  0.08677248677248685
# current asv score is:  0.058
# The DCF is:  0.08650793650793659
# current asv score is:  0.059000000000000004
# The DCF is:  0.08630952380952389
# current asv score is:  0.06
# The DCF is:  0.0860670194003528
# current asv score is:  0.061
# The DCF is:  0.08593474426807768
# current asv score is:  0.062
# The DCF is:  0.08573633156966498
# current asv score is:  0.063
# The DCF is:  0.08544973544973553
# current asv score is:  0.064
# The DCF is:  0.08522927689594363
# current asv score is:  0.065
# The DCF is:  0.08487654320987661
# current asv score is:  0.066
# The DCF is:  0.0847222222222223
# current asv score is:  0.067
# The DCF is:  0.0845017636684304
# current asv score is:  0.068
# The DCF is:  0.0843474426807761
# current asv score is:  0.069
# The DCF is:  0.08419312169312178
# current asv score is:  0.07
# The DCF is:  0.08395061728395069
# current asv score is:  0.07100000000000001
# The DCF is:  0.08368606701940043
# current asv score is:  0.07200000000000001
# The DCF is:  0.08322310405643747
# current asv score is:  0.073
# The DCF is:  0.0829805996472664
# current asv score is:  0.074
# The DCF is:  0.08262786596119936
# current asv score is:  0.075
# The DCF is:  0.08234126984126991
# current asv score is:  0.076
# The DCF is:  0.08214285714285721
# current asv score is:  0.077
# The DCF is:  0.08192239858906533
# current asv score is:  0.078
# The DCF is:  0.08172398589065263
# current asv score is:  0.079
# The DCF is:  0.08145943562610236
# current asv score is:  0.08
# The DCF is:  0.08110670194003534
# current asv score is:  0.081
# The DCF is:  0.08086419753086427
# current asv score is:  0.082
# The DCF is:  0.08059964726631401
# current asv score is:  0.083
# The DCF is:  0.08037918871252211
# current asv score is:  0.084
# The DCF is:  0.08011463844797186
# current asv score is:  0.085
# The DCF is:  0.07991622574955914
# current asv score is:  0.08600000000000001
# The DCF is:  0.07960758377425052
# current asv score is:  0.08700000000000001
# The DCF is:  0.07925485008818349
# current asv score is:  0.088
# The DCF is:  0.07899029982363323
# current asv score is:  0.089
# The DCF is:  0.07852733686067026
# current asv score is:  0.09
# The DCF is:  0.07828483245149918
# current asv score is:  0.091
# The DCF is:  0.0780643738977073
# current asv score is:  0.092
# The DCF is:  0.07773368606701947
# current asv score is:  0.093
# The DCF is:  0.07742504409171083
# current asv score is:  0.094
# The DCF is:  0.07718253968253976
# current asv score is:  0.095
# The DCF is:  0.07687389770723112
# current asv score is:  0.096
# The DCF is:  0.07658730158730166
# current asv score is:  0.097
# The DCF is:  0.07641093474426815
# current asv score is:  0.098
# The DCF is:  0.0761022927689595
# current asv score is:  0.099
# The DCF is:  0.0759038800705468
# current asv score is:  0.1
# The DCF is:  0.0755291005291006
# current asv score is:  0.101
# The DCF is:  0.07526455026455034
# current asv score is:  0.10200000000000001
# The DCF is:  0.07513227513227519
# current asv score is:  0.10300000000000001
# The DCF is:  0.07477954144620817
# current asv score is:  0.10400000000000001
# The DCF is:  0.07451499118165791
# current asv score is:  0.105
# The DCF is:  0.0743606701940036
# current asv score is:  0.106
# The DCF is:  0.07405202821869496
# current asv score is:  0.107
# The DCF is:  0.07387566137566144
# current asv score is:  0.108
# The DCF is:  0.07361111111111118
# current asv score is:  0.109
# The DCF is:  0.07339065255731929
# current asv score is:  0.11
# The DCF is:  0.07314814814814821
# current asv score is:  0.111
# The DCF is:  0.07283950617283957
# current asv score is:  0.112
# The DCF is:  0.07250881834215174
# current asv score is:  0.113
# The DCF is:  0.07224426807760148
# current asv score is:  0.114
# The DCF is:  0.07186948853615527
# current asv score is:  0.115
# The DCF is:  0.07158289241622581
# current asv score is:  0.116
# The DCF is:  0.07127425044091718
# current asv score is:  0.117
# The DCF is:  0.07107583774250448
# current asv score is:  0.11800000000000001
# The DCF is:  0.07065696649029989
# current asv score is:  0.11900000000000001
# The DCF is:  0.07032627865961207
# current asv score is:  0.12
# The DCF is:  0.06995149911816584
# current asv score is:  0.121
# The DCF is:  0.06962081128747802
# current asv score is:  0.122
# The DCF is:  0.06931216931216938
# current asv score is:  0.123
# The DCF is:  0.06909171075837749
# current asv score is:  0.124
# The DCF is:  0.06865079365079371
# current asv score is:  0.125
# The DCF is:  0.06818783068783074
# current asv score is:  0.126
# The DCF is:  0.06798941798941804
# current asv score is:  0.127
# The DCF is:  0.06757054673721347
# current asv score is:  0.128
# The DCF is:  0.06717372134038806
# current asv score is:  0.129
# The DCF is:  0.0667328042328043
# current asv score is:  0.13
# The DCF is:  0.06649029982363322
# current asv score is:  0.131
# The DCF is:  0.06624779541446214
# current asv score is:  0.132
# The DCF is:  0.06578483245149917
# current asv score is:  0.133
# The DCF is:  0.06543209876543216
# current asv score is:  0.134
# The DCF is:  0.06521164021164026
# current asv score is:  0.135
# The DCF is:  0.06483686067019406
# current asv score is:  0.136
# The DCF is:  0.0645723104056438
# current asv score is:  0.137
# The DCF is:  0.06413139329806003
# current asv score is:  0.138
# The DCF is:  0.06366843033509706
# current asv score is:  0.139
# The DCF is:  0.06335978835978842
# current asv score is:  0.14
# The DCF is:  0.06289682539682545
# current asv score is:  0.14100000000000001
# The DCF is:  0.06254409171075843
# current asv score is:  0.14200000000000002
# The DCF is:  0.06221340388007061
# current asv score is:  0.14300000000000002
# The DCF is:  0.061772486772486826
# current asv score is:  0.14400000000000002
# The DCF is:  0.06146384479717819
# current asv score is:  0.145
# The DCF is:  0.06082451499118171
# current asv score is:  0.146
# The DCF is:  0.06033950617283956
# current asv score is:  0.147
# The DCF is:  0.06005291005291011
# current asv score is:  0.148
# The DCF is:  0.059678130511463895
# current asv score is:  0.149
# The DCF is:  0.05912698412698418
# current asv score is:  0.15
# The DCF is:  0.05884038800705473
# current asv score is:  0.151
# The DCF is:  0.05848765432098771
# current asv score is:  0.152
# The DCF is:  0.05813492063492069
# current asv score is:  0.153
# The DCF is:  0.05780423280423285
# current asv score is:  0.154
# The DCF is:  0.0575176366843034
# current asv score is:  0.155
# The DCF is:  0.05709876543209882
# current asv score is:  0.156
# The DCF is:  0.056746031746031794
# current asv score is:  0.157
# The DCF is:  0.0563271604938272
# current asv score is:  0.158
# The DCF is:  0.055952380952381
# current asv score is:  0.159
# The DCF is:  0.05531305114638453
# current asv score is:  0.16
# The DCF is:  0.05487213403880075
# current asv score is:  0.161
# The DCF is:  0.05449735449735455
# current asv score is:  0.162
# The DCF is:  0.05414462081128753
# current asv score is:  0.163
# The DCF is:  0.05359347442680781
# current asv score is:  0.164
# The DCF is:  0.05324074074074079
# current asv score is:  0.165
# The DCF is:  0.052821869488536205
# current asv score is:  0.166
# The DCF is:  0.05240299823633161
# current asv score is:  0.167
# The DCF is:  0.05202821869488541
# current asv score is:  0.168
# The DCF is:  0.05169753086419757
# current asv score is:  0.169
# The DCF is:  0.0514550264550265
# current asv score is:  0.17
# The DCF is:  0.05097001763668435
# current asv score is:  0.171
# The DCF is:  0.050749559082892456
# current asv score is:  0.17200000000000001
# The DCF is:  0.05019841269841274
# current asv score is:  0.17300000000000001
# The DCF is:  0.04977954144620816
# current asv score is:  0.17400000000000002
# The DCF is:  0.04942680776014114
# current asv score is:  0.17500000000000002
# The DCF is:  0.04898589065255736
# current asv score is:  0.176
# The DCF is:  0.048611111111111154
# current asv score is:  0.177
# The DCF is:  0.04810405643738981
# current asv score is:  0.178
# The DCF is:  0.047707231040564416
# current asv score is:  0.179
# The DCF is:  0.04733245149911821
# current asv score is:  0.18
# The DCF is:  0.046869488536155246
# current asv score is:  0.181
# The DCF is:  0.04647266313932985
# current asv score is:  0.182
# The DCF is:  0.04611992945326283
# current asv score is:  0.183
# The DCF is:  0.04567901234567905
# current asv score is:  0.184
# The DCF is:  0.04523809523809528
# current asv score is:  0.185
# The DCF is:  0.04486331569664907
# current asv score is:  0.186
# The DCF is:  0.04446649029982368
# current asv score is:  0.187
# The DCF is:  0.043959435626102335
# current asv score is:  0.188
# The DCF is:  0.04365079365079369
# current asv score is:  0.189
# The DCF is:  0.043320105820105856
# current asv score is:  0.19
# The DCF is:  0.04292328042328046
# current asv score is:  0.191
# The DCF is:  0.042614638447971816
# current asv score is:  0.192
# The DCF is:  0.04210758377425048
# current asv score is:  0.193
# The DCF is:  0.041666666666666706
# current asv score is:  0.194
# The DCF is:  0.0412918871252205
# current asv score is:  0.195
# The DCF is:  0.04082892416225753
# current asv score is:  0.196
# The DCF is:  0.04047619047619051
# current asv score is:  0.197
# The DCF is:  0.04014550264550268
# current asv score is:  0.198
# The DCF is:  0.039726631393298094
# current asv score is:  0.199
# The DCF is:  0.03930776014109351
# current asv score is:  0.2
# The DCF is:  0.038866843033509735
# current asv score is:  0.201
# The DCF is:  0.03858024691358028
# current asv score is:  0.202
# The DCF is:  0.038161375661375695
# current asv score is:  0.203
# The DCF is:  0.0377645502645503
# current asv score is:  0.20400000000000001
# The DCF is:  0.03750000000000003
# current asv score is:  0.20500000000000002
# The DCF is:  0.03714726631393302
# current asv score is:  0.20600000000000002
# The DCF is:  0.036684303350970046
# current asv score is:  0.20700000000000002
# The DCF is:  0.03628747795414465
# current asv score is:  0.20800000000000002
# The DCF is:  0.035956790123456824
# current asv score is:  0.209
# The DCF is:  0.03549382716049386
# current asv score is:  0.21
# The DCF is:  0.035185185185185215
# current asv score is:  0.211
# The DCF is:  0.03478835978835982
# current asv score is:  0.212
# The DCF is:  0.034259259259259295
# current asv score is:  0.213
# The DCF is:  0.03392857142857146
# current asv score is:  0.214
# The DCF is:  0.033686067019400384
# current asv score is:  0.215
# The DCF is:  0.03333333333333336
# current asv score is:  0.216
# The DCF is:  0.032936507936507965
# current asv score is:  0.217
# The DCF is:  0.03251763668430338
# current asv score is:  0.218
# The DCF is:  0.032142857142857174
# current asv score is:  0.219
# The DCF is:  0.03181216931216934
# current asv score is:  0.22
# The DCF is:  0.03132716049382719
# current asv score is:  0.221
# The DCF is:  0.030908289241622606
# current asv score is:  0.222
# The DCF is:  0.03062169312169315
# current asv score is:  0.223
# The DCF is:  0.030180776014109373
# current asv score is:  0.224
# The DCF is:  0.029805996472663163
# current asv score is:  0.225
# The DCF is:  0.029409171075837768
# current asv score is:  0.226
# The DCF is:  0.029078483245149937
# current asv score is:  0.227
# The DCF is:  0.028703703703703728
# current asv score is:  0.228
# The DCF is:  0.028328924162257522
# current asv score is:  0.229
# The DCF is:  0.027910052910052937
# current asv score is:  0.23
# The DCF is:  0.027601410934744292
# current asv score is:  0.231
# The DCF is:  0.027248677248677276
# current asv score is:  0.232
# The DCF is:  0.02691798941798944
# current asv score is:  0.233
# The DCF is:  0.026653439153439176
# current asv score is:  0.234
# The DCF is:  0.02625661375661378
# current asv score is:  0.23500000000000001
# The DCF is:  0.025837742504409195
# current asv score is:  0.23600000000000002
# The DCF is:  0.025396825396825418
# current asv score is:  0.23700000000000002
# The DCF is:  0.025132275132275155
# current asv score is:  0.23800000000000002
# The DCF is:  0.02466931216931219
# current asv score is:  0.23900000000000002
# The DCF is:  0.024206349206349228
# current asv score is:  0.24
# The DCF is:  0.023941798941798962
# current asv score is:  0.241
# The DCF is:  0.02363315696649032
# current asv score is:  0.242
# The DCF is:  0.02330246913580249
# current asv score is:  0.243
# The DCF is:  0.023037918871252224
# current asv score is:  0.244
# The DCF is:  0.02264109347442683
# current asv score is:  0.245
# The DCF is:  0.022376543209876563
# current asv score is:  0.246
# The DCF is:  0.022178130511463865
# current asv score is:  0.247
# The DCF is:  0.0219135802469136
# current asv score is:  0.248
# The DCF is:  0.021494708994709014
# current asv score is:  0.249
# The DCF is:  0.02116402116402118
# current asv score is:  0.25
# The DCF is:  0.020943562610229297
# current asv score is:  0.251
# The DCF is:  0.02070105820105822
# current asv score is:  0.252
# The DCF is:  0.020502645502645522
# current asv score is:  0.253
# The DCF is:  0.020194003527336878
# current asv score is:  0.254
# The DCF is:  0.01999559082892418
# current asv score is:  0.255
# The DCF is:  0.019731040564373914
# current asv score is:  0.256
# The DCF is:  0.019356261022927708
# current asv score is:  0.257
# The DCF is:  0.01911375661375663
# current asv score is:  0.258
# The DCF is:  0.018738977072310422
# current asv score is:  0.259
# The DCF is:  0.01840828924162259
# current asv score is:  0.26
# The DCF is:  0.017835097001763684
# current asv score is:  0.261
# The DCF is:  0.01770282186948855
# current asv score is:  0.262
# The DCF is:  0.017526455026455043
# current asv score is:  0.263
# The DCF is:  0.017283950617283966
# current asv score is:  0.264
# The DCF is:  0.016975308641975325
# current asv score is:  0.265
# The DCF is:  0.01673280423280425
# current asv score is:  0.266
# The DCF is:  0.016446208112874793
# current asv score is:  0.267
# The DCF is:  0.016203703703703717
# current asv score is:  0.268
# The DCF is:  0.015939153439153454
# current asv score is:  0.269
# The DCF is:  0.015630511463844813
# current asv score is:  0.27
# The DCF is:  0.015432098765432112
# current asv score is:  0.271
# The DCF is:  0.015145502645502658
# current asv score is:  0.272
# The DCF is:  0.014902998236331582
# current asv score is:  0.273
# The DCF is:  0.014660493827160509
# current asv score is:  0.274
# The DCF is:  0.01444003527336862
# current asv score is:  0.275
# The DCF is:  0.014241622574955922
# current asv score is:  0.276
# The DCF is:  0.013977072310405656
# current asv score is:  0.277
# The DCF is:  0.013800705467372146
# current asv score is:  0.278
# The DCF is:  0.013580246913580259
# current asv score is:  0.279
# The DCF is:  0.013359788359788372
# current asv score is:  0.28
# The DCF is:  0.013051146384479729
# current asv score is:  0.281
# The DCF is:  0.012698412698412709
# current asv score is:  0.28200000000000003
# The DCF is:  0.012566137566137578
# current asv score is:  0.28300000000000003
# The DCF is:  0.012257495590828935
# current asv score is:  0.28400000000000003
# The DCF is:  0.012147266313932991
# current asv score is:  0.28500000000000003
# The DCF is:  0.011948853615520292
# current asv score is:  0.28600000000000003
# The DCF is:  0.011772486772486782
# current asv score is:  0.28700000000000003
# The DCF is:  0.011596119929453273
# current asv score is:  0.28800000000000003
# The DCF is:  0.011441798941798953
# current asv score is:  0.289
# The DCF is:  0.01113315696649031
# current asv score is:  0.29
# The DCF is:  0.01093474426807761
# current asv score is:  0.291
# The DCF is:  0.010802469135802479
# current asv score is:  0.292
# The DCF is:  0.01058201058201059
# current asv score is:  0.293
# The DCF is:  0.010383597883597892
# current asv score is:  0.294
# The DCF is:  0.010141093474426816
# current asv score is:  0.295
# The DCF is:  0.010008818342151685
# current asv score is:  0.296
# The DCF is:  0.010925925925925936
# current asv score is:  0.297
# The DCF is:  0.01063932980599648
# current asv score is:  0.298
# The DCF is:  0.01050705467372135
# current asv score is:  0.299
# The DCF is:  0.010242504409171084
# current asv score is:  0.3
# The DCF is:  0.010088183421516763
# current asv score is:  0.301
# The DCF is:  0.009955908289241632
# current asv score is:  0.302
# The DCF is:  0.009735449735449745
# current asv score is:  0.303
# The DCF is:  0.009559082892416235
# current asv score is:  0.304
# The DCF is:  0.009426807760141102
# current asv score is:  0.305
# The DCF is:  0.009294532627865969
# current asv score is:  0.306
# The DCF is:  0.009096119929453271
# current asv score is:  0.307
# The DCF is:  0.009902998236331575
# current asv score is:  0.308
# The DCF is:  0.009726631393298067
# current asv score is:  0.309
# The DCF is:  0.009572310405643747
# current asv score is:  0.31
# The DCF is:  0.009417989417989424
# current asv score is:  0.311
# The DCF is:  0.00932980599647267
# current asv score is:  0.312
# The DCF is:  0.00917548500881835
# current asv score is:  0.313
# The DCF is:  0.009021164021164027
# current asv score is:  0.314
# The DCF is:  0.008888888888888894
# current asv score is:  0.315
# The DCF is:  0.00880070546737214
# current asv score is:  0.316
# The DCF is:  0.008668430335097007
# current asv score is:  0.317
# The DCF is:  0.00864638447971782
# current asv score is:  0.318
# The DCF is:  0.009607583774250448
# current asv score is:  0.319
# The DCF is:  0.009541446208112881
# current asv score is:  0.32
# The DCF is:  0.009409171075837748
# current asv score is:  0.321
# The DCF is:  0.00918871252204586
# current asv score is:  0.322
# The DCF is:  0.009144620811287484
# current asv score is:  0.323
# The DCF is:  0.00903439153439154
# current asv score is:  0.324
# The DCF is:  0.008924162257495597
# current asv score is:  0.325
# The DCF is:  0.008769841269841275
# current asv score is:  0.326
# The DCF is:  0.008637566137566142
# current asv score is:  0.327
# The DCF is:  0.008505291005291009
# current asv score is:  0.328
# The DCF is:  0.008395061728395065
# current asv score is:  0.329
# The DCF is:  0.008240740740740746
# current asv score is:  0.33
# The DCF is:  0.008108465608465613
# current asv score is:  0.331
# The DCF is:  0.00906966490299824
# current asv score is:  0.332
# The DCF is:  0.009942680776014113
# current asv score is:  0.333
# The DCF is:  0.009876543209876548
# current asv score is:  0.334
# The DCF is:  0.009700176366843036
# current asv score is:  0.335
# The DCF is:  0.00965608465608466
# current asv score is:  0.336
# The DCF is:  0.009611992945326282
# current asv score is:  0.337
# The DCF is:  0.009567901234567905
# current asv score is:  0.338
# The DCF is:  0.009523809523809528
# current asv score is:  0.339
# The DCF is:  0.009413580246913585
# current asv score is:  0.34
# The DCF is:  0.009369488536155206
# current asv score is:  0.341
# The DCF is:  0.009281305114638452
# current asv score is:  0.342
# The DCF is:  0.009171075837742508
# current asv score is:  0.343
# The DCF is:  0.009149029982363319
# current asv score is:  0.34400000000000003
# The DCF is:  0.010198412698412703
# current asv score is:  0.34500000000000003
# The DCF is:  0.010132275132275137
# current asv score is:  0.34600000000000003
# The DCF is:  0.01006613756613757
# current asv score is:  0.34700000000000003
# The DCF is:  0.010000000000000004
# current asv score is:  0.34800000000000003
# The DCF is:  0.00986772486772487
# current asv score is:  0.34900000000000003
# The DCF is:  0.009757495590828927
# current asv score is:  0.35000000000000003
# The DCF is:  0.00969135802469136
# current asv score is:  0.35100000000000003
# The DCF is:  0.009625220458553796
# current asv score is:  0.352
# The DCF is:  0.009625220458553796
# current asv score is:  0.353
# The DCF is:  0.009492945326278663
# current asv score is:  0.354
# The DCF is:  0.009426807760141096
# current asv score is:  0.355
# The DCF is:  0.009338624338624342
# current asv score is:  0.356
# The DCF is:  0.009228395061728399
# current asv score is:  0.357
# The DCF is:  0.009162257495590832
# current asv score is:  0.358
# The DCF is:  0.009140211640211643
# current asv score is:  0.359
# The DCF is:  0.009096119929453266
# current asv score is:  0.36
# The DCF is:  0.00900793650793651
# current asv score is:  0.361
# The DCF is:  0.008963844797178133
# current asv score is:  0.362
# The DCF is:  0.008875661375661379
# current asv score is:  0.363
# The DCF is:  0.008831569664903002
# current asv score is:  0.364
# The DCF is:  0.008765432098765435
# current asv score is:  0.365
# The DCF is:  0.008743386243386246
# current asv score is:  0.366
# The DCF is:  0.00867724867724868
# current asv score is:  0.367
# The DCF is:  0.008544973544973548
# current asv score is:  0.368
# The DCF is:  0.008500881834215171
# current asv score is:  0.369
# The DCF is:  0.008456790123456792
# current asv score is:  0.37
# The DCF is:  0.008434744268077604
# current asv score is:  0.371
# The DCF is:  0.008412698412698415
# current asv score is:  0.372
# The DCF is:  0.008346560846560849
# current asv score is:  0.373
# The DCF is:  0.009351851851851853
# current asv score is:  0.374
# The DCF is:  0.009307760141093475
# current asv score is:  0.375
# The DCF is:  0.009241622574955909
# current asv score is:  0.376
# The DCF is:  0.010246913580246916
# current asv score is:  0.377
# The DCF is:  0.010224867724867727
# current asv score is:  0.378
# The DCF is:  0.01015873015873016
# current asv score is:  0.379
# The DCF is:  0.011097883597883598
# current asv score is:  0.38
# The DCF is:  0.011097883597883598
# current asv score is:  0.381
# The DCF is:  0.01105379188712522
# current asv score is:  0.382
# The DCF is:  0.011031746031746031
# current asv score is:  0.383
# The DCF is:  0.011031746031746031
# current asv score is:  0.384
# The DCF is:  0.011009700176366844
# current asv score is:  0.385
# The DCF is:  0.011009700176366844
# current asv score is:  0.386
# The DCF is:  0.010965608465608467
# current asv score is:  0.387
# The DCF is:  0.010965608465608467
# current asv score is:  0.388
# The DCF is:  0.010965608465608467
# current asv score is:  0.389
# The DCF is:  0.010943562610229277
# current asv score is:  0.39
# The DCF is:  0.010921516754850088
# current asv score is:  0.391
# The DCF is:  0.0108994708994709
# current asv score is:  0.392
# The DCF is:  0.01087742504409171
# current asv score is:  0.393
# The DCF is:  0.010855379188712523
# current asv score is:  0.394
# The DCF is:  0.011904761904761906
# current asv score is:  0.395
# The DCF is:  0.01183862433862434
# current asv score is:  0.396
# The DCF is:  0.011816578483245152
# current asv score is:  0.397
# The DCF is:  0.011794532627865962
# current asv score is:  0.398
# The DCF is:  0.011728395061728396
# current asv score is:  0.399
# The DCF is:  0.011728395061728396
# current asv score is:  0.4
# The DCF is:  0.011706349206349206
# current asv score is:  0.401
# The DCF is:  0.012711640211640212
# current asv score is:  0.402
# The DCF is:  0.013761022927689597
# current asv score is:  0.403
# The DCF is:  0.013738977072310407
# current asv score is:  0.404
# The DCF is:  0.014810405643738977
# current asv score is:  0.405
# The DCF is:  0.015837742504409173
# current asv score is:  0.406
# The DCF is:  0.015793650793650794
# current asv score is:  0.40700000000000003
# The DCF is:  0.015793650793650794
# current asv score is:  0.40800000000000003
# The DCF is:  0.015771604938271604
# current asv score is:  0.40900000000000003
# The DCF is:  0.016843033509700175
# current asv score is:  0.41000000000000003
# The DCF is:  0.0167989417989418
# current asv score is:  0.41100000000000003
# The DCF is:  0.0167989417989418
# current asv score is:  0.41200000000000003
# The DCF is:  0.017826278659611994
# current asv score is:  0.41300000000000003
# The DCF is:  0.017826278659611994
# current asv score is:  0.41400000000000003
# The DCF is:  0.017782186948853616
# current asv score is:  0.41500000000000004
# The DCF is:  0.017782186948853616
# current asv score is:  0.41600000000000004
# The DCF is:  0.01773809523809524
# current asv score is:  0.417
# The DCF is:  0.01880952380952381
# current asv score is:  0.418
# The DCF is:  0.01880952380952381
# current asv score is:  0.419
# The DCF is:  0.01880952380952381
# current asv score is:  0.42
# The DCF is:  0.01880952380952381
# current asv score is:  0.421
# The DCF is:  0.01880952380952381
# current asv score is:  0.422
# The DCF is:  0.01880952380952381
# current asv score is:  0.423
# The DCF is:  0.019836860670194002
# current asv score is:  0.424
# The DCF is:  0.019836860670194002
# current asv score is:  0.425
# The DCF is:  0.019836860670194002
# current asv score is:  0.426
# The DCF is:  0.019814814814814813
# current asv score is:  0.427
# The DCF is:  0.021957671957671957
# current asv score is:  0.428
# The DCF is:  0.02193562610229277
# current asv score is:  0.429
# The DCF is:  0.02193562610229277
# current asv score is:  0.43
# The DCF is:  0.021913580246913582
# current asv score is:  0.431
# The DCF is:  0.021869488536155203
# current asv score is:  0.432
# The DCF is:  0.021847442680776014
# current asv score is:  0.433
# The DCF is:  0.021847442680776014
# current asv score is:  0.434
# The DCF is:  0.021847442680776014
# current asv score is:  0.435
# The DCF is:  0.021825396825396824
# current asv score is:  0.436
# The DCF is:  0.02178130511463845
# current asv score is:  0.437
# The DCF is:  0.02178130511463845
# current asv score is:  0.438
# The DCF is:  0.02175925925925926
# current asv score is:  0.439
# The DCF is:  0.0239021164021164
# current asv score is:  0.44
# The DCF is:  0.0239021164021164
# current asv score is:  0.441
# The DCF is:  0.024951499118165785
# current asv score is:  0.442
# The DCF is:  0.027094356261022925
# current asv score is:  0.443
# The DCF is:  0.027072310405643736
# current asv score is:  0.444
# The DCF is:  0.028099647266313935
# current asv score is:  0.445
# The DCF is:  0.028099647266313935
# current asv score is:  0.446
# The DCF is:  0.028055555555555556
# current asv score is:  0.447
# The DCF is:  0.028055555555555556
# current asv score is:  0.448
# The DCF is:  0.028055555555555556
# current asv score is:  0.449
# The DCF is:  0.028055555555555556
# current asv score is:  0.45
# The DCF is:  0.028055555555555556
# current asv score is:  0.451
# The DCF is:  0.029126984126984126
# current asv score is:  0.452
# The DCF is:  0.029126984126984126
# current asv score is:  0.453
# The DCF is:  0.030198412698412697
# current asv score is:  0.454
# The DCF is:  0.03231922398589065
# current asv score is:  0.455
# The DCF is:  0.03231922398589065
# current asv score is:  0.456
# The DCF is:  0.03231922398589065
# current asv score is:  0.457
# The DCF is:  0.034462081128747796
# current asv score is:  0.458
# The DCF is:  0.034440035273368606
# current asv score is:  0.459
# The DCF is:  0.03551146384479718
# current asv score is:  0.46
# The DCF is:  0.037610229276895946
# current asv score is:  0.461
# The DCF is:  0.038681657848324516
# current asv score is:  0.462
# The DCF is:  0.038681657848324516
# current asv score is:  0.463
# The DCF is:  0.038681657848324516
# current asv score is:  0.464
# The DCF is:  0.039753086419753086
# current asv score is:  0.465
# The DCF is:  0.040802469135802474
# current asv score is:  0.466
# The DCF is:  0.041873897707231045
# current asv score is:  0.467
# The DCF is:  0.041829805996472666
# current asv score is:  0.468
# The DCF is:  0.041829805996472666
# current asv score is:  0.46900000000000003
# The DCF is:  0.041829805996472666
# current asv score is:  0.47000000000000003
# The DCF is:  0.041829805996472666
# current asv score is:  0.47100000000000003
# The DCF is:  0.041829805996472666
# current asv score is:  0.47200000000000003
# The DCF is:  0.042901234567901236
# current asv score is:  0.47300000000000003
# The DCF is:  0.04504409171075838
# current asv score is:  0.47400000000000003
# The DCF is:  0.04504409171075838
# current asv score is:  0.47500000000000003
# The DCF is:  0.04504409171075838
# current asv score is:  0.47600000000000003
# The DCF is:  0.04611552028218695
# current asv score is:  0.47700000000000004
# The DCF is:  0.050401234567901236
# current asv score is:  0.47800000000000004
# The DCF is:  0.05361552028218695
# current asv score is:  0.47900000000000004
# The DCF is:  0.05361552028218695
# current asv score is:  0.48
# The DCF is:  0.05468694885361552
# current asv score is:  0.481
# The DCF is:  0.055758377425044095
# current asv score is:  0.482
# The DCF is:  0.056829805996472665
# current asv score is:  0.483
# The DCF is:  0.057901234567901236
# current asv score is:  0.484
# The DCF is:  0.06004409171075838
# current asv score is:  0.485
# The DCF is:  0.06111552028218695
# current asv score is:  0.486
# The DCF is:  0.06218694885361552
# current asv score is:  0.487
# The DCF is:  0.06432980599647266
# current asv score is:  0.488
# The DCF is:  0.06432980599647266
# current asv score is:  0.489
# The DCF is:  0.06540123456790123
# current asv score is:  0.49
# The DCF is:  0.06754409171075837
# current asv score is:  0.491
# The DCF is:  0.06754409171075837
# current asv score is:  0.492
# The DCF is:  0.06754409171075837
# current asv score is:  0.493
# The DCF is:  0.0707583774250441
# current asv score is:  0.494
# The DCF is:  0.07287918871252204
# current asv score is:  0.495
# The DCF is:  0.07502204585537918
# current asv score is:  0.496
# The DCF is:  0.07609347442680775
# current asv score is:  0.497
# The DCF is:  0.0782363315696649
# current asv score is:  0.498
# The DCF is:  0.0782363315696649
# current asv score is:  0.499
# The DCF is:  0.07930776014109346
# current asv score is:  0.5
# The DCF is:  0.08037918871252203
# current asv score is:  0.501
# The DCF is:  0.08037918871252203
# current asv score is:  0.502
# The DCF is:  0.08037918871252203
# current asv score is:  0.503
# The DCF is:  0.08037918871252203
# current asv score is:  0.504
# The DCF is:  0.08252204585537917
# current asv score is:  0.505
# The DCF is:  0.08252204585537917
# current asv score is:  0.506
# The DCF is:  0.08359347442680776
# current asv score is:  0.507
# The DCF is:  0.08466490299823633
# current asv score is:  0.508
# The DCF is:  0.0857363315696649
# current asv score is:  0.509
# The DCF is:  0.0857363315696649
# current asv score is:  0.51
# The DCF is:  0.0857363315696649
# current asv score is:  0.511
# The DCF is:  0.0857363315696649
# current asv score is:  0.512
# The DCF is:  0.0857363315696649
# current asv score is:  0.513
# The DCF is:  0.0857363315696649
# current asv score is:  0.514
# The DCF is:  0.0857363315696649
# current asv score is:  0.515
# The DCF is:  0.08787918871252204
# current asv score is:  0.516
# The DCF is:  0.08895061728395061
# current asv score is:  0.517
# The DCF is:  0.09537918871252205
# current asv score is:  0.518
# The DCF is:  0.09752204585537917
# current asv score is:  0.519
# The DCF is:  0.1007363315696649
# current asv score is:  0.52
# The DCF is:  0.10287918871252205
# current asv score is:  0.521
# The DCF is:  0.10609347442680775
# current asv score is:  0.522
# The DCF is:  0.1082363315696649
# current asv score is:  0.523
# The DCF is:  0.10930776014109346
# current asv score is:  0.524
# The DCF is:  0.11037918871252204
# current asv score is:  0.525
# The DCF is:  0.11252204585537917
# current asv score is:  0.526
# The DCF is:  0.11252204585537917
# current asv score is:  0.527
# The DCF is:  0.11359347442680776
# current asv score is:  0.528
# The DCF is:  0.11571428571428571
# current asv score is:  0.529
# The DCF is:  0.11785714285714285
# current asv score is:  0.53
# The DCF is:  0.12
# current asv score is:  0.531
# The DCF is:  0.12214285714285714
# current asv score is:  0.532
# The DCF is:  0.12214285714285714
# current asv score is:  0.533
# The DCF is:  0.12321428571428572
# current asv score is:  0.534
# The DCF is:  0.12428571428571428
# current asv score is:  0.535
# The DCF is:  0.12642857142857145
# current asv score is:  0.536
# The DCF is:  0.1307142857142857
# current asv score is:  0.537
# The DCF is:  0.13392857142857142
# current asv score is:  0.538
# The DCF is:  0.13607142857142857
# current asv score is:  0.539
# The DCF is:  0.13607142857142857
# current asv score is:  0.54
# The DCF is:  0.14250000000000002
# current asv score is:  0.541
# The DCF is:  0.14464285714285713
# current asv score is:  0.542
# The DCF is:  0.14464285714285713
# current asv score is:  0.543
# The DCF is:  0.14892857142857144
# current asv score is:  0.544
# The DCF is:  0.15214285714285714
# current asv score is:  0.545
# The DCF is:  0.15428571428571428
# current asv score is:  0.546
# The DCF is:  0.1575
# current asv score is:  0.547
# The DCF is:  0.15857142857142856
# current asv score is:  0.548
# The DCF is:  0.1607142857142857
# current asv score is:  0.549
# The DCF is:  0.16499999999999998
# current asv score is:  0.55
# The DCF is:  0.16714285714285715
# current asv score is:  0.551
# The DCF is:  0.17142857142857143
# current asv score is:  0.552
# The DCF is:  0.17250000000000001
# current asv score is:  0.553
# The DCF is:  0.17357142857142857
# current asv score is:  0.554
# The DCF is:  0.1757142857142857
# current asv score is:  0.555
# The DCF is:  0.18
# current asv score is:  0.556
# The DCF is:  0.18214285714285713
# current asv score is:  0.557
# The DCF is:  0.18321428571428572
# current asv score is:  0.558
# The DCF is:  0.18428571428571427
# current asv score is:  0.559
# The DCF is:  0.1875
# current asv score is:  0.56
# The DCF is:  0.19071428571428573
# current asv score is:  0.561
# The DCF is:  0.19178571428571428
# current asv score is:  0.562
# The DCF is:  0.19178571428571428
# current asv score is:  0.5630000000000001
# The DCF is:  0.19714285714285715
# current asv score is:  0.5640000000000001
# The DCF is:  0.20142857142857143
# current asv score is:  0.5650000000000001
# The DCF is:  0.20142857142857143
# current asv score is:  0.5660000000000001
# The DCF is:  0.20142857142857143
# current asv score is:  0.5670000000000001
# The DCF is:  0.2067857142857143
# current asv score is:  0.5680000000000001
# The DCF is:  0.20785714285714285
# current asv score is:  0.5690000000000001
# The DCF is:  0.21
# current asv score is:  0.5700000000000001
# The DCF is:  0.21428571428571427
# current asv score is:  0.5710000000000001
# The DCF is:  0.21857142857142856
# current asv score is:  0.5720000000000001
# The DCF is:  0.22178571428571428
# current asv score is:  0.5730000000000001
# The DCF is:  0.22392857142857142
# current asv score is:  0.5740000000000001
# The DCF is:  0.22714285714285715
# current asv score is:  0.5750000000000001
# The DCF is:  0.2292857142857143
# current asv score is:  0.5760000000000001
# The DCF is:  0.23142857142857143
# current asv score is:  0.577
# The DCF is:  0.23357142857142857
# current asv score is:  0.578
# The DCF is:  0.23464285714285713
# current asv score is:  0.579
# The DCF is:  0.2367857142857143
# current asv score is:  0.58
# The DCF is:  0.2475
# current asv score is:  0.581
# The DCF is:  0.2475
# current asv score is:  0.582
# The DCF is:  0.25392857142857145
# current asv score is:  0.583
# The DCF is:  0.25607142857142856
# current asv score is:  0.584
# The DCF is:  0.26035714285714284
# current asv score is:  0.585
# The DCF is:  0.26571428571428574
# current asv score is:  0.586
# The DCF is:  0.26571428571428574
# current asv score is:  0.587
# The DCF is:  0.2667857142857143
# current asv score is:  0.588
# The DCF is:  0.2710714285714286
# current asv score is:  0.589
# The DCF is:  0.27214285714285713
# current asv score is:  0.59
# The DCF is:  0.2742857142857143
# current asv score is:  0.591
# The DCF is:  0.2764285714285714
# current asv score is:  0.592
# The DCF is:  0.2785714285714286
# current asv score is:  0.593
# The DCF is:  0.2807142857142857
# current asv score is:  0.594
# The DCF is:  0.2839285714285714
# current asv score is:  0.595
# The DCF is:  0.2860714285714286
# current asv score is:  0.596
# The DCF is:  0.29464285714285715
# current asv score is:  0.597
# The DCF is:  0.29892857142857143
# current asv score is:  0.598
# The DCF is:  0.30214285714285716
# current asv score is:  0.599
# The DCF is:  0.3075
# current asv score is:  0.6
# The DCF is:  0.31392857142857145
# current asv score is:  0.601
# The DCF is:  0.3192857142857143
# current asv score is:  0.602
# The DCF is:  0.3246428571428572
# current asv score is:  0.603
# The DCF is:  0.32785714285714285
# current asv score is:  0.604
# The DCF is:  0.32999999999999996
# current asv score is:  0.605
# The DCF is:  0.3310714285714285
# current asv score is:  0.606
# The DCF is:  0.3321428571428572
# current asv score is:  0.607
# The DCF is:  0.33535714285714285
# current asv score is:  0.608
# The DCF is:  0.3364285714285714
# current asv score is:  0.609
# The DCF is:  0.34500000000000003
# current asv score is:  0.61
# The DCF is:  0.35250000000000004
# current asv score is:  0.611
# The DCF is:  0.3578571428571428
# current asv score is:  0.612
# The DCF is:  0.36
# current asv score is:  0.613
# The DCF is:  0.3632142857142857
# current asv score is:  0.614
# The DCF is:  0.36642857142857144
# current asv score is:  0.615
# The DCF is:  0.37071428571428566
# current asv score is:  0.616
# The DCF is:  0.3728571428571429
# current asv score is:  0.617
# The DCF is:  0.38035714285714284
# current asv score is:  0.618
# The DCF is:  0.38142857142857145
# current asv score is:  0.619
# The DCF is:  0.3846428571428572
# current asv score is:  0.62
# The DCF is:  0.3889285714285714
# current asv score is:  0.621
# The DCF is:  0.39535714285714285
# current asv score is:  0.622
# The DCF is:  0.4039285714285714
# current asv score is:  0.623
# The DCF is:  0.4082142857142857
# current asv score is:  0.624
# The DCF is:  0.41250000000000003
# current asv score is:  0.625
# The DCF is:  0.42
# current asv score is:  0.626
# The DCF is:  0.42428571428571427
# current asv score is:  0.627
# The DCF is:  0.42857142857142855
# current asv score is:  0.628
# The DCF is:  0.43392857142857144
# current asv score is:  0.629
# The DCF is:  0.4392857142857143
# current asv score is:  0.63
# The DCF is:  0.44571428571428573
# current asv score is:  0.631
# The DCF is:  0.44999999999999996
# current asv score is:  0.632
# The DCF is:  0.45321428571428574
# current asv score is:  0.633
# The DCF is:  0.4585714285714286
# current asv score is:  0.634
# The DCF is:  0.46285714285714286
# current asv score is:  0.635
# The DCF is:  0.46714285714285714
# current asv score is:  0.636
# The DCF is:  0.47250000000000003
# current asv score is:  0.637
# The DCF is:  0.47464285714285714
# current asv score is:  0.638
# The DCF is:  0.48
# current asv score is:  0.639
# The DCF is:  0.48642857142857143
# current asv score is:  0.64
# The DCF is:  0.4907142857142857
# current asv score is:  0.641
# The DCF is:  0.4971428571428571
# current asv score is:  0.642
# The DCF is:  0.5003571428571428
# current asv score is:  0.643
# The DCF is:  0.5067857142857143
# current asv score is:  0.644
# The DCF is:  0.5089285714285715
# current asv score is:  0.645
# The DCF is:  0.5121428571428571
# current asv score is:  0.646
# The DCF is:  0.5153571428571428
# current asv score is:  0.647
# The DCF is:  0.5228571428571428
# current asv score is:  0.648
# The DCF is:  0.5260714285714286
# current asv score is:  0.649
# The DCF is:  0.5346428571428571
# current asv score is:  0.65
# The DCF is:  0.5367857142857143
# current asv score is:  0.651
# The DCF is:  0.5389285714285714
# current asv score is:  0.652
# The DCF is:  0.5485714285714286
# current asv score is:  0.653
# The DCF is:  0.5539285714285714
# current asv score is:  0.654
# The DCF is:  0.5582142857142857
# current asv score is:  0.655
# The DCF is:  0.5614285714285714
# current asv score is:  0.656
# The DCF is:  0.5646428571428572
# current asv score is:  0.657
# The DCF is:  0.5710714285714286
# current asv score is:  0.658
# The DCF is:  0.5817857142857142
# current asv score is:  0.659
# The DCF is:  0.5839285714285714
# current asv score is:  0.66
# The DCF is:  0.5903571428571429
# current asv score is:  0.661
# The DCF is:  0.5925
# current asv score is:  0.662
# The DCF is:  0.5946428571428571
# current asv score is:  0.663
# The DCF is:  0.5967857142857143
# current asv score is:  0.664
# The DCF is:  0.6010714285714285
# current asv score is:  0.665
# The DCF is:  0.6053571428571429
# current asv score is:  0.666
# The DCF is:  0.6128571428571429
# current asv score is:  0.667
# The DCF is:  0.6192857142857142
# current asv score is:  0.668
# The DCF is:  0.6224999999999999
# current asv score is:  0.669
# The DCF is:  0.6278571428571429
# current asv score is:  0.67
# The DCF is:  0.6289285714285715
# current asv score is:  0.671
# The DCF is:  0.63
# current asv score is:  0.672
# The DCF is:  0.6364285714285715
# current asv score is:  0.673
# The DCF is:  0.6364285714285715
# current asv score is:  0.674
# The DCF is:  0.6428571428571428
# current asv score is:  0.675
# The DCF is:  0.6471428571428571
# current asv score is:  0.676
# The DCF is:  0.6535714285714286
# current asv score is:  0.677
# The DCF is:  0.6578571428571428
# current asv score is:  0.678
# The DCF is:  0.6610714285714285
# current asv score is:  0.679
# The DCF is:  0.6685714285714286
# current asv score is:  0.68
# The DCF is:  0.6739285714285714
# current asv score is:  0.681
# The DCF is:  0.6782142857142857
# current asv score is:  0.682
# The DCF is:  0.6782142857142857
# current asv score is:  0.683
# The DCF is:  0.6825
# current asv score is:  0.684
# The DCF is:  0.6900000000000001
# current asv score is:  0.685
# The DCF is:  0.6953571428571428
# current asv score is:  0.686
# The DCF is:  0.6975
# current asv score is:  0.687
# The DCF is:  0.7028571428571428
# current asv score is:  0.6880000000000001
# The DCF is:  0.7082142857142857
# current asv score is:  0.6890000000000001
# The DCF is:  0.7135714285714285
# current asv score is:  0.6900000000000001
# The DCF is:  0.7178571428571429
# current asv score is:  0.6910000000000001
# The DCF is:  0.7221428571428571
# current asv score is:  0.6920000000000001
# The DCF is:  0.7264285714285714
# current asv score is:  0.6930000000000001
# The DCF is:  0.735
# current asv score is:  0.6940000000000001
# The DCF is:  0.7414285714285713
# current asv score is:  0.6950000000000001
# The DCF is:  0.7424999999999999
# current asv score is:  0.6960000000000001
# The DCF is:  0.7489285714285714
# current asv score is:  0.6970000000000001
# The DCF is:  0.7521428571428571
# current asv score is:  0.6980000000000001
# The DCF is:  0.7542857142857142
# current asv score is:  0.6990000000000001
# The DCF is:  0.7585714285714286
# current asv score is:  0.7000000000000001
# The DCF is:  0.7639285714285715
# current asv score is:  0.7010000000000001
# The DCF is:  0.7671428571428571
# current asv score is:  0.7020000000000001
# The DCF is:  0.7692857142857144
# current asv score is:  0.7030000000000001
# The DCF is:  0.7735714285714286
# current asv score is:  0.704
# The DCF is:  0.7778571428571428
# current asv score is:  0.705
# The DCF is:  0.7853571428571429
# current asv score is:  0.706
# The DCF is:  0.7885714285714286
# current asv score is:  0.707
# The DCF is:  0.7917857142857143
# current asv score is:  0.708
# The DCF is:  0.7971428571428572
# current asv score is:  0.709
# The DCF is:  0.8025
# current asv score is:  0.71
# The DCF is:  0.8046428571428572
# current asv score is:  0.711
# The DCF is:  0.8078571428571428
# current asv score is:  0.712
# The DCF is:  0.8121428571428572
# current asv score is:  0.713
# The DCF is:  0.8175
# current asv score is:  0.714
# The DCF is:  0.8196428571428571
# current asv score is:  0.715
# The DCF is:  0.822857142857143
# current asv score is:  0.716
# The DCF is:  0.8271428571428572
# current asv score is:  0.717
# The DCF is:  0.8282142857142857
# current asv score is:  0.718
# The DCF is:  0.8325
# current asv score is:  0.719
# The DCF is:  0.8389285714285714
# current asv score is:  0.72
# The DCF is:  0.8432142857142858
# current asv score is:  0.721
# The DCF is:  0.8475
# current asv score is:  0.722
# The DCF is:  0.8507142857142858
# current asv score is:  0.723
# The DCF is:  0.8528571428571429
# current asv score is:  0.724
# The DCF is:  0.855
# current asv score is:  0.725
# The DCF is:  0.8571428571428571
# current asv score is:  0.726
# The DCF is:  0.8614285714285714
# current asv score is:  0.727
# The DCF is:  0.8625
# current asv score is:  0.728
# The DCF is:  0.8667857142857143
# current asv score is:  0.729
# The DCF is:  0.8689285714285714
# current asv score is:  0.73
# The DCF is:  0.8710714285714286
# current asv score is:  0.731
# The DCF is:  0.8732142857142857
# current asv score is:  0.732
# The DCF is:  0.8753571428571428
# current asv score is:  0.733
# The DCF is:  0.8764285714285714
# current asv score is:  0.734
# The DCF is:  0.8775
# current asv score is:  0.735
# The DCF is:  0.8807142857142857
# current asv score is:  0.736
# The DCF is:  0.8839285714285715
# current asv score is:  0.737
# The DCF is:  0.8839285714285715
# current asv score is:  0.738
# The DCF is:  0.8882142857142857
# current asv score is:  0.739
# The DCF is:  0.8882142857142857
# current asv score is:  0.74
# The DCF is:  0.8892857142857142
# current asv score is:  0.741
# The DCF is:  0.8914285714285715
# current asv score is:  0.742
# The DCF is:  0.8925
# current asv score is:  0.743
# The DCF is:  0.8925
# current asv score is:  0.744
# The DCF is:  0.8957142857142857
# current asv score is:  0.745
# The DCF is:  0.8989285714285714
# current asv score is:  0.746
# The DCF is:  0.8999999999999999
# current asv score is:  0.747
# The DCF is:  0.9010714285714286
# current asv score is:  0.748
# The DCF is:  0.9053571428571429
# current asv score is:  0.749
# The DCF is:  0.9064285714285715
# current asv score is:  0.75
# The DCF is:  0.9096428571428571
# current asv score is:  0.751
# The DCF is:  0.9096428571428571
# current asv score is:  0.752
# The DCF is:  0.9149999999999999
# current asv score is:  0.753
# The DCF is:  0.9182142857142856
# current asv score is:  0.754
# The DCF is:  0.9225
# current asv score is:  0.755
# The DCF is:  0.9235714285714286
# current asv score is:  0.756
# The DCF is:  0.9246428571428572
# current asv score is:  0.757
# The DCF is:  0.9267857142857143
# current asv score is:  0.758
# The DCF is:  0.93
# current asv score is:  0.759
# The DCF is:  0.9332142857142857
# current asv score is:  0.76
# The DCF is:  0.9342857142857143
# current asv score is:  0.761
# The DCF is:  0.9342857142857143
# current asv score is:  0.762
# The DCF is:  0.9342857142857143
# current asv score is:  0.763
# The DCF is:  0.9375
# current asv score is:  0.764
# The DCF is:  0.9385714285714285
# current asv score is:  0.765
# The DCF is:  0.9407142857142857
# current asv score is:  0.766
# The DCF is:  0.9407142857142857
# current asv score is:  0.767
# The DCF is:  0.9417857142857143
# current asv score is:  0.768
# The DCF is:  0.9417857142857143
# current asv score is:  0.769
# The DCF is:  0.9460714285714286
# current asv score is:  0.77
# The DCF is:  0.9482142857142857
# current asv score is:  0.771
# The DCF is:  0.9482142857142857
# current asv score is:  0.772
# The DCF is:  0.9482142857142857
# current asv score is:  0.773
# The DCF is:  0.9514285714285714
# current asv score is:  0.774
# The DCF is:  0.9514285714285714
# current asv score is:  0.775
# The DCF is:  0.9525
# current asv score is:  0.776
# The DCF is:  0.9535714285714285
# current asv score is:  0.777
# The DCF is:  0.9546428571428571
# current asv score is:  0.778
# The DCF is:  0.9546428571428571
# current asv score is:  0.779
# The DCF is:  0.9546428571428571
# current asv score is:  0.78
# The DCF is:  0.9546428571428571
# current asv score is:  0.781
# The DCF is:  0.9557142857142856
# current asv score is:  0.782
# The DCF is:  0.9589285714285714
# current asv score is:  0.783
# The DCF is:  0.9621428571428572
# current asv score is:  0.784
# The DCF is:  0.9621428571428572
# current asv score is:  0.785
# The DCF is:  0.9621428571428572
# current asv score is:  0.786
# The DCF is:  0.9632142857142857
# current asv score is:  0.787
# The DCF is:  0.9664285714285714
# current asv score is:  0.788
# The DCF is:  0.9664285714285714
# current asv score is:  0.789
# The DCF is:  0.9685714285714285
# current asv score is:  0.79
# The DCF is:  0.9685714285714285
# current asv score is:  0.791
# The DCF is:  0.9707142857142858
# current asv score is:  0.792
# The DCF is:  0.9707142857142858
# current asv score is:  0.793
# The DCF is:  0.9717857142857143
# current asv score is:  0.794
# The DCF is:  0.9739285714285714
# current asv score is:  0.795
# The DCF is:  0.9739285714285714
# current asv score is:  0.796
# The DCF is:  0.9739285714285714
# current asv score is:  0.797
# The DCF is:  0.975
# current asv score is:  0.798
# The DCF is:  0.9760714285714285
# current asv score is:  0.799
# The DCF is:  0.9760714285714285
# current asv score is:  0.8
# The DCF is:  0.9771428571428571
# current asv score is:  0.801
# The DCF is:  0.9782142857142857
# current asv score is:  0.802
# The DCF is:  0.9782142857142857
# current asv score is:  0.803
# The DCF is:  0.9782142857142857
# current asv score is:  0.804
# The DCF is:  0.9782142857142857
# current asv score is:  0.805
# The DCF is:  0.9782142857142857
# current asv score is:  0.806
# The DCF is:  0.9792857142857142
# current asv score is:  0.807
# The DCF is:  0.9792857142857142
# current asv score is:  0.808
# The DCF is:  0.9792857142857142
# current asv score is:  0.809
# The DCF is:  0.9803571428571429
# current asv score is:  0.81
# The DCF is:  0.9803571428571429
# current asv score is:  0.811
# The DCF is:  0.9803571428571429
# current asv score is:  0.812
# The DCF is:  0.9814285714285714
# current asv score is:  0.8130000000000001
# The DCF is:  0.9814285714285714
# current asv score is:  0.8140000000000001
# The DCF is:  0.9814285714285714
# current asv score is:  0.8150000000000001
# The DCF is:  0.9814285714285714
# current asv score is:  0.8160000000000001
# The DCF is:  0.9825
# current asv score is:  0.8170000000000001
# The DCF is:  0.9825
# current asv score is:  0.8180000000000001
# The DCF is:  0.9835714285714287
# current asv score is:  0.8190000000000001
# The DCF is:  0.9835714285714287
# current asv score is:  0.8200000000000001
# The DCF is:  0.9835714285714287
# current asv score is:  0.8210000000000001
# The DCF is:  0.9835714285714287
# current asv score is:  0.8220000000000001
# The DCF is:  0.9835714285714287
# current asv score is:  0.8230000000000001
# The DCF is:  0.9846428571428572
# current asv score is:  0.8240000000000001
# The DCF is:  0.9846428571428572
# current asv score is:  0.8250000000000001
# The DCF is:  0.9846428571428572
# current asv score is:  0.8260000000000001
# The DCF is:  0.9846428571428572
# current asv score is:  0.8270000000000001
# The DCF is:  0.9857142857142858
# current asv score is:  0.8280000000000001
# The DCF is:  0.9857142857142858
# current asv score is:  0.8290000000000001
# The DCF is:  0.9857142857142858
# current asv score is:  0.8300000000000001
# The DCF is:  0.9857142857142858
# current asv score is:  0.8310000000000001
# The DCF is:  0.9857142857142858
# current asv score is:  0.8320000000000001
# The DCF is:  0.9857142857142858
# current asv score is:  0.833
# The DCF is:  0.9867857142857143
# current asv score is:  0.834
# The DCF is:  0.9867857142857143
# current asv score is:  0.835
# The DCF is:  0.9878571428571429
# current asv score is:  0.836
# The DCF is:  0.9878571428571429
# current asv score is:  0.837
# The DCF is:  0.9878571428571429
# current asv score is:  0.838
# The DCF is:  0.9878571428571429
# current asv score is:  0.839
# The DCF is:  0.9889285714285714
# current asv score is:  0.84
# The DCF is:  0.9889285714285714
# current asv score is:  0.841
# The DCF is:  0.9889285714285714
# current asv score is:  0.842
# The DCF is:  0.99
# current asv score is:  0.843
# The DCF is:  0.99
# current asv score is:  0.844
# The DCF is:  0.99
# current asv score is:  0.845
# The DCF is:  0.99
# current asv score is:  0.846
# The DCF is:  0.99
# current asv score is:  0.847
# The DCF is:  0.99
# current asv score is:  0.848
# The DCF is:  0.99
# current asv score is:  0.849
# The DCF is:  0.99
# current asv score is:  0.85
# The DCF is:  0.99
# current asv score is:  0.851
# The DCF is:  0.99
# current asv score is:  0.852
# The DCF is:  0.99
# current asv score is:  0.853
# The DCF is:  0.99
# current asv score is:  0.854
# The DCF is:  0.99
# current asv score is:  0.855
# The DCF is:  0.99
# current asv score is:  0.856
# The DCF is:  0.99
# current asv score is:  0.857
# The DCF is:  0.99
# current asv score is:  0.858
# The DCF is:  0.99
# current asv score is:  0.859
# The DCF is:  0.99
# current asv score is:  0.86
# The DCF is:  0.99
# current asv score is:  0.861
# The DCF is:  0.99
# current asv score is:  0.862
# The DCF is:  0.99
# current asv score is:  0.863
# The DCF is:  0.99
# current asv score is:  0.864
# The DCF is:  0.99
# current asv score is:  0.865
# The DCF is:  0.99
# current asv score is:  0.866
# The DCF is:  0.99
# current asv score is:  0.867
# The DCF is:  0.99
# current asv score is:  0.868
# The DCF is:  0.99
# current asv score is:  0.869
# The DCF is:  0.99
# current asv score is:  0.87
# The DCF is:  0.99
# current asv score is:  0.871
# The DCF is:  0.99
# current asv score is:  0.872
# The DCF is:  0.99
# current asv score is:  0.873
# The DCF is:  0.99
# current asv score is:  0.874
# The DCF is:  0.99
# current asv score is:  0.875
# The DCF is:  0.99
# current asv score is:  0.876
# The DCF is:  0.99
# current asv score is:  0.877
# The DCF is:  0.99
# current asv score is:  0.878
# The DCF is:  0.99
# current asv score is:  0.879
# The DCF is:  0.99
# current asv score is:  0.88
# The DCF is:  0.99
# current asv score is:  0.881
# The DCF is:  0.99
# current asv score is:  0.882
# The DCF is:  0.99
# current asv score is:  0.883
# The DCF is:  0.99
# current asv score is:  0.884
# The DCF is:  0.99
# current asv score is:  0.885
# The DCF is:  0.99
# current asv score is:  0.886
# The DCF is:  0.99
# current asv score is:  0.887
# The DCF is:  0.99
# current asv score is:  0.888
# The DCF is:  0.99
# current asv score is:  0.889
# The DCF is:  0.99
# current asv score is:  0.89
# The DCF is:  0.99
# current asv score is:  0.891
# The DCF is:  0.99
# current asv score is:  0.892
# The DCF is:  0.99
# current asv score is:  0.893
# The DCF is:  0.99
# current asv score is:  0.894
# The DCF is:  0.99
# current asv score is:  0.895
# The DCF is:  0.99
# current asv score is:  0.896
# The DCF is:  0.99
# current asv score is:  0.897
# The DCF is:  0.99
# current asv score is:  0.898
# The DCF is:  0.99
# current asv score is:  0.899
# The DCF is:  0.99
# current asv score is:  0.9
# The DCF is:  0.99
# current asv score is:  0.901
# The DCF is:  0.99
# current asv score is:  0.902
# The DCF is:  0.99
# current asv score is:  0.903
# The DCF is:  0.99
# current asv score is:  0.904
# The DCF is:  0.99
# current asv score is:  0.905
# The DCF is:  0.99
# current asv score is:  0.906
# The DCF is:  0.99
# current asv score is:  0.907
# The DCF is:  0.99
# current asv score is:  0.908
# The DCF is:  0.99
# current asv score is:  0.909
# The DCF is:  0.99
# current asv score is:  0.91
# The DCF is:  0.99
# current asv score is:  0.911
# The DCF is:  0.99
# current asv score is:  0.912
# The DCF is:  0.99
# current asv score is:  0.913
# The DCF is:  0.99
# current asv score is:  0.914
# The DCF is:  0.99
# current asv score is:  0.915
# The DCF is:  0.99
# current asv score is:  0.916
# The DCF is:  0.99
# current asv score is:  0.917
# The DCF is:  0.99
# current asv score is:  0.918
# The DCF is:  0.99
# current asv score is:  0.919
# The DCF is:  0.99
# current asv score is:  0.92
# The DCF is:  0.99
# current asv score is:  0.921
# The DCF is:  0.99
# current asv score is:  0.922
# The DCF is:  0.99
# current asv score is:  0.923
# The DCF is:  0.99
# current asv score is:  0.924
# The DCF is:  0.99
# current asv score is:  0.925
# The DCF is:  0.99
# current asv score is:  0.926
# The DCF is:  0.99
# current asv score is:  0.927
# The DCF is:  0.99
# current asv score is:  0.928
# The DCF is:  0.99
# current asv score is:  0.929
# The DCF is:  0.99
# current asv score is:  0.93
# The DCF is:  0.99
# current asv score is:  0.931
# The DCF is:  0.99
# current asv score is:  0.932
# The DCF is:  0.99
# current asv score is:  0.933
# The DCF is:  0.99
# current asv score is:  0.934
# The DCF is:  0.99
# current asv score is:  0.935
# The DCF is:  0.99
# current asv score is:  0.936
# The DCF is:  0.99
# current asv score is:  0.937
# The DCF is:  0.99
# current asv score is:  0.9380000000000001
# The DCF is:  0.99
# current asv score is:  0.9390000000000001
# The DCF is:  0.99
# current asv score is:  0.9400000000000001
# The DCF is:  0.99
# current asv score is:  0.9410000000000001
# The DCF is:  0.99
# current asv score is:  0.9420000000000001
# The DCF is:  0.99
# current asv score is:  0.9430000000000001
# The DCF is:  0.99
# current asv score is:  0.9440000000000001
# The DCF is:  0.99
# current asv score is:  0.9450000000000001
# The DCF is:  0.99
# current asv score is:  0.9460000000000001
# The DCF is:  0.99
# current asv score is:  0.9470000000000001
# The DCF is:  0.99
# current asv score is:  0.9480000000000001
# The DCF is:  0.99
# current asv score is:  0.9490000000000001
# The DCF is:  0.99
# current asv score is:  0.9500000000000001
# The DCF is:  0.99
# current asv score is:  0.9510000000000001
# The DCF is:  0.99
# current asv score is:  0.9520000000000001
# The DCF is:  0.99
# current asv score is:  0.9530000000000001
# The DCF is:  0.99
# current asv score is:  0.9540000000000001
# The DCF is:  0.99
# current asv score is:  0.9550000000000001
# The DCF is:  0.99
# current asv score is:  0.9560000000000001
# The DCF is:  0.99
# current asv score is:  0.9570000000000001
# The DCF is:  0.99
# current asv score is:  0.9580000000000001
# The DCF is:  0.99
# current asv score is:  0.9590000000000001
# The DCF is:  0.99
# current asv score is:  0.96
# The DCF is:  0.99
# current asv score is:  0.961
# The DCF is:  0.99
# current asv score is:  0.962
# The DCF is:  0.99
# current asv score is:  0.963
# The DCF is:  0.99
# current asv score is:  0.964
# The DCF is:  0.99
# current asv score is:  0.965
# The DCF is:  0.99
# current asv score is:  0.966
# The DCF is:  0.99
# current asv score is:  0.967
# The DCF is:  0.99
# current asv score is:  0.968
# The DCF is:  0.99
# current asv score is:  0.969
# The DCF is:  0.99
# current asv score is:  0.97
# The DCF is:  0.99
# current asv score is:  0.971
# The DCF is:  0.99
# current asv score is:  0.972
# The DCF is:  0.99
# current asv score is:  0.973
# The DCF is:  0.99
# current asv score is:  0.974
# The DCF is:  0.99
# current asv score is:  0.975
# The DCF is:  0.99
# current asv score is:  0.976
# The DCF is:  0.99
# current asv score is:  0.977
# The DCF is:  0.99
# current asv score is:  0.978
# The DCF is:  0.99
# current asv score is:  0.979
# The DCF is:  0.99
# current asv score is:  0.98
# The DCF is:  0.99
# current asv score is:  0.981
# The DCF is:  0.99
# current asv score is:  0.982
# The DCF is:  0.99
# current asv score is:  0.983
# The DCF is:  0.99
# current asv score is:  0.984
# The DCF is:  0.99
# current asv score is:  0.985
# The DCF is:  0.99
# current asv score is:  0.986
# The DCF is:  0.99
# current asv score is:  0.987
# The DCF is:  0.99
# current asv score is:  0.988
# The DCF is:  0.99
# current asv score is:  0.989
# The DCF is:  0.99
# current asv score is:  0.99
# The DCF is:  0.99
# current asv score is:  0.991
# The DCF is:  0.99
# current asv score is:  0.992
# The DCF is:  0.99
# current asv score is:  0.993
# The DCF is:  0.99
# current asv score is:  0.994
# The DCF is:  0.99
# current asv score is:  0.995
# The DCF is:  0.99
# current asv score is:  0.996
# The DCF is:  0.99
# current asv score is:  0.997
# The DCF is:  0.99
# current asv score is:  0.998
# The DCF is:  0.99
# current asv score is:  0.999
# The DCF is:  0.99
# current asv score is:  1.0
# The DCF is:  0.99
# current asv score is:  1.0010000000000001
# The DCF is:  0.99
# current asv score is:  1.002
# The DCF is:  0.99
# current asv score is:  1.0030000000000001
# The DCF is:  0.99
# current asv score is:  1.004
# The DCF is:  0.99
# current asv score is:  1.0050000000000001
# The DCF is:  0.99
# current asv score is:  1.006
# The DCF is:  0.99
# current asv score is:  1.0070000000000001
# The DCF is:  0.99
# current asv score is:  1.008
# The DCF is:  0.99
# current asv score is:  1.0090000000000001
# The DCF is:  0.99
# the EER is:  0.010812489979156646
# the threshold of the EER is:  0.3966511271216653
# the minDCF is: 0.008108465608465613
# the threshold of the minDCF is:  0.33

# %%
def metric(labels, scores):
    dcf_list = []
    target_scores = scores[labels == 1]
    nontarget_scores = scores[labels == 0]

    # Check if either target_scores or nontarget_scores is empty
    if target_scores.size == 0 or nontarget_scores.size == 0:
        center_eer = 100 * 0.010812489979156646
        center_thr_eer =  0.3966511271216653
        center_minDCF = 0.008108465608465613
        print("Warning: Empty target or nontarget scores. Ignoring this case.")
        return [center_eer, center_thr_eer,  center_minDCF]  #return the center of the confidence interval for the EER, threshold, and minDCF

    # Compute EER and threshold
    eer, thr_eer, _, _ = eval_metrics.compute_eer(target_scores, nontarget_scores)

    for asv_thr in asv_thr_list:  # Iterate over each ASV score
        # Obtain ASV error rates
        Pfa_asv, Pmiss_asv, _, _ = eval_metrics.obtain_asv_error_rates(
            target_scores, nontarget_scores, np.array([]), asv_thr
        )

        # Compute DCF
        dcf = dcf_formula(
            Pfa_asv,
            Pmiss_asv,
            Prior_target=Prior_target,
            Prior_non_target=Prior_non_target,
            cost_model_dcf=cost_model_dcf,
            is_print=False
        )
        dcf_list.append(dcf)

    # Get the minimum DCF
    minDCF_index = np.argmin(np.array(dcf_list))

    return [100 * eer, thr_eer, dcf_list[minDCF_index]]


target_scores = results_list_dev_female.loc[results_list_dev_female['label_ground_truth'] == "target"]["pred_scores"]
nontarget_scores = results_list_dev_female.loc[results_list_dev_female['label_ground_truth'] == "nontarget"]["pred_scores"]
target_labels = results_list_dev_female.loc[results_list_dev_female['label_ground_truth'] == "target"]["label_ground_truth"]
nontarget_labels = results_list_dev_female.loc[results_list_dev_female['label_ground_truth'] == "nontarget"]["label_ground_truth"]
speakers = results_list_dev_female['speaker_id'][
    (results_list_dev_female['label_ground_truth'] == "nontarget") |
    (results_list_dev_female['label_ground_truth'] == "target")
].values
scores = np.concatenate([target_scores.to_numpy(),nontarget_scores.to_numpy()])
labels = np.concatenate([target_labels.to_numpy(),nontarget_labels.to_numpy()])
labels = np.where(labels == 'target', 1, 0)

res = evaluate_with_conf_int(samples = scores, metric = metric, labels = labels, conditions = speakers, num_bootstraps=num_bootstraps, alpha=alpha)
print("result:\n", res)
# Out:
# result:
#  ([1.0812489979156645, 0.3966511271216653, 0.008108465608465613], [(0.0, 2.398463760593927), (0.33441906625574286, 0.4593112224882299), (0.0, 0.01169451956904134)])

# %%
plotting_eer_and_dcf(asv_thr_list,dcf_list_dev_female,frr,far,eer,thr_eer,data_name = f"ECAPA-TDNN Female Development Protocol \n with Prior_target = {Prior_target}, Cmiss_ASV = {cost_model_dcf['Cmiss_asv']}, Cfa_ASV = {cost_model_dcf['Cfa_asv']}")

target_scores = results_list_dev_female.loc[results_list_dev_female['label_ground_truth'] == "target"]["pred_scores"]
nontarget_scores = results_list_dev_female.loc[results_list_dev_female['label_ground_truth'] == "nontarget"]["pred_scores"]
spoof_scores = results_list_dev_female.loc[results_list_dev_female['label_ground_truth'] == "spoof"]["pred_scores"]

# Plot the histograms
plotting_probability_histogram(nontarget_scores,target_scores,num_bins=100,colors=['yellow', 'purple'],data_name = f"Female dev protocol")
plotting_probability_histogram(nontarget_scores,target_scores,spoof_scores,num_bins=100,colors=['yellow', 'purple','red'],data_name = f"ECAPA-TDNN Female Development Protocol")

# %%
vc_filter = (results_list_dev_female['attack_type'] == "A05") | (results_list_dev_female['attack_type'] == "A06")
tts_filter = (results_list_dev_female['attack_type'] == "A01") | (results_list_dev_female['attack_type'] == "A02") | (results_list_dev_female['attack_type'] == "A03") | (results_list_dev_female['attack_type'] == "A04")


target_scores = results_list_dev_female.loc[results_list_dev_female['label_ground_truth'] == "target"]["pred_scores"]
nontarget_scores = results_list_dev_female.loc[results_list_dev_female['label_ground_truth'] == "nontarget"]["pred_scores"]
VC_scores = results_list_dev_female.loc[vc_filter]["pred_scores"]
TTS_scores = results_list_dev_female.loc[tts_filter]["pred_scores"]

plotting_probability_histogram_TTS_and_VC(nontarget_scores,target_scores,TTS_scores,VC_scores,combine_TTS_VC_scores=None,num_bins=100,colors=['yellow', 'purple','green','blue','brown'],data_name= f"\n ECAPA-TDNN Female \n Development Protocol")
# Out:
# C:\Users\avish\AppData\Local\Temp\ipykernel_8696\4014528629.py:19: UserWarning: The palette list has more values (5) than needed (4), which may not be intended.
#   sns.histplot([nontarget_scores.to_numpy(), target_scores.to_numpy(),TTS_scores.to_numpy(),VC_scores.to_numpy()], kde=True, stat='probability', bins=100, palette=colors, linewidth=1)# Add labels and title

# %% [markdown]
# ### DCF - Female:

# %%
from ASV_utils.dcf_my_functions import calculate_dcf
import matplotlib.pyplot as plt

Prior_target =  0.99

Prior_non_target = 1 - Prior_target

dcf_list_eval_female = []
is_print = True

cost_model_dcf = {
    'Cmiss_asv': 1,      # Cost of ASV falsely rejecting target
    'Cfa_asv': 10,       # Cost of ASV falsely accepting nontarget
}

 

# for all eval
asv_thr_list = np.arange(0, 1.01, 0.001).tolist()

##results_list_eval_female = calculate_dcf_avg_score(list_eval_files,df_eval_female_protocol,enrollment_eval_female,embeddings_eval,Eval_dataset_all)


import pickle
file_path = 'asv_results_eval_fixed_female.pkl'

results_list_eval_female = pickle.load(open(file_path, 'rb'))

# Open the file in binary write mode and dump the data
#with open(file_path, 'wb') as f:
#    pickle.dump(results_list_eval_female, f)

target_scores = results_list_eval_female.loc[results_list_eval_female['label_ground_truth'] == "target"]["pred_scores"]
nontarget_scores = results_list_eval_female.loc[results_list_eval_female['label_ground_truth'] == "nontarget"]["pred_scores"]

eer, thr_eer, frr, far = eval_metrics.compute_eer(target_scores,nontarget_scores)
    
for asv_thr in asv_thr_list: # over each asv score

    print("current asv score is: ",asv_thr)

    Pfa_asv, Pmiss_asv, _, _ = eval_metrics.obtain_asv_error_rates(target_scores,nontarget_scores,np.array([]),asv_thr)
    dcf = dcf_formula(Pfa_asv,Pmiss_asv,Prior_target = Prior_target,Prior_non_target= Prior_non_target,cost_model_dcf=cost_model_dcf,is_print=is_print)
    dcf_list_eval_female.append(dcf)
    
    
print("the EER is: ",eer)
print("the threshold of the EER is: ",thr_eer)
minDCF_index = np.argmin(np.array(dcf_list_eval_female))
print("the minDCF is:",dcf_list_eval_female[minDCF_index])
print("the threshold of the minDCF is: ",asv_thr_list[minDCF_index])
# Out:
# current asv score is:  0.0
# The DCF is:  0.09540495529039604
# current asv score is:  0.001
# The DCF is:  0.09528789765121451
# current asv score is:  0.002
# The DCF is:  0.09516147540089845
# current asv score is:  0.003
# The DCF is:  0.09506314698398596
# current asv score is:  0.004
# The DCF is:  0.09496950087264074
# current asv score is:  0.005
# The DCF is:  0.09487117245572825
# current asv score is:  0.006
# The DCF is:  0.09477752634438302
# current asv score is:  0.007
# The DCF is:  0.09466983331633601
# current asv score is:  0.008
# The DCF is:  0.09452468184375092
# current asv score is:  0.009000000000000001
# The DCF is:  0.09440762420456937
# current asv score is:  0.01
# The DCF is:  0.09427651964868607
# current asv score is:  0.011
# The DCF is:  0.09413605048166822
# current asv score is:  0.012
# The DCF is:  0.0940049459257849
# current asv score is:  0.013000000000000001
# The DCF is:  0.09385511214763254
# current asv score is:  0.014
# The DCF is:  0.09375210142515279
# current asv score is:  0.015
# The DCF is:  0.09362567917483675
# current asv score is:  0.016
# The DCF is:  0.09345711617441534
# current asv score is:  0.017
# The DCF is:  0.09329791778512846
# current asv score is:  0.018000000000000002
# The DCF is:  0.09312935478470703
# current asv score is:  0.019
# The DCF is:  0.09295610947871837
# current asv score is:  0.02
# The DCF is:  0.09282500492283506
# current asv score is:  0.021
# The DCF is:  0.09265644192241365
# current asv score is:  0.022
# The DCF is:  0.09252065506096306
# current asv score is:  0.023
# The DCF is:  0.09231463361600356
# current asv score is:  0.024
# The DCF is:  0.09213202369888038
# current asv score is:  0.025
# The DCF is:  0.09197282530959348
# current asv score is:  0.026000000000000002
# The DCF is:  0.09181830922587386
# current asv score is:  0.027
# The DCF is:  0.09166379314215424
# current asv score is:  0.028
# The DCF is:  0.09150927705843462
# current asv score is:  0.029
# The DCF is:  0.09130325561347512
# current asv score is:  0.03
# The DCF is:  0.0911487395297555
# current asv score is:  0.031
# The DCF is:  0.09096612961263231
# current asv score is:  0.032
# The DCF is:  0.0908209781400472
# current asv score is:  0.033
# The DCF is:  0.09060090977838592
# current asv score is:  0.034
# The DCF is:  0.09043234677796451
# current asv score is:  0.035
# The DCF is:  0.09027314838867763
# current asv score is:  0.036000000000000004
# The DCF is:  0.09005776233258361
# current asv score is:  0.037
# The DCF is:  0.08986578780432589
# current asv score is:  0.038
# The DCF is:  0.08969254249833722
# current asv score is:  0.039
# The DCF is:  0.08948652105337773
# current asv score is:  0.04
# The DCF is:  0.08928986421955275
# current asv score is:  0.041
# The DCF is:  0.08906979585789147
# current asv score is:  0.042
# The DCF is:  0.08884972749623019
# current asv score is:  0.043000000000000003
# The DCF is:  0.08866243527353974
# current asv score is:  0.044
# The DCF is:  0.08837213232836953
# current asv score is:  0.045
# The DCF is:  0.0881099232166029
# current asv score is:  0.046
# The DCF is:  0.08815972562972206
# current asv score is:  0.047
# The DCF is:  0.087925610351359
# current asv score is:  0.048
# The DCF is:  0.08771958890639951
# current asv score is:  0.049
# The DCF is:  0.08751356746144
# current asv score is:  0.05
# The DCF is:  0.08722794682183707
# current asv score is:  0.051000000000000004
# The DCF is:  0.08700787846017578
# current asv score is:  0.052000000000000005
# The DCF is:  0.08674098704284189
# current asv score is:  0.053
# The DCF is:  0.08645068409767169
# current asv score is:  0.054
# The DCF is:  0.08619315729147231
# current asv score is:  0.055
# The DCF is:  0.08590753665186937
# current asv score is:  0.056
# The DCF is:  0.08567342137350631
# current asv score is:  0.057
# The DCF is:  0.08542525917844146
# current asv score is:  0.058
# The DCF is:  0.08510218009430043
# current asv score is:  0.059000000000000004
# The DCF is:  0.08477441870459214
# current asv score is:  0.06
# The DCF is:  0.08447475114828741
# current asv score is:  0.061
# The DCF is:  0.08419381281425173
# current asv score is:  0.062
# The DCF is:  0.083894145257947
# current asv score is:  0.063
# The DCF is:  0.0835570192571042
# current asv score is:  0.064
# The DCF is:  0.08319648172842506
# current asv score is:  0.065
# The DCF is:  0.08294831953336021
# current asv score is:  0.066
# The DCF is:  0.08266269889375728
# current asv score is:  0.067
# The DCF is:  0.08235834903188528
# current asv score is:  0.068
# The DCF is:  0.08206336378114783
# current asv score is:  0.069
# The DCF is:  0.08174964930814133
# current asv score is:  0.07
# The DCF is:  0.08143593483513481
# current asv score is:  0.07100000000000001
# The DCF is:  0.0810847619175902
# current asv score is:  0.07200000000000001
# The DCF is:  0.08073827130561287
# current asv score is:  0.073
# The DCF is:  0.0804198745270391
# current asv score is:  0.074
# The DCF is:  0.0800921131373308
# current asv score is:  0.075
# The DCF is:  0.07970348177524811
# current asv score is:  0.076
# The DCF is:  0.07933826194100174
# current asv score is:  0.077
# The DCF is:  0.07902922977356248
# current asv score is:  0.078
# The DCF is:  0.07869210377271968
# current asv score is:  0.079
# The DCF is:  0.07836434238301138
# current asv score is:  0.08
# The DCF is:  0.07802721638216857
# current asv score is:  0.081
# The DCF is:  0.07760580888111505
# current asv score is:  0.082
# The DCF is:  0.07722185982459961
# current asv score is:  0.083
# The DCF is:  0.07682854615694966
# current asv score is:  0.084
# The DCF is:  0.07646800862827055
# current asv score is:  0.085
# The DCF is:  0.07606533034948608
# current asv score is:  0.08600000000000001
# The DCF is:  0.07565796976513434
# current asv score is:  0.08700000000000001
# The DCF is:  0.07535830220882961
# current asv score is:  0.088
# The DCF is:  0.07502585851355406
# current asv score is:  0.089
# The DCF is:  0.07458103948466423
# current asv score is:  0.09
# The DCF is:  0.07421113734485059
# current asv score is:  0.091
# The DCF is:  0.07383655289946968
# current asv score is:  0.092
# The DCF is:  0.07336364003717628
# current asv score is:  0.093
# The DCF is:  0.07289540948045016
# current asv score is:  0.094
# The DCF is:  0.07245995506269484
# current asv score is:  0.095
# The DCF is:  0.07205727678391037
# current asv score is:  0.096
# The DCF is:  0.07162650467172234
# current asv score is:  0.097
# The DCF is:  0.07123787330963964
# current asv score is:  0.098
# The DCF is:  0.070867971169826
# current asv score is:  0.099
# The DCF is:  0.07039974061309986
# current asv score is:  0.1
# The DCF is:  0.07001110925101718
# current asv score is:  0.101
# The DCF is:  0.0696084309722327
# current asv score is:  0.10200000000000001
# The DCF is:  0.06922916422128454
# current asv score is:  0.10300000000000001
# The DCF is:  0.06885926208147089
# current asv score is:  0.10400000000000001
# The DCF is:  0.06846126610825368
# current asv score is:  0.105
# The DCF is:  0.06803985860720016
# current asv score is:  0.106
# The DCF is:  0.06765590955068473
# current asv score is:  0.107
# The DCF is:  0.06722981974406395
# current asv score is:  0.108
# The DCF is:  0.06680841224301043
# current asv score is:  0.109
# The DCF is:  0.06643382779762952
# current asv score is:  0.11
# The DCF is:  0.06604051412997958
# current asv score is:  0.111
# The DCF is:  0.0656378358511951
# current asv score is:  0.112
# The DCF is:  0.06520706373900706
# current asv score is:  0.113
# The DCF is:  0.06472010396001188
# current asv score is:  0.114
# The DCF is:  0.0643548841257655
# current asv score is:  0.115
# The DCF is:  0.06392879431914472
# current asv score is:  0.116
# The DCF is:  0.06347929298468763
# current asv score is:  0.117
# The DCF is:  0.06306725009476864
# current asv score is:  0.11800000000000001
# The DCF is:  0.06266457181598417
# current asv score is:  0.11900000000000001
# The DCF is:  0.06230871659287231
# current asv score is:  0.12
# The DCF is:  0.06190135600852057
# current asv score is:  0.121
# The DCF is:  0.06151272464643788
# current asv score is:  0.122
# The DCF is:  0.06112877558992245
# current asv score is:  0.123
# The DCF is:  0.060726097311137976
# current asv score is:  0.124
# The DCF is:  0.06035151286575707
# current asv score is:  0.125
# The DCF is:  0.05987860000346368
# current asv score is:  0.126
# The DCF is:  0.05941036944673754
# current asv score is:  0.127
# The DCF is:  0.05902173808465485
# current asv score is:  0.128
# The DCF is:  0.05865183594484121
# current asv score is:  0.129
# The DCF is:  0.05822574613822042
# current asv score is:  0.13
# The DCF is:  0.05783243247057048
# current asv score is:  0.131
# The DCF is:  0.057429754191786
# current asv score is:  0.132
# The DCF is:  0.05693811210722357
# current asv score is:  0.133
# The DCF is:  0.05653543382843909
# current asv score is:  0.134
# The DCF is:  0.056165531688625446
# current asv score is:  0.135
# The DCF is:  0.05569730113189931
# current asv score is:  0.136
# The DCF is:  0.055257164408576746
# current asv score is:  0.137
# The DCF is:  0.05472338157390896
# current asv score is:  0.138
# The DCF is:  0.05427856254501913
# current asv score is:  0.139
# The DCF is:  0.053852472738398355
# current asv score is:  0.14
# The DCF is:  0.053412336015075786
# current asv score is:  0.14100000000000001
# The DCF is:  0.05294878776391692
# current asv score is:  0.14200000000000002
# The DCF is:  0.052396275706980085
# current asv score is:  0.14300000000000002
# The DCF is:  0.05196082128922477
# current asv score is:  0.14400000000000002
# The DCF is:  0.05152068456590221
# current asv score is:  0.145
# The DCF is:  0.051113323981550475
# current asv score is:  0.146
# The DCF is:  0.05066382264709338
# current asv score is:  0.147
# The DCF is:  0.050200274395934524
# current asv score is:  0.148
# The DCF is:  0.049797596117150046
# current asv score is:  0.149
# The DCF is:  0.04928722481031856
# current asv score is:  0.15
# The DCF is:  0.04880494733689064
# current asv score is:  0.151
# The DCF is:  0.04840226905810617
# current asv score is:  0.152
# The DCF is:  0.047994908473754434
# current asv score is:  0.153
# The DCF is:  0.047643735556209835
# current asv score is:  0.154
# The DCF is:  0.047198916527320015
# current asv score is:  0.155
# The DCF is:  0.046782191331833756
# current asv score is:  0.156
# The DCF is:  0.04638419535861654
# current asv score is:  0.157
# The DCF is:  0.04592064710745767
# current asv score is:  0.158
# The DCF is:  0.045513286523105934
# current asv score is:  0.159
# The DCF is:  0.045054420577514326
# current asv score is:  0.16
# The DCF is:  0.044628330770893544
# current asv score is:  0.161
# The DCF is:  0.04421628788097454
# current asv score is:  0.162
# The DCF is:  0.04385575035229543
# current asv score is:  0.163
# The DCF is:  0.043429660545674646
# current asv score is:  0.164
# The DCF is:  0.04294738307224673
# current asv score is:  0.165
# The DCF is:  0.04260557476583665
# current asv score is:  0.166
# The DCF is:  0.04225440184829205
# current asv score is:  0.167
# The DCF is:  0.04184235895837306
# current asv score is:  0.168
# The DCF is:  0.04138349301278145
# current asv score is:  0.169
# The DCF is:  0.0410744608453422
# current asv score is:  0.17
# The DCF is:  0.04062027720531785
# current asv score is:  0.171
# The DCF is:  0.040264421982205985
# current asv score is:  0.17200000000000001
# The DCF is:  0.03986642600898878
# current asv score is:  0.17300000000000001
# The DCF is:  0.03947311234133883
# current asv score is:  0.17400000000000002
# The DCF is:  0.03901424639574722
# current asv score is:  0.17500000000000002
# The DCF is:  0.038602203505828214
# current asv score is:  0.176
# The DCF is:  0.03821357214374553
# current asv score is:  0.177
# The DCF is:  0.037881128448469976
# current asv score is:  0.178
# The DCF is:  0.03738948636390754
# current asv score is:  0.179
# The DCF is:  0.037000855001824845
# current asv score is:  0.18
# The DCF is:  0.036659046695414775
# current asv score is:  0.181
# The DCF is:  0.03630319147230291
# current asv score is:  0.182
# The DCF is:  0.03592860702692201
# current asv score is:  0.183
# The DCF is:  0.035586798720511924
# current asv score is:  0.184
# The DCF is:  0.03518880274729472
# current asv score is:  0.185
# The DCF is:  0.034828265218615595
# current asv score is:  0.186
# The DCF is:  0.034514550745609086
# current asv score is:  0.187
# The DCF is:  0.03417274243919901
# current asv score is:  0.188
# The DCF is:  0.03376538185484727
# current asv score is:  0.189
# The DCF is:  0.033437620465138984
# current asv score is:  0.19
# The DCF is:  0.03306771832532533
# current asv score is:  0.191
# The DCF is:  0.03273059232448252
# current asv score is:  0.192
# The DCF is:  0.0324309247681778
# current asv score is:  0.193
# The DCF is:  0.03207975185063319
# current asv score is:  0.194
# The DCF is:  0.03171921432195408
# current asv score is:  0.195
# The DCF is:  0.03138208832111126
# current asv score is:  0.196
# The DCF is:  0.031044962320268446
# current asv score is:  0.197
# The DCF is:  0.03074997706953098
# current asv score is:  0.198
# The DCF is:  0.030375392624150073
# current asv score is:  0.199
# The DCF is:  0.030019537401038215
# current asv score is:  0.2
# The DCF is:  0.029719869844733487
# current asv score is:  0.201
# The DCF is:  0.029401473066159717
# current asv score is:  0.202
# The DCF is:  0.029087758593153212
# current asv score is:  0.203
# The DCF is:  0.02876467950901218
# current asv score is:  0.20400000000000001
# The DCF is:  0.028465011952707453
# current asv score is:  0.20500000000000002
# The DCF is:  0.02816066209083547
# current asv score is:  0.20600000000000002
# The DCF is:  0.027865676840098007
# current asv score is:  0.20700000000000002
# The DCF is:  0.0275519623670915
# current asv score is:  0.20800000000000002
# The DCF is:  0.027182060227277854
# current asv score is:  0.209
# The DCF is:  0.026905804198809433
# current asv score is:  0.21
# The DCF is:  0.02660613664250471
# current asv score is:  0.211
# The DCF is:  0.026315833697334503
# current asv score is:  0.212
# The DCF is:  0.026002119224328
# current asv score is:  0.213
# The DCF is:  0.025679040140186966
# current asv score is:  0.214
# The DCF is:  0.025388737195016765
# current asv score is:  0.215
# The DCF is:  0.025112481166548347
# current asv score is:  0.216
# The DCF is:  0.0250686374683223
# current asv score is:  0.217
# The DCF is:  0.02478769913428662
# current asv score is:  0.218
# The DCF is:  0.024544219244789032
# current asv score is:  0.219
# The DCF is:  0.024249233994051565
# current asv score is:  0.22
# The DCF is:  0.023968295660015886
# current asv score is:  0.221
# The DCF is:  0.02365926349257664
# current asv score is:  0.222
# The DCF is:  0.02340641899194453
# current asv score is:  0.223
# The DCF is:  0.023073975296668974
# current asv score is:  0.224
# The DCF is:  0.022802401573767818
# current asv score is:  0.225
# The DCF is:  0.022484004795194048
# current asv score is:  0.226
# The DCF is:  0.022231160294561937
# current asv score is:  0.227
# The DCF is:  0.0218846696825846
# current asv score is:  0.228
# The DCF is:  0.021552225987309045
# current asv score is:  0.229
# The DCF is:  0.021271287653273366
# current asv score is:  0.23
# The DCF is:  0.02092947934686329
# current asv score is:  0.231
# The DCF is:  0.02064385870726035
# current asv score is:  0.232
# The DCF is:  0.020376967289926454
# current asv score is:  0.233
# The DCF is:  0.020100711261458033
# current asv score is:  0.234
# The DCF is:  0.019815090621855092
# current asv score is:  0.23500000000000001
# The DCF is:  0.019520105371117633
# current asv score is:  0.23600000000000002
# The DCF is:  0.01927194317605278
# current asv score is:  0.23700000000000002
# The DCF is:  0.018995687147584362
# current asv score is:  0.23800000000000002
# The DCF is:  0.018756889563654035
# current asv score is:  0.23900000000000002
# The DCF is:  0.018475951229618353
# current asv score is:  0.24
# The DCF is:  0.018218424423418984
# current asv score is:  0.241
# The DCF is:  0.018012402978459484
# current asv score is:  0.242
# The DCF is:  0.01771741772772202
# current asv score is:  0.243
# The DCF is:  0.017413067865850035
# current asv score is:  0.244
# The DCF is:  0.01714149414294888
# current asv score is:  0.245
# The DCF is:  0.01689801425345129
# current asv score is:  0.246
# The DCF is:  0.01665921666952096
# current asv score is:  0.247
# The DCF is:  0.016397007557754327
# current asv score is:  0.248
# The DCF is:  0.016176939196093046
# current asv score is:  0.249
# The DCF is:  0.015896000862057367
# current asv score is:  0.25
# The DCF is:  0.015675932500396086
# current asv score is:  0.251
# The DCF is:  0.015455864138734803
# current asv score is:  0.252
# The DCF is:  0.015226431165938997
# current asv score is:  0.253
# The DCF is:  0.015011045109844978
# current asv score is:  0.254
# The DCF is:  0.014734789081376558
# current asv score is:  0.255
# The DCF is:  0.014505356108580754
# current asv score is:  0.256
# The DCF is:  0.014261876219083165
# current asv score is:  0.257
# The DCF is:  0.014055854774123668
# current asv score is:  0.258
# The DCF is:  0.013821739495760599
# current asv score is:  0.259
# The DCF is:  0.013620400356368365
# current asv score is:  0.26
# The DCF is:  0.013400331994707082
# current asv score is:  0.261
# The DCF is:  0.01321772207758389
# current asv score is:  0.262
# The DCF is:  0.012978924493653562
# current asv score is:  0.263
# The DCF is:  0.012796314576530372
# current asv score is:  0.264
# The DCF is:  0.012623069270541703
# current asv score is:  0.265
# The DCF is:  0.012412365520014942
# current asv score is:  0.266
# The DCF is:  0.012187614852786398
# current asv score is:  0.267
# The DCF is:  0.011981593407826901
# current asv score is:  0.268
# The DCF is:  0.011789618879569187
# current asv score is:  0.269
# The DCF is:  0.011560185906773383
# current asv score is:  0.27
# The DCF is:  0.011396305211919235
# current asv score is:  0.271
# The DCF is:  0.011204330683661522
# current asv score is:  0.272
# The DCF is:  0.01103108537767285
# current asv score is:  0.273
# The DCF is:  0.01084847546054966
# current asv score is:  0.274
# The DCF is:  0.01067054784899373
# current asv score is:  0.275
# The DCF is:  0.0104926202374378
# current asv score is:  0.276
# The DCF is:  0.010375562598256267
# current asv score is:  0.277
# The DCF is:  0.010188270375565814
# current asv score is:  0.278
# The DCF is:  0.010043118902980713
# current asv score is:  0.279
# The DCF is:  0.009912014347097394
# current asv score is:  0.28
# The DCF is:  0.009752815957810511
# current asv score is:  0.281
# The DCF is:  0.009579570651821842
# current asv score is:  0.28200000000000003
# The DCF is:  0.009425054568102218
# current asv score is:  0.28300000000000003
# The DCF is:  0.009293950012218902
# current asv score is:  0.28400000000000003
# The DCF is:  0.009139433928499278
# current asv score is:  0.28500000000000003
# The DCF is:  0.008998964761481439
# current asv score is:  0.28600000000000003
# The DCF is:  0.00882571945549277
# current asv score is:  0.28700000000000003
# The DCF is:  0.008675885677340405
# current asv score is:  0.28800000000000003
# The DCF is:  0.00854946342702435
# current asv score is:  0.289
# The DCF is:  0.008390265037737465
# current asv score is:  0.29
# The DCF is:  0.008235748954017841
# current asv score is:  0.291
# The DCF is:  0.008118691314836309
# current asv score is:  0.292
# The DCF is:  0.00802036289792382
# current asv score is:  0.293
# The DCF is:  0.008131035283417397
# current asv score is:  0.294
# The DCF is:  0.00800461303310134
# current asv score is:  0.295
# The DCF is:  0.0078641438660835
# current asv score is:  0.296
# The DCF is:  0.007737721615767445
# current asv score is:  0.297
# The DCF is:  0.0076440755044222194
# current asv score is:  0.298
# The DCF is:  0.007545747087509731
# current asv score is:  0.299
# The DCF is:  0.007438054059462721
# current asv score is:  0.3
# The DCF is:  0.007325678725848448
# current asv score is:  0.301
# The DCF is:  0.0072133033922341765
# current asv score is:  0.302
# The DCF is:  0.0071290218920234735
# current asv score is:  0.303
# The DCF is:  0.007021328863976464
# current asv score is:  0.304
# The DCF is:  0.006908953530362191
# current asv score is:  0.305
# The DCF is:  0.006782531280046135
# current asv score is:  0.306
# The DCF is:  0.0066514267241628185
# current asv score is:  0.307
# The DCF is:  0.006576509835086638
# current asv score is:  0.308
# The DCF is:  0.0064547698903378425
# current asv score is:  0.309
# The DCF is:  0.006630994553773077
# current asv score is:  0.31
# The DCF is:  0.006523301525726066
# current asv score is:  0.311
# The DCF is:  0.006424973108813578
# current asv score is:  0.312
# The DCF is:  0.006336009303035613
# current asv score is:  0.313
# The DCF is:  0.006261092413959432
# current asv score is:  0.314
# The DCF is:  0.006153399385912422
# current asv score is:  0.315
# The DCF is:  0.00604102405229815
# current asv score is:  0.316
# The DCF is:  0.00597078946878923
# current asv score is:  0.317
# The DCF is:  0.005877143357444004
# current asv score is:  0.318
# The DCF is:  0.006039321104177454
# current asv score is:  0.319
# The DCF is:  0.005931628076130444
# current asv score is:  0.32
# The DCF is:  0.005880122714890569
# current asv score is:  0.321
# The DCF is:  0.0058098881313816495
# current asv score is:  0.322
# The DCF is:  0.0057256066311709465
# current asv score is:  0.323
# The DCF is:  0.0056741012699310705
# current asv score is:  0.324
# The DCF is:  0.005580455158585845
# current asv score is:  0.325
# The DCF is:  0.005505538269509664
# current asv score is:  0.326
# The DCF is:  0.005449350602702527
# current asv score is:  0.327
# The DCF is:  0.005341657574655517
# current asv score is:  0.328
# The DCF is:  0.005531929154792535
# current asv score is:  0.329
# The DCF is:  0.005466376876850877
# current asv score is:  0.33
# The DCF is:  0.005396142293341956
# current asv score is:  0.331
# The DCF is:  0.005316543098698515
# current asv score is:  0.332
# The DCF is:  0.005250990820756856
# current asv score is:  0.333
# The DCF is:  0.005162027014978891
# current asv score is:  0.334
# The DCF is:  0.005096474737037232
# current asv score is:  0.335
# The DCF is:  0.005059016292499142
# current asv score is:  0.336
# The DCF is:  0.005002828625692006
# current asv score is:  0.337
# The DCF is:  0.005160324066858195
# current asv score is:  0.338
# The DCF is:  0.005094771788916536
# current asv score is:  0.339
# The DCF is:  0.005289725674620816
# current asv score is:  0.34
# The DCF is:  0.00523353800781368
# current asv score is:  0.341
# The DCF is:  0.00520076186884285
# current asv score is:  0.342
# The DCF is:  0.005121162674199408
# current asv score is:  0.343
# The DCF is:  0.005036881173988704
# current asv score is:  0.34400000000000003
# The DCF is:  0.005013469646152398
# current asv score is:  0.34500000000000003
# The DCF is:  0.004957281979345262
# current asv score is:  0.34600000000000003
# The DCF is:  0.00488236509026908
# current asv score is:  0.34700000000000003
# The DCF is:  0.005082001281540622
# current asv score is:  0.34800000000000003
# The DCF is:  0.005295684389513946
# current asv score is:  0.34900000000000003
# The DCF is:  0.005234814417139549
# current asv score is:  0.35000000000000003
# The DCF is:  0.005187991361466936
# current asv score is:  0.35100000000000003
# The DCF is:  0.005122439083525278
# current asv score is:  0.352
# The DCF is:  0.005080298333419926
# current asv score is:  0.353
# The DCF is:  0.005028792972180051
# current asv score is:  0.354
# The DCF is:  0.005242476080153376
# current asv score is:  0.355
# The DCF is:  0.005205017635615285
# current asv score is:  0.356
# The DCF is:  0.005176923802211717
# current asv score is:  0.357
# The DCF is:  0.005134783052106366
# current asv score is:  0.358
# The DCF is:  0.005116053829837321
# current asv score is:  0.359
# The DCF is:  0.005055183857462923
# current asv score is:  0.36
# The DCF is:  0.004998996190655787
# current asv score is:  0.361
# The DCF is:  0.0049615377461176965
# current asv score is:  0.362
# The DCF is:  0.005156491631821977
# current asv score is:  0.363
# The DCF is:  0.005119033187283886
# current asv score is:  0.364
# The DCF is:  0.00509562165944758
# current asv score is:  0.365
# The DCF is:  0.005058163214909489
# current asv score is:  0.366
# The DCF is:  0.005281210934017336
# current asv score is:  0.367
# The DCF is:  0.005234387878344723
# current asv score is:  0.368
# The DCF is:  0.005192247128239371
# current asv score is:  0.369
# The DCF is:  0.00541997715291448
# current asv score is:  0.37
# The DCF is:  0.005605566427484237
# current asv score is:  0.371
# The DCF is:  0.005563425677378884
# current asv score is:  0.372
# The DCF is:  0.005540014149542578
# current asv score is:  0.373
# The DCF is:  0.0060235680322963635
# current asv score is:  0.374
# The DCF is:  0.0064930749983483655
# current asv score is:  0.375
# The DCF is:  0.006711440411888952
# current asv score is:  0.376
# The DCF is:  0.006915758908727754
# current asv score is:  0.377
# The DCF is:  0.007134124322268341
# current asv score is:  0.378
# The DCF is:  0.0073805835692124944
# current asv score is:  0.379
# The DCF is:  0.0073571720413761876
# current asv score is:  0.38
# The DCF is:  0.007338442819107142
# current asv score is:  0.381
# The DCF is:  0.0072822551523000064
# current asv score is:  0.382
# The DCF is:  0.007244796707761916
# current asv score is:  0.383
# The DCF is:  0.007202655957656564
# current asv score is:  0.384
# The DCF is:  0.007179244429820257
# current asv score is:  0.385
# The DCF is:  0.007155832901983951
# current asv score is:  0.386
# The DCF is:  0.00764875139587226
# current asv score is:  0.387
# The DCF is:  0.00761129295133417
# current asv score is:  0.388
# The DCF is:  0.007583199117930602
# current asv score is:  0.389
# The DCF is:  0.007550422978959772
# current asv score is:  0.39
# The DCF is:  0.007517646839988942
# current asv score is:  0.391
# The DCF is:  0.007721965336827744
# current asv score is:  0.392
# The DCF is:  0.00770791842012596
# current asv score is:  0.393
# The DCF is:  0.007684506892289654
# current asv score is:  0.394
# The DCF is:  0.00767045997558787
# current asv score is:  0.395
# The DCF is:  0.008409837716420333
# current asv score is:  0.396
# The DCF is:  0.008391108494151287
# current asv score is:  0.397
# The DCF is:  0.008381743883016764
# current asv score is:  0.398
# The DCF is:  0.008358332355180458
# current asv score is:  0.399
# The DCF is:  0.00859542699099009
# current asv score is:  0.4
# The DCF is:  0.008581380074288306
# current asv score is:  0.401
# The DCF is:  0.008567333157586522
# current asv score is:  0.402
# The DCF is:  0.008799745487828891
# current asv score is:  0.403
# The DCF is:  0.009269252453880893
# current asv score is:  0.404
# The DCF is:  0.009264570148313632
# current asv score is:  0.405
# The DCF is:  0.009748124031067418
# current asv score is:  0.406
# The DCF is:  0.009989900972444312
# current asv score is:  0.40700000000000003
# The DCF is:  0.009975854055742528
# current asv score is:  0.40800000000000003
# The DCF is:  0.011212832596030559
# current asv score is:  0.40900000000000003
# The DCF is:  0.011440562620705669
# current asv score is:  0.41000000000000003
# The DCF is:  0.011682339562082561
# current asv score is:  0.41100000000000003
# The DCF is:  0.012170575750403608
# current asv score is:  0.41200000000000003
# The DCF is:  0.012147164222567302
# current asv score is:  0.41300000000000003
# The DCF is:  0.012133117305865517
# current asv score is:  0.41400000000000003
# The DCF is:  0.012114388083596474
# current asv score is:  0.41500000000000004
# The DCF is:  0.012090976555760167
# current asv score is:  0.41600000000000004
# The DCF is:  0.012328071191569798
# current asv score is:  0.417
# The DCF is:  0.01230465966373349
# current asv score is:  0.418
# The DCF is:  0.012551118910677644
# current asv score is:  0.419
# The DCF is:  0.013048719710133215
# current asv score is:  0.42
# The DCF is:  0.01329986126264463
# current asv score is:  0.421
# The DCF is:  0.013285814345942846
# current asv score is:  0.422
# The DCF is:  0.013532273592887
# current asv score is:  0.423
# The DCF is:  0.013778732839831154
# current asv score is:  0.424
# The DCF is:  0.013760003617562109
# current asv score is:  0.425
# The DCF is:  0.013760003617562109
# current asv score is:  0.426
# The DCF is:  0.014001780558939001
# current asv score is:  0.427
# The DCF is:  0.013992415947804478
# current asv score is:  0.428
# The DCF is:  0.014485334441692787
# current asv score is:  0.429
# The DCF is:  0.014466605219423742
# current asv score is:  0.43
# The DCF is:  0.014708382160800636
# current asv score is:  0.431
# The DCF is:  0.015205982960256206
# current asv score is:  0.432
# The DCF is:  0.015196618349121683
# current asv score is:  0.433
# The DCF is:  0.015168524515718115
# current asv score is:  0.434
# The DCF is:  0.015145112987881808
# current asv score is:  0.435
# The DCF is:  0.0153868899292587
# current asv score is:  0.436
# The DCF is:  0.016126267670091163
# current asv score is:  0.437
# The DCF is:  0.016368044611468055
# current asv score is:  0.438
# The DCF is:  0.016368044611468055
# current asv score is:  0.439
# The DCF is:  0.01710742235230052
# current asv score is:  0.44
# The DCF is:  0.01734451698811015
# current asv score is:  0.441
# The DCF is:  0.01784680009313298
# current asv score is:  0.442
# The DCF is:  0.01834908319815581
# current asv score is:  0.443
# The DCF is:  0.018595542445099967
# current asv score is:  0.444
# The DCF is:  0.019600108655145627
# current asv score is:  0.445
# The DCF is:  0.019590744044011104
# current asv score is:  0.446
# The DCF is:  0.020088344843466676
# current asv score is:  0.447
# The DCF is:  0.02033948639597809
# current asv score is:  0.448
# The DCF is:  0.02084176950100092
# current asv score is:  0.449
# The DCF is:  0.02159519415853517
# current asv score is:  0.45
# The DCF is:  0.022348618816069414
# current asv score is:  0.451
# The DCF is:  0.02233925420493489
# current asv score is:  0.452
# The DCF is:  0.02283685500439046
# current asv score is:  0.453
# The DCF is:  0.023841421214436123
# current asv score is:  0.454
# The DCF is:  0.023813327381032555
# current asv score is:  0.455
# The DCF is:  0.024310928180488123
# current asv score is:  0.456
# The DCF is:  0.02456206973299954
# current asv score is:  0.457
# The DCF is:  0.025817777495556617
# current asv score is:  0.458
# The DCF is:  0.026808296788900496
# current asv score is:  0.459
# The DCF is:  0.02705943834141191
# current asv score is:  0.46
# The DCF is:  0.027050073730277388
# current asv score is:  0.461
# The DCF is:  0.027552356835300218
# current asv score is:  0.462
# The DCF is:  0.028803382292290035
# current asv score is:  0.463
# The DCF is:  0.02904984153923419
# current asv score is:  0.464
# The DCF is:  0.029793901585633914
# current asv score is:  0.465
# The DCF is:  0.03003567852701081
# current asv score is:  0.466
# The DCF is:  0.031040244737056473
# current asv score is:  0.467
# The DCF is:  0.03153316323094478
# current asv score is:  0.468
# The DCF is:  0.031528480925377515
# current asv score is:  0.46900000000000003
# The DCF is:  0.03202608172483309
# current asv score is:  0.47000000000000003
# The DCF is:  0.03352824873433432
# current asv score is:  0.47100000000000003
# The DCF is:  0.034779274191324136
# current asv score is:  0.47200000000000003
# The DCF is:  0.0352768749907797
# current asv score is:  0.47300000000000003
# The DCF is:  0.03602561734274669
# current asv score is:  0.47400000000000003
# The DCF is:  0.036774359694713675
# current asv score is:  0.47500000000000003
# The DCF is:  0.036774359694713675
# current asv score is:  0.47600000000000003
# The DCF is:  0.037276642799736505
# current asv score is:  0.47700000000000004
# The DCF is:  0.038281209009782165
# current asv score is:  0.47800000000000004
# The DCF is:  0.03902995136174915
# current asv score is:  0.47900000000000004
# The DCF is:  0.039783376019283404
# current asv score is:  0.48
# The DCF is:  0.04128086072321737
# current asv score is:  0.481
# The DCF is:  0.04228542693326303
# current asv score is:  0.482
# The DCF is:  0.04278771003828587
# current asv score is:  0.483
# The DCF is:  0.04328531083774143
# current asv score is:  0.484
# The DCF is:  0.04353177008468559
# current asv score is:  0.485
# The DCF is:  0.045033937094186814
# current asv score is:  0.486
# The DCF is:  0.045531537893642386
# current asv score is:  0.487
# The DCF is:  0.04703838720871088
# current asv score is:  0.488
# The DCF is:  0.04828941266570069
# current asv score is:  0.489
# The DCF is:  0.048782331159589
# current asv score is:  0.49
# The DCF is:  0.05054032202716891
# current asv score is:  0.491
# The DCF is:  0.05078678127411307
# current asv score is:  0.492
# The DCF is:  0.05203780673110288
# current asv score is:  0.493
# The DCF is:  0.053042372941148545
# current asv score is:  0.494
# The DCF is:  0.054549222256217035
# current asv score is:  0.495
# The DCF is:  0.05504214075010534
# current asv score is:  0.496
# The DCF is:  0.056297848512662424
# current asv score is:  0.497
# The DCF is:  0.0575535562752195
# current asv score is:  0.498
# The DCF is:  0.05805583938024233
# current asv score is:  0.499
# The DCF is:  0.059060405590287995
# current asv score is:  0.5
# The DCF is:  0.060567254905356485
# current asv score is:  0.501
# The DCF is:  0.06181828036234631
# current asv score is:  0.502
# The DCF is:  0.06257170501988055
# current asv score is:  0.503
# The DCF is:  0.0633251296774148
# current asv score is:  0.504
# The DCF is:  0.06508312054499471
# current asv score is:  0.505
# The DCF is:  0.06583654520252895
# current asv score is:  0.506
# The DCF is:  0.06709225296508603
# current asv score is:  0.507
# The DCF is:  0.06884556152709868
# current asv score is:  0.508
# The DCF is:  0.0703477285365999
# current asv score is:  0.509
# The DCF is:  0.07135229474664556
# current asv score is:  0.51
# The DCF is:  0.0733614271667369
# current asv score is:  0.511
# The DCF is:  0.07461713492929396
# current asv score is:  0.512
# The DCF is:  0.07586816038628379
# current asv score is:  0.513
# The DCF is:  0.0776261512538637
# current asv score is:  0.514
# The DCF is:  0.07913300056893219
# current asv score is:  0.515
# The DCF is:  0.08038870833148927
# current asv score is:  0.516
# The DCF is:  0.08088630913094484
# current asv score is:  0.517
# The DCF is:  0.08113745068345625
# current asv score is:  0.518
# The DCF is:  0.08239315844601333
# current asv score is:  0.519
# The DCF is:  0.08415114931359324
# current asv score is:  0.52
# The DCF is:  0.08616028173368456
# current asv score is:  0.521
# The DCF is:  0.08841587340072005
# current asv score is:  0.522
# The DCF is:  0.09042500582081137
# current asv score is:  0.523
# The DCF is:  0.09168071358336845
# current asv score is:  0.524
# The DCF is:  0.0924341382409027
# current asv score is:  0.525
# The DCF is:  0.09443390604985949
# current asv score is:  0.526
# The DCF is:  0.09543847225990515
# current asv score is:  0.527
# The DCF is:  0.09719646312748506
# current asv score is:  0.528
# The DCF is:  0.09895445399506497
# current asv score is:  0.529
# The DCF is:  0.10121472796766771
# current asv score is:  0.53
# The DCF is:  0.10171701107269054
# current asv score is:  0.531
# The DCF is:  0.10372614349278186
# current asv score is:  0.532
# The DCF is:  0.10547945205479452
# current asv score is:  0.533
# The DCF is:  0.10698630136986301
# current asv score is:  0.534
# The DCF is:  0.10899543378995433
# current asv score is:  0.535
# The DCF is:  0.11150684931506849
# current asv score is:  0.536
# The DCF is:  0.11276255707762556
# current asv score is:  0.537
# The DCF is:  0.11527397260273972
# current asv score is:  0.538
# The DCF is:  0.11728310502283104
# current asv score is:  0.539
# The DCF is:  0.12004566210045661
# current asv score is:  0.54
# The DCF is:  0.1213013698630137
# current asv score is:  0.541
# The DCF is:  0.12331050228310501
# current asv score is:  0.542
# The DCF is:  0.12557077625570776
# current asv score is:  0.543
# The DCF is:  0.12707762557077626
# current asv score is:  0.544
# The DCF is:  0.12808219178082192
# current asv score is:  0.545
# The DCF is:  0.1313470319634703
# current asv score is:  0.546
# The DCF is:  0.13335616438356163
# current asv score is:  0.547
# The DCF is:  0.13662100456621004
# current asv score is:  0.548
# The DCF is:  0.13888127853881277
# current asv score is:  0.549
# The DCF is:  0.14063926940639268
# current asv score is:  0.55
# The DCF is:  0.14164383561643834
# current asv score is:  0.551
# The DCF is:  0.142648401826484
# current asv score is:  0.552
# The DCF is:  0.14465753424657532
# current asv score is:  0.553
# The DCF is:  0.14767123287671233
# current asv score is:  0.554
# The DCF is:  0.14942922374429224
# current asv score is:  0.555
# The DCF is:  0.15118721461187212
# current asv score is:  0.556
# The DCF is:  0.1539497716894977
# current asv score is:  0.557
# The DCF is:  0.15621004566210045
# current asv score is:  0.558
# The DCF is:  0.1587214611872146
# current asv score is:  0.559
# The DCF is:  0.16098173515981734
# current asv score is:  0.56
# The DCF is:  0.1622374429223744
# current asv score is:  0.561
# The DCF is:  0.16525114155251142
# current asv score is:  0.562
# The DCF is:  0.16776255707762555
# current asv score is:  0.5630000000000001
# The DCF is:  0.16977168949771687
# current asv score is:  0.5640000000000001
# The DCF is:  0.17102739726027397
# current asv score is:  0.5650000000000001
# The DCF is:  0.17404109589041095
# current asv score is:  0.5660000000000001
# The DCF is:  0.17705479452054793
# current asv score is:  0.5670000000000001
# The DCF is:  0.1798173515981735
# current asv score is:  0.5680000000000001
# The DCF is:  0.18207762557077625
# current asv score is:  0.5690000000000001
# The DCF is:  0.18509132420091323
# current asv score is:  0.5700000000000001
# The DCF is:  0.18735159817351596
# current asv score is:  0.5710000000000001
# The DCF is:  0.18910958904109587
# current asv score is:  0.5720000000000001
# The DCF is:  0.19136986301369863
# current asv score is:  0.5730000000000001
# The DCF is:  0.1943835616438356
# current asv score is:  0.5740000000000001
# The DCF is:  0.197648401826484
# current asv score is:  0.5750000000000001
# The DCF is:  0.20141552511415522
# current asv score is:  0.5760000000000001
# The DCF is:  0.20442922374429223
# current asv score is:  0.577
# The DCF is:  0.2074429223744292
# current asv score is:  0.578
# The DCF is:  0.20995433789954338
# current asv score is:  0.579
# The DCF is:  0.21347031963470317
# current asv score is:  0.58
# The DCF is:  0.21673515981735159
# current asv score is:  0.581
# The DCF is:  0.2202511415525114
# current asv score is:  0.582
# The DCF is:  0.22426940639269405
# current asv score is:  0.583
# The DCF is:  0.2267808219178082
# current asv score is:  0.584
# The DCF is:  0.23105022831050226
# current asv score is:  0.585
# The DCF is:  0.23331050228310501
# current asv score is:  0.586
# The DCF is:  0.2378310502283105
# current asv score is:  0.587
# The DCF is:  0.24084474885844748
# current asv score is:  0.588
# The DCF is:  0.2426027397260274
# current asv score is:  0.589
# The DCF is:  0.24561643835616437
# current asv score is:  0.59
# The DCF is:  0.24863013698630135
# current asv score is:  0.591
# The DCF is:  0.2511415525114155
# current asv score is:  0.592
# The DCF is:  0.25515981735159815
# current asv score is:  0.593
# The DCF is:  0.2591780821917808
# current asv score is:  0.594
# The DCF is:  0.2634474885844749
# current asv score is:  0.595
# The DCF is:  0.26595890410958906
# current asv score is:  0.596
# The DCF is:  0.2707305936073059
# current asv score is:  0.597
# The DCF is:  0.2732420091324201
# current asv score is:  0.598
# The DCF is:  0.2767579908675799
# current asv score is:  0.599
# The DCF is:  0.28052511415525117
# current asv score is:  0.6
# The DCF is:  0.2835388127853881
# current asv score is:  0.601
# The DCF is:  0.2857990867579909
# current asv score is:  0.602
# The DCF is:  0.29207762557077627
# current asv score is:  0.603
# The DCF is:  0.29684931506849316
# current asv score is:  0.604
# The DCF is:  0.29961187214611873
# current asv score is:  0.605
# The DCF is:  0.30237442922374425
# current asv score is:  0.606
# The DCF is:  0.3043835616438356
# current asv score is:  0.607
# The DCF is:  0.3081506849315069
# current asv score is:  0.608
# The DCF is:  0.3129223744292237
# current asv score is:  0.609
# The DCF is:  0.3144292237442922
# current asv score is:  0.61
# The DCF is:  0.3202054794520548
# current asv score is:  0.611
# The DCF is:  0.3224657534246575
# current asv score is:  0.612
# The DCF is:  0.32723744292237444
# current asv score is:  0.613
# The DCF is:  0.33100456621004565
# current asv score is:  0.614
# The DCF is:  0.3337671232876712
# current asv score is:  0.615
# The DCF is:  0.3367808219178082
# current asv score is:  0.616
# The DCF is:  0.33979452054794523
# current asv score is:  0.617
# The DCF is:  0.3473287671232877
# current asv score is:  0.618
# The DCF is:  0.35134703196347034
# current asv score is:  0.619
# The DCF is:  0.35561643835616435
# current asv score is:  0.62
# The DCF is:  0.3603881278538813
# current asv score is:  0.621
# The DCF is:  0.3631506849315068
# current asv score is:  0.622
# The DCF is:  0.36867579908675796
# current asv score is:  0.623
# The DCF is:  0.3747031963470319
# current asv score is:  0.624
# The DCF is:  0.3822374429223744
# current asv score is:  0.625
# The DCF is:  0.38751141552511414
# current asv score is:  0.626
# The DCF is:  0.39228310502283104
# current asv score is:  0.627
# The DCF is:  0.39730593607305936
# current asv score is:  0.628
# The DCF is:  0.40232876712328763
# current asv score is:  0.629
# The DCF is:  0.4048401826484018
# current asv score is:  0.63
# The DCF is:  0.4091095890410959
# current asv score is:  0.631
# The DCF is:  0.41162100456621004
# current asv score is:  0.632
# The DCF is:  0.4171461187214612
# current asv score is:  0.633
# The DCF is:  0.423675799086758
# current asv score is:  0.634
# The DCF is:  0.4286986301369863
# current asv score is:  0.635
# The DCF is:  0.4322146118721461
# current asv score is:  0.636
# The DCF is:  0.43773972602739725
# current asv score is:  0.637
# The DCF is:  0.4427625570776256
# current asv score is:  0.638
# The DCF is:  0.44878995433789953
# current asv score is:  0.639
# The DCF is:  0.45280821917808217
# current asv score is:  0.64
# The DCF is:  0.45707762557077625
# current asv score is:  0.641
# The DCF is:  0.4621004566210045
# current asv score is:  0.642
# The DCF is:  0.46837899543378997
# current asv score is:  0.643
# The DCF is:  0.4744063926940639
# current asv score is:  0.644
# The DCF is:  0.47942922374429225
# current asv score is:  0.645
# The DCF is:  0.4869634703196347
# current asv score is:  0.646
# The DCF is:  0.4914840182648402
# current asv score is:  0.647
# The DCF is:  0.4975114155251142
# current asv score is:  0.648
# The DCF is:  0.5040410958904109
# current asv score is:  0.649
# The DCF is:  0.5090639269406393
# current asv score is:  0.65
# The DCF is:  0.5138356164383562
# current asv score is:  0.651
# The DCF is:  0.5218721461187215
# current asv score is:  0.652
# The DCF is:  0.5278995433789955
# current asv score is:  0.653
# The DCF is:  0.5334246575342465
# current asv score is:  0.654
# The DCF is:  0.5359360730593608
# current asv score is:  0.655
# The DCF is:  0.5429680365296804
# current asv score is:  0.656
# The DCF is:  0.5510045662100457
# current asv score is:  0.657
# The DCF is:  0.5555251141552511
# current asv score is:  0.658
# The DCF is:  0.5600456621004566
# current asv score is:  0.659
# The DCF is:  0.566324200913242
# current asv score is:  0.66
# The DCF is:  0.5718493150684932
# current asv score is:  0.661
# The DCF is:  0.5778767123287671
# current asv score is:  0.662
# The DCF is:  0.5823972602739725
# current asv score is:  0.663
# The DCF is:  0.5874200913242009
# current asv score is:  0.664
# The DCF is:  0.5914383561643836
# current asv score is:  0.665
# The DCF is:  0.5959589041095891
# current asv score is:  0.666
# The DCF is:  0.6002283105022831
# current asv score is:  0.667
# The DCF is:  0.6067579908675799
# current asv score is:  0.668
# The DCF is:  0.6105251141552511
# current asv score is:  0.669
# The DCF is:  0.6157990867579908
# current asv score is:  0.67
# The DCF is:  0.6203196347031964
# current asv score is:  0.671
# The DCF is:  0.625593607305936
# current asv score is:  0.672
# The DCF is:  0.6313698630136987
# current asv score is:  0.673
# The DCF is:  0.6371461187214612
# current asv score is:  0.674
# The DCF is:  0.6421689497716896
# current asv score is:  0.675
# The DCF is:  0.6461872146118722
# current asv score is:  0.676
# The DCF is:  0.6499543378995434
# current asv score is:  0.677
# The DCF is:  0.6557305936073059
# current asv score is:  0.678
# The DCF is:  0.6620091324200913
# current asv score is:  0.679
# The DCF is:  0.6667808219178082
# current asv score is:  0.68
# The DCF is:  0.6715525114155251
# current asv score is:  0.681
# The DCF is:  0.6775799086757991
# current asv score is:  0.682
# The DCF is:  0.6831050228310502
# current asv score is:  0.683
# The DCF is:  0.6893835616438356
# current asv score is:  0.684
# The DCF is:  0.6946575342465754
# current asv score is:  0.685
# The DCF is:  0.7014383561643835
# current asv score is:  0.686
# The DCF is:  0.7059589041095891
# current asv score is:  0.687
# The DCF is:  0.711986301369863
# current asv score is:  0.6880000000000001
# The DCF is:  0.71675799086758
# current asv score is:  0.6890000000000001
# The DCF is:  0.7227853881278539
# current asv score is:  0.6900000000000001
# The DCF is:  0.7265525114155251
# current asv score is:  0.6910000000000001
# The DCF is:  0.731324200913242
# current asv score is:  0.6920000000000001
# The DCF is:  0.7365981735159818
# current asv score is:  0.6930000000000001
# The DCF is:  0.7418721461187214
# current asv score is:  0.6940000000000001
# The DCF is:  0.7458904109589041
# current asv score is:  0.6950000000000001
# The DCF is:  0.7494063926940638
# current asv score is:  0.6960000000000001
# The DCF is:  0.7551826484018265
# current asv score is:  0.6970000000000001
# The DCF is:  0.759703196347032
# current asv score is:  0.6980000000000001
# The DCF is:  0.763972602739726
# current asv score is:  0.6990000000000001
# The DCF is:  0.7697488584474886
# current asv score is:  0.7000000000000001
# The DCF is:  0.773013698630137
# current asv score is:  0.7010000000000001
# The DCF is:  0.7782876712328767
# current asv score is:  0.7020000000000001
# The DCF is:  0.7830593607305936
# current asv score is:  0.7030000000000001
# The DCF is:  0.7873287671232877
# current asv score is:  0.704
# The DCF is:  0.791095890410959
# current asv score is:  0.705
# The DCF is:  0.7938584474885845
# current asv score is:  0.706
# The DCF is:  0.7981278538812785
# current asv score is:  0.707
# The DCF is:  0.8016438356164383
# current asv score is:  0.708
# The DCF is:  0.8069178082191781
# current asv score is:  0.709
# The DCF is:  0.8114383561643835
# current asv score is:  0.71
# The DCF is:  0.8167123287671232
# current asv score is:  0.711
# The DCF is:  0.8209817351598174
# current asv score is:  0.712
# The DCF is:  0.8262557077625571
# current asv score is:  0.713
# The DCF is:  0.8290182648401827
# current asv score is:  0.714
# The DCF is:  0.8337899543378995
# current asv score is:  0.715
# The DCF is:  0.838310502283105
# current asv score is:  0.716
# The DCF is:  0.8408219178082191
# current asv score is:  0.717
# The DCF is:  0.842579908675799
# current asv score is:  0.718
# The DCF is:  0.8471004566210046
# current asv score is:  0.719
# The DCF is:  0.8506164383561644
# current asv score is:  0.72
# The DCF is:  0.8531278538812785
# current asv score is:  0.721
# The DCF is:  0.8568949771689497
# current asv score is:  0.722
# The DCF is:  0.8591552511415526
# current asv score is:  0.723
# The DCF is:  0.8616666666666667
# current asv score is:  0.724
# The DCF is:  0.8659360730593607
# current asv score is:  0.725
# The DCF is:  0.8686986301369862
# current asv score is:  0.726
# The DCF is:  0.873972602739726
# current asv score is:  0.727
# The DCF is:  0.8777397260273972
# current asv score is:  0.728
# The DCF is:  0.8810045662100456
# current asv score is:  0.729
# The DCF is:  0.8840182648401826
# current asv score is:  0.73
# The DCF is:  0.8860273972602739
# current asv score is:  0.731
# The DCF is:  0.8887899543378995
# current asv score is:  0.732
# The DCF is:  0.8920547945205479
# current asv score is:  0.733
# The DCF is:  0.8938127853881278
# current asv score is:  0.734
# The DCF is:  0.8965753424657534
# current asv score is:  0.735
# The DCF is:  0.8990867579908676
# current asv score is:  0.736
# The DCF is:  0.9015981735159817
# current asv score is:  0.737
# The DCF is:  0.9041095890410958
# current asv score is:  0.738
# The DCF is:  0.9076255707762557
# current asv score is:  0.739
# The DCF is:  0.9108904109589041
# current asv score is:  0.74
# The DCF is:  0.9131506849315068
# current asv score is:  0.741
# The DCF is:  0.9164155251141552
# current asv score is:  0.742
# The DCF is:  0.9184246575342466
# current asv score is:  0.743
# The DCF is:  0.9221917808219178
# current asv score is:  0.744
# The DCF is:  0.9247031963470319
# current asv score is:  0.745
# The DCF is:  0.9264611872146119
# current asv score is:  0.746
# The DCF is:  0.928972602739726
# current asv score is:  0.747
# The DCF is:  0.9299771689497717
# current asv score is:  0.748
# The DCF is:  0.9319863013698629
# current asv score is:  0.749
# The DCF is:  0.9337442922374429
# current asv score is:  0.75
# The DCF is:  0.9357534246575342
# current asv score is:  0.751
# The DCF is:  0.938013698630137
# current asv score is:  0.752
# The DCF is:  0.9395205479452055
# current asv score is:  0.753
# The DCF is:  0.9420319634703196
# current asv score is:  0.754
# The DCF is:  0.9442922374429223
# current asv score is:  0.755
# The DCF is:  0.9455479452054795
# current asv score is:  0.756
# The DCF is:  0.9470547945205479
# current asv score is:  0.757
# The DCF is:  0.9495662100456621
# current asv score is:  0.758
# The DCF is:  0.9503196347031962
# current asv score is:  0.759
# The DCF is:  0.9515753424657535
# current asv score is:  0.76
# The DCF is:  0.9533333333333333
# current asv score is:  0.761
# The DCF is:  0.9540867579908675
# current asv score is:  0.762
# The DCF is:  0.9548401826484019
# current asv score is:  0.763
# The DCF is:  0.9565981735159818
# current asv score is:  0.764
# The DCF is:  0.9568493150684931
# current asv score is:  0.765
# The DCF is:  0.9583561643835616
# current asv score is:  0.766
# The DCF is:  0.9606164383561644
# current asv score is:  0.767
# The DCF is:  0.9628767123287671
# current asv score is:  0.768
# The DCF is:  0.9641324200913242
# current asv score is:  0.769
# The DCF is:  0.9651369863013698
# current asv score is:  0.77
# The DCF is:  0.967648401826484
# current asv score is:  0.771
# The DCF is:  0.9684018264840182
# current asv score is:  0.772
# The DCF is:  0.9696575342465754
# current asv score is:  0.773
# The DCF is:  0.9704109589041096
# current asv score is:  0.774
# The DCF is:  0.9704109589041096
# current asv score is:  0.775
# The DCF is:  0.9714155251141552
# current asv score is:  0.776
# The DCF is:  0.9726712328767123
# current asv score is:  0.777
# The DCF is:  0.9741780821917808
# current asv score is:  0.778
# The DCF is:  0.9746803652968037
# current asv score is:  0.779
# The DCF is:  0.9749315068493151
# current asv score is:  0.78
# The DCF is:  0.9759360730593607
# current asv score is:  0.781
# The DCF is:  0.9764383561643835
# current asv score is:  0.782
# The DCF is:  0.9769406392694063
# current asv score is:  0.783
# The DCF is:  0.9779452054794521
# current asv score is:  0.784
# The DCF is:  0.9784474885844748
# current asv score is:  0.785
# The DCF is:  0.9786986301369863
# current asv score is:  0.786
# The DCF is:  0.979703196347032
# current asv score is:  0.787
# The DCF is:  0.9802054794520547
# current asv score is:  0.788
# The DCF is:  0.9802054794520547
# current asv score is:  0.789
# The DCF is:  0.9812100456621005
# current asv score is:  0.79
# The DCF is:  0.9819634703196347
# current asv score is:  0.791
# The DCF is:  0.9824657534246575
# current asv score is:  0.792
# The DCF is:  0.9824657534246575
# current asv score is:  0.793
# The DCF is:  0.9832191780821917
# current asv score is:  0.794
# The DCF is:  0.9842237442922374
# current asv score is:  0.795
# The DCF is:  0.9844748858447488
# current asv score is:  0.796
# The DCF is:  0.9852283105022831
# current asv score is:  0.797
# The DCF is:  0.9852283105022831
# current asv score is:  0.798
# The DCF is:  0.985730593607306
# current asv score is:  0.799
# The DCF is:  0.9862328767123287
# current asv score is:  0.8
# The DCF is:  0.9862328767123287
# current asv score is:  0.801
# The DCF is:  0.9864840182648401
# current asv score is:  0.802
# The DCF is:  0.9864840182648401
# current asv score is:  0.803
# The DCF is:  0.9864840182648401
# current asv score is:  0.804
# The DCF is:  0.9864840182648401
# current asv score is:  0.805
# The DCF is:  0.9864840182648401
# current asv score is:  0.806
# The DCF is:  0.9864840182648401
# current asv score is:  0.807
# The DCF is:  0.9867351598173516
# current asv score is:  0.808
# The DCF is:  0.986986301369863
# current asv score is:  0.809
# The DCF is:  0.9872374429223744
# current asv score is:  0.81
# The DCF is:  0.9872374429223744
# current asv score is:  0.811
# The DCF is:  0.9872374429223744
# current asv score is:  0.812
# The DCF is:  0.9872374429223744
# current asv score is:  0.8130000000000001
# The DCF is:  0.9874885844748857
# current asv score is:  0.8140000000000001
# The DCF is:  0.9874885844748857
# current asv score is:  0.8150000000000001
# The DCF is:  0.9874885844748857
# current asv score is:  0.8160000000000001
# The DCF is:  0.9879908675799086
# current asv score is:  0.8170000000000001
# The DCF is:  0.9879908675799086
# current asv score is:  0.8180000000000001
# The DCF is:  0.9879908675799086
# current asv score is:  0.8190000000000001
# The DCF is:  0.9879908675799086
# current asv score is:  0.8200000000000001
# The DCF is:  0.9882420091324201
# current asv score is:  0.8210000000000001
# The DCF is:  0.9884931506849315
# current asv score is:  0.8220000000000001
# The DCF is:  0.988744292237443
# current asv score is:  0.8230000000000001
# The DCF is:  0.988744292237443
# current asv score is:  0.8240000000000001
# The DCF is:  0.988744292237443
# current asv score is:  0.8250000000000001
# The DCF is:  0.9889954337899544
# current asv score is:  0.8260000000000001
# The DCF is:  0.9892465753424657
# current asv score is:  0.8270000000000001
# The DCF is:  0.9892465753424657
# current asv score is:  0.8280000000000001
# The DCF is:  0.9894977168949771
# current asv score is:  0.8290000000000001
# The DCF is:  0.9894977168949771
# current asv score is:  0.8300000000000001
# The DCF is:  0.9894977168949771
# current asv score is:  0.8310000000000001
# The DCF is:  0.9897488584474886
# current asv score is:  0.8320000000000001
# The DCF is:  0.9897488584474886
# current asv score is:  0.833
# The DCF is:  0.9897488584474886
# current asv score is:  0.834
# The DCF is:  0.9897488584474886
# current asv score is:  0.835
# The DCF is:  0.9897488584474886
# current asv score is:  0.836
# The DCF is:  0.99
# current asv score is:  0.837
# The DCF is:  0.99
# current asv score is:  0.838
# The DCF is:  0.99
# current asv score is:  0.839
# The DCF is:  0.99
# current asv score is:  0.84
# The DCF is:  0.99
# current asv score is:  0.841
# The DCF is:  0.99
# current asv score is:  0.842
# The DCF is:  0.99
# current asv score is:  0.843
# The DCF is:  0.99
# current asv score is:  0.844
# The DCF is:  0.99
# current asv score is:  0.845
# The DCF is:  0.99
# current asv score is:  0.846
# The DCF is:  0.99
# current asv score is:  0.847
# The DCF is:  0.99
# current asv score is:  0.848
# The DCF is:  0.99
# current asv score is:  0.849
# The DCF is:  0.99
# current asv score is:  0.85
# The DCF is:  0.99
# current asv score is:  0.851
# The DCF is:  0.99
# current asv score is:  0.852
# The DCF is:  0.99
# current asv score is:  0.853
# The DCF is:  0.99
# current asv score is:  0.854
# The DCF is:  0.99
# current asv score is:  0.855
# The DCF is:  0.99
# current asv score is:  0.856
# The DCF is:  0.99
# current asv score is:  0.857
# The DCF is:  0.99
# current asv score is:  0.858
# The DCF is:  0.99
# current asv score is:  0.859
# The DCF is:  0.99
# current asv score is:  0.86
# The DCF is:  0.99
# current asv score is:  0.861
# The DCF is:  0.99
# current asv score is:  0.862
# The DCF is:  0.99
# current asv score is:  0.863
# The DCF is:  0.99
# current asv score is:  0.864
# The DCF is:  0.99
# current asv score is:  0.865
# The DCF is:  0.99
# current asv score is:  0.866
# The DCF is:  0.99
# current asv score is:  0.867
# The DCF is:  0.99
# current asv score is:  0.868
# The DCF is:  0.99
# current asv score is:  0.869
# The DCF is:  0.99
# current asv score is:  0.87
# The DCF is:  0.99
# current asv score is:  0.871
# The DCF is:  0.99
# current asv score is:  0.872
# The DCF is:  0.99
# current asv score is:  0.873
# The DCF is:  0.99
# current asv score is:  0.874
# The DCF is:  0.99
# current asv score is:  0.875
# The DCF is:  0.99
# current asv score is:  0.876
# The DCF is:  0.99
# current asv score is:  0.877
# The DCF is:  0.99
# current asv score is:  0.878
# The DCF is:  0.99
# current asv score is:  0.879
# The DCF is:  0.99
# current asv score is:  0.88
# The DCF is:  0.99
# current asv score is:  0.881
# The DCF is:  0.99
# current asv score is:  0.882
# The DCF is:  0.99
# current asv score is:  0.883
# The DCF is:  0.99
# current asv score is:  0.884
# The DCF is:  0.99
# current asv score is:  0.885
# The DCF is:  0.99
# current asv score is:  0.886
# The DCF is:  0.99
# current asv score is:  0.887
# The DCF is:  0.99
# current asv score is:  0.888
# The DCF is:  0.99
# current asv score is:  0.889
# The DCF is:  0.99
# current asv score is:  0.89
# The DCF is:  0.99
# current asv score is:  0.891
# The DCF is:  0.99
# current asv score is:  0.892
# The DCF is:  0.99
# current asv score is:  0.893
# The DCF is:  0.99
# current asv score is:  0.894
# The DCF is:  0.99
# current asv score is:  0.895
# The DCF is:  0.99
# current asv score is:  0.896
# The DCF is:  0.99
# current asv score is:  0.897
# The DCF is:  0.99
# current asv score is:  0.898
# The DCF is:  0.99
# current asv score is:  0.899
# The DCF is:  0.99
# current asv score is:  0.9
# The DCF is:  0.99
# current asv score is:  0.901
# The DCF is:  0.99
# current asv score is:  0.902
# The DCF is:  0.99
# current asv score is:  0.903
# The DCF is:  0.99
# current asv score is:  0.904
# The DCF is:  0.99
# current asv score is:  0.905
# The DCF is:  0.99
# current asv score is:  0.906
# The DCF is:  0.99
# current asv score is:  0.907
# The DCF is:  0.99
# current asv score is:  0.908
# The DCF is:  0.99
# current asv score is:  0.909
# The DCF is:  0.99
# current asv score is:  0.91
# The DCF is:  0.99
# current asv score is:  0.911
# The DCF is:  0.99
# current asv score is:  0.912
# The DCF is:  0.99
# current asv score is:  0.913
# The DCF is:  0.99
# current asv score is:  0.914
# The DCF is:  0.99
# current asv score is:  0.915
# The DCF is:  0.99
# current asv score is:  0.916
# The DCF is:  0.99
# current asv score is:  0.917
# The DCF is:  0.99
# current asv score is:  0.918
# The DCF is:  0.99
# current asv score is:  0.919
# The DCF is:  0.99
# current asv score is:  0.92
# The DCF is:  0.99
# current asv score is:  0.921
# The DCF is:  0.99
# current asv score is:  0.922
# The DCF is:  0.99
# current asv score is:  0.923
# The DCF is:  0.99
# current asv score is:  0.924
# The DCF is:  0.99
# current asv score is:  0.925
# The DCF is:  0.99
# current asv score is:  0.926
# The DCF is:  0.99
# current asv score is:  0.927
# The DCF is:  0.99
# current asv score is:  0.928
# The DCF is:  0.99
# current asv score is:  0.929
# The DCF is:  0.99
# current asv score is:  0.93
# The DCF is:  0.99
# current asv score is:  0.931
# The DCF is:  0.99
# current asv score is:  0.932
# The DCF is:  0.99
# current asv score is:  0.933
# The DCF is:  0.99
# current asv score is:  0.934
# The DCF is:  0.99
# current asv score is:  0.935
# The DCF is:  0.99
# current asv score is:  0.936
# The DCF is:  0.99
# current asv score is:  0.937
# The DCF is:  0.99
# current asv score is:  0.9380000000000001
# The DCF is:  0.99
# current asv score is:  0.9390000000000001
# The DCF is:  0.99
# current asv score is:  0.9400000000000001
# The DCF is:  0.99
# current asv score is:  0.9410000000000001
# The DCF is:  0.99
# current asv score is:  0.9420000000000001
# The DCF is:  0.99
# current asv score is:  0.9430000000000001
# The DCF is:  0.99
# current asv score is:  0.9440000000000001
# The DCF is:  0.99
# current asv score is:  0.9450000000000001
# The DCF is:  0.99
# current asv score is:  0.9460000000000001
# The DCF is:  0.99
# current asv score is:  0.9470000000000001
# The DCF is:  0.99
# current asv score is:  0.9480000000000001
# The DCF is:  0.99
# current asv score is:  0.9490000000000001
# The DCF is:  0.99
# current asv score is:  0.9500000000000001
# The DCF is:  0.99
# current asv score is:  0.9510000000000001
# The DCF is:  0.99
# current asv score is:  0.9520000000000001
# The DCF is:  0.99
# current asv score is:  0.9530000000000001
# The DCF is:  0.99
# current asv score is:  0.9540000000000001
# The DCF is:  0.99
# current asv score is:  0.9550000000000001
# The DCF is:  0.99
# current asv score is:  0.9560000000000001
# The DCF is:  0.99
# current asv score is:  0.9570000000000001
# The DCF is:  0.99
# current asv score is:  0.9580000000000001
# The DCF is:  0.99
# current asv score is:  0.9590000000000001
# The DCF is:  0.99
# current asv score is:  0.96
# The DCF is:  0.99
# current asv score is:  0.961
# The DCF is:  0.99
# current asv score is:  0.962
# The DCF is:  0.99
# current asv score is:  0.963
# The DCF is:  0.99
# current asv score is:  0.964
# The DCF is:  0.99
# current asv score is:  0.965
# The DCF is:  0.99
# current asv score is:  0.966
# The DCF is:  0.99
# current asv score is:  0.967
# The DCF is:  0.99
# current asv score is:  0.968
# The DCF is:  0.99
# current asv score is:  0.969
# The DCF is:  0.99
# current asv score is:  0.97
# The DCF is:  0.99
# current asv score is:  0.971
# The DCF is:  0.99
# current asv score is:  0.972
# The DCF is:  0.99
# current asv score is:  0.973
# The DCF is:  0.99
# current asv score is:  0.974
# The DCF is:  0.99
# current asv score is:  0.975
# The DCF is:  0.99
# current asv score is:  0.976
# The DCF is:  0.99
# current asv score is:  0.977
# The DCF is:  0.99
# current asv score is:  0.978
# The DCF is:  0.99
# current asv score is:  0.979
# The DCF is:  0.99
# current asv score is:  0.98
# The DCF is:  0.99
# current asv score is:  0.981
# The DCF is:  0.99
# current asv score is:  0.982
# The DCF is:  0.99
# current asv score is:  0.983
# The DCF is:  0.99
# current asv score is:  0.984
# The DCF is:  0.99
# current asv score is:  0.985
# The DCF is:  0.99
# current asv score is:  0.986
# The DCF is:  0.99
# current asv score is:  0.987
# The DCF is:  0.99
# current asv score is:  0.988
# The DCF is:  0.99
# current asv score is:  0.989
# The DCF is:  0.99
# current asv score is:  0.99
# The DCF is:  0.99
# current asv score is:  0.991
# The DCF is:  0.99
# current asv score is:  0.992
# The DCF is:  0.99
# current asv score is:  0.993
# The DCF is:  0.99
# current asv score is:  0.994
# The DCF is:  0.99
# current asv score is:  0.995
# The DCF is:  0.99
# current asv score is:  0.996
# The DCF is:  0.99
# current asv score is:  0.997
# The DCF is:  0.99
# current asv score is:  0.998
# The DCF is:  0.99
# current asv score is:  0.999
# The DCF is:  0.99
# current asv score is:  1.0
# The DCF is:  0.99
# current asv score is:  1.0010000000000001
# The DCF is:  0.99
# current asv score is:  1.002
# The DCF is:  0.99
# current asv score is:  1.0030000000000001
# The DCF is:  0.99
# current asv score is:  1.004
# The DCF is:  0.99
# current asv score is:  1.0050000000000001
# The DCF is:  0.99
# current asv score is:  1.006
# The DCF is:  0.99
# current asv score is:  1.0070000000000001
# The DCF is:  0.99
# current asv score is:  1.008
# The DCF is:  0.99
# current asv score is:  1.0090000000000001
# The DCF is:  0.99
# the EER is:  0.007865150882486318
# the threshold of the EER is:  0.4007310758937489
# the minDCF is: 0.00488236509026908
# the threshold of the minDCF is:  0.34600000000000003

# %%
def metric(labels, scores):
    dcf_list = []
    target_scores = scores[labels == 1]
    nontarget_scores = scores[labels == 0]

    # Check if either target_scores or nontarget_scores is empty
    if target_scores.size == 0 or nontarget_scores.size == 0:
        center_eer = 100 * 0.007865150882486318
        center_thr_eer =   0.4007310758937489
        center_minDCF = 0.34600000000000003
        print("Warning: Empty target or nontarget scores. Ignoring this case.")
        return [center_eer, center_thr_eer,  center_minDCF]  #return the center of the confidence interval for the EER, threshold, and minDCF

    # Compute EER and threshold
    eer, thr_eer, _, _ = eval_metrics.compute_eer(target_scores, nontarget_scores)

    for asv_thr in asv_thr_list:  # Iterate over each ASV score
        # Obtain ASV error rates
        Pfa_asv, Pmiss_asv, _, _ = eval_metrics.obtain_asv_error_rates(
            target_scores, nontarget_scores, np.array([]), asv_thr
        )

        # Compute DCF
        dcf = dcf_formula(
            Pfa_asv,
            Pmiss_asv,
            Prior_target=Prior_target,
            Prior_non_target=Prior_non_target,
            cost_model_dcf=cost_model_dcf,
            is_print=False
        )
        dcf_list.append(dcf)

    # Get the minimum DCF
    minDCF_index = np.argmin(np.array(dcf_list))

    return [100 * eer, thr_eer, dcf_list[minDCF_index]]


target_scores = results_list_eval_female.loc[results_list_eval_female['label_ground_truth'] == "target"]["pred_scores"]
nontarget_scores = results_list_eval_female.loc[results_list_eval_female['label_ground_truth'] == "nontarget"]["pred_scores"]
target_labels = results_list_eval_female.loc[results_list_eval_female['label_ground_truth'] == "target"]["label_ground_truth"]
nontarget_labels = results_list_eval_female.loc[results_list_eval_female['label_ground_truth'] == "nontarget"]["label_ground_truth"]
speakers = results_list_eval_female['speaker_id'][
    (results_list_eval_female['label_ground_truth'] == "nontarget") |
    (results_list_eval_female['label_ground_truth'] == "target")
].values
scores = np.concatenate([target_scores.to_numpy(),nontarget_scores.to_numpy()])
labels = np.concatenate([target_labels.to_numpy(),nontarget_labels.to_numpy()])
labels = np.where(labels == 'target', 1, 0)

res = evaluate_with_conf_int(samples = scores, metric = metric, labels = labels, conditions = speakers, num_bootstraps=num_bootstraps, alpha=alpha)
print("result:\n", res)
# Out:
# result:
#  ([0.7865150882486318, 0.4007310758937489, 0.00488236509026908], [(0.4038695604388437, 1.32189854898849), (0.3726530373096466, 0.43162969371134585), (0.0017658124998090256, 0.007515634374858153)])

# %%
plotting_eer_and_dcf(asv_thr_list,dcf_list_eval_female,frr,far,eer,thr_eer,data_name = f"ECAPA-TDNN Female Evaluation Protocol \n with Prior_target = {Prior_target}, Cmiss_ASV = {cost_model_dcf['Cmiss_asv']}, Cfa_ASV = {cost_model_dcf['Cfa_asv']}")

target_scores = results_list_eval_female.loc[results_list_eval_female['label_ground_truth'] == "target"]["pred_scores"]
nontarget_scores = results_list_eval_female.loc[results_list_eval_female['label_ground_truth'] == "nontarget"]["pred_scores"]
spoof_scores = results_list_eval_female.loc[results_list_eval_female['label_ground_truth'] == "spoof"]["pred_scores"]

# Plot the histograms
plotting_probability_histogram(nontarget_scores,target_scores,num_bins=100,colors=['yellow', 'purple'],data_name = f"Female eval protocol")
plotting_probability_histogram(nontarget_scores,target_scores,spoof_scores,num_bins=100,colors=['yellow', 'purple','red'],data_name = f"\n ECAPA-TDNN Female \n Evaluation Protocol")

# %%
vc_filter = results_list_eval_female['attack_type'].isin(["A17", "A18", "A19"])
tts_filter = results_list_eval_female['attack_type'].isin(["A07", "A08", "A09", "A10","A11","A12","A16"])
combine_TTS_VC_filter = results_list_eval_female['attack_type'].isin(["A13", "A14", "A15"])

target_scores = results_list_eval_female.loc[results_list_eval_female['label_ground_truth'] == "target"]["pred_scores"]
nontarget_scores = results_list_eval_female.loc[results_list_eval_female['label_ground_truth'] == "nontarget"]["pred_scores"]
VC_scores = results_list_eval_female.loc[vc_filter]["pred_scores"]
TTS_scores = results_list_eval_female.loc[tts_filter]["pred_scores"]
combine_TTS_VC_scores = results_list_eval_female.loc[combine_TTS_VC_filter]["pred_scores"]


plotting_probability_histogram_TTS_and_VC(nontarget_scores,target_scores,TTS_scores,VC_scores,combine_TTS_VC_scores,num_bins=100,colors=['yellow', 'purple','green','blue','brown'],data_name= f"\n ECAPA-TDNN Female \n Evaluation Protocol")
